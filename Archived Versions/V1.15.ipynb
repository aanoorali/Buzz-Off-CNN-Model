# %% [markdown]
# Varroa Mite Detection 1.15 Blue Shift and Blur

# %%
# Cell Block 1: Importing Libraries
import os
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold, train_test_split
import numpy as np
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Cell Block 2: Load Data and Preprocess

df = pd.read_csv('labels_augmented.csv')

df['filename'] = df['filename'].apply(lambda fn: os.path.join('rotations_flips', fn.strip()))

filepaths = df['filename'].values
labels = df['has_mite'].values

# %%
# Cell Block 3: Splitting Data

X_rest, X_holdout, y_rest, y_holdout = train_test_split(
    filepaths, labels,
    test_size=0.10,
    stratify=labels,
    random_state=42
)

# %%
# Cell Block 3: K-Fold Cross-Validation

# Early stopping callback
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    # min_delta=1e-4,
    restore_best_weights=True
)

k = 10  # Number of folds
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

fold = 1
all_test_accuracies = []
best_epochs = []

# Model creation function
def create_model():
    model = models.Sequential([
        layers.Input(shape=(224, 224, 3)),
        layers.Conv2D(32, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Guassian kernel function
def gaussian_kernel(size: int, sigma: float):
    x = tf.range(-size // 2 + 1, size // 2 + 1, dtype=tf.float32)
    xx, yy = tf.meshgrid(x, x)
    kernel = tf.exp(-(xx**2 + yy**2) / (2.0 * sigma**2))
    kernel = kernel / tf.reduce_sum(kernel)
    return kernel

def apply_gaussian_blur(image, kernel_size=5, sigma=1.0):
    kernel = gaussian_kernel(kernel_size, sigma)                 # [5, 5]
    kernel = kernel[:, :, tf.newaxis, tf.newaxis]                # [5, 5, 1, 1]
    kernel = tf.repeat(kernel, repeats=3, axis=2)                # [5, 5, 3, 1] ✅ CORRECT shape
    image = tf.expand_dims(image, 0)                             # [1, H, W, 3]
    blurred = tf.nn.depthwise_conv2d(image, kernel, strides=[1,1,1,1], padding='SAME')
    
    return tf.squeeze(blurred, axis=0)

# Preprocessing function
def preprocess(paths, labels):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    def load_img(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [224, 224])
        img = img / 255.0

        # 1) Apply Gaussian blur
        img = apply_gaussian_blur(img, kernel_size=5, sigma=1.0)

        # 2) Boost blue channel
        img = tf.clip_by_value(img + [0.0, 0.0, 0.2], 0.0, 1.0) 

        # # 3) Increase contrast
        # img = tf.image.adjust_contrast(img, 2.0) 

        # # 4). Boost red channel
        # img = tf.clip_by_value(img + [0.2, 0.0, 0.0], 0.0, 1.0)
        
        return img, label

    return ds.map(load_img).batch(32).prefetch(tf.data.AUTOTUNE)

for trainval_index, test_index in skf.split(filepaths, labels):
    print(f"\n🧪 Fold {fold} -----------------------------")

    # Split into trainval and test
    X_trainval, X_test = filepaths[trainval_index], filepaths[test_index]
    y_trainval, y_test = labels[trainval_index], labels[test_index]

    # Further split trainval into train and val (e.g. 80/20)
    val_split = int(0.8 * len(X_trainval))
    X_train, X_val = X_trainval[:val_split], X_trainval[val_split:]
    y_train, y_val = y_trainval[:val_split], y_trainval[val_split:]


    # Preprocess each split
    train_ds = preprocess(X_train, y_train)
    val_ds = preprocess(X_val, y_val)
    test_ds = preprocess(X_test, y_test)



    # Train model with early stopping
    model = create_model()
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[earlystop],
        verbose=1
    )

    # Record best epoch (smallest val_loss)
    best_epoch = np.argmin(history.history['val_loss']) + 1
    best_epochs.append(best_epoch)
    print(f"🏁 Best epoch for Fold {fold}: {best_epoch}")

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    all_test_accuracies.append(test_acc)
    print(f"✅ Fold {fold} test accuracy: {test_acc:.4f}")

    fold += 1

# Calculate mean best epoch
ep_mean = int(np.round(np.mean(best_epochs)))
print(f"\n📌 Mean optimal epoch across folds: {ep_mean}")
# Out:
# 🧪 Fold 1 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 426ms/step - accuracy: 0.5871 - loss: 0.7822 - val_accuracy: 0.5922 - val_loss: 0.6783
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 434ms/step - accuracy: 0.6091 - loss: 0.6729 - val_accuracy: 0.5922 - val_loss: 0.6775
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 418ms/step - accuracy: 0.5957 - loss: 0.6720 - val_accuracy: 0.5922 - val_loss: 0.6769
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 439ms/step - accuracy: 0.6042 - loss: 0.6757 - val_accuracy: 0.5922 - val_loss: 0.6759
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 43s 458ms/step - accuracy: 0.6091 - loss: 0.6759 - val_accuracy: 0.5922 - val_loss: 0.6879
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 432ms/step - accuracy: 0.6091 - loss: 0.6859 - val_accuracy: 0.5922 - val_loss: 0.6847
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 426ms/step - accuracy: 0.6091 - loss: 0.6822 - val_accuracy: 0.5922 - val_loss: 0.6824
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 419ms/step - accuracy: 0.6091 - loss: 0.6794 - val_accuracy: 0.5922 - val_loss: 0.6806
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 416ms/step - accuracy: 0.6091 - loss: 0.6771 - val_accuracy: 0.5922 - val_loss: 0.6793
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 420ms/step - accuracy: 0.6091 - loss: 0.6754 - val_accuracy: 0.5922 - val_loss: 0.6783
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 420ms/step - accuracy: 0.6091 - loss: 0.6741 - val_accuracy: 0.5922 - val_loss: 0.6776
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 418ms/step - accuracy: 0.6091 - loss: 0.6730 - val_accuracy: 0.5922 - val_loss: 0.6771
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 423ms/step - accuracy: 0.6091 - loss: 0.6722 - val_accuracy: 0.5922 - val_loss: 0.6767
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 415ms/step - accuracy: 0.6091 - loss: 0.6716 - val_accuracy: 0.5922 - val_loss: 0.6765
# 🏁 Best epoch for Fold 1: 4
# ✅ Fold 1 test accuracy: 0.6029
#
# 🧪 Fold 2 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 431ms/step - accuracy: 0.5780 - loss: 0.7604 - val_accuracy: 0.5868 - val_loss: 0.6803
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 436ms/step - accuracy: 0.6182 - loss: 0.6682 - val_accuracy: 0.5868 - val_loss: 0.6789
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 426ms/step - accuracy: 0.6182 - loss: 0.6687 - val_accuracy: 0.5868 - val_loss: 0.6793
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.6182 - loss: 0.6699 - val_accuracy: 0.5868 - val_loss: 0.6768
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.6127 - loss: 0.6664 - val_accuracy: 0.5868 - val_loss: 0.6788
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 426ms/step - accuracy: 0.6193 - loss: 0.6665 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.6141 - loss: 0.6746 - val_accuracy: 0.5868 - val_loss: 0.6869
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 428ms/step - accuracy: 0.6182 - loss: 0.6833 - val_accuracy: 0.5868 - val_loss: 0.6842
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 435ms/step - accuracy: 0.6182 - loss: 0.6795 - val_accuracy: 0.5868 - val_loss: 0.6822
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 426ms/step - accuracy: 0.6182 - loss: 0.6765 - val_accuracy: 0.5868 - val_loss: 0.6808
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 437ms/step - accuracy: 0.6182 - loss: 0.6741 - val_accuracy: 0.5868 - val_loss: 0.6798
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 426ms/step - accuracy: 0.6182 - loss: 0.6723 - val_accuracy: 0.5868 - val_loss: 0.6791
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 426ms/step - accuracy: 0.6182 - loss: 0.6709 - val_accuracy: 0.5868 - val_loss: 0.6787
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 434ms/step - accuracy: 0.6182 - loss: 0.6698 - val_accuracy: 0.5868 - val_loss: 0.6784
# 🏁 Best epoch for Fold 2: 4
# ✅ Fold 2 test accuracy: 0.6029
#
# 🧪 Fold 3 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 42s 441ms/step - accuracy: 0.5708 - loss: 0.7395 - val_accuracy: 0.5828 - val_loss: 0.6774
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 435ms/step - accuracy: 0.6131 - loss: 0.6697 - val_accuracy: 0.5828 - val_loss: 0.6910
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 429ms/step - accuracy: 0.6173 - loss: 0.6888 - val_accuracy: 0.5828 - val_loss: 0.6875
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 426ms/step - accuracy: 0.6173 - loss: 0.6839 - val_accuracy: 0.5828 - val_loss: 0.6850
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 425ms/step - accuracy: 0.6173 - loss: 0.6801 - val_accuracy: 0.5828 - val_loss: 0.6832
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 430ms/step - accuracy: 0.6173 - loss: 0.6772 - val_accuracy: 0.5828 - val_loss: 0.6819
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 426ms/step - accuracy: 0.6173 - loss: 0.6748 - val_accuracy: 0.5828 - val_loss: 0.6809
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 429ms/step - accuracy: 0.6173 - loss: 0.6730 - val_accuracy: 0.5828 - val_loss: 0.6803
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 430ms/step - accuracy: 0.6173 - loss: 0.6715 - val_accuracy: 0.5828 - val_loss: 0.6799
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 429ms/step - accuracy: 0.6173 - loss: 0.6703 - val_accuracy: 0.5828 - val_loss: 0.6796
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 430ms/step - accuracy: 0.6173 - loss: 0.6694 - val_accuracy: 0.5828 - val_loss: 0.6795
# 🏁 Best epoch for Fold 3: 1
# ✅ Fold 3 test accuracy: 0.6029
#
# 🧪 Fold 4 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 431ms/step - accuracy: 0.5986 - loss: 0.7899 - val_accuracy: 0.5814 - val_loss: 0.6810
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 442ms/step - accuracy: 0.6154 - loss: 0.6741 - val_accuracy: 0.5814 - val_loss: 0.6808
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 440ms/step - accuracy: 0.6024 - loss: 0.6733 - val_accuracy: 0.5814 - val_loss: 0.6846
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 441ms/step - accuracy: 0.6183 - loss: 0.6751 - val_accuracy: 0.5814 - val_loss: 0.6801
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 431ms/step - accuracy: 0.6183 - loss: 0.6686 - val_accuracy: 0.5814 - val_loss: 0.6800
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 429ms/step - accuracy: 0.6183 - loss: 0.6714 - val_accuracy: 0.5814 - val_loss: 0.6804
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 436ms/step - accuracy: 0.6183 - loss: 0.6704 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 433ms/step - accuracy: 0.6183 - loss: 0.6690 - val_accuracy: 0.5814 - val_loss: 0.6798
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 443ms/step - accuracy: 0.6183 - loss: 0.6682 - val_accuracy: 0.5814 - val_loss: 0.6800
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 444ms/step - accuracy: 0.6183 - loss: 0.6677 - val_accuracy: 0.5814 - val_loss: 0.6801
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 428ms/step - accuracy: 0.6183 - loss: 0.6675 - val_accuracy: 0.5814 - val_loss: 0.6801
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 428ms/step - accuracy: 0.6183 - loss: 0.6676 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 430ms/step - accuracy: 0.6183 - loss: 0.6684 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 429ms/step - accuracy: 0.6183 - loss: 0.6675 - val_accuracy: 0.5814 - val_loss: 0.6802
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 430ms/step - accuracy: 0.6183 - loss: 0.6670 - val_accuracy: 0.5814 - val_loss: 0.6803
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 423ms/step - accuracy: 0.6183 - loss: 0.6670 - val_accuracy: 0.5814 - val_loss: 0.6803
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 422ms/step - accuracy: 0.6183 - loss: 0.6669 - val_accuracy: 0.5814 - val_loss: 0.6803
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 420ms/step - accuracy: 0.6183 - loss: 0.6669 - val_accuracy: 0.5814 - val_loss: 0.6803
# 🏁 Best epoch for Fold 4: 8
# ✅ Fold 4 test accuracy: 0.6029
#
# 🧪 Fold 5 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 42s 439ms/step - accuracy: 0.5782 - loss: 0.7453 - val_accuracy: 0.5922 - val_loss: 0.6774
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.6098 - loss: 0.6725 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 423ms/step - accuracy: 0.6099 - loss: 0.6722 - val_accuracy: 0.5922 - val_loss: 0.6893
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 421ms/step - accuracy: 0.6099 - loss: 0.6817 - val_accuracy: 0.5922 - val_loss: 0.6783
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 435ms/step - accuracy: 0.6081 - loss: 0.6736 - val_accuracy: 0.5922 - val_loss: 0.6740
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 423ms/step - accuracy: 0.6212 - loss: 0.6575 - val_accuracy: 0.5922 - val_loss: 0.6645
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 426ms/step - accuracy: 0.6436 - loss: 0.6281 - val_accuracy: 0.5908 - val_loss: 0.6759
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.6080 - loss: 0.6718 - val_accuracy: 0.5949 - val_loss: 0.6667
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 435ms/step - accuracy: 0.6642 - loss: 0.6146 - val_accuracy: 0.5895 - val_loss: 0.6764
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 431ms/step - accuracy: 0.6059 - loss: 0.6657 - val_accuracy: 0.6406 - val_loss: 0.6716
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 433ms/step - accuracy: 0.6914 - loss: 0.5833 - val_accuracy: 0.6137 - val_loss: 0.6569
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 422ms/step - accuracy: 0.7373 - loss: 0.5243 - val_accuracy: 0.6326 - val_loss: 0.6498
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 408ms/step - accuracy: 0.7768 - loss: 0.4453 - val_accuracy: 0.6245 - val_loss: 0.7163
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 415ms/step - accuracy: 0.8358 - loss: 0.3630 - val_accuracy: 0.6258 - val_loss: 0.8014
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.8670 - loss: 0.2930 - val_accuracy: 0.6218 - val_loss: 0.9044
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 429ms/step - accuracy: 0.9146 - loss: 0.2170 - val_accuracy: 0.5962 - val_loss: 0.9333
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 428ms/step - accuracy: 0.9390 - loss: 0.1601 - val_accuracy: 0.5922 - val_loss: 0.9795
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 426ms/step - accuracy: 0.9567 - loss: 0.1246 - val_accuracy: 0.5882 - val_loss: 1.2932
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.9627 - loss: 0.0891 - val_accuracy: 0.6057 - val_loss: 1.3650
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 430ms/step - accuracy: 0.9839 - loss: 0.0605 - val_accuracy: 0.5922 - val_loss: 1.7276
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.9922 - loss: 0.0347 - val_accuracy: 0.5707 - val_loss: 2.0236
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 429ms/step - accuracy: 0.9918 - loss: 0.0310 - val_accuracy: 0.5976 - val_loss: 2.5503
# 🏁 Best epoch for Fold 5: 12
# ✅ Fold 5 test accuracy: 0.6005
#
# 🧪 Fold 6 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 427ms/step - accuracy: 0.6049 - loss: 0.8450 - val_accuracy: 0.5774 - val_loss: 0.6919
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 428ms/step - accuracy: 0.6132 - loss: 0.6765 - val_accuracy: 0.5774 - val_loss: 0.6906
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 428ms/step - accuracy: 0.6124 - loss: 0.6881 - val_accuracy: 0.5774 - val_loss: 0.6872
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 428ms/step - accuracy: 0.6124 - loss: 0.6830 - val_accuracy: 0.5774 - val_loss: 0.6848
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 429ms/step - accuracy: 0.6124 - loss: 0.6793 - val_accuracy: 0.5774 - val_loss: 0.6833
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 431ms/step - accuracy: 0.6124 - loss: 0.6764 - val_accuracy: 0.5774 - val_loss: 0.6822
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.6124 - loss: 0.6743 - val_accuracy: 0.5774 - val_loss: 0.6816
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6124 - loss: 0.6727 - val_accuracy: 0.5774 - val_loss: 0.6813
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6124 - loss: 0.6715 - val_accuracy: 0.5774 - val_loss: 0.6811
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6124 - loss: 0.6705 - val_accuracy: 0.5774 - val_loss: 0.6811
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6124 - loss: 0.6699 - val_accuracy: 0.5774 - val_loss: 0.6812
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6124 - loss: 0.6694 - val_accuracy: 0.5774 - val_loss: 0.6813
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6124 - loss: 0.6690 - val_accuracy: 0.5774 - val_loss: 0.6815
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.6124 - loss: 0.6687 - val_accuracy: 0.5774 - val_loss: 0.6816
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 437ms/step - accuracy: 0.6124 - loss: 0.6685 - val_accuracy: 0.5774 - val_loss: 0.6818
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 438ms/step - accuracy: 0.6124 - loss: 0.6683 - val_accuracy: 0.5774 - val_loss: 0.6820
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 436ms/step - accuracy: 0.6124 - loss: 0.6682 - val_accuracy: 0.5774 - val_loss: 0.6821
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 438ms/step - accuracy: 0.6124 - loss: 0.6681 - val_accuracy: 0.5774 - val_loss: 0.6822
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 434ms/step - accuracy: 0.6124 - loss: 0.6680 - val_accuracy: 0.5774 - val_loss: 0.6824
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 439ms/step - accuracy: 0.6124 - loss: 0.6680 - val_accuracy: 0.5774 - val_loss: 0.6825
# 🏁 Best epoch for Fold 6: 10
# ✅ Fold 6 test accuracy: 0.6019
#
# 🧪 Fold 7 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 42s 444ms/step - accuracy: 0.5832 - loss: 0.7953 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 440ms/step - accuracy: 0.6191 - loss: 0.6701 - val_accuracy: 0.5882 - val_loss: 0.6778
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 436ms/step - accuracy: 0.6153 - loss: 0.6670 - val_accuracy: 0.5882 - val_loss: 0.6719
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 433ms/step - accuracy: 0.6410 - loss: 0.6404 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 437ms/step - accuracy: 0.6300 - loss: 0.6594 - val_accuracy: 0.7174 - val_loss: 0.6091
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 436ms/step - accuracy: 0.7066 - loss: 0.5815 - val_accuracy: 0.7295 - val_loss: 0.6138
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 435ms/step - accuracy: 0.7692 - loss: 0.5102 - val_accuracy: 0.7039 - val_loss: 0.6161
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 439ms/step - accuracy: 0.7792 - loss: 0.4863 - val_accuracy: 0.7618 - val_loss: 0.5475
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 385ms/step - accuracy: 0.8008 - loss: 0.4557 - val_accuracy: 0.7631 - val_loss: 0.5320
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.8161 - loss: 0.4230 - val_accuracy: 0.7752 - val_loss: 0.5459
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.8202 - loss: 0.4141 - val_accuracy: 0.7577 - val_loss: 0.5443
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.8293 - loss: 0.3892 - val_accuracy: 0.7470 - val_loss: 0.5436
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.8399 - loss: 0.3648 - val_accuracy: 0.7699 - val_loss: 0.5472
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.8658 - loss: 0.3184 - val_accuracy: 0.7699 - val_loss: 0.5251
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.8859 - loss: 0.2779 - val_accuracy: 0.7712 - val_loss: 0.5146
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.8899 - loss: 0.2577 - val_accuracy: 0.7685 - val_loss: 0.5448
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.9046 - loss: 0.2303 - val_accuracy: 0.7537 - val_loss: 0.5690
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.9198 - loss: 0.2080 - val_accuracy: 0.7645 - val_loss: 0.6883
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.9200 - loss: 0.1795 - val_accuracy: 0.7699 - val_loss: 0.7248
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.9450 - loss: 0.1367 - val_accuracy: 0.7537 - val_loss: 0.7993
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.9575 - loss: 0.1039 - val_accuracy: 0.7322 - val_loss: 0.9506
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.9632 - loss: 0.0838 - val_accuracy: 0.7376 - val_loss: 1.0094
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.9710 - loss: 0.0783 - val_accuracy: 0.7564 - val_loss: 0.9900
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.9775 - loss: 0.0621 - val_accuracy: 0.7577 - val_loss: 1.0980
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.9899 - loss: 0.0381 - val_accuracy: 0.7497 - val_loss: 1.0974
# 🏁 Best epoch for Fold 7: 15
# ✅ Fold 7 test accuracy: 0.8010
#
# 🧪 Fold 8 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 380ms/step - accuracy: 0.5958 - loss: 0.8183 - val_accuracy: 0.5908 - val_loss: 0.6793
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6148 - loss: 0.6702 - val_accuracy: 0.5908 - val_loss: 0.6774
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6140 - loss: 0.6721 - val_accuracy: 0.5908 - val_loss: 0.6899
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6148 - loss: 0.6877 - val_accuracy: 0.5908 - val_loss: 0.6861
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.6148 - loss: 0.6830 - val_accuracy: 0.5908 - val_loss: 0.6833
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6148 - loss: 0.6794 - val_accuracy: 0.5908 - val_loss: 0.6813
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6148 - loss: 0.6767 - val_accuracy: 0.5908 - val_loss: 0.6798
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6148 - loss: 0.6745 - val_accuracy: 0.5908 - val_loss: 0.6787
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6148 - loss: 0.6729 - val_accuracy: 0.5908 - val_loss: 0.6780
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6148 - loss: 0.6716 - val_accuracy: 0.5908 - val_loss: 0.6775
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6148 - loss: 0.6706 - val_accuracy: 0.5908 - val_loss: 0.6771
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6148 - loss: 0.6698 - val_accuracy: 0.5908 - val_loss: 0.6769
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6148 - loss: 0.6692 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6148 - loss: 0.6687 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6148 - loss: 0.6683 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6148 - loss: 0.6680 - val_accuracy: 0.5908 - val_loss: 0.6765
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6148 - loss: 0.6678 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6148 - loss: 0.6676 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6148 - loss: 0.6674 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 384ms/step - accuracy: 0.6148 - loss: 0.6673 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6148 - loss: 0.6672 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6148 - loss: 0.6672 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 391ms/step - accuracy: 0.6148 - loss: 0.6671 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6148 - loss: 0.6670 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6148 - loss: 0.6670 - val_accuracy: 0.5908 - val_loss: 0.6768
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6148 - loss: 0.6670 - val_accuracy: 0.5908 - val_loss: 0.6768
# 🏁 Best epoch for Fold 8: 16
# ✅ Fold 8 test accuracy: 0.6019
#
# 🧪 Fold 9 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.5937 - loss: 0.8247 - val_accuracy: 0.5922 - val_loss: 0.6912
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 385ms/step - accuracy: 0.6165 - loss: 0.6791 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6207 - loss: 0.6726 - val_accuracy: 0.5922 - val_loss: 0.6844
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6206 - loss: 0.6718 - val_accuracy: 0.5922 - val_loss: 0.6775
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6198 - loss: 0.6704 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6206 - loss: 0.6705 - val_accuracy: 0.5922 - val_loss: 0.6835
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 384ms/step - accuracy: 0.6206 - loss: 0.6730 - val_accuracy: 0.5922 - val_loss: 0.6833
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6206 - loss: 0.6783 - val_accuracy: 0.5922 - val_loss: 0.6783
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6206 - loss: 0.6705 - val_accuracy: 0.5922 - val_loss: 0.6792
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6252 - loss: 0.6687 - val_accuracy: 0.5922 - val_loss: 0.6765
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 385ms/step - accuracy: 0.6162 - loss: 0.6685 - val_accuracy: 0.5922 - val_loss: 0.6785
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6206 - loss: 0.6709 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6206 - loss: 0.6668 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6206 - loss: 0.6662 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 386ms/step - accuracy: 0.6206 - loss: 0.6660 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 384ms/step - accuracy: 0.6206 - loss: 0.6660 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6206 - loss: 0.6659 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 445ms/step - accuracy: 0.6206 - loss: 0.6659 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 439ms/step - accuracy: 0.6206 - loss: 0.6658 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 418ms/step - accuracy: 0.6206 - loss: 0.6658 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 441ms/step - accuracy: 0.6206 - loss: 0.6657 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 441ms/step - accuracy: 0.6206 - loss: 0.6657 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 42s 449ms/step - accuracy: 0.6206 - loss: 0.6657 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 443ms/step - accuracy: 0.6206 - loss: 0.6657 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 445ms/step - accuracy: 0.6206 - loss: 0.6656 - val_accuracy: 0.5922 - val_loss: 0.6761
# 🏁 Best epoch for Fold 9: 15
# ✅ Fold 9 test accuracy: 0.6019
#
# 🧪 Fold 10 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 42s 440ms/step - accuracy: 0.5959 - loss: 0.8535 - val_accuracy: 0.5922 - val_loss: 0.6767
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 406ms/step - accuracy: 0.6145 - loss: 0.6728 - val_accuracy: 0.5922 - val_loss: 0.6900
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 417ms/step - accuracy: 0.6145 - loss: 0.6880 - val_accuracy: 0.5922 - val_loss: 0.6861
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 412ms/step - accuracy: 0.6145 - loss: 0.6832 - val_accuracy: 0.5922 - val_loss: 0.6832
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 413ms/step - accuracy: 0.6145 - loss: 0.6796 - val_accuracy: 0.5922 - val_loss: 0.6811
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 416ms/step - accuracy: 0.6145 - loss: 0.6768 - val_accuracy: 0.5922 - val_loss: 0.6795
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 415ms/step - accuracy: 0.6145 - loss: 0.6746 - val_accuracy: 0.5922 - val_loss: 0.6784
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 415ms/step - accuracy: 0.6145 - loss: 0.6729 - val_accuracy: 0.5922 - val_loss: 0.6776
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 416ms/step - accuracy: 0.6145 - loss: 0.6716 - val_accuracy: 0.5922 - val_loss: 0.6770
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 413ms/step - accuracy: 0.6145 - loss: 0.6706 - val_accuracy: 0.5922 - val_loss: 0.6767
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 413ms/step - accuracy: 0.6145 - loss: 0.6698 - val_accuracy: 0.5922 - val_loss: 0.6764
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 413ms/step - accuracy: 0.6145 - loss: 0.6692 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 413ms/step - accuracy: 0.6145 - loss: 0.6687 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 411ms/step - accuracy: 0.6145 - loss: 0.6684 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 408ms/step - accuracy: 0.6145 - loss: 0.6681 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 45s 485ms/step - accuracy: 0.6145 - loss: 0.6679 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 414ms/step - accuracy: 0.6145 - loss: 0.6677 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 44s 474ms/step - accuracy: 0.6145 - loss: 0.6675 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 435ms/step - accuracy: 0.6145 - loss: 0.6674 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 418ms/step - accuracy: 0.6145 - loss: 0.6673 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 413ms/step - accuracy: 0.6145 - loss: 0.6673 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 414ms/step - accuracy: 0.6145 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 411ms/step - accuracy: 0.6145 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 411ms/step - accuracy: 0.6145 - loss: 0.6671 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 411ms/step - accuracy: 0.6145 - loss: 0.6671 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 407ms/step - accuracy: 0.6145 - loss: 0.6671 - val_accuracy: 0.5922 - val_loss: 0.6763
# 🏁 Best epoch for Fold 10: 16
# ✅ Fold 10 test accuracy: 0.6019
#
# 📌 Mean optimal epoch across folds: 10

# %%
# Cell Block 5: Final Model Training on data again, but for ep_mean Epochs (no validation needed)

# Build your TF datasets
train_final_ds = preprocess(X_rest, y_rest)        # ALL data used in K-Fold
test_final_ds  = preprocess(X_holdout, y_holdout)  # NEVER seen during CV

# Instantiate & train your final model
final_model = create_model()
final_model.fit(
    train_final_ds,
    epochs=ep_mean,
    verbose=1
)

# Evaluate once—only on the true hold-out set
final_results = final_model.evaluate(
    test_final_ds,
    verbose=1
)
print("Hold-out test loss & accuracy:", final_results)
# Out:
# Epoch 1/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 46s 388ms/step - accuracy: 0.5676 - loss: 0.7849
# Epoch 2/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 45s 389ms/step - accuracy: 0.6061 - loss: 0.6632
# Epoch 3/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 44s 381ms/step - accuracy: 0.7061 - loss: 0.6022
# Epoch 4/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 44s 381ms/step - accuracy: 0.7575 - loss: 0.5180
# Epoch 5/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 45s 384ms/step - accuracy: 0.8164 - loss: 0.4316
# Epoch 6/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 45s 387ms/step - accuracy: 0.8551 - loss: 0.3658
# Epoch 7/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 45s 383ms/step - accuracy: 0.8589 - loss: 0.3407
# Epoch 8/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 45s 383ms/step - accuracy: 0.8792 - loss: 0.2983
# Epoch 9/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 45s 385ms/step - accuracy: 0.9066 - loss: 0.2391
# Epoch 10/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 45s 388ms/step - accuracy: 0.9090 - loss: 0.2207
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.6949 - loss: 0.9086
# Hold-out test loss & accuracy: [0.8890923261642456, 0.7215496301651001]

# %%
# Cell Block 5: Final Evaluation

# Evaluate final model on the 20% test set
final_test_loss, final_test_acc = final_model.evaluate(test_final_ds, verbose=0)

# Report both results
print(f"\n📊 {k}-Fold Test Accuracy: {np.mean(all_test_accuracies):.4f} ± {np.std(all_test_accuracies):.4f}")
print(f"🏁 Final model test accuracy (trained on hold-out): {final_test_acc:.4f}")
# Out:
# 📊 10-Fold Test Accuracy: 0.6221 ± 0.0596
# 🏁 Final model test accuracy (trained on hold-out): 0.7215

# %%
import numpy as np
from sklearn.metrics import precision_score, roc_curve, auc, f1_score, recall_score
import matplotlib.pyplot as plt

# 1. Extract true labels and model scores from your hold-out dataset
y_true = np.concatenate([y.numpy() for x, y in test_final_ds], axis=0)
y_pred_prob = final_model.predict(test_final_ds)

# 2. If your model outputs two probabilities (one per class), take the “positive” class
if y_pred_prob.ndim > 1 and y_pred_prob.shape[1] > 1:
    y_scores = y_pred_prob[:, 1]
else:
    y_scores = y_pred_prob.ravel()

# 3. Compute ROC curve metrics
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# 4. Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr)               # ROC curve
plt.plot([0, 1], [0, 1], linestyle='--')  # chance line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (AUC = {roc_auc:.2f})')
plt.show()



# 1. Turn your predicted probabilities into binary preds (threshold = 0.5)
y_pred = (y_scores >= 0.5).astype(int)

# 2. Compute precision, recall, F1
precision = precision_score(y_true, y_pred)
recall    = recall_score(y_true, y_pred)
f1        = f1_score(y_true, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step
# Precision: 0.61
# Recall:    0.85
# F1 Score:  0.71
