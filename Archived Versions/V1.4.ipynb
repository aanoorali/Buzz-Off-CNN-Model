# %% [markdown]
# Varroa Mite Detection 1.4 Augmented

# %%
# Cell Block 1: Importing Libraries
import os
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold, train_test_split
import numpy as np
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Cell Block 2: Load Data and Preprocess

df = pd.read_csv('labels.csv')

df['filename'] = df['filename'].apply(lambda fn: os.path.join('images', fn.strip()))

filepaths = df['filename'].values
labels = df['has_mite'].values

# %%
# Cell Block 3: K-Fold Cross-Validation

# Early stopping callback
earlystop = EarlyStopping(
    monitor='val_loss',
    # patience=3, Original
    patience=10,
    # min_delta=1e-4,
    restore_best_weights=True
)

k = 10  # Number of folds
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

fold = 1
all_test_accuracies = []
best_epochs = []

# Model creation function
def create_model():
    model = models.Sequential([
        layers.Input(shape=(224, 224, 3)),
        layers.Conv2D(32, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Preprocessing function
def preprocess(paths, labels):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    def load_img(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [224, 224])
        img = img / 255.0
        return img, label

    return ds.map(load_img).batch(32).prefetch(tf.data.AUTOTUNE)

for trainval_index, test_index in skf.split(filepaths, labels):
    print(f"\n🧪 Fold {fold} -----------------------------")

    # Split into trainval and test
    X_trainval, X_test = filepaths[trainval_index], filepaths[test_index]
    y_trainval, y_test = labels[trainval_index], labels[test_index]

    # Further split trainval into train and val (e.g. 80/20)
    val_split = int(0.8 * len(X_trainval))
    X_train, X_val = X_trainval[:val_split], X_trainval[val_split:]
    y_train, y_val = y_trainval[:val_split], y_trainval[val_split:]


    # Preprocess each split
    train_ds = preprocess(X_train, y_train)
    val_ds = preprocess(X_val, y_val)
    test_ds = preprocess(X_test, y_test)



    # Train model with early stopping
    model = create_model()
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[earlystop],
        verbose=1
    )

    # Record best epoch (smallest val_loss)
    best_epoch = np.argmin(history.history['val_loss']) + 1
    best_epochs.append(best_epoch)
    print(f"🏁 Best epoch for Fold {fold}: {best_epoch}")

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    all_test_accuracies.append(test_acc)
    print(f"✅ Fold {fold} test accuracy: {test_acc:.4f}")

    fold += 1

# Calculate mean best epoch
ep_mean = int(np.round(np.mean(best_epochs)))
print(f"\n📌 Mean optimal epoch across folds: {ep_mean}")
# Out:
# 🧪 Fold 1 -----------------------------
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 396ms/step - accuracy: 0.5985 - loss: 0.9451 - val_accuracy: 0.5839 - val_loss: 0.6814
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 365ms/step - accuracy: 0.6290 - loss: 0.6763 - val_accuracy: 0.5839 - val_loss: 0.6797
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 375ms/step - accuracy: 0.6290 - loss: 0.6729 - val_accuracy: 0.5839 - val_loss: 0.6792
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 371ms/step - accuracy: 0.6290 - loss: 0.6722 - val_accuracy: 0.5839 - val_loss: 0.6786
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 380ms/step - accuracy: 0.6290 - loss: 0.6658 - val_accuracy: 0.5839 - val_loss: 0.6764
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 399ms/step - accuracy: 0.6290 - loss: 0.6660 - val_accuracy: 0.5839 - val_loss: 0.6768
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 380ms/step - accuracy: 0.6290 - loss: 0.6600 - val_accuracy: 0.5839 - val_loss: 0.6722
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 381ms/step - accuracy: 0.6290 - loss: 0.6467 - val_accuracy: 0.5839 - val_loss: 0.6647
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 386ms/step - accuracy: 0.6290 - loss: 0.6213 - val_accuracy: 0.5839 - val_loss: 0.6732
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 393ms/step - accuracy: 0.6394 - loss: 0.5593 - val_accuracy: 0.6309 - val_loss: 0.6362
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 374ms/step - accuracy: 0.7322 - loss: 0.5275 - val_accuracy: 0.6174 - val_loss: 0.6456
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 393ms/step - accuracy: 0.7415 - loss: 0.5041 - val_accuracy: 0.6040 - val_loss: 0.6441
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 397ms/step - accuracy: 0.8142 - loss: 0.4458 - val_accuracy: 0.6846 - val_loss: 0.6767
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 369ms/step - accuracy: 0.8573 - loss: 0.3582 - val_accuracy: 0.7047 - val_loss: 0.8663
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.8870 - loss: 0.2785 - val_accuracy: 0.6846 - val_loss: 0.9328
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 362ms/step - accuracy: 0.9101 - loss: 0.2139 - val_accuracy: 0.6443 - val_loss: 0.9170
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 358ms/step - accuracy: 0.9373 - loss: 0.1820 - val_accuracy: 0.5570 - val_loss: 1.1106
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 371ms/step - accuracy: 0.8745 - loss: 0.2585 - val_accuracy: 0.6577 - val_loss: 0.8567
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 370ms/step - accuracy: 0.9549 - loss: 0.1116 - val_accuracy: 0.6577 - val_loss: 0.9967
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 361ms/step - accuracy: 0.9968 - loss: 0.0435 - val_accuracy: 0.6644 - val_loss: 1.3248
# 🏁 Best epoch for Fold 1: 10
# ✅ Fold 1 test accuracy: 0.7108
#
# 🧪 Fold 2 -----------------------------
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 363ms/step - accuracy: 0.5884 - loss: 0.9167 - val_accuracy: 0.6040 - val_loss: 0.6763
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 362ms/step - accuracy: 0.6215 - loss: 0.6784 - val_accuracy: 0.6040 - val_loss: 0.6715
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 369ms/step - accuracy: 0.6215 - loss: 0.6765 - val_accuracy: 0.6040 - val_loss: 0.6721
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 367ms/step - accuracy: 0.6396 - loss: 0.6636 - val_accuracy: 0.6040 - val_loss: 0.6546
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 379ms/step - accuracy: 0.6816 - loss: 0.6074 - val_accuracy: 0.7517 - val_loss: 0.6309
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 372ms/step - accuracy: 0.7437 - loss: 0.5259 - val_accuracy: 0.6913 - val_loss: 0.6464
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.7440 - loss: 0.5221 - val_accuracy: 0.7315 - val_loss: 0.6066
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.7751 - loss: 0.4623 - val_accuracy: 0.7517 - val_loss: 0.5932
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 388ms/step - accuracy: 0.8128 - loss: 0.4266 - val_accuracy: 0.7651 - val_loss: 0.6549
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 371ms/step - accuracy: 0.8309 - loss: 0.3493 - val_accuracy: 0.7919 - val_loss: 0.6247
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 365ms/step - accuracy: 0.8759 - loss: 0.2914 - val_accuracy: 0.7785 - val_loss: 0.6648
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 358ms/step - accuracy: 0.9005 - loss: 0.2391 - val_accuracy: 0.7718 - val_loss: 0.7180
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 358ms/step - accuracy: 0.9274 - loss: 0.2067 - val_accuracy: 0.7315 - val_loss: 0.7983
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 358ms/step - accuracy: 0.9150 - loss: 0.2344 - val_accuracy: 0.7517 - val_loss: 0.9241
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 366ms/step - accuracy: 0.9617 - loss: 0.1439 - val_accuracy: 0.7718 - val_loss: 1.3820
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 366ms/step - accuracy: 0.9497 - loss: 0.1357 - val_accuracy: 0.7181 - val_loss: 1.1264
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 368ms/step - accuracy: 0.9830 - loss: 0.0639 - val_accuracy: 0.7181 - val_loss: 1.1474
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 363ms/step - accuracy: 0.9816 - loss: 0.0597 - val_accuracy: 0.7383 - val_loss: 1.4263
# 🏁 Best epoch for Fold 2: 8
# ✅ Fold 2 test accuracy: 0.7349
#
# 🧪 Fold 3 -----------------------------
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 364ms/step - accuracy: 0.5207 - loss: 1.2280 - val_accuracy: 0.5436 - val_loss: 0.6937
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.6331 - loss: 0.6712 - val_accuracy: 0.5436 - val_loss: 0.6987
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.6331 - loss: 0.6662 - val_accuracy: 0.5436 - val_loss: 0.6917
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.6331 - loss: 0.6631 - val_accuracy: 0.5436 - val_loss: 0.6950
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.6331 - loss: 0.6540 - val_accuracy: 0.5436 - val_loss: 0.6929
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.5992 - loss: 0.6487 - val_accuracy: 0.5436 - val_loss: 0.6825
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 354ms/step - accuracy: 0.6370 - loss: 0.6238 - val_accuracy: 0.5436 - val_loss: 0.7089
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.6979 - loss: 0.5989 - val_accuracy: 0.6577 - val_loss: 0.6805
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 365ms/step - accuracy: 0.7548 - loss: 0.5015 - val_accuracy: 0.6107 - val_loss: 0.7167
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 364ms/step - accuracy: 0.7936 - loss: 0.4373 - val_accuracy: 0.6443 - val_loss: 0.6773
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.8133 - loss: 0.4770 - val_accuracy: 0.7181 - val_loss: 0.7338
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.8275 - loss: 0.4017 - val_accuracy: 0.6107 - val_loss: 0.6902
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.8020 - loss: 0.4048 - val_accuracy: 0.6913 - val_loss: 0.7090
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 358ms/step - accuracy: 0.8918 - loss: 0.2922 - val_accuracy: 0.7181 - val_loss: 0.7590
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.9107 - loss: 0.2514 - val_accuracy: 0.6779 - val_loss: 0.7743
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 365ms/step - accuracy: 0.9208 - loss: 0.2202 - val_accuracy: 0.6846 - val_loss: 0.8974
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 365ms/step - accuracy: 0.9334 - loss: 0.1580 - val_accuracy: 0.7181 - val_loss: 1.0546
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 363ms/step - accuracy: 0.9826 - loss: 0.0717 - val_accuracy: 0.7248 - val_loss: 1.1748
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 352ms/step - accuracy: 0.9909 - loss: 0.0402 - val_accuracy: 0.7047 - val_loss: 1.3966
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.9944 - loss: 0.0330 - val_accuracy: 0.7114 - val_loss: 1.4736
# 🏁 Best epoch for Fold 3: 10
# ✅ Fold 3 test accuracy: 0.6506
#
# 🧪 Fold 4 -----------------------------
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 373ms/step - accuracy: 0.5925 - loss: 0.9287 - val_accuracy: 0.5705 - val_loss: 0.6827
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 365ms/step - accuracy: 0.6361 - loss: 0.6767 - val_accuracy: 0.5705 - val_loss: 0.6856
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 362ms/step - accuracy: 0.6361 - loss: 0.6748 - val_accuracy: 0.5705 - val_loss: 0.6884
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 361ms/step - accuracy: 0.6361 - loss: 0.6759 - val_accuracy: 0.5705 - val_loss: 0.6845
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 358ms/step - accuracy: 0.6361 - loss: 0.6817 - val_accuracy: 0.5705 - val_loss: 0.6789
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 361ms/step - accuracy: 0.6499 - loss: 0.6710 - val_accuracy: 0.5705 - val_loss: 0.6603
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.6731 - loss: 0.6233 - val_accuracy: 0.6174 - val_loss: 0.6411
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 352ms/step - accuracy: 0.6531 - loss: 0.6064 - val_accuracy: 0.6510 - val_loss: 0.6421
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.7637 - loss: 0.5497 - val_accuracy: 0.7047 - val_loss: 0.6325
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.8060 - loss: 0.4683 - val_accuracy: 0.6443 - val_loss: 0.6683
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.7996 - loss: 0.4368 - val_accuracy: 0.7450 - val_loss: 0.6439
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 367ms/step - accuracy: 0.8497 - loss: 0.3413 - val_accuracy: 0.7315 - val_loss: 0.6243
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 366ms/step - accuracy: 0.8858 - loss: 0.2981 - val_accuracy: 0.7248 - val_loss: 0.6629
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.8836 - loss: 0.2825 - val_accuracy: 0.7181 - val_loss: 0.7019
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.9162 - loss: 0.2304 - val_accuracy: 0.6510 - val_loss: 0.8611
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.8909 - loss: 0.2419 - val_accuracy: 0.6779 - val_loss: 1.0566
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.9419 - loss: 0.1556 - val_accuracy: 0.7383 - val_loss: 1.2817
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.9744 - loss: 0.0875 - val_accuracy: 0.7517 - val_loss: 1.4662
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.9725 - loss: 0.0746 - val_accuracy: 0.7517 - val_loss: 1.4619
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.9789 - loss: 0.0562 - val_accuracy: 0.7517 - val_loss: 1.7662
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 1.0000 - loss: 0.0287 - val_accuracy: 0.7383 - val_loss: 1.7076
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.9975 - loss: 0.0132 - val_accuracy: 0.7450 - val_loss: 1.3087
# 🏁 Best epoch for Fold 4: 12
# ✅ Fold 4 test accuracy: 0.8072
#
# 🧪 Fold 5 -----------------------------
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.6044 - loss: 1.0803 - val_accuracy: 0.5973 - val_loss: 0.6751
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 374ms/step - accuracy: 0.6247 - loss: 0.6821 - val_accuracy: 0.5973 - val_loss: 0.6764
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 370ms/step - accuracy: 0.6247 - loss: 0.6787 - val_accuracy: 0.5973 - val_loss: 0.6774
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 369ms/step - accuracy: 0.6247 - loss: 0.6710 - val_accuracy: 0.5973 - val_loss: 0.6727
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.6247 - loss: 0.6622 - val_accuracy: 0.5973 - val_loss: 0.6714
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 358ms/step - accuracy: 0.6247 - loss: 0.6618 - val_accuracy: 0.5973 - val_loss: 0.6660
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.6247 - loss: 0.6489 - val_accuracy: 0.5973 - val_loss: 0.6580
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.6200 - loss: 0.6176 - val_accuracy: 0.5973 - val_loss: 0.6453
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 361ms/step - accuracy: 0.6247 - loss: 0.5768 - val_accuracy: 0.5973 - val_loss: 0.6435
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.6247 - loss: 0.5706 - val_accuracy: 0.5973 - val_loss: 0.6531
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.6559 - loss: 0.5316 - val_accuracy: 0.6443 - val_loss: 0.6757
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.7643 - loss: 0.4875 - val_accuracy: 0.6309 - val_loss: 0.7033
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 358ms/step - accuracy: 0.7780 - loss: 0.4441 - val_accuracy: 0.6510 - val_loss: 0.6444
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.8430 - loss: 0.3677 - val_accuracy: 0.6644 - val_loss: 0.6868
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.9007 - loss: 0.2844 - val_accuracy: 0.6913 - val_loss: 0.7437
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.9252 - loss: 0.2101 - val_accuracy: 0.6980 - val_loss: 0.7798
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.9194 - loss: 0.2089 - val_accuracy: 0.6242 - val_loss: 0.8495
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 363ms/step - accuracy: 0.9407 - loss: 0.1775 - val_accuracy: 0.5906 - val_loss: 1.0611
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 358ms/step - accuracy: 0.9278 - loss: 0.1530 - val_accuracy: 0.6577 - val_loss: 1.1674
# 🏁 Best epoch for Fold 5: 9
# ✅ Fold 5 test accuracy: 0.6024
#
# 🧪 Fold 6 -----------------------------
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 366ms/step - accuracy: 0.5767 - loss: 1.2493 - val_accuracy: 0.5906 - val_loss: 0.6766
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.6271 - loss: 0.6740 - val_accuracy: 0.5906 - val_loss: 0.6773
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 368ms/step - accuracy: 0.6271 - loss: 0.6781 - val_accuracy: 0.5906 - val_loss: 0.6767
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 366ms/step - accuracy: 0.6271 - loss: 0.6695 - val_accuracy: 0.5906 - val_loss: 0.6755
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.6271 - loss: 0.6626 - val_accuracy: 0.5906 - val_loss: 0.6749
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 361ms/step - accuracy: 0.6271 - loss: 0.6600 - val_accuracy: 0.5906 - val_loss: 0.6735
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 358ms/step - accuracy: 0.6271 - loss: 0.6568 - val_accuracy: 0.5906 - val_loss: 0.6706
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.6271 - loss: 0.6514 - val_accuracy: 0.5906 - val_loss: 0.6667
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.6328 - loss: 0.6336 - val_accuracy: 0.5906 - val_loss: 0.6593
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 358ms/step - accuracy: 0.6271 - loss: 0.6044 - val_accuracy: 0.5906 - val_loss: 0.6688
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.6321 - loss: 0.5592 - val_accuracy: 0.6309 - val_loss: 0.6545
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 366ms/step - accuracy: 0.6957 - loss: 0.5553 - val_accuracy: 0.6040 - val_loss: 0.6719
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.6763 - loss: 0.5295 - val_accuracy: 0.6510 - val_loss: 0.6547
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.7600 - loss: 0.5036 - val_accuracy: 0.5973 - val_loss: 0.7079
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.7903 - loss: 0.4721 - val_accuracy: 0.6242 - val_loss: 0.6771
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 361ms/step - accuracy: 0.8628 - loss: 0.3652 - val_accuracy: 0.6443 - val_loss: 0.7771
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.9049 - loss: 0.2788 - val_accuracy: 0.6040 - val_loss: 0.8464
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.9162 - loss: 0.2075 - val_accuracy: 0.6040 - val_loss: 1.0316
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.9570 - loss: 0.1167 - val_accuracy: 0.6644 - val_loss: 1.3421
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.9894 - loss: 0.0647 - val_accuracy: 0.5906 - val_loss: 1.3730
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 358ms/step - accuracy: 0.9728 - loss: 0.0851 - val_accuracy: 0.5168 - val_loss: 2.0129
# 🏁 Best epoch for Fold 6: 11
# ✅ Fold 6 test accuracy: 0.6220
#
# 🧪 Fold 7 -----------------------------
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 365ms/step - accuracy: 0.6384 - loss: 1.4716 - val_accuracy: 0.5638 - val_loss: 0.6861
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.6385 - loss: 0.6734 - val_accuracy: 0.5638 - val_loss: 0.6848
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.6385 - loss: 0.6705 - val_accuracy: 0.5638 - val_loss: 0.6858
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 361ms/step - accuracy: 0.6385 - loss: 0.6636 - val_accuracy: 0.5638 - val_loss: 0.6846
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 367ms/step - accuracy: 0.6385 - loss: 0.6636 - val_accuracy: 0.5638 - val_loss: 0.6839
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 367ms/step - accuracy: 0.6385 - loss: 0.6631 - val_accuracy: 0.5638 - val_loss: 0.6843
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 366ms/step - accuracy: 0.6385 - loss: 0.6632 - val_accuracy: 0.5638 - val_loss: 0.6795
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.6385 - loss: 0.6612 - val_accuracy: 0.5638 - val_loss: 0.6877
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.6385 - loss: 0.6389 - val_accuracy: 0.5638 - val_loss: 0.6801
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 358ms/step - accuracy: 0.6385 - loss: 0.6485 - val_accuracy: 0.5638 - val_loss: 0.6922
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 361ms/step - accuracy: 0.6385 - loss: 0.6905 - val_accuracy: 0.5638 - val_loss: 0.6912
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 363ms/step - accuracy: 0.6385 - loss: 0.6885 - val_accuracy: 0.5638 - val_loss: 0.6905
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.6385 - loss: 0.6867 - val_accuracy: 0.5638 - val_loss: 0.6897
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 364ms/step - accuracy: 0.6385 - loss: 0.6849 - val_accuracy: 0.5638 - val_loss: 0.6891
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 368ms/step - accuracy: 0.6385 - loss: 0.6833 - val_accuracy: 0.5638 - val_loss: 0.6885
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 358ms/step - accuracy: 0.6385 - loss: 0.6817 - val_accuracy: 0.5638 - val_loss: 0.6880
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 361ms/step - accuracy: 0.6385 - loss: 0.6803 - val_accuracy: 0.5638 - val_loss: 0.6876
# 🏁 Best epoch for Fold 7: 7
# ✅ Fold 7 test accuracy: 0.5976
#
# 🧪 Fold 8 -----------------------------
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 366ms/step - accuracy: 0.5086 - loss: 0.9380 - val_accuracy: 0.5772 - val_loss: 0.6835
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.6290 - loss: 0.6777 - val_accuracy: 0.5772 - val_loss: 0.6975
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 358ms/step - accuracy: 0.5734 - loss: 0.6700 - val_accuracy: 0.5772 - val_loss: 0.7256
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.6275 - loss: 0.6746 - val_accuracy: 0.5772 - val_loss: 0.7166
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 361ms/step - accuracy: 0.5742 - loss: 0.6789 - val_accuracy: 0.5772 - val_loss: 0.6867
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 368ms/step - accuracy: 0.6290 - loss: 0.6943 - val_accuracy: 0.5772 - val_loss: 0.7042
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 367ms/step - accuracy: 0.6290 - loss: 0.6760 - val_accuracy: 0.5772 - val_loss: 0.7109
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.6290 - loss: 0.6719 - val_accuracy: 0.5772 - val_loss: 0.6860
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.6290 - loss: 0.6777 - val_accuracy: 0.5772 - val_loss: 0.6880
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 362ms/step - accuracy: 0.6290 - loss: 0.6713 - val_accuracy: 0.5772 - val_loss: 0.6808
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.6290 - loss: 0.6693 - val_accuracy: 0.5772 - val_loss: 0.6831
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.5801 - loss: 0.6735 - val_accuracy: 0.5772 - val_loss: 0.6822
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 363ms/step - accuracy: 0.6290 - loss: 0.6852 - val_accuracy: 0.5772 - val_loss: 0.6824
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 358ms/step - accuracy: 0.6290 - loss: 0.6681 - val_accuracy: 0.5772 - val_loss: 0.6810
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.6290 - loss: 0.6661 - val_accuracy: 0.5772 - val_loss: 0.6831
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.6290 - loss: 0.6614 - val_accuracy: 0.5772 - val_loss: 0.6810
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 366ms/step - accuracy: 0.6290 - loss: 0.6651 - val_accuracy: 0.5772 - val_loss: 0.6810
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 361ms/step - accuracy: 0.6290 - loss: 0.6595 - val_accuracy: 0.5772 - val_loss: 0.6805
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.6290 - loss: 0.6648 - val_accuracy: 0.5772 - val_loss: 0.6778
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 362ms/step - accuracy: 0.6323 - loss: 0.6562 - val_accuracy: 0.5638 - val_loss: 0.6692
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 368ms/step - accuracy: 0.6208 - loss: 0.6387 - val_accuracy: 0.5772 - val_loss: 0.6796
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 369ms/step - accuracy: 0.6094 - loss: 0.6448 - val_accuracy: 0.5772 - val_loss: 0.6738
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 364ms/step - accuracy: 0.6655 - loss: 0.5993 - val_accuracy: 0.6711 - val_loss: 0.6821
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 365ms/step - accuracy: 0.7512 - loss: 0.5224 - val_accuracy: 0.6174 - val_loss: 0.6892
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.7519 - loss: 0.4955 - val_accuracy: 0.6577 - val_loss: 0.8116
# Epoch 26/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 363ms/step - accuracy: 0.8172 - loss: 0.4445 - val_accuracy: 0.6779 - val_loss: 0.8870
# Epoch 27/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 362ms/step - accuracy: 0.8100 - loss: 0.4109 - val_accuracy: 0.7114 - val_loss: 0.6765
# Epoch 28/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.8500 - loss: 0.3407 - val_accuracy: 0.7047 - val_loss: 0.7319
# Epoch 29/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 358ms/step - accuracy: 0.8198 - loss: 0.3906 - val_accuracy: 0.7181 - val_loss: 0.7149
# Epoch 30/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.8812 - loss: 0.2789 - val_accuracy: 0.6913 - val_loss: 0.7207
# 🏁 Best epoch for Fold 8: 20
# ✅ Fold 8 test accuracy: 0.6220
#
# 🧪 Fold 9 -----------------------------
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 375ms/step - accuracy: 0.6140 - loss: 0.8383 - val_accuracy: 0.5973 - val_loss: 0.6783
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 382ms/step - accuracy: 0.6228 - loss: 0.6857 - val_accuracy: 0.5973 - val_loss: 0.6743
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 373ms/step - accuracy: 0.6228 - loss: 0.6805 - val_accuracy: 0.5973 - val_loss: 0.6752
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 363ms/step - accuracy: 0.6228 - loss: 0.6755 - val_accuracy: 0.5973 - val_loss: 0.6779
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 364ms/step - accuracy: 0.6286 - loss: 0.6619 - val_accuracy: 0.5973 - val_loss: 0.6696
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 362ms/step - accuracy: 0.6420 - loss: 0.6438 - val_accuracy: 0.6107 - val_loss: 0.6595
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.6492 - loss: 0.5982 - val_accuracy: 0.6040 - val_loss: 0.7375
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 362ms/step - accuracy: 0.7409 - loss: 0.5643 - val_accuracy: 0.6980 - val_loss: 0.7270
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 365ms/step - accuracy: 0.8015 - loss: 0.4715 - val_accuracy: 0.7114 - val_loss: 0.6261
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 366ms/step - accuracy: 0.7663 - loss: 0.4681 - val_accuracy: 0.7114 - val_loss: 0.6586
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 368ms/step - accuracy: 0.7907 - loss: 0.4373 - val_accuracy: 0.7181 - val_loss: 0.7030
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.8404 - loss: 0.3706 - val_accuracy: 0.7315 - val_loss: 0.6818
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.8832 - loss: 0.3107 - val_accuracy: 0.6779 - val_loss: 0.7212
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 361ms/step - accuracy: 0.8969 - loss: 0.2540 - val_accuracy: 0.6510 - val_loss: 0.7211
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.9271 - loss: 0.2334 - val_accuracy: 0.6510 - val_loss: 0.7473
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 361ms/step - accuracy: 0.9051 - loss: 0.2516 - val_accuracy: 0.6913 - val_loss: 0.8849
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 365ms/step - accuracy: 0.9431 - loss: 0.1810 - val_accuracy: 0.6846 - val_loss: 1.2266
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 365ms/step - accuracy: 0.9183 - loss: 0.1814 - val_accuracy: 0.6980 - val_loss: 1.2417
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.9308 - loss: 0.1704 - val_accuracy: 0.7047 - val_loss: 1.3881
# 🏁 Best epoch for Fold 9: 9
# ✅ Fold 9 test accuracy: 0.8049
#
# 🧪 Fold 10 -----------------------------
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 370ms/step - accuracy: 0.5065 - loss: 0.8310 - val_accuracy: 0.5772 - val_loss: 0.6856
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 367ms/step - accuracy: 0.6344 - loss: 0.6729 - val_accuracy: 0.5772 - val_loss: 0.6845
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 364ms/step - accuracy: 0.6344 - loss: 0.6775 - val_accuracy: 0.5772 - val_loss: 0.6839
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 362ms/step - accuracy: 0.6344 - loss: 0.6705 - val_accuracy: 0.5772 - val_loss: 0.6798
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 363ms/step - accuracy: 0.6344 - loss: 0.6589 - val_accuracy: 0.5772 - val_loss: 0.6760
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.6354 - loss: 0.6532 - val_accuracy: 0.5772 - val_loss: 0.6700
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 361ms/step - accuracy: 0.6282 - loss: 0.6284 - val_accuracy: 0.5772 - val_loss: 0.6728
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 366ms/step - accuracy: 0.6600 - loss: 0.6252 - val_accuracy: 0.6510 - val_loss: 0.6494
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 366ms/step - accuracy: 0.6731 - loss: 0.5868 - val_accuracy: 0.6577 - val_loss: 0.6398
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 369ms/step - accuracy: 0.7280 - loss: 0.5574 - val_accuracy: 0.6913 - val_loss: 0.6319
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 365ms/step - accuracy: 0.7601 - loss: 0.4879 - val_accuracy: 0.6980 - val_loss: 0.6489
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 364ms/step - accuracy: 0.8072 - loss: 0.4142 - val_accuracy: 0.7114 - val_loss: 0.6396
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 362ms/step - accuracy: 0.8491 - loss: 0.3502 - val_accuracy: 0.6846 - val_loss: 0.6597
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 366ms/step - accuracy: 0.8410 - loss: 0.3201 - val_accuracy: 0.6174 - val_loss: 0.8204
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 363ms/step - accuracy: 0.8980 - loss: 0.2373 - val_accuracy: 0.7114 - val_loss: 1.0940
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.9697 - loss: 0.0968 - val_accuracy: 0.6107 - val_loss: 1.2238
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 363ms/step - accuracy: 0.9693 - loss: 0.0845 - val_accuracy: 0.6376 - val_loss: 1.1795
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - accuracy: 0.9840 - loss: 0.0684 - val_accuracy: 0.7181 - val_loss: 1.3348
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.9878 - loss: 0.0360 - val_accuracy: 0.6510 - val_loss: 1.3934
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 363ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.6711 - val_loss: 1.5701
# 🏁 Best epoch for Fold 10: 10
# ✅ Fold 10 test accuracy: 0.6585
#
# 📌 Mean optimal epoch across folds: 11

# %%
# Cell Block 4: Final Model Training on data again, but for ep_mean Epochs (no validation needed)

## NOTE: THIS IS NOT TESTING ON HIDDEN DATA - IT WAS TECHNICALLY SEEN IN THE k-FOLD.
## CAN TALK ABOUT THIS TO AYUSHMAN

# Split all data into 80% train and 20% test
X_train_final, X_test_final, y_train_final, y_test_final = train_test_split(
    filepaths, labels, test_size=0.2, stratify=labels, random_state=42
)

# Use your same preprocess function
train_final_ds = preprocess(X_train_final, y_train_final)
test_final_ds = preprocess(X_test_final, y_test_final)

# Create and train model with ep_mean
final_model = create_model()
final_model.fit(
    train_final_ds,
    epochs=ep_mean,
    verbose=1
)
# Out:
# Epoch 1/11
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 353ms/step - accuracy: 0.5013 - loss: 0.8653
# Epoch 2/11
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 334ms/step - accuracy: 0.6309 - loss: 0.6678
# Epoch 3/11
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 337ms/step - accuracy: 0.6309 - loss: 0.6831
# Epoch 4/11
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 336ms/step - accuracy: 0.6309 - loss: 0.6710
# Epoch 5/11
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 339ms/step - accuracy: 0.6309 - loss: 0.6738
# Epoch 6/11
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 336ms/step - accuracy: 0.6309 - loss: 0.6639
# Epoch 7/11
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 337ms/step - accuracy: 0.6309 - loss: 0.6721
# Epoch 8/11
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 337ms/step - accuracy: 0.6309 - loss: 0.6777
# Epoch 9/11
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 336ms/step - accuracy: 0.6309 - loss: 0.6668
# Epoch 10/11
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 334ms/step - accuracy: 0.6309 - loss: 0.6674
# Epoch 11/11
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 335ms/step - accuracy: 0.6309 - loss: 0.6729

# %%
# Cell Block 5: Final Evaluation

# Evaluate final model on the 20% test set
final_test_loss, final_test_acc = final_model.evaluate(test_final_ds, verbose=0)

# Report both results
print(f"\n📊 {k}-Fold Test Accuracy: {np.mean(all_test_accuracies):.4f} ± {np.std(all_test_accuracies):.4f}")
print(f"🏁 Final model test accuracy (trained on 80% for {ep_mean} epochs): {final_test_acc:.4f}")
# Out:
# 📊 10-Fold Test Accuracy: 0.6811 ± 0.0752
# 🏁 Final model test accuracy (trained on 80% for 11 epochs): 0.6000

# %%
import numpy as np
from sklearn.metrics import precision_score, roc_curve, auc, f1_score, recall_score
import matplotlib.pyplot as plt

# 1. Extract true labels and model scores from your hold-out dataset
y_true = np.concatenate([y.numpy() for x, y in test_final_ds], axis=0)
y_pred_prob = final_model.predict(test_final_ds)

# 2. If your model outputs two probabilities (one per class), take the “positive” class
if y_pred_prob.ndim > 1 and y_pred_prob.shape[1] > 1:
    y_scores = y_pred_prob[:, 1]
else:
    y_scores = y_pred_prob.ravel()

# 3. Compute ROC curve metrics
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# 4. Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr)               # ROC curve
plt.plot([0, 1], [0, 1], linestyle='--')  # chance line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (AUC = {roc_auc:.2f})')
plt.show()



# 1. Turn your predicted probabilities into binary preds (threshold = 0.5)
y_pred = (y_scores >= 0.5).astype(int)

# 2. Compute precision, recall, F1
precision = precision_score(y_true, y_pred)
recall    = recall_score(y_true, y_pred)
f1        = f1_score(y_true, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Precision: 0.00
# Recall:    0.00
# F1 Score:  0.00
# c:\Users\NBDY\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
