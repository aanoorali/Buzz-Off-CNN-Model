# %% [markdown]
# Varroa Mite Detection 1.5 Big Data Set

# %%
# Cell Block 1: Importing Libraries
import os
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold, train_test_split
import numpy as np
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Cell Block 2: Load Data and Preprocess

df = pd.read_csv('labels_augmented.csv')

df['filename'] = df['filename'].apply(lambda fn: os.path.join('rotations_flips', fn.strip()))

filepaths = df['filename'].values
labels = df['has_mite'].values

# %%
# Cell Block 3: K-Fold Cross-Validation

# Early stopping callback
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    # min_delta=1e-4,
    restore_best_weights=True
)

k = 10  # Number of folds
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

fold = 1
all_test_accuracies = []
best_epochs = []

# Model creation function
def create_model():
    model = models.Sequential([
        layers.Input(shape=(224, 224, 3)),
        layers.Conv2D(32, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Preprocessing function
def preprocess(paths, labels):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    def load_img(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [224, 224])
        img = img / 255.0
        return img, label

    return ds.map(load_img).batch(32).prefetch(tf.data.AUTOTUNE)

for trainval_index, test_index in skf.split(filepaths, labels):
    print(f"\n🧪 Fold {fold} -----------------------------")

    # Split into trainval and test
    X_trainval, X_test = filepaths[trainval_index], filepaths[test_index]
    y_trainval, y_test = labels[trainval_index], labels[test_index]

    # Further split trainval into train and val (e.g. 80/20)
    val_split = int(0.8 * len(X_trainval))
    X_train, X_val = X_trainval[:val_split], X_trainval[val_split:]
    y_train, y_val = y_trainval[:val_split], y_trainval[val_split:]


    # Preprocess each split
    train_ds = preprocess(X_train, y_train)
    val_ds = preprocess(X_val, y_val)
    test_ds = preprocess(X_test, y_test)



    # Train model with early stopping
    model = create_model()
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[earlystop],
        verbose=1
    )

    # Record best epoch (smallest val_loss)
    best_epoch = np.argmin(history.history['val_loss']) + 1
    best_epochs.append(best_epoch)
    print(f"🏁 Best epoch for Fold {fold}: {best_epoch}")

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    all_test_accuracies.append(test_acc)
    print(f"✅ Fold {fold} test accuracy: {test_acc:.4f}")

    fold += 1

# Calculate mean best epoch
ep_mean = int(np.round(np.mean(best_epochs)))
print(f"\n📌 Mean optimal epoch across folds: {ep_mean}")
# Out:
# 🧪 Fold 1 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 378ms/step - accuracy: 0.5754 - loss: 0.9007 - val_accuracy: 0.5922 - val_loss: 0.6773
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 355ms/step - accuracy: 0.6091 - loss: 0.6765 - val_accuracy: 0.5922 - val_loss: 0.6770
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.6091 - loss: 0.6747 - val_accuracy: 0.5922 - val_loss: 0.6770
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.6091 - loss: 0.6738 - val_accuracy: 0.5922 - val_loss: 0.6877
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6091 - loss: 0.6857 - val_accuracy: 0.5922 - val_loss: 0.6846
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6091 - loss: 0.6821 - val_accuracy: 0.5922 - val_loss: 0.6823
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6091 - loss: 0.6793 - val_accuracy: 0.5922 - val_loss: 0.6805
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 370ms/step - accuracy: 0.6091 - loss: 0.6771 - val_accuracy: 0.5922 - val_loss: 0.6793
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 360ms/step - accuracy: 0.6091 - loss: 0.6754 - val_accuracy: 0.5922 - val_loss: 0.6783
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 361ms/step - accuracy: 0.6091 - loss: 0.6741 - val_accuracy: 0.5922 - val_loss: 0.6776
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6091 - loss: 0.6730 - val_accuracy: 0.5922 - val_loss: 0.6771
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6091 - loss: 0.6722 - val_accuracy: 0.5922 - val_loss: 0.6767
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 361ms/step - accuracy: 0.6091 - loss: 0.6716 - val_accuracy: 0.5922 - val_loss: 0.6765
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6091 - loss: 0.6711 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6091 - loss: 0.6707 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6091 - loss: 0.6704 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6091 - loss: 0.6702 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.6091 - loss: 0.6700 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6091 - loss: 0.6698 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6091 - loss: 0.6697 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6091 - loss: 0.6696 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 364ms/step - accuracy: 0.6091 - loss: 0.6695 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 364ms/step - accuracy: 0.6091 - loss: 0.6695 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 365ms/step - accuracy: 0.6091 - loss: 0.6694 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.6091 - loss: 0.6694 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 363ms/step - accuracy: 0.6091 - loss: 0.6694 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6091 - loss: 0.6693 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 28/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6091 - loss: 0.6693 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 29/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.6091 - loss: 0.6693 - val_accuracy: 0.5922 - val_loss: 0.6762
# 🏁 Best epoch for Fold 1: 19
# ✅ Fold 1 test accuracy: 0.6029
#
# 🧪 Fold 2 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 360ms/step - accuracy: 0.5927 - loss: 0.8168 - val_accuracy: 0.5868 - val_loss: 0.6802
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.6182 - loss: 0.6705 - val_accuracy: 0.5868 - val_loss: 0.6903
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6182 - loss: 0.6879 - val_accuracy: 0.5868 - val_loss: 0.6867
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 362ms/step - accuracy: 0.6182 - loss: 0.6831 - val_accuracy: 0.5868 - val_loss: 0.6841
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 360ms/step - accuracy: 0.6182 - loss: 0.6794 - val_accuracy: 0.5868 - val_loss: 0.6822
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 363ms/step - accuracy: 0.6182 - loss: 0.6765 - val_accuracy: 0.5868 - val_loss: 0.6809
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6182 - loss: 0.6742 - val_accuracy: 0.5868 - val_loss: 0.6799
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6182 - loss: 0.6724 - val_accuracy: 0.5868 - val_loss: 0.6792
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6182 - loss: 0.6710 - val_accuracy: 0.5868 - val_loss: 0.6787
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 356ms/step - accuracy: 0.6182 - loss: 0.6699 - val_accuracy: 0.5868 - val_loss: 0.6784
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6182 - loss: 0.6690 - val_accuracy: 0.5868 - val_loss: 0.6782
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6182 - loss: 0.6683 - val_accuracy: 0.5868 - val_loss: 0.6781
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 362ms/step - accuracy: 0.6182 - loss: 0.6677 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 361ms/step - accuracy: 0.6182 - loss: 0.6673 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 355ms/step - accuracy: 0.6182 - loss: 0.6669 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6182 - loss: 0.6666 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6182 - loss: 0.6664 - val_accuracy: 0.5868 - val_loss: 0.6781
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6182 - loss: 0.6662 - val_accuracy: 0.5868 - val_loss: 0.6781
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6182 - loss: 0.6661 - val_accuracy: 0.5868 - val_loss: 0.6782
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6182 - loss: 0.6659 - val_accuracy: 0.5868 - val_loss: 0.6783
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6182 - loss: 0.6658 - val_accuracy: 0.5868 - val_loss: 0.6783
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6182 - loss: 0.6657 - val_accuracy: 0.5868 - val_loss: 0.6784
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6182 - loss: 0.6657 - val_accuracy: 0.5868 - val_loss: 0.6784
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6182 - loss: 0.6656 - val_accuracy: 0.5868 - val_loss: 0.6784
# 🏁 Best epoch for Fold 2: 14
# ✅ Fold 2 test accuracy: 0.6029
#
# 🧪 Fold 3 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 338ms/step - accuracy: 0.6092 - loss: 0.7973 - val_accuracy: 0.5828 - val_loss: 0.6813
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6173 - loss: 0.6710 - val_accuracy: 0.5828 - val_loss: 0.6908
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6173 - loss: 0.6885 - val_accuracy: 0.5828 - val_loss: 0.6874
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.6173 - loss: 0.6837 - val_accuracy: 0.5828 - val_loss: 0.6849
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6173 - loss: 0.6799 - val_accuracy: 0.5828 - val_loss: 0.6831
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6173 - loss: 0.6770 - val_accuracy: 0.5828 - val_loss: 0.6818
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6173 - loss: 0.6747 - val_accuracy: 0.5828 - val_loss: 0.6809
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6173 - loss: 0.6729 - val_accuracy: 0.5828 - val_loss: 0.6803
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6173 - loss: 0.6714 - val_accuracy: 0.5828 - val_loss: 0.6799
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6173 - loss: 0.6703 - val_accuracy: 0.5828 - val_loss: 0.6796
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6173 - loss: 0.6694 - val_accuracy: 0.5828 - val_loss: 0.6795
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6173 - loss: 0.6686 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6173 - loss: 0.6681 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6173 - loss: 0.6676 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6173 - loss: 0.6672 - val_accuracy: 0.5828 - val_loss: 0.6795
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6173 - loss: 0.6670 - val_accuracy: 0.5828 - val_loss: 0.6796
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6173 - loss: 0.6667 - val_accuracy: 0.5828 - val_loss: 0.6796
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6173 - loss: 0.6665 - val_accuracy: 0.5828 - val_loss: 0.6797
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6173 - loss: 0.6664 - val_accuracy: 0.5828 - val_loss: 0.6798
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6173 - loss: 0.6662 - val_accuracy: 0.5828 - val_loss: 0.6799
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6173 - loss: 0.6661 - val_accuracy: 0.5828 - val_loss: 0.6800
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6173 - loss: 0.6661 - val_accuracy: 0.5828 - val_loss: 0.6800
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.6173 - loss: 0.6660 - val_accuracy: 0.5828 - val_loss: 0.6801
# 🏁 Best epoch for Fold 3: 13
# ✅ Fold 3 test accuracy: 0.6029
#
# 🧪 Fold 4 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 336ms/step - accuracy: 0.5847 - loss: 0.7559 - val_accuracy: 0.5814 - val_loss: 0.6873
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6183 - loss: 0.6721 - val_accuracy: 0.5814 - val_loss: 0.6854
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6183 - loss: 0.6737 - val_accuracy: 0.5814 - val_loss: 0.6825
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6183 - loss: 0.6786 - val_accuracy: 0.5814 - val_loss: 0.6805
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6183 - loss: 0.6728 - val_accuracy: 0.5814 - val_loss: 0.6807
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6183 - loss: 0.6729 - val_accuracy: 0.5814 - val_loss: 0.6800
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6183 - loss: 0.6717 - val_accuracy: 0.5814 - val_loss: 0.6817
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6183 - loss: 0.6764 - val_accuracy: 0.5814 - val_loss: 0.6856
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6183 - loss: 0.6804 - val_accuracy: 0.5814 - val_loss: 0.6811
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6161 - loss: 0.6713 - val_accuracy: 0.5814 - val_loss: 0.6797
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6183 - loss: 0.6701 - val_accuracy: 0.5814 - val_loss: 0.6941
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6183 - loss: 0.6733 - val_accuracy: 0.5814 - val_loss: 0.6800
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6183 - loss: 0.6626 - val_accuracy: 0.5814 - val_loss: 0.6824
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6168 - loss: 0.6658 - val_accuracy: 0.5814 - val_loss: 0.6830
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6183 - loss: 0.6762 - val_accuracy: 0.5814 - val_loss: 0.6818
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6183 - loss: 0.6738 - val_accuracy: 0.5814 - val_loss: 0.6809
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6183 - loss: 0.6720 - val_accuracy: 0.5814 - val_loss: 0.6804
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6183 - loss: 0.6706 - val_accuracy: 0.5814 - val_loss: 0.6801
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6183 - loss: 0.6695 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6183 - loss: 0.6687 - val_accuracy: 0.5814 - val_loss: 0.6798
# 🏁 Best epoch for Fold 4: 10
# ✅ Fold 4 test accuracy: 0.6029
#
# 🧪 Fold 5 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 337ms/step - accuracy: 0.5884 - loss: 0.7725 - val_accuracy: 0.5922 - val_loss: 0.6789
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6099 - loss: 0.6738 - val_accuracy: 0.5922 - val_loss: 0.6782
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.5689 - loss: 0.6860 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6099 - loss: 0.6722 - val_accuracy: 0.5922 - val_loss: 0.6776
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6093 - loss: 0.6741 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6099 - loss: 0.6752 - val_accuracy: 0.5922 - val_loss: 0.6771
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6099 - loss: 0.6750 - val_accuracy: 0.5922 - val_loss: 0.6786
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6099 - loss: 0.6745 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6099 - loss: 0.6717 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6099 - loss: 0.6710 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6084 - loss: 0.6714 - val_accuracy: 0.5922 - val_loss: 0.6753
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6237 - loss: 0.6556 - val_accuracy: 0.6756 - val_loss: 0.6331
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.7086 - loss: 0.5852 - val_accuracy: 0.7039 - val_loss: 0.6258
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.7397 - loss: 0.5416 - val_accuracy: 0.7295 - val_loss: 0.5841
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.8038 - loss: 0.4545 - val_accuracy: 0.7564 - val_loss: 0.5517
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.8239 - loss: 0.4102 - val_accuracy: 0.8008 - val_loss: 0.5016
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.8507 - loss: 0.3454 - val_accuracy: 0.8143 - val_loss: 0.4784
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.8707 - loss: 0.3130 - val_accuracy: 0.8048 - val_loss: 0.5712
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.8792 - loss: 0.2886 - val_accuracy: 0.8048 - val_loss: 0.6030
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.8940 - loss: 0.2510 - val_accuracy: 0.7981 - val_loss: 0.5580
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.8971 - loss: 0.2409 - val_accuracy: 0.7779 - val_loss: 0.7598
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.9252 - loss: 0.1914 - val_accuracy: 0.7860 - val_loss: 0.8000
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9427 - loss: 0.1473 - val_accuracy: 0.7793 - val_loss: 0.9247
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.9557 - loss: 0.1159 - val_accuracy: 0.7833 - val_loss: 1.1752
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.9696 - loss: 0.0918 - val_accuracy: 0.7672 - val_loss: 1.2531
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.9592 - loss: 0.1068 - val_accuracy: 0.7335 - val_loss: 1.3612
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.9667 - loss: 0.0874 - val_accuracy: 0.7564 - val_loss: 1.5343
# 🏁 Best epoch for Fold 5: 17
# ✅ Fold 5 test accuracy: 0.8499
#
# 🧪 Fold 6 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.5864 - loss: 0.7644 - val_accuracy: 0.5774 - val_loss: 0.6986
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6124 - loss: 0.6795 - val_accuracy: 0.5774 - val_loss: 0.6820
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6124 - loss: 0.6798 - val_accuracy: 0.5774 - val_loss: 0.6920
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6124 - loss: 0.6783 - val_accuracy: 0.5774 - val_loss: 0.6877
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6124 - loss: 0.6837 - val_accuracy: 0.5774 - val_loss: 0.6851
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6124 - loss: 0.6797 - val_accuracy: 0.5774 - val_loss: 0.6834
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6124 - loss: 0.6768 - val_accuracy: 0.5774 - val_loss: 0.6823
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6124 - loss: 0.6745 - val_accuracy: 0.5774 - val_loss: 0.6817
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6124 - loss: 0.6729 - val_accuracy: 0.5774 - val_loss: 0.6813
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6124 - loss: 0.6716 - val_accuracy: 0.5774 - val_loss: 0.6811
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6124 - loss: 0.6706 - val_accuracy: 0.5774 - val_loss: 0.6811
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6124 - loss: 0.6699 - val_accuracy: 0.5774 - val_loss: 0.6812
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6124 - loss: 0.6694 - val_accuracy: 0.5774 - val_loss: 0.6813
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6124 - loss: 0.6690 - val_accuracy: 0.5774 - val_loss: 0.6815
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6124 - loss: 0.6687 - val_accuracy: 0.5774 - val_loss: 0.6816
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6124 - loss: 0.6685 - val_accuracy: 0.5774 - val_loss: 0.6818
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6124 - loss: 0.6683 - val_accuracy: 0.5774 - val_loss: 0.6819
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6124 - loss: 0.6682 - val_accuracy: 0.5774 - val_loss: 0.6821
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6124 - loss: 0.6681 - val_accuracy: 0.5774 - val_loss: 0.6822
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6124 - loss: 0.6680 - val_accuracy: 0.5774 - val_loss: 0.6824
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 364ms/step - accuracy: 0.6124 - loss: 0.6680 - val_accuracy: 0.5774 - val_loss: 0.6825
# 🏁 Best epoch for Fold 6: 11
# ✅ Fold 6 test accuracy: 0.6019
#
# 🧪 Fold 7 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 417ms/step - accuracy: 0.6083 - loss: 0.7886 - val_accuracy: 0.5882 - val_loss: 0.6784
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 428ms/step - accuracy: 0.6307 - loss: 0.6571 - val_accuracy: 0.5882 - val_loss: 0.6689
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 426ms/step - accuracy: 0.6606 - loss: 0.6154 - val_accuracy: 0.6756 - val_loss: 0.6433
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 428ms/step - accuracy: 0.7262 - loss: 0.5597 - val_accuracy: 0.7429 - val_loss: 0.6069
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 428ms/step - accuracy: 0.7649 - loss: 0.5070 - val_accuracy: 0.7995 - val_loss: 0.5459
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.8256 - loss: 0.4068 - val_accuracy: 0.8048 - val_loss: 0.4963
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.8539 - loss: 0.3569 - val_accuracy: 0.8102 - val_loss: 0.4556
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 429ms/step - accuracy: 0.8616 - loss: 0.3318 - val_accuracy: 0.8022 - val_loss: 0.4521
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 430ms/step - accuracy: 0.8773 - loss: 0.2863 - val_accuracy: 0.8075 - val_loss: 0.4536
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.9024 - loss: 0.2467 - val_accuracy: 0.7968 - val_loss: 0.4944
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 428ms/step - accuracy: 0.9153 - loss: 0.2178 - val_accuracy: 0.7550 - val_loss: 0.5743
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 426ms/step - accuracy: 0.9303 - loss: 0.1810 - val_accuracy: 0.7201 - val_loss: 0.6414
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 430ms/step - accuracy: 0.9310 - loss: 0.1780 - val_accuracy: 0.7147 - val_loss: 0.7656
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 417ms/step - accuracy: 0.8828 - loss: 0.2783 - val_accuracy: 0.7470 - val_loss: 0.7211
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 408ms/step - accuracy: 0.9357 - loss: 0.1574 - val_accuracy: 0.7699 - val_loss: 0.8937
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.9569 - loss: 0.1167 - val_accuracy: 0.7806 - val_loss: 1.0982
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.9748 - loss: 0.0635 - val_accuracy: 0.7981 - val_loss: 1.3965
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.9857 - loss: 0.0307 - val_accuracy: 0.7860 - val_loss: 1.5653
# 🏁 Best epoch for Fold 7: 8
# ✅ Fold 7 test accuracy: 0.8568
#
# 🧪 Fold 8 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 403ms/step - accuracy: 0.5850 - loss: 0.8218 - val_accuracy: 0.5908 - val_loss: 0.6772
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 408ms/step - accuracy: 0.6148 - loss: 0.6730 - val_accuracy: 0.5908 - val_loss: 0.6769
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 369ms/step - accuracy: 0.6148 - loss: 0.6725 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6148 - loss: 0.6718 - val_accuracy: 0.5908 - val_loss: 0.6770
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 356ms/step - accuracy: 0.6131 - loss: 0.6724 - val_accuracy: 0.5908 - val_loss: 0.6708
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6148 - loss: 0.6700 - val_accuracy: 0.5908 - val_loss: 0.6874
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 356ms/step - accuracy: 0.6148 - loss: 0.6847 - val_accuracy: 0.5908 - val_loss: 0.6843
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 361ms/step - accuracy: 0.6148 - loss: 0.6807 - val_accuracy: 0.5908 - val_loss: 0.6820
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 360ms/step - accuracy: 0.6148 - loss: 0.6776 - val_accuracy: 0.5908 - val_loss: 0.6803
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 364ms/step - accuracy: 0.6148 - loss: 0.6752 - val_accuracy: 0.5908 - val_loss: 0.6791
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6148 - loss: 0.6734 - val_accuracy: 0.5908 - val_loss: 0.6782
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6148 - loss: 0.6720 - val_accuracy: 0.5908 - val_loss: 0.6776
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6148 - loss: 0.6709 - val_accuracy: 0.5908 - val_loss: 0.6772
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.6148 - loss: 0.6700 - val_accuracy: 0.5908 - val_loss: 0.6769
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6148 - loss: 0.6694 - val_accuracy: 0.5908 - val_loss: 0.6767
# 🏁 Best epoch for Fold 8: 5
# ✅ Fold 8 test accuracy: 0.6019
#
# 🧪 Fold 9 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 358ms/step - accuracy: 0.5735 - loss: 0.7751 - val_accuracy: 0.5922 - val_loss: 0.6788
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 364ms/step - accuracy: 0.6206 - loss: 0.6702 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6197 - loss: 0.6678 - val_accuracy: 0.5922 - val_loss: 0.6897
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 361ms/step - accuracy: 0.6206 - loss: 0.6873 - val_accuracy: 0.5922 - val_loss: 0.6859
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6206 - loss: 0.6824 - val_accuracy: 0.5922 - val_loss: 0.6831
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6206 - loss: 0.6786 - val_accuracy: 0.5922 - val_loss: 0.6810
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 363ms/step - accuracy: 0.6206 - loss: 0.6756 - val_accuracy: 0.5922 - val_loss: 0.6795
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 364ms/step - accuracy: 0.6206 - loss: 0.6733 - val_accuracy: 0.5922 - val_loss: 0.6784
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6206 - loss: 0.6715 - val_accuracy: 0.5922 - val_loss: 0.6776
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 356ms/step - accuracy: 0.6206 - loss: 0.6701 - val_accuracy: 0.5922 - val_loss: 0.6771
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 364ms/step - accuracy: 0.6206 - loss: 0.6689 - val_accuracy: 0.5922 - val_loss: 0.6767
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6206 - loss: 0.6681 - val_accuracy: 0.5922 - val_loss: 0.6764
# 🏁 Best epoch for Fold 9: 2
# ✅ Fold 9 test accuracy: 0.6019
#
# 🧪 Fold 10 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 361ms/step - accuracy: 0.5982 - loss: 0.7368 - val_accuracy: 0.5922 - val_loss: 0.6788
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6139 - loss: 0.6775 - val_accuracy: 0.5922 - val_loss: 0.6788
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.5961 - loss: 0.6813 - val_accuracy: 0.5922 - val_loss: 0.6775
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 360ms/step - accuracy: 0.6004 - loss: 0.6768 - val_accuracy: 0.5922 - val_loss: 0.6786
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 361ms/step - accuracy: 0.6185 - loss: 0.6790 - val_accuracy: 0.5922 - val_loss: 0.6767
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6145 - loss: 0.6718 - val_accuracy: 0.5922 - val_loss: 0.6792
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.6145 - loss: 0.6728 - val_accuracy: 0.5922 - val_loss: 0.6771
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 362ms/step - accuracy: 0.6145 - loss: 0.6712 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 360ms/step - accuracy: 0.6145 - loss: 0.6687 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 362ms/step - accuracy: 0.6145 - loss: 0.6678 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 356ms/step - accuracy: 0.6145 - loss: 0.6674 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6145 - loss: 0.6673 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.6145 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.6145 - loss: 0.6711 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 360ms/step - accuracy: 0.6145 - loss: 0.6708 - val_accuracy: 0.5922 - val_loss: 0.6764
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6145 - loss: 0.6671 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 364ms/step - accuracy: 0.6145 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6764
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6145 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6764
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 361ms/step - accuracy: 0.6145 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6728
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 369ms/step - accuracy: 0.6140 - loss: 0.6685 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 361ms/step - accuracy: 0.6093 - loss: 0.6700 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.6145 - loss: 0.6673 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 361ms/step - accuracy: 0.6145 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 360ms/step - accuracy: 0.6145 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.6145 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6145 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6145 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 28/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6145 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 29/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 333ms/step - accuracy: 0.6145 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6763
# 🏁 Best epoch for Fold 10: 19
# ✅ Fold 10 test accuracy: 0.6019
#
# 📌 Mean optimal epoch across folds: 12

# %%
# Cell Block 4: Final Model Training on data again, but for ep_mean Epochs (no validation needed)

## NOTE: THIS IS NOT TESTING ON HIDDEN DATA - IT WAS TECHNICALLY SEEN IN THE k-FOLD.
## CAN TALK ABOUT THIS TO AYUSHMAN

# Split all data into 80% train and 20% test
X_train_final, X_test_final, y_train_final, y_test_final = train_test_split(
    filepaths, labels, test_size=0.2, stratify=labels, random_state=42
)

# Use your same preprocess function
train_final_ds = preprocess(X_train_final, y_train_final)
test_final_ds = preprocess(X_test_final, y_test_final)

# Create and train model with ep_mean
final_model = create_model()
final_model.fit(
    train_final_ds,
    epochs=ep_mean,
    verbose=1
)
# Out:
# Epoch 1/12
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 38s 361ms/step - accuracy: 0.5615 - loss: 0.8240
# Epoch 2/12
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 337ms/step - accuracy: 0.5981 - loss: 0.6698
# Epoch 3/12
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 337ms/step - accuracy: 0.6402 - loss: 0.6361
# Epoch 4/12
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 342ms/step - accuracy: 0.6960 - loss: 0.5788
# Epoch 5/12
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - accuracy: 0.7496 - loss: 0.5050
# Epoch 6/12
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 341ms/step - accuracy: 0.8017 - loss: 0.4266
# Epoch 7/12
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 342ms/step - accuracy: 0.8233 - loss: 0.3787
# Epoch 8/12
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 342ms/step - accuracy: 0.8901 - loss: 0.2749
# Epoch 9/12
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 345ms/step - accuracy: 0.8986 - loss: 0.2333
# Epoch 10/12
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 338ms/step - accuracy: 0.9143 - loss: 0.1930
# Epoch 11/12
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - accuracy: 0.8851 - loss: 0.2462
# Epoch 12/12
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 345ms/step - accuracy: 0.9519 - loss: 0.1117

# %%
# Cell Block 5: Final Evaluation

# Evaluate final model on the 20% test set
final_test_loss, final_test_acc = final_model.evaluate(test_final_ds, verbose=0)

# Report both results
print(f"\n📊 {k}-Fold Test Accuracy: {np.mean(all_test_accuracies):.4f} ± {np.std(all_test_accuracies):.4f}")
print(f"🏁 Final model test accuracy (trained on 80% for {ep_mean} epochs): {final_test_acc:.4f}")
# Out:
# 📊 10-Fold Test Accuracy: 0.6526 ± 0.1004
# 🏁 Final model test accuracy (trained on 80% for 12 epochs): 0.6618

# %%
import numpy as np
from sklearn.metrics import precision_score, roc_curve, auc, f1_score, recall_score
import matplotlib.pyplot as plt

# 1. Extract true labels and model scores from your hold-out dataset
y_true = np.concatenate([y.numpy() for x, y in test_final_ds], axis=0)
y_pred_prob = final_model.predict(test_final_ds)

# 2. If your model outputs two probabilities (one per class), take the “positive” class
if y_pred_prob.ndim > 1 and y_pred_prob.shape[1] > 1:
    y_scores = y_pred_prob[:, 1]
else:
    y_scores = y_pred_prob.ravel()

# 3. Compute ROC curve metrics
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# 4. Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr)               # ROC curve
plt.plot([0, 1], [0, 1], linestyle='--')  # chance line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (AUC = {roc_auc:.2f})')
plt.show()



# 1. Turn your predicted probabilities into binary preds (threshold = 0.5)
y_pred = (y_scores >= 0.5).astype(int)

# 2. Compute precision, recall, F1
precision = precision_score(y_true, y_pred)
recall    = recall_score(y_true, y_pred)
f1        = f1_score(y_true, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# Precision: 0.66
# Recall:    0.30
# F1 Score:  0.42
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
