# %% [markdown]
# Varroa Mite Detection 1.20 Brightness

# %%
# Cell Block 1: Importing Libraries
import os
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold, train_test_split
import numpy as np
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Cell Block 2: Load Data and Preprocess

df = pd.read_csv('labels_augmented.csv')

df['filename'] = df['filename'].apply(lambda fn: os.path.join('rotations_flips', fn.strip()))

filepaths = df['filename'].values
labels = df['has_mite'].values

# %%
# Cell Block 3: Splitting Data

X_rest, X_holdout, y_rest, y_holdout = train_test_split(
    filepaths, labels,
    test_size=0.10,
    stratify=labels,
    random_state=42
)

# %%
# Cell Block 3: K-Fold Cross-Validation

# Early stopping callback
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    # min_delta=1e-4,
    restore_best_weights=True
)

k = 10  # Number of folds
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

fold = 1
all_test_accuracies = []
best_epochs = []

# Model creation function
def create_model():
    model = models.Sequential([
        layers.Input(shape=(224, 224, 3)),
        layers.Conv2D(32, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Guassian kernel function
def gaussian_kernel(size: int, sigma: float):
    x = tf.range(-size // 2 + 1, size // 2 + 1, dtype=tf.float32)
    xx, yy = tf.meshgrid(x, x)
    kernel = tf.exp(-(xx**2 + yy**2) / (2.0 * sigma**2))
    kernel = kernel / tf.reduce_sum(kernel)
    return kernel

def apply_gaussian_blur(image, kernel_size=5, sigma=1.0):
    kernel = gaussian_kernel(kernel_size, sigma)                 # [5, 5]
    kernel = kernel[:, :, tf.newaxis, tf.newaxis]                # [5, 5, 1, 1]
    kernel = tf.repeat(kernel, repeats=3, axis=2)                # [5, 5, 3, 1] ✅ CORRECT shape
    image = tf.expand_dims(image, 0)                             # [1, H, W, 3]
    blurred = tf.nn.depthwise_conv2d(image, kernel, strides=[1,1,1,1], padding='SAME')
    
    return tf.squeeze(blurred, axis=0)

# Preprocessing function
def preprocess(paths, labels):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    def load_img(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [224, 224])
        img = img / 255.0

        # # 1) Apply Gaussian blur
        # img = apply_gaussian_blur(img, kernel_size=5, sigma=1.0)

        # # 2) Boost blue channel
        # img = tf.clip_by_value(img + [0.0, 0.0, 0.2], 0.0, 1.0) 

        # # 3) Increase contrast
        # img = tf.image.adjust_contrast(img, 2.0) 

        # # 4) Boost red channel
        # img = tf.clip_by_value(img + [0.2, 0.0, 0.0], 0.0, 1.0)

        # # 5) Boost blue and red channel
        # img = tf.clip_by_value(img + [0.2, 0.0, 0.2], 0.0, 1.0)

        # 6) Boost the Brightness
        img = tf.image.adjust_brightness(img, delta=0.1)

        
        return img, label

    return ds.map(load_img).batch(32).prefetch(tf.data.AUTOTUNE)

for trainval_index, test_index in skf.split(filepaths, labels):
    print(f"\n🧪 Fold {fold} -----------------------------")

    # Split into trainval and test
    X_trainval, X_test = filepaths[trainval_index], filepaths[test_index]
    y_trainval, y_test = labels[trainval_index], labels[test_index]

    # Further split trainval into train and val (e.g. 80/20)
    val_split = int(0.8 * len(X_trainval))
    X_train, X_val = X_trainval[:val_split], X_trainval[val_split:]
    y_train, y_val = y_trainval[:val_split], y_trainval[val_split:]


    # Preprocess each split
    train_ds = preprocess(X_train, y_train)
    val_ds = preprocess(X_val, y_val)
    test_ds = preprocess(X_test, y_test)



    # Train model with early stopping
    model = create_model()
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[earlystop],
        verbose=1
    )

    # Record best epoch (smallest val_loss)
    best_epoch = np.argmin(history.history['val_loss']) + 1
    best_epochs.append(best_epoch)
    print(f"🏁 Best epoch for Fold {fold}: {best_epoch}")

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    all_test_accuracies.append(test_acc)
    print(f"✅ Fold {fold} test accuracy: {test_acc:.4f}")

    fold += 1

# Calculate mean best epoch
ep_mean = int(np.round(np.mean(best_epochs)))
print(f"\n📌 Mean optimal epoch across folds: {ep_mean}")
# Out:
# 🧪 Fold 1 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 42s 442ms/step - accuracy: 0.5683 - loss: 0.8134 - val_accuracy: 0.5922 - val_loss: 0.6766
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 390ms/step - accuracy: 0.6091 - loss: 0.6758 - val_accuracy: 0.5922 - val_loss: 0.6783
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6096 - loss: 0.6740 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 384ms/step - accuracy: 0.6091 - loss: 0.6732 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 386ms/step - accuracy: 0.6091 - loss: 0.6720 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 388ms/step - accuracy: 0.6091 - loss: 0.6715 - val_accuracy: 0.5922 - val_loss: 0.6717
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 389ms/step - accuracy: 0.6091 - loss: 0.6714 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 387ms/step - accuracy: 0.6091 - loss: 0.6711 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 385ms/step - accuracy: 0.6091 - loss: 0.6711 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 386ms/step - accuracy: 0.6091 - loss: 0.6721 - val_accuracy: 0.5922 - val_loss: 0.6870
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 387ms/step - accuracy: 0.6091 - loss: 0.6848 - val_accuracy: 0.5922 - val_loss: 0.6839
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 385ms/step - accuracy: 0.6091 - loss: 0.6812 - val_accuracy: 0.5922 - val_loss: 0.6817
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6091 - loss: 0.6785 - val_accuracy: 0.5922 - val_loss: 0.6801
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6091 - loss: 0.6765 - val_accuracy: 0.5922 - val_loss: 0.6789
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6091 - loss: 0.6749 - val_accuracy: 0.5922 - val_loss: 0.6780
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6091 - loss: 0.6736 - val_accuracy: 0.5922 - val_loss: 0.6774
# 🏁 Best epoch for Fold 1: 6
# ✅ Fold 1 test accuracy: 0.6029
#
# 🧪 Fold 2 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.5986 - loss: 0.7870 - val_accuracy: 0.5868 - val_loss: 0.6794
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6182 - loss: 0.6708 - val_accuracy: 0.5868 - val_loss: 0.6832
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 387ms/step - accuracy: 0.6182 - loss: 0.6723 - val_accuracy: 0.5868 - val_loss: 0.6787
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 381ms/step - accuracy: 0.6182 - loss: 0.6686 - val_accuracy: 0.5868 - val_loss: 0.6791
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6182 - loss: 0.6709 - val_accuracy: 0.5868 - val_loss: 0.6787
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6182 - loss: 0.6669 - val_accuracy: 0.5868 - val_loss: 0.6793
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6182 - loss: 0.6683 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6133 - loss: 0.6707 - val_accuracy: 0.5868 - val_loss: 0.6802
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6182 - loss: 0.6719 - val_accuracy: 0.5868 - val_loss: 0.6802
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 387ms/step - accuracy: 0.6182 - loss: 0.6722 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6182 - loss: 0.6691 - val_accuracy: 0.5868 - val_loss: 0.6783
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6182 - loss: 0.6693 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6182 - loss: 0.6685 - val_accuracy: 0.5868 - val_loss: 0.6778
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6182 - loss: 0.6686 - val_accuracy: 0.5868 - val_loss: 0.6770
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6182 - loss: 0.6728 - val_accuracy: 0.5868 - val_loss: 0.6834
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6182 - loss: 0.6782 - val_accuracy: 0.5868 - val_loss: 0.6816
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6182 - loss: 0.6755 - val_accuracy: 0.5868 - val_loss: 0.6804
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 339ms/step - accuracy: 0.6182 - loss: 0.6733 - val_accuracy: 0.5868 - val_loss: 0.6795
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6182 - loss: 0.6717 - val_accuracy: 0.5868 - val_loss: 0.6789
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6182 - loss: 0.6704 - val_accuracy: 0.5868 - val_loss: 0.6785
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6182 - loss: 0.6694 - val_accuracy: 0.5868 - val_loss: 0.6783
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6182 - loss: 0.6686 - val_accuracy: 0.5868 - val_loss: 0.6781
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6182 - loss: 0.6679 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6182 - loss: 0.6674 - val_accuracy: 0.5868 - val_loss: 0.6780
# 🏁 Best epoch for Fold 2: 14
# ✅ Fold 2 test accuracy: 0.6029
#
# 🧪 Fold 3 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 345ms/step - accuracy: 0.5739 - loss: 0.7505 - val_accuracy: 0.5828 - val_loss: 0.6819
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6173 - loss: 0.6737 - val_accuracy: 0.5828 - val_loss: 0.6799
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6173 - loss: 0.6719 - val_accuracy: 0.5828 - val_loss: 0.6790
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6173 - loss: 0.6777 - val_accuracy: 0.5828 - val_loss: 0.6888
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6173 - loss: 0.6855 - val_accuracy: 0.5828 - val_loss: 0.6805
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6173 - loss: 0.6697 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6173 - loss: 0.6712 - val_accuracy: 0.5828 - val_loss: 0.6845
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6173 - loss: 0.6792 - val_accuracy: 0.5828 - val_loss: 0.6827
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6173 - loss: 0.6764 - val_accuracy: 0.5828 - val_loss: 0.6815
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6173 - loss: 0.6742 - val_accuracy: 0.5828 - val_loss: 0.6807
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6173 - loss: 0.6724 - val_accuracy: 0.5828 - val_loss: 0.6801
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6173 - loss: 0.6711 - val_accuracy: 0.5828 - val_loss: 0.6798
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6173 - loss: 0.6700 - val_accuracy: 0.5828 - val_loss: 0.6795
# 🏁 Best epoch for Fold 3: 3
# ✅ Fold 3 test accuracy: 0.6029
#
# 🧪 Fold 4 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 349ms/step - accuracy: 0.5946 - loss: 1.0258 - val_accuracy: 0.5814 - val_loss: 0.6867
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6182 - loss: 0.6826 - val_accuracy: 0.5814 - val_loss: 0.6904
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6183 - loss: 0.6878 - val_accuracy: 0.5814 - val_loss: 0.6872
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6183 - loss: 0.6831 - val_accuracy: 0.5814 - val_loss: 0.6848
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6183 - loss: 0.6794 - val_accuracy: 0.5814 - val_loss: 0.6831
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6183 - loss: 0.6765 - val_accuracy: 0.5814 - val_loss: 0.6819
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6183 - loss: 0.6742 - val_accuracy: 0.5814 - val_loss: 0.6811
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6183 - loss: 0.6724 - val_accuracy: 0.5814 - val_loss: 0.6805
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6183 - loss: 0.6710 - val_accuracy: 0.5814 - val_loss: 0.6802
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6183 - loss: 0.6698 - val_accuracy: 0.5814 - val_loss: 0.6800
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6183 - loss: 0.6689 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6183 - loss: 0.6682 - val_accuracy: 0.5814 - val_loss: 0.6798
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6183 - loss: 0.6676 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6183 - loss: 0.6672 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6183 - loss: 0.6668 - val_accuracy: 0.5814 - val_loss: 0.6800
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6183 - loss: 0.6665 - val_accuracy: 0.5814 - val_loss: 0.6801
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6183 - loss: 0.6663 - val_accuracy: 0.5814 - val_loss: 0.6802
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6183 - loss: 0.6661 - val_accuracy: 0.5814 - val_loss: 0.6803
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 339ms/step - accuracy: 0.6183 - loss: 0.6659 - val_accuracy: 0.5814 - val_loss: 0.6804
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6183 - loss: 0.6658 - val_accuracy: 0.5814 - val_loss: 0.6805
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6183 - loss: 0.6657 - val_accuracy: 0.5814 - val_loss: 0.6806
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6183 - loss: 0.6656 - val_accuracy: 0.5814 - val_loss: 0.6806
# 🏁 Best epoch for Fold 4: 12
# ✅ Fold 4 test accuracy: 0.6029
#
# 🧪 Fold 5 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.5696 - loss: 0.8038 - val_accuracy: 0.5922 - val_loss: 0.6770
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6099 - loss: 0.6720 - val_accuracy: 0.5922 - val_loss: 0.6771
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6099 - loss: 0.6771 - val_accuracy: 0.5922 - val_loss: 0.6773
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6099 - loss: 0.6708 - val_accuracy: 0.5922 - val_loss: 0.6805
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 339ms/step - accuracy: 0.6099 - loss: 0.6721 - val_accuracy: 0.5922 - val_loss: 0.6782
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6099 - loss: 0.6746 - val_accuracy: 0.5922 - val_loss: 0.6862
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6099 - loss: 0.6838 - val_accuracy: 0.5922 - val_loss: 0.6831
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6099 - loss: 0.6801 - val_accuracy: 0.5922 - val_loss: 0.6809
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6099 - loss: 0.6774 - val_accuracy: 0.5922 - val_loss: 0.6794
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6099 - loss: 0.6754 - val_accuracy: 0.5922 - val_loss: 0.6783
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6099 - loss: 0.6738 - val_accuracy: 0.5922 - val_loss: 0.6775
# 🏁 Best epoch for Fold 5: 1
# ✅ Fold 5 test accuracy: 0.6029
#
# 🧪 Fold 6 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.5805 - loss: 0.7740 - val_accuracy: 0.5774 - val_loss: 0.6933
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6059 - loss: 0.6761 - val_accuracy: 0.5774 - val_loss: 0.6815
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6124 - loss: 0.6724 - val_accuracy: 0.5774 - val_loss: 0.6825
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6124 - loss: 0.6712 - val_accuracy: 0.5774 - val_loss: 0.6846
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6124 - loss: 0.6723 - val_accuracy: 0.5774 - val_loss: 0.6823
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6124 - loss: 0.6709 - val_accuracy: 0.5774 - val_loss: 0.6833
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6124 - loss: 0.6706 - val_accuracy: 0.5774 - val_loss: 0.6827
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6124 - loss: 0.6704 - val_accuracy: 0.5774 - val_loss: 0.6826
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6124 - loss: 0.6703 - val_accuracy: 0.5774 - val_loss: 0.6825
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6124 - loss: 0.6713 - val_accuracy: 0.5774 - val_loss: 0.6819
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6124 - loss: 0.6701 - val_accuracy: 0.5774 - val_loss: 0.6825
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6124 - loss: 0.6699 - val_accuracy: 0.5774 - val_loss: 0.6825
# 🏁 Best epoch for Fold 6: 2
# ✅ Fold 6 test accuracy: 0.6019
#
# 🧪 Fold 7 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 343ms/step - accuracy: 0.5981 - loss: 0.7914 - val_accuracy: 0.5882 - val_loss: 0.6814
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6111 - loss: 0.6696 - val_accuracy: 0.5882 - val_loss: 0.6789
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6191 - loss: 0.6732 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6191 - loss: 0.6724 - val_accuracy: 0.5882 - val_loss: 0.6888
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6191 - loss: 0.6860 - val_accuracy: 0.5882 - val_loss: 0.6854
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6191 - loss: 0.6813 - val_accuracy: 0.5882 - val_loss: 0.6829
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6191 - loss: 0.6777 - val_accuracy: 0.5882 - val_loss: 0.6811
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6191 - loss: 0.6749 - val_accuracy: 0.5882 - val_loss: 0.6799
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6191 - loss: 0.6728 - val_accuracy: 0.5882 - val_loss: 0.6790
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6191 - loss: 0.6711 - val_accuracy: 0.5882 - val_loss: 0.6784
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6191 - loss: 0.6699 - val_accuracy: 0.5882 - val_loss: 0.6780
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6191 - loss: 0.6688 - val_accuracy: 0.5882 - val_loss: 0.6778
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6191 - loss: 0.6681 - val_accuracy: 0.5882 - val_loss: 0.6776
# 🏁 Best epoch for Fold 7: 3
# ✅ Fold 7 test accuracy: 0.6019
#
# 🧪 Fold 8 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 342ms/step - accuracy: 0.5777 - loss: 1.0033 - val_accuracy: 0.5908 - val_loss: 0.6910
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6148 - loss: 0.6892 - val_accuracy: 0.5908 - val_loss: 0.6872
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6148 - loss: 0.6845 - val_accuracy: 0.5908 - val_loss: 0.6843
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6148 - loss: 0.6808 - val_accuracy: 0.5908 - val_loss: 0.6821
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6148 - loss: 0.6778 - val_accuracy: 0.5908 - val_loss: 0.6804
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6148 - loss: 0.6755 - val_accuracy: 0.5908 - val_loss: 0.6792
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.6148 - loss: 0.6736 - val_accuracy: 0.5908 - val_loss: 0.6783
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6148 - loss: 0.6722 - val_accuracy: 0.5908 - val_loss: 0.6777
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6148 - loss: 0.6711 - val_accuracy: 0.5908 - val_loss: 0.6773
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6148 - loss: 0.6702 - val_accuracy: 0.5908 - val_loss: 0.6770
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6148 - loss: 0.6695 - val_accuracy: 0.5908 - val_loss: 0.6768
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6148 - loss: 0.6689 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6148 - loss: 0.6685 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6148 - loss: 0.6682 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6148 - loss: 0.6679 - val_accuracy: 0.5908 - val_loss: 0.6765
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6148 - loss: 0.6677 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6148 - loss: 0.6675 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6148 - loss: 0.6674 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6148 - loss: 0.6673 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6148 - loss: 0.6672 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6148 - loss: 0.6671 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6148 - loss: 0.6671 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6148 - loss: 0.6670 - val_accuracy: 0.5908 - val_loss: 0.6768
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6148 - loss: 0.6670 - val_accuracy: 0.5908 - val_loss: 0.6768
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6148 - loss: 0.6670 - val_accuracy: 0.5908 - val_loss: 0.6768
# 🏁 Best epoch for Fold 8: 15
# ✅ Fold 8 test accuracy: 0.6019
#
# 🧪 Fold 9 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.5935 - loss: 0.7991 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6123 - loss: 0.6718 - val_accuracy: 0.5922 - val_loss: 0.6768
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6206 - loss: 0.6724 - val_accuracy: 0.5922 - val_loss: 0.6732
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6147 - loss: 0.6616 - val_accuracy: 0.5922 - val_loss: 0.6733
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6206 - loss: 0.6736 - val_accuracy: 0.5949 - val_loss: 0.6443
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6436 - loss: 0.7037 - val_accuracy: 0.5922 - val_loss: 0.6868
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6206 - loss: 0.6836 - val_accuracy: 0.5922 - val_loss: 0.6837
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6206 - loss: 0.6794 - val_accuracy: 0.5922 - val_loss: 0.6815
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6206 - loss: 0.6763 - val_accuracy: 0.5922 - val_loss: 0.6798
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6206 - loss: 0.6738 - val_accuracy: 0.5922 - val_loss: 0.6786
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6206 - loss: 0.6719 - val_accuracy: 0.5922 - val_loss: 0.6778
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6206 - loss: 0.6703 - val_accuracy: 0.5922 - val_loss: 0.6772
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6206 - loss: 0.6692 - val_accuracy: 0.5922 - val_loss: 0.6768
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6206 - loss: 0.6682 - val_accuracy: 0.5922 - val_loss: 0.6765
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6206 - loss: 0.6675 - val_accuracy: 0.5922 - val_loss: 0.6763
# 🏁 Best epoch for Fold 9: 5
# ✅ Fold 9 test accuracy: 0.6044
#
# 🧪 Fold 10 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 348ms/step - accuracy: 0.6099 - loss: 0.7800 - val_accuracy: 0.5922 - val_loss: 0.6780
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6145 - loss: 0.6756 - val_accuracy: 0.5922 - val_loss: 0.6905
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6145 - loss: 0.6886 - val_accuracy: 0.5922 - val_loss: 0.6864
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6145 - loss: 0.6837 - val_accuracy: 0.5922 - val_loss: 0.6835
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6145 - loss: 0.6799 - val_accuracy: 0.5922 - val_loss: 0.6813
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6145 - loss: 0.6770 - val_accuracy: 0.5922 - val_loss: 0.6797
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6145 - loss: 0.6748 - val_accuracy: 0.5922 - val_loss: 0.6785
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6145 - loss: 0.6731 - val_accuracy: 0.5922 - val_loss: 0.6777
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 356ms/step - accuracy: 0.6145 - loss: 0.6717 - val_accuracy: 0.5922 - val_loss: 0.6771
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6145 - loss: 0.6707 - val_accuracy: 0.5922 - val_loss: 0.6767
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6145 - loss: 0.6699 - val_accuracy: 0.5922 - val_loss: 0.6764
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6145 - loss: 0.6693 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6145 - loss: 0.6688 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6145 - loss: 0.6684 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6145 - loss: 0.6681 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6145 - loss: 0.6679 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6145 - loss: 0.6677 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6145 - loss: 0.6676 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6145 - loss: 0.6674 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6145 - loss: 0.6674 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.6145 - loss: 0.6673 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6145 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6145 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6145 - loss: 0.6671 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6145 - loss: 0.6671 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6145 - loss: 0.6671 - val_accuracy: 0.5922 - val_loss: 0.6763
# 🏁 Best epoch for Fold 10: 16
# ✅ Fold 10 test accuracy: 0.6019
#
# 📌 Mean optimal epoch across folds: 8

# %%
# Cell Block 5: Final Model Training on data again, but for ep_mean Epochs (no validation needed)

# Build your TF datasets
train_final_ds = preprocess(X_rest, y_rest)        # ALL data used in K-Fold
test_final_ds  = preprocess(X_holdout, y_holdout)  # NEVER seen during CV

# Instantiate & train your final model
final_model = create_model()
final_model.fit(
    train_final_ds,
    epochs=ep_mean,
    verbose=1
)

# Evaluate once—only on the true hold-out set
final_results = final_model.evaluate(
    test_final_ds,
    verbose=1
)
print("Hold-out test loss & accuracy:", final_results)
# Out:
# Epoch 1/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 37s 315ms/step - accuracy: 0.5808 - loss: 0.9304
# Epoch 2/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 312ms/step - accuracy: 0.6107 - loss: 0.6447
# Epoch 3/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 37s 316ms/step - accuracy: 0.6859 - loss: 0.6135
# Epoch 4/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 37s 316ms/step - accuracy: 0.7931 - loss: 0.5407
# Epoch 5/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 37s 320ms/step - accuracy: 0.8287 - loss: 0.4920
# Epoch 6/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 313ms/step - accuracy: 0.8499 - loss: 0.4556
# Epoch 7/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 314ms/step - accuracy: 0.8487 - loss: 0.4299
# Epoch 8/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 37s 317ms/step - accuracy: 0.8733 - loss: 0.4013
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.8441 - loss: 0.4642
# Hold-out test loss & accuracy: [0.4739857316017151, 0.842615008354187]

# %%
# Cell Block 5: Final Evaluation

# Evaluate final model on the 20% test set
final_test_loss, final_test_acc = final_model.evaluate(test_final_ds, verbose=0)

# Report both results
print(f"\n📊 {k}-Fold Test Accuracy: {np.mean(all_test_accuracies):.4f} ± {np.std(all_test_accuracies):.4f}")
print(f"🏁 Final model test accuracy (trained on hold-out): {final_test_acc:.4f}")
# Out:
# 📊 10-Fold Test Accuracy: 0.6027 ± 0.0007
# 🏁 Final model test accuracy (trained on hold-out): 0.8426

# %%
import numpy as np
from sklearn.metrics import precision_score, roc_curve, auc, f1_score, recall_score
import matplotlib.pyplot as plt

# 1. Extract true labels and model scores from your hold-out dataset
y_true = np.concatenate([y.numpy() for x, y in test_final_ds], axis=0)
y_pred_prob = final_model.predict(test_final_ds)

# 2. If your model outputs two probabilities (one per class), take the “positive” class
if y_pred_prob.ndim > 1 and y_pred_prob.shape[1] > 1:
    y_scores = y_pred_prob[:, 1]
else:
    y_scores = y_pred_prob.ravel()

# 3. Compute ROC curve metrics
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# 4. Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr)               # ROC curve
plt.plot([0, 1], [0, 1], linestyle='--')  # chance line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (AUC = {roc_auc:.2f})')
plt.show()



# 1. Turn your predicted probabilities into binary preds (threshold = 0.5)
y_pred = (y_scores >= 0.5).astype(int)

# 2. Compute precision, recall, F1
precision = precision_score(y_true, y_pred)
recall    = recall_score(y_true, y_pred)
f1        = f1_score(y_true, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# Precision: 0.82
# Recall:    0.77
# F1 Score:  0.79
