# %% [markdown]
# Varroa Mite Detection 1.12 Blue Shift with Contrast

# %%
# Cell Block 1: Importing Libraries
import os
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold, train_test_split
import numpy as np
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Cell Block 2: Load Data and Preprocess

df = pd.read_csv('labels_augmented.csv')

df['filename'] = df['filename'].apply(lambda fn: os.path.join('rotations_flips', fn.strip()))

filepaths = df['filename'].values
labels = df['has_mite'].values

# %%
# Cell Block 3: Splitting Data

X_rest, X_holdout, y_rest, y_holdout = train_test_split(
    filepaths, labels,
    test_size=0.10,
    stratify=labels,
    random_state=42
)

# %%
# Cell Block 3: K-Fold Cross-Validation

# Early stopping callback
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    # min_delta=1e-4,
    restore_best_weights=True
)

k = 10  # Number of folds
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

fold = 1
all_test_accuracies = []
best_epochs = []

# Model creation function
def create_model():
    model = models.Sequential([
        layers.Input(shape=(224, 224, 3)),
        layers.Conv2D(32, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Preprocessing function
def preprocess(paths, labels):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    def load_img(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [224, 224])
        img = img / 255.0


        # 1) Boost blue channel
        img = tf.clip_by_value(img + [0.0, 0.0, 0.2], 0.0, 1.0) 

        # 2) Increase contrast
        img = tf.image.adjust_contrast(img, 2.0) 

        # 3). Boost red channel
        # img = tf.clip_by_value(img + [0.2, 0.0, 0.0], 0.0, 1.0)
      
        return img, label

    return ds.map(load_img).batch(32).prefetch(tf.data.AUTOTUNE)

for trainval_index, test_index in skf.split(filepaths, labels):
    print(f"\n🧪 Fold {fold} -----------------------------")

    # Split into trainval and test
    X_trainval, X_test = filepaths[trainval_index], filepaths[test_index]
    y_trainval, y_test = labels[trainval_index], labels[test_index]

    # Further split trainval into train and val (e.g. 80/20)
    val_split = int(0.8 * len(X_trainval))
    X_train, X_val = X_trainval[:val_split], X_trainval[val_split:]
    y_train, y_val = y_trainval[:val_split], y_trainval[val_split:]


    # Preprocess each split
    train_ds = preprocess(X_train, y_train)
    val_ds = preprocess(X_val, y_val)
    test_ds = preprocess(X_test, y_test)



    # Train model with early stopping
    model = create_model()
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[earlystop],
        verbose=1
    )

    # Record best epoch (smallest val_loss)
    best_epoch = np.argmin(history.history['val_loss']) + 1
    best_epochs.append(best_epoch)
    print(f"🏁 Best epoch for Fold {fold}: {best_epoch}")

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    all_test_accuracies.append(test_acc)
    print(f"✅ Fold {fold} test accuracy: {test_acc:.4f}")

    fold += 1

# Calculate mean best epoch
ep_mean = int(np.round(np.mean(best_epochs)))
print(f"\n📌 Mean optimal epoch across folds: {ep_mean}")
# Out:
# 🧪 Fold 1 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 365ms/step - accuracy: 0.5703 - loss: 0.8193 - val_accuracy: 0.5922 - val_loss: 0.6778
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6091 - loss: 0.6725 - val_accuracy: 0.6218 - val_loss: 0.6508
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6007 - loss: 0.6547 - val_accuracy: 0.6245 - val_loss: 0.6658
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 368ms/step - accuracy: 0.6406 - loss: 0.6234 - val_accuracy: 0.6474 - val_loss: 0.6718
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 369ms/step - accuracy: 0.6566 - loss: 0.6002 - val_accuracy: 0.6689 - val_loss: 0.6430
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.6958 - loss: 0.5565 - val_accuracy: 0.6608 - val_loss: 0.6346
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 369ms/step - accuracy: 0.7410 - loss: 0.4964 - val_accuracy: 0.6649 - val_loss: 0.6661
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 370ms/step - accuracy: 0.7837 - loss: 0.4075 - val_accuracy: 0.6608 - val_loss: 0.8249
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 371ms/step - accuracy: 0.8222 - loss: 0.3438 - val_accuracy: 0.6662 - val_loss: 0.7379
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 370ms/step - accuracy: 0.8176 - loss: 0.3328 - val_accuracy: 0.6595 - val_loss: 0.7477
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 367ms/step - accuracy: 0.8705 - loss: 0.2466 - val_accuracy: 0.6649 - val_loss: 0.8440
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 370ms/step - accuracy: 0.8983 - loss: 0.1991 - val_accuracy: 0.6783 - val_loss: 0.9698
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.9143 - loss: 0.1666 - val_accuracy: 0.6514 - val_loss: 1.1910
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.9164 - loss: 0.1726 - val_accuracy: 0.6568 - val_loss: 1.0747
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 368ms/step - accuracy: 0.9632 - loss: 0.1048 - val_accuracy: 0.6770 - val_loss: 1.1995
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.9703 - loss: 0.0989 - val_accuracy: 0.6756 - val_loss: 1.4038
# 🏁 Best epoch for Fold 1: 6
# ✅ Fold 1 test accuracy: 0.6707
#
# 🧪 Fold 2 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 367ms/step - accuracy: 0.5748 - loss: 0.9063 - val_accuracy: 0.5868 - val_loss: 0.6726
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 369ms/step - accuracy: 0.6123 - loss: 0.6534 - val_accuracy: 0.6218 - val_loss: 0.6425
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 371ms/step - accuracy: 0.6358 - loss: 0.6490 - val_accuracy: 0.6420 - val_loss: 0.6325
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 367ms/step - accuracy: 0.6835 - loss: 0.6035 - val_accuracy: 0.6622 - val_loss: 0.6131
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 371ms/step - accuracy: 0.7160 - loss: 0.5385 - val_accuracy: 0.6447 - val_loss: 0.6601
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.7766 - loss: 0.4459 - val_accuracy: 0.6595 - val_loss: 0.8264
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.8204 - loss: 0.3517 - val_accuracy: 0.6528 - val_loss: 0.8654
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.8686 - loss: 0.2505 - val_accuracy: 0.6447 - val_loss: 1.2747
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.8874 - loss: 0.2148 - val_accuracy: 0.6339 - val_loss: 1.4795
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 369ms/step - accuracy: 0.9134 - loss: 0.1891 - val_accuracy: 0.6326 - val_loss: 1.5226
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.9398 - loss: 0.1332 - val_accuracy: 0.6285 - val_loss: 1.5737
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.9507 - loss: 0.1243 - val_accuracy: 0.6353 - val_loss: 1.6074
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.9622 - loss: 0.0858 - val_accuracy: 0.6272 - val_loss: 1.8569
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9712 - loss: 0.0838 - val_accuracy: 0.6030 - val_loss: 1.6120
# 🏁 Best epoch for Fold 2: 4
# ✅ Fold 2 test accuracy: 0.6295
#
# 🧪 Fold 3 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.5560 - loss: 0.8609 - val_accuracy: 0.5828 - val_loss: 0.6802
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.6153 - loss: 0.6741 - val_accuracy: 0.5828 - val_loss: 0.6819
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6161 - loss: 0.6715 - val_accuracy: 0.5828 - val_loss: 0.6895
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6173 - loss: 0.6866 - val_accuracy: 0.5828 - val_loss: 0.6864
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.6173 - loss: 0.6822 - val_accuracy: 0.5828 - val_loss: 0.6842
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.6173 - loss: 0.6788 - val_accuracy: 0.5828 - val_loss: 0.6826
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6173 - loss: 0.6761 - val_accuracy: 0.5828 - val_loss: 0.6814
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6173 - loss: 0.6740 - val_accuracy: 0.5828 - val_loss: 0.6806
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6173 - loss: 0.6723 - val_accuracy: 0.5828 - val_loss: 0.6801
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6173 - loss: 0.6710 - val_accuracy: 0.5828 - val_loss: 0.6797
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6173 - loss: 0.6699 - val_accuracy: 0.5828 - val_loss: 0.6795
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6173 - loss: 0.6691 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6173 - loss: 0.6684 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6173 - loss: 0.6679 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6173 - loss: 0.6675 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6173 - loss: 0.6671 - val_accuracy: 0.5828 - val_loss: 0.6795
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6173 - loss: 0.6669 - val_accuracy: 0.5828 - val_loss: 0.6796
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6173 - loss: 0.6666 - val_accuracy: 0.5828 - val_loss: 0.6797
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6173 - loss: 0.6665 - val_accuracy: 0.5828 - val_loss: 0.6798
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6173 - loss: 0.6663 - val_accuracy: 0.5828 - val_loss: 0.6798
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.6173 - loss: 0.6662 - val_accuracy: 0.5828 - val_loss: 0.6799
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6173 - loss: 0.6661 - val_accuracy: 0.5828 - val_loss: 0.6800
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6173 - loss: 0.6660 - val_accuracy: 0.5828 - val_loss: 0.6801
# 🏁 Best epoch for Fold 3: 13
# ✅ Fold 3 test accuracy: 0.6029
#
# 🧪 Fold 4 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.5952 - loss: 1.0416 - val_accuracy: 0.5814 - val_loss: 0.6902
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6215 - loss: 0.6624 - val_accuracy: 0.5976 - val_loss: 0.6745
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6498 - loss: 0.6327 - val_accuracy: 0.6406 - val_loss: 0.6711
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.7005 - loss: 0.5909 - val_accuracy: 0.6743 - val_loss: 0.6653
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.7206 - loss: 0.5558 - val_accuracy: 0.7079 - val_loss: 0.6540
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.7689 - loss: 0.4879 - val_accuracy: 0.7820 - val_loss: 0.5488
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.8328 - loss: 0.3850 - val_accuracy: 0.7833 - val_loss: 0.5787
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.8689 - loss: 0.2992 - val_accuracy: 0.7860 - val_loss: 0.5357
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9052 - loss: 0.2213 - val_accuracy: 0.8022 - val_loss: 0.5865
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.9256 - loss: 0.1737 - val_accuracy: 0.8022 - val_loss: 0.6607
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.9684 - loss: 0.0918 - val_accuracy: 0.7779 - val_loss: 0.7535
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.9708 - loss: 0.0861 - val_accuracy: 0.7658 - val_loss: 0.8142
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9658 - loss: 0.0897 - val_accuracy: 0.7968 - val_loss: 0.6700
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.9770 - loss: 0.0763 - val_accuracy: 0.7618 - val_loss: 1.0498
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.9782 - loss: 0.0555 - val_accuracy: 0.7618 - val_loss: 1.1604
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9854 - loss: 0.0471 - val_accuracy: 0.7779 - val_loss: 1.5233
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.9844 - loss: 0.0554 - val_accuracy: 0.7820 - val_loss: 1.0328
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.9961 - loss: 0.0127 - val_accuracy: 0.7645 - val_loss: 1.3245
# 🏁 Best epoch for Fold 4: 8
# ✅ Fold 4 test accuracy: 0.7893
#
# 🧪 Fold 5 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.5733 - loss: 0.9029 - val_accuracy: 0.5922 - val_loss: 0.6791
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.5939 - loss: 0.6806 - val_accuracy: 0.5922 - val_loss: 0.6807
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6099 - loss: 0.6780 - val_accuracy: 0.5922 - val_loss: 0.6859
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6099 - loss: 0.6819 - val_accuracy: 0.5922 - val_loss: 0.6825
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6099 - loss: 0.6783 - val_accuracy: 0.5922 - val_loss: 0.6748
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6099 - loss: 0.6630 - val_accuracy: 0.6124 - val_loss: 0.6504
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.5980 - loss: 0.6652 - val_accuracy: 0.6501 - val_loss: 0.6434
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6344 - loss: 0.6571 - val_accuracy: 0.6595 - val_loss: 0.6305
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6742 - loss: 0.6089 - val_accuracy: 0.6931 - val_loss: 0.6037
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.7438 - loss: 0.5248 - val_accuracy: 0.7429 - val_loss: 0.5448
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.8096 - loss: 0.4110 - val_accuracy: 0.7658 - val_loss: 0.5753
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.8716 - loss: 0.3107 - val_accuracy: 0.7550 - val_loss: 0.7646
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.9072 - loss: 0.2205 - val_accuracy: 0.7443 - val_loss: 0.8407
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9358 - loss: 0.1478 - val_accuracy: 0.6380 - val_loss: 1.1846
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.9258 - loss: 0.1725 - val_accuracy: 0.6985 - val_loss: 0.7790
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.9524 - loss: 0.1366 - val_accuracy: 0.7389 - val_loss: 1.1887
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.9634 - loss: 0.0880 - val_accuracy: 0.7160 - val_loss: 1.0821
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.9712 - loss: 0.0714 - val_accuracy: 0.7147 - val_loss: 1.0426
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.9847 - loss: 0.0455 - val_accuracy: 0.7241 - val_loss: 1.2772
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.9815 - loss: 0.0488 - val_accuracy: 0.6851 - val_loss: 1.5160
# 🏁 Best epoch for Fold 5: 10
# ✅ Fold 5 test accuracy: 0.7579
#
# 🧪 Fold 6 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.5898 - loss: 0.8914 - val_accuracy: 0.5774 - val_loss: 0.6874
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6124 - loss: 0.6789 - val_accuracy: 0.5774 - val_loss: 0.6751
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6131 - loss: 0.6691 - val_accuracy: 0.6070 - val_loss: 0.6588
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.6346 - loss: 0.6264 - val_accuracy: 0.6743 - val_loss: 0.6511
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6713 - loss: 0.5991 - val_accuracy: 0.6756 - val_loss: 0.6559
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.7054 - loss: 0.5576 - val_accuracy: 0.6676 - val_loss: 0.6680
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.7523 - loss: 0.5022 - val_accuracy: 0.6756 - val_loss: 0.6851
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.7853 - loss: 0.4300 - val_accuracy: 0.6635 - val_loss: 0.7050
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.8291 - loss: 0.3671 - val_accuracy: 0.6810 - val_loss: 0.7300
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.8525 - loss: 0.2999 - val_accuracy: 0.6689 - val_loss: 0.9526
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.8978 - loss: 0.2302 - val_accuracy: 0.6824 - val_loss: 1.2177
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.9215 - loss: 0.1759 - val_accuracy: 0.6743 - val_loss: 1.3716
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.9406 - loss: 0.1506 - val_accuracy: 0.6918 - val_loss: 1.5232
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.9483 - loss: 0.1296 - val_accuracy: 0.6891 - val_loss: 1.6797
# 🏁 Best epoch for Fold 6: 4
# ✅ Fold 6 test accuracy: 0.6699
#
# 🧪 Fold 7 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 354ms/step - accuracy: 0.5642 - loss: 0.8851 - val_accuracy: 0.5882 - val_loss: 0.6819
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6191 - loss: 0.6731 - val_accuracy: 0.5882 - val_loss: 0.6785
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6162 - loss: 0.6697 - val_accuracy: 0.5882 - val_loss: 0.6811
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6152 - loss: 0.6694 - val_accuracy: 0.5882 - val_loss: 0.6811
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6191 - loss: 0.6700 - val_accuracy: 0.5882 - val_loss: 0.6880
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6191 - loss: 0.6848 - val_accuracy: 0.5882 - val_loss: 0.6848
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6191 - loss: 0.6804 - val_accuracy: 0.5882 - val_loss: 0.6824
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6191 - loss: 0.6770 - val_accuracy: 0.5882 - val_loss: 0.6808
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6191 - loss: 0.6744 - val_accuracy: 0.5882 - val_loss: 0.6797
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6191 - loss: 0.6724 - val_accuracy: 0.5882 - val_loss: 0.6789
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6191 - loss: 0.6708 - val_accuracy: 0.5882 - val_loss: 0.6783
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6191 - loss: 0.6696 - val_accuracy: 0.5882 - val_loss: 0.6780
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6191 - loss: 0.6686 - val_accuracy: 0.5882 - val_loss: 0.6777
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6191 - loss: 0.6679 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6191 - loss: 0.6673 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6191 - loss: 0.6668 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6191 - loss: 0.6665 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6191 - loss: 0.6662 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6191 - loss: 0.6660 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6191 - loss: 0.6658 - val_accuracy: 0.5882 - val_loss: 0.6777
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6191 - loss: 0.6656 - val_accuracy: 0.5882 - val_loss: 0.6777
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6191 - loss: 0.6655 - val_accuracy: 0.5882 - val_loss: 0.6778
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6191 - loss: 0.6654 - val_accuracy: 0.5882 - val_loss: 0.6778
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6191 - loss: 0.6653 - val_accuracy: 0.5882 - val_loss: 0.6778
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6191 - loss: 0.6653 - val_accuracy: 0.5882 - val_loss: 0.6779
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6191 - loss: 0.6652 - val_accuracy: 0.5882 - val_loss: 0.6779
# 🏁 Best epoch for Fold 7: 16
# ✅ Fold 7 test accuracy: 0.6019
#
# 🧪 Fold 8 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 345ms/step - accuracy: 0.5763 - loss: 0.8475 - val_accuracy: 0.5908 - val_loss: 0.6779
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6155 - loss: 0.6683 - val_accuracy: 0.5908 - val_loss: 0.6772
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6109 - loss: 0.6734 - val_accuracy: 0.6272 - val_loss: 0.6531
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6585 - loss: 0.6350 - val_accuracy: 0.6864 - val_loss: 0.6272
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.7648 - loss: 0.5345 - val_accuracy: 0.7308 - val_loss: 0.5949
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.8240 - loss: 0.4219 - val_accuracy: 0.8116 - val_loss: 0.4589
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.8626 - loss: 0.3159 - val_accuracy: 0.7954 - val_loss: 0.4992
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.8759 - loss: 0.3050 - val_accuracy: 0.8264 - val_loss: 0.4370
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.8904 - loss: 0.2670 - val_accuracy: 0.8371 - val_loss: 0.4390
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.9092 - loss: 0.2250 - val_accuracy: 0.8520 - val_loss: 0.3954
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.9218 - loss: 0.1940 - val_accuracy: 0.8573 - val_loss: 0.3992
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.9384 - loss: 0.1507 - val_accuracy: 0.8466 - val_loss: 0.4762
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.9451 - loss: 0.1153 - val_accuracy: 0.8439 - val_loss: 0.5248
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.9588 - loss: 0.0926 - val_accuracy: 0.8223 - val_loss: 0.5450
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9657 - loss: 0.0831 - val_accuracy: 0.7618 - val_loss: 0.6878
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.9611 - loss: 0.0901 - val_accuracy: 0.8223 - val_loss: 0.6178
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 333ms/step - accuracy: 0.9691 - loss: 0.0794 - val_accuracy: 0.8197 - val_loss: 0.7401
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9686 - loss: 0.0760 - val_accuracy: 0.8291 - val_loss: 0.8737
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.9712 - loss: 0.0659 - val_accuracy: 0.7968 - val_loss: 1.1883
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.9777 - loss: 0.0564 - val_accuracy: 0.8479 - val_loss: 0.6663
# 🏁 Best epoch for Fold 8: 10
# ✅ Fold 8 test accuracy: 0.8762
#
# 🧪 Fold 9 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6177 - loss: 0.9853 - val_accuracy: 0.5922 - val_loss: 0.6773
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6206 - loss: 0.6642 - val_accuracy: 0.5922 - val_loss: 0.6753
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6206 - loss: 0.6625 - val_accuracy: 0.5922 - val_loss: 0.6888
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6206 - loss: 0.6651 - val_accuracy: 0.5922 - val_loss: 0.6796
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6206 - loss: 0.6473 - val_accuracy: 0.5922 - val_loss: 0.6456
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6206 - loss: 0.6132 - val_accuracy: 0.5922 - val_loss: 0.6507
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6206 - loss: 0.6028 - val_accuracy: 0.5922 - val_loss: 0.6690
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6206 - loss: 0.5630 - val_accuracy: 0.5922 - val_loss: 0.7270
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.7165 - loss: 0.5190 - val_accuracy: 0.6824 - val_loss: 0.6825
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.7948 - loss: 0.4685 - val_accuracy: 0.7416 - val_loss: 0.6830
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.8494 - loss: 0.4138 - val_accuracy: 0.7577 - val_loss: 0.6579
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.8719 - loss: 0.3681 - val_accuracy: 0.7618 - val_loss: 0.6880
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.8920 - loss: 0.3423 - val_accuracy: 0.7550 - val_loss: 0.8192
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.8957 - loss: 0.3256 - val_accuracy: 0.7443 - val_loss: 0.6846
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9274 - loss: 0.2989 - val_accuracy: 0.7685 - val_loss: 0.8293
# 🏁 Best epoch for Fold 9: 5
# ✅ Fold 9 test accuracy: 0.6019
#
# 🧪 Fold 10 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.5729 - loss: 0.8940 - val_accuracy: 0.5922 - val_loss: 0.6764
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6145 - loss: 0.6765 - val_accuracy: 0.5922 - val_loss: 0.6765
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6145 - loss: 0.6747 - val_accuracy: 0.5922 - val_loss: 0.6651
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6150 - loss: 0.6699 - val_accuracy: 0.6070 - val_loss: 0.6546
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6124 - loss: 0.6636 - val_accuracy: 0.6433 - val_loss: 0.6426
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6614 - loss: 0.6145 - val_accuracy: 0.6528 - val_loss: 0.6393
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.7188 - loss: 0.5484 - val_accuracy: 0.6460 - val_loss: 0.7077
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.7960 - loss: 0.4319 - val_accuracy: 0.6541 - val_loss: 0.8359
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.8358 - loss: 0.3438 - val_accuracy: 0.6420 - val_loss: 0.9810
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.8844 - loss: 0.2569 - val_accuracy: 0.6366 - val_loss: 1.1392
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.9028 - loss: 0.2047 - val_accuracy: 0.6433 - val_loss: 1.2015
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.9314 - loss: 0.1422 - val_accuracy: 0.6326 - val_loss: 1.3486
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.9393 - loss: 0.1284 - val_accuracy: 0.6164 - val_loss: 1.2353
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9514 - loss: 0.0929 - val_accuracy: 0.6299 - val_loss: 1.2873
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.9601 - loss: 0.0646 - val_accuracy: 0.6393 - val_loss: 1.8304
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.9670 - loss: 0.0467 - val_accuracy: 0.6245 - val_loss: 2.1746
# 🏁 Best epoch for Fold 10: 6
# ✅ Fold 10 test accuracy: 0.6481
#
# 📌 Mean optimal epoch across folds: 8

# %%
# Cell Block 5: Final Model Training on data again, but for ep_mean Epochs (no validation needed)

# Build your TF datasets
train_final_ds = preprocess(X_rest, y_rest)        # ALL data used in K-Fold
test_final_ds  = preprocess(X_holdout, y_holdout)  # NEVER seen during CV

# Instantiate & train your final model
final_model = create_model()
final_model.fit(
    train_final_ds,
    epochs=ep_mean,
    verbose=1
)

# Evaluate once—only on the true hold-out set
final_results = final_model.evaluate(
    test_final_ds,
    verbose=1
)
print("Hold-out test loss & accuracy:", final_results)
# Out:
# Epoch 1/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 49s 410ms/step - accuracy: 0.5871 - loss: 0.8714
# Epoch 2/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 364ms/step - accuracy: 0.6827 - loss: 0.6130
# Epoch 3/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 362ms/step - accuracy: 0.7770 - loss: 0.4751
# Epoch 4/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 362ms/step - accuracy: 0.8705 - loss: 0.3344
# Epoch 5/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 361ms/step - accuracy: 0.8946 - loss: 0.2659
# Epoch 6/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 363ms/step - accuracy: 0.9140 - loss: 0.2273
# Epoch 7/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 45s 386ms/step - accuracy: 0.9235 - loss: 0.1883
# Epoch 8/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 44s 375ms/step - accuracy: 0.9221 - loss: 0.1854
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - accuracy: 0.8775 - loss: 0.3760
# Hold-out test loss & accuracy: [0.38583236932754517, 0.8644067645072937]

# %%
# Cell Block 5: Final Evaluation

# Evaluate final model on the 20% test set
final_test_loss, final_test_acc = final_model.evaluate(test_final_ds, verbose=0)

# Report both results
print(f"\n📊 {k}-Fold Test Accuracy: {np.mean(all_test_accuracies):.4f} ± {np.std(all_test_accuracies):.4f}")
print(f"🏁 Final model test accuracy (trained on hold-out): {final_test_acc:.4f}")
# Out:
# 📊 10-Fold Test Accuracy: 0.6848 ± 0.0884
# 🏁 Final model test accuracy (trained on hold-out): 0.8644

# %%
import numpy as np
from sklearn.metrics import precision_score, roc_curve, auc, f1_score, recall_score
import matplotlib.pyplot as plt

# 1. Extract true labels and model scores from your hold-out dataset
y_true = np.concatenate([y.numpy() for x, y in test_final_ds], axis=0)
y_pred_prob = final_model.predict(test_final_ds)

# 2. If your model outputs two probabilities (one per class), take the “positive” class
if y_pred_prob.ndim > 1 and y_pred_prob.shape[1] > 1:
    y_scores = y_pred_prob[:, 1]
else:
    y_scores = y_pred_prob.ravel()

# 3. Compute ROC curve metrics
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# 4. Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr)               # ROC curve
plt.plot([0, 1], [0, 1], linestyle='--')  # chance line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (AUC = {roc_auc:.2f})')
plt.show()



# 1. Turn your predicted probabilities into binary preds (threshold = 0.5)
y_pred = (y_scores >= 0.5).astype(int)

# 2. Compute precision, recall, F1
precision = precision_score(y_true, y_pred)
recall    = recall_score(y_true, y_pred)
f1        = f1_score(y_true, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step
# Precision: 0.86
# Recall:    0.79
# F1 Score:  0.82
