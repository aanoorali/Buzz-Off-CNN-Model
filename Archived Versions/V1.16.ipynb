# %% [markdown]
# Varroa Mite Detection 1.16 Red Shift and Blur

# %%
# Cell Block 1: Importing Libraries
import os
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold, train_test_split
import numpy as np
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Cell Block 2: Load Data and Preprocess

df = pd.read_csv('labels_augmented.csv')

df['filename'] = df['filename'].apply(lambda fn: os.path.join('rotations_flips', fn.strip()))

filepaths = df['filename'].values
labels = df['has_mite'].values

# %%
# Cell Block 3: Splitting Data

X_rest, X_holdout, y_rest, y_holdout = train_test_split(
    filepaths, labels,
    test_size=0.10,
    stratify=labels,
    random_state=42
)

# %%
# Cell Block 3: K-Fold Cross-Validation

# Early stopping callback
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    # min_delta=1e-4,
    restore_best_weights=True
)

k = 10  # Number of folds
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

fold = 1
all_test_accuracies = []
best_epochs = []

# Model creation function
def create_model():
    model = models.Sequential([
        layers.Input(shape=(224, 224, 3)),
        layers.Conv2D(32, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Guassian kernel function
def gaussian_kernel(size: int, sigma: float):
    x = tf.range(-size // 2 + 1, size // 2 + 1, dtype=tf.float32)
    xx, yy = tf.meshgrid(x, x)
    kernel = tf.exp(-(xx**2 + yy**2) / (2.0 * sigma**2))
    kernel = kernel / tf.reduce_sum(kernel)
    return kernel

def apply_gaussian_blur(image, kernel_size=5, sigma=1.0):
    kernel = gaussian_kernel(kernel_size, sigma)                 # [5, 5]
    kernel = kernel[:, :, tf.newaxis, tf.newaxis]                # [5, 5, 1, 1]
    kernel = tf.repeat(kernel, repeats=3, axis=2)                # [5, 5, 3, 1] ✅ CORRECT shape
    image = tf.expand_dims(image, 0)                             # [1, H, W, 3]
    blurred = tf.nn.depthwise_conv2d(image, kernel, strides=[1,1,1,1], padding='SAME')
    
    return tf.squeeze(blurred, axis=0)

# Preprocessing function
def preprocess(paths, labels):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    def load_img(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [224, 224])
        img = img / 255.0

        # 1) Apply Gaussian blur
        img = apply_gaussian_blur(img, kernel_size=5, sigma=1.0)

        # # 2) Boost blue channel
        # img = tf.clip_by_value(img + [0.0, 0.0, 0.2], 0.0, 1.0) 

        # # 3) Increase contrast
        # img = tf.image.adjust_contrast(img, 2.0) 

        # 4). Boost red channel
        img = tf.clip_by_value(img + [0.2, 0.0, 0.0], 0.0, 1.0)
        
        return img, label

    return ds.map(load_img).batch(32).prefetch(tf.data.AUTOTUNE)

for trainval_index, test_index in skf.split(filepaths, labels):
    print(f"\n🧪 Fold {fold} -----------------------------")

    # Split into trainval and test
    X_trainval, X_test = filepaths[trainval_index], filepaths[test_index]
    y_trainval, y_test = labels[trainval_index], labels[test_index]

    # Further split trainval into train and val (e.g. 80/20)
    val_split = int(0.8 * len(X_trainval))
    X_train, X_val = X_trainval[:val_split], X_trainval[val_split:]
    y_train, y_val = y_trainval[:val_split], y_trainval[val_split:]


    # Preprocess each split
    train_ds = preprocess(X_train, y_train)
    val_ds = preprocess(X_val, y_val)
    test_ds = preprocess(X_test, y_test)



    # Train model with early stopping
    model = create_model()
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[earlystop],
        verbose=1
    )

    # Record best epoch (smallest val_loss)
    best_epoch = np.argmin(history.history['val_loss']) + 1
    best_epochs.append(best_epoch)
    print(f"🏁 Best epoch for Fold {fold}: {best_epoch}")

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    all_test_accuracies.append(test_acc)
    print(f"✅ Fold {fold} test accuracy: {test_acc:.4f}")

    fold += 1

# Calculate mean best epoch
ep_mean = int(np.round(np.mean(best_epochs)))
print(f"\n📌 Mean optimal epoch across folds: {ep_mean}")
# Out:
# 🧪 Fold 1 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 413ms/step - accuracy: 0.5856 - loss: 0.7610 - val_accuracy: 0.5922 - val_loss: 0.6904
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 420ms/step - accuracy: 0.6091 - loss: 0.6716 - val_accuracy: 0.5922 - val_loss: 0.6774
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 389ms/step - accuracy: 0.6091 - loss: 0.6745 - val_accuracy: 0.5922 - val_loss: 0.6785
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 388ms/step - accuracy: 0.6025 - loss: 0.6727 - val_accuracy: 0.5922 - val_loss: 0.6816
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 386ms/step - accuracy: 0.6091 - loss: 0.6746 - val_accuracy: 0.5922 - val_loss: 0.6757
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6091 - loss: 0.6794 - val_accuracy: 0.5922 - val_loss: 0.6756
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6149 - loss: 0.6716 - val_accuracy: 0.5922 - val_loss: 0.6759
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6091 - loss: 0.6719 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6091 - loss: 0.6729 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 396ms/step - accuracy: 0.6091 - loss: 0.6725 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 432ms/step - accuracy: 0.6091 - loss: 0.6721 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 406ms/step - accuracy: 0.6091 - loss: 0.6719 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 399ms/step - accuracy: 0.6091 - loss: 0.6716 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 395ms/step - accuracy: 0.6091 - loss: 0.6714 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 413ms/step - accuracy: 0.6091 - loss: 0.6713 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.6091 - loss: 0.6711 - val_accuracy: 0.5922 - val_loss: 0.6761
# 🏁 Best epoch for Fold 1: 6
# ✅ Fold 1 test accuracy: 0.6029
#
# 🧪 Fold 2 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 397ms/step - accuracy: 0.6141 - loss: 0.7467 - val_accuracy: 0.5868 - val_loss: 0.6786
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 396ms/step - accuracy: 0.6182 - loss: 0.6679 - val_accuracy: 0.5868 - val_loss: 0.6776
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.6182 - loss: 0.6690 - val_accuracy: 0.5868 - val_loss: 0.6895
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 401ms/step - accuracy: 0.6182 - loss: 0.6869 - val_accuracy: 0.5868 - val_loss: 0.6861
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 415ms/step - accuracy: 0.6182 - loss: 0.6823 - val_accuracy: 0.5868 - val_loss: 0.6837
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 409ms/step - accuracy: 0.6182 - loss: 0.6787 - val_accuracy: 0.5868 - val_loss: 0.6819
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 416ms/step - accuracy: 0.6182 - loss: 0.6759 - val_accuracy: 0.5868 - val_loss: 0.6806
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 434ms/step - accuracy: 0.6182 - loss: 0.6738 - val_accuracy: 0.5868 - val_loss: 0.6797
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 413ms/step - accuracy: 0.6182 - loss: 0.6721 - val_accuracy: 0.5868 - val_loss: 0.6790
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 399ms/step - accuracy: 0.6182 - loss: 0.6707 - val_accuracy: 0.5868 - val_loss: 0.6786
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 399ms/step - accuracy: 0.6182 - loss: 0.6696 - val_accuracy: 0.5868 - val_loss: 0.6783
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 406ms/step - accuracy: 0.6182 - loss: 0.6688 - val_accuracy: 0.5868 - val_loss: 0.6781
# 🏁 Best epoch for Fold 2: 2
# ✅ Fold 2 test accuracy: 0.6029
#
# 🧪 Fold 3 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 415ms/step - accuracy: 0.5843 - loss: 0.7844 - val_accuracy: 0.5828 - val_loss: 0.6913
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 418ms/step - accuracy: 0.6173 - loss: 0.6893 - val_accuracy: 0.5828 - val_loss: 0.6879
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 412ms/step - accuracy: 0.6173 - loss: 0.6845 - val_accuracy: 0.5828 - val_loss: 0.6853
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 432ms/step - accuracy: 0.6173 - loss: 0.6806 - val_accuracy: 0.5828 - val_loss: 0.6835
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 420ms/step - accuracy: 0.6173 - loss: 0.6776 - val_accuracy: 0.5828 - val_loss: 0.6821
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 421ms/step - accuracy: 0.6173 - loss: 0.6752 - val_accuracy: 0.5828 - val_loss: 0.6811
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 402ms/step - accuracy: 0.6173 - loss: 0.6733 - val_accuracy: 0.5828 - val_loss: 0.6804
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 437ms/step - accuracy: 0.6173 - loss: 0.6717 - val_accuracy: 0.5828 - val_loss: 0.6799
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 414ms/step - accuracy: 0.6173 - loss: 0.6705 - val_accuracy: 0.5828 - val_loss: 0.6796
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6173 - loss: 0.6696 - val_accuracy: 0.5828 - val_loss: 0.6795
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6173 - loss: 0.6688 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 406ms/step - accuracy: 0.6173 - loss: 0.6682 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.6173 - loss: 0.6677 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 399ms/step - accuracy: 0.6173 - loss: 0.6673 - val_accuracy: 0.5828 - val_loss: 0.6795
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 403ms/step - accuracy: 0.6173 - loss: 0.6670 - val_accuracy: 0.5828 - val_loss: 0.6795
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.6173 - loss: 0.6668 - val_accuracy: 0.5828 - val_loss: 0.6796
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 399ms/step - accuracy: 0.6173 - loss: 0.6666 - val_accuracy: 0.5828 - val_loss: 0.6797
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.6173 - loss: 0.6664 - val_accuracy: 0.5828 - val_loss: 0.6798
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 402ms/step - accuracy: 0.6173 - loss: 0.6663 - val_accuracy: 0.5828 - val_loss: 0.6799
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.6173 - loss: 0.6662 - val_accuracy: 0.5828 - val_loss: 0.6799
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 396ms/step - accuracy: 0.6173 - loss: 0.6661 - val_accuracy: 0.5828 - val_loss: 0.6800
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 399ms/step - accuracy: 0.6173 - loss: 0.6660 - val_accuracy: 0.5828 - val_loss: 0.6801
# 🏁 Best epoch for Fold 3: 12
# ✅ Fold 3 test accuracy: 0.6029
#
# 🧪 Fold 4 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 402ms/step - accuracy: 0.5727 - loss: 0.7802 - val_accuracy: 0.5814 - val_loss: 0.6879
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 401ms/step - accuracy: 0.6127 - loss: 0.6774 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.6183 - loss: 0.6701 - val_accuracy: 0.5814 - val_loss: 0.6804
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 401ms/step - accuracy: 0.6183 - loss: 0.6728 - val_accuracy: 0.5814 - val_loss: 0.6894
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6183 - loss: 0.6863 - val_accuracy: 0.5814 - val_loss: 0.6863
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6183 - loss: 0.6818 - val_accuracy: 0.5814 - val_loss: 0.6842
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6183 - loss: 0.6783 - val_accuracy: 0.5814 - val_loss: 0.6827
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6183 - loss: 0.6756 - val_accuracy: 0.5814 - val_loss: 0.6816
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 385ms/step - accuracy: 0.6183 - loss: 0.6735 - val_accuracy: 0.5814 - val_loss: 0.6808
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6183 - loss: 0.6718 - val_accuracy: 0.5814 - val_loss: 0.6804
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 412ms/step - accuracy: 0.6183 - loss: 0.6705 - val_accuracy: 0.5814 - val_loss: 0.6801
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6183 - loss: 0.6694 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 403ms/step - accuracy: 0.6183 - loss: 0.6686 - val_accuracy: 0.5814 - val_loss: 0.6798
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6183 - loss: 0.6679 - val_accuracy: 0.5814 - val_loss: 0.6798
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 403ms/step - accuracy: 0.6183 - loss: 0.6674 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6183 - loss: 0.6670 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 407ms/step - accuracy: 0.6183 - loss: 0.6667 - val_accuracy: 0.5814 - val_loss: 0.6800
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6183 - loss: 0.6664 - val_accuracy: 0.5814 - val_loss: 0.6801
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6183 - loss: 0.6662 - val_accuracy: 0.5814 - val_loss: 0.6802
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6183 - loss: 0.6660 - val_accuracy: 0.5814 - val_loss: 0.6803
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6183 - loss: 0.6659 - val_accuracy: 0.5814 - val_loss: 0.6804
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 408ms/step - accuracy: 0.6183 - loss: 0.6658 - val_accuracy: 0.5814 - val_loss: 0.6805
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 403ms/step - accuracy: 0.6183 - loss: 0.6657 - val_accuracy: 0.5814 - val_loss: 0.6806
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 406ms/step - accuracy: 0.6183 - loss: 0.6656 - val_accuracy: 0.5814 - val_loss: 0.6807
# 🏁 Best epoch for Fold 4: 14
# ✅ Fold 4 test accuracy: 0.6029
#
# 🧪 Fold 5 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 398ms/step - accuracy: 0.5843 - loss: 0.7471 - val_accuracy: 0.5922 - val_loss: 0.6771
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6047 - loss: 0.6758 - val_accuracy: 0.5922 - val_loss: 0.6788
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6099 - loss: 0.6761 - val_accuracy: 0.5922 - val_loss: 0.6789
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6083 - loss: 0.6740 - val_accuracy: 0.5922 - val_loss: 0.6773
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6099 - loss: 0.6751 - val_accuracy: 0.5922 - val_loss: 0.6784
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6090 - loss: 0.6729 - val_accuracy: 0.5922 - val_loss: 0.6769
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6029 - loss: 0.6787 - val_accuracy: 0.5922 - val_loss: 0.6768
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.6099 - loss: 0.6735 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6099 - loss: 0.6730 - val_accuracy: 0.5922 - val_loss: 0.6781
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6099 - loss: 0.6730 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6099 - loss: 0.6702 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6099 - loss: 0.6695 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6099 - loss: 0.6693 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 386ms/step - accuracy: 0.6099 - loss: 0.6693 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6099 - loss: 0.6692 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6099 - loss: 0.6692 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6099 - loss: 0.6692 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.6099 - loss: 0.6692 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 404ms/step - accuracy: 0.6099 - loss: 0.6692 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 403ms/step - accuracy: 0.6099 - loss: 0.6692 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 443ms/step - accuracy: 0.6099 - loss: 0.6692 - val_accuracy: 0.5922 - val_loss: 0.6763
# 🏁 Best epoch for Fold 5: 11
# ✅ Fold 5 test accuracy: 0.6029
#
# 🧪 Fold 6 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 412ms/step - accuracy: 0.5838 - loss: 0.8331 - val_accuracy: 0.5774 - val_loss: 0.6890
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 404ms/step - accuracy: 0.6124 - loss: 0.6769 - val_accuracy: 0.5774 - val_loss: 0.6861
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6124 - loss: 0.6732 - val_accuracy: 0.5774 - val_loss: 0.6893
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 403ms/step - accuracy: 0.6124 - loss: 0.6861 - val_accuracy: 0.5774 - val_loss: 0.6862
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 404ms/step - accuracy: 0.6124 - loss: 0.6815 - val_accuracy: 0.5774 - val_loss: 0.6842
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 402ms/step - accuracy: 0.6124 - loss: 0.6781 - val_accuracy: 0.5774 - val_loss: 0.6828
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 404ms/step - accuracy: 0.6124 - loss: 0.6755 - val_accuracy: 0.5774 - val_loss: 0.6820
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6124 - loss: 0.6736 - val_accuracy: 0.5774 - val_loss: 0.6815
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 403ms/step - accuracy: 0.6124 - loss: 0.6721 - val_accuracy: 0.5774 - val_loss: 0.6812
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6124 - loss: 0.6711 - val_accuracy: 0.5774 - val_loss: 0.6811
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 404ms/step - accuracy: 0.6124 - loss: 0.6702 - val_accuracy: 0.5774 - val_loss: 0.6811
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 403ms/step - accuracy: 0.6124 - loss: 0.6696 - val_accuracy: 0.5774 - val_loss: 0.6812
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 402ms/step - accuracy: 0.6124 - loss: 0.6692 - val_accuracy: 0.5774 - val_loss: 0.6814
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6124 - loss: 0.6688 - val_accuracy: 0.5774 - val_loss: 0.6815
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 403ms/step - accuracy: 0.6124 - loss: 0.6686 - val_accuracy: 0.5774 - val_loss: 0.6817
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 410ms/step - accuracy: 0.6124 - loss: 0.6684 - val_accuracy: 0.5774 - val_loss: 0.6819
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 406ms/step - accuracy: 0.6124 - loss: 0.6682 - val_accuracy: 0.5774 - val_loss: 0.6820
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 384ms/step - accuracy: 0.6124 - loss: 0.6681 - val_accuracy: 0.5774 - val_loss: 0.6822
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6124 - loss: 0.6681 - val_accuracy: 0.5774 - val_loss: 0.6823
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6124 - loss: 0.6680 - val_accuracy: 0.5774 - val_loss: 0.6824
# 🏁 Best epoch for Fold 6: 10
# ✅ Fold 6 test accuracy: 0.6019
#
# 🧪 Fold 7 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 377ms/step - accuracy: 0.5909 - loss: 0.8500 - val_accuracy: 0.5882 - val_loss: 0.6809
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.6191 - loss: 0.6700 - val_accuracy: 0.5882 - val_loss: 0.6782
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6179 - loss: 0.6716 - val_accuracy: 0.5882 - val_loss: 0.6792
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.6178 - loss: 0.6725 - val_accuracy: 0.5882 - val_loss: 0.6774
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6191 - loss: 0.6690 - val_accuracy: 0.5882 - val_loss: 0.6780
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6191 - loss: 0.6707 - val_accuracy: 0.5882 - val_loss: 0.6778
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.6191 - loss: 0.6697 - val_accuracy: 0.5882 - val_loss: 0.6785
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6191 - loss: 0.6697 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6191 - loss: 0.6675 - val_accuracy: 0.5882 - val_loss: 0.6866
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6191 - loss: 0.6829 - val_accuracy: 0.5882 - val_loss: 0.6837
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6191 - loss: 0.6788 - val_accuracy: 0.5882 - val_loss: 0.6817
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.6191 - loss: 0.6757 - val_accuracy: 0.5882 - val_loss: 0.6802
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6191 - loss: 0.6734 - val_accuracy: 0.5882 - val_loss: 0.6792
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6191 - loss: 0.6716 - val_accuracy: 0.5882 - val_loss: 0.6786
# 🏁 Best epoch for Fold 7: 4
# ✅ Fold 7 test accuracy: 0.6019
#
# 🧪 Fold 8 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 380ms/step - accuracy: 0.5821 - loss: 0.8298 - val_accuracy: 0.5908 - val_loss: 0.6795
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6119 - loss: 0.6712 - val_accuracy: 0.5908 - val_loss: 0.6752
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.6148 - loss: 0.6747 - val_accuracy: 0.5908 - val_loss: 0.6754
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6148 - loss: 0.6739 - val_accuracy: 0.5908 - val_loss: 0.6771
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6148 - loss: 0.6738 - val_accuracy: 0.5908 - val_loss: 0.6810
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6148 - loss: 0.6750 - val_accuracy: 0.5908 - val_loss: 0.6782
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6148 - loss: 0.6745 - val_accuracy: 0.5908 - val_loss: 0.6801
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6153 - loss: 0.6757 - val_accuracy: 0.5908 - val_loss: 0.6811
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6148 - loss: 0.6758 - val_accuracy: 0.5908 - val_loss: 0.6773
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6148 - loss: 0.6707 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6148 - loss: 0.6690 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6148 - loss: 0.6699 - val_accuracy: 0.5908 - val_loss: 0.6768
# 🏁 Best epoch for Fold 8: 2
# ✅ Fold 8 test accuracy: 0.6019
#
# 🧪 Fold 9 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 385ms/step - accuracy: 0.6208 - loss: 0.8496 - val_accuracy: 0.5922 - val_loss: 0.6767
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6046 - loss: 0.6721 - val_accuracy: 0.5922 - val_loss: 0.6909
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6206 - loss: 0.6888 - val_accuracy: 0.5922 - val_loss: 0.6867
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6206 - loss: 0.6835 - val_accuracy: 0.5922 - val_loss: 0.6837
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6206 - loss: 0.6795 - val_accuracy: 0.5922 - val_loss: 0.6815
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6206 - loss: 0.6763 - val_accuracy: 0.5922 - val_loss: 0.6799
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6206 - loss: 0.6739 - val_accuracy: 0.5922 - val_loss: 0.6787
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6206 - loss: 0.6720 - val_accuracy: 0.5922 - val_loss: 0.6778
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6206 - loss: 0.6704 - val_accuracy: 0.5922 - val_loss: 0.6772
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6206 - loss: 0.6692 - val_accuracy: 0.5922 - val_loss: 0.6768
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6206 - loss: 0.6683 - val_accuracy: 0.5922 - val_loss: 0.6765
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6206 - loss: 0.6675 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6206 - loss: 0.6669 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6206 - loss: 0.6665 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.6206 - loss: 0.6661 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6206 - loss: 0.6658 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6206 - loss: 0.6655 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6206 - loss: 0.6653 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6206 - loss: 0.6652 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6206 - loss: 0.6650 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 389ms/step - accuracy: 0.6206 - loss: 0.6649 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 384ms/step - accuracy: 0.6206 - loss: 0.6648 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6206 - loss: 0.6647 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6206 - loss: 0.6647 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6206 - loss: 0.6646 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6206 - loss: 0.6646 - val_accuracy: 0.5922 - val_loss: 0.6763
# 🏁 Best epoch for Fold 9: 16
# ✅ Fold 9 test accuracy: 0.6019
#
# 🧪 Fold 10 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6013 - loss: 0.7349 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 385ms/step - accuracy: 0.6145 - loss: 0.6765 - val_accuracy: 0.5922 - val_loss: 0.6904
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6145 - loss: 0.6884 - val_accuracy: 0.5922 - val_loss: 0.6863
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6145 - loss: 0.6835 - val_accuracy: 0.5922 - val_loss: 0.6834
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6145 - loss: 0.6798 - val_accuracy: 0.5922 - val_loss: 0.6812
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6145 - loss: 0.6769 - val_accuracy: 0.5922 - val_loss: 0.6796
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6145 - loss: 0.6747 - val_accuracy: 0.5922 - val_loss: 0.6785
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6145 - loss: 0.6730 - val_accuracy: 0.5922 - val_loss: 0.6776
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6145 - loss: 0.6717 - val_accuracy: 0.5922 - val_loss: 0.6771
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6145 - loss: 0.6707 - val_accuracy: 0.5922 - val_loss: 0.6767
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6145 - loss: 0.6699 - val_accuracy: 0.5922 - val_loss: 0.6764
# 🏁 Best epoch for Fold 10: 1
# ✅ Fold 10 test accuracy: 0.6019
#
# 📌 Mean optimal epoch across folds: 8

# %%
# Cell Block 5: Final Model Training on data again, but for ep_mean Epochs (no validation needed)

# Build your TF datasets
train_final_ds = preprocess(X_rest, y_rest)        # ALL data used in K-Fold
test_final_ds  = preprocess(X_holdout, y_holdout)  # NEVER seen during CV

# Instantiate & train your final model
final_model = create_model()
final_model.fit(
    train_final_ds,
    epochs=ep_mean,
    verbose=1
)

# Evaluate once—only on the true hold-out set
final_results = final_model.evaluate(
    test_final_ds,
    verbose=1
)
print("Hold-out test loss & accuracy:", final_results)
# Out:
# Epoch 1/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 49s 417ms/step - accuracy: 0.5805 - loss: 0.7929
# Epoch 2/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - accuracy: 0.6001 - loss: 0.6674
# Epoch 3/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 47s 407ms/step - accuracy: 0.6090 - loss: 0.6558
# Epoch 4/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 47s 409ms/step - accuracy: 0.6718 - loss: 0.6201
# Epoch 5/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 48s 416ms/step - accuracy: 0.7471 - loss: 0.5472
# Epoch 6/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - accuracy: 0.7896 - loss: 0.4819
# Epoch 7/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 48s 410ms/step - accuracy: 0.8371 - loss: 0.3963
# Epoch 8/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 48s 412ms/step - accuracy: 0.8494 - loss: 0.3663
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.6535 - loss: 0.6157
# Hold-out test loss & accuracy: [0.6011191606521606, 0.6828086972236633]

# %%
# Cell Block 5: Final Evaluation

# Evaluate final model on the 20% test set
final_test_loss, final_test_acc = final_model.evaluate(test_final_ds, verbose=0)

# Report both results
print(f"\n📊 {k}-Fold Test Accuracy: {np.mean(all_test_accuracies):.4f} ± {np.std(all_test_accuracies):.4f}")
print(f"🏁 Final model test accuracy (trained on hold-out): {final_test_acc:.4f}")
# Out:
# 📊 10-Fold Test Accuracy: 0.6024 ± 0.0005
# 🏁 Final model test accuracy (trained on hold-out): 0.6828

# %%
import numpy as np
from sklearn.metrics import precision_score, roc_curve, auc, f1_score, recall_score
import matplotlib.pyplot as plt

# 1. Extract true labels and model scores from your hold-out dataset
y_true = np.concatenate([y.numpy() for x, y in test_final_ds], axis=0)
y_pred_prob = final_model.predict(test_final_ds)

# 2. If your model outputs two probabilities (one per class), take the “positive” class
if y_pred_prob.ndim > 1 and y_pred_prob.shape[1] > 1:
    y_scores = y_pred_prob[:, 1]
else:
    y_scores = y_pred_prob.ravel()

# 3. Compute ROC curve metrics
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# 4. Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr)               # ROC curve
plt.plot([0, 1], [0, 1], linestyle='--')  # chance line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (AUC = {roc_auc:.2f})')
plt.show()



# 1. Turn your predicted probabilities into binary preds (threshold = 0.5)
y_pred = (y_scores >= 0.5).astype(int)

# 2. Compute precision, recall, F1
precision = precision_score(y_true, y_pred)
recall    = recall_score(y_true, y_pred)
f1        = f1_score(y_true, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step
# Precision: 0.58
# Recall:    0.75
# F1 Score:  0.65
