# %% [markdown]
# Varroa Mite Detection 1.8 Blue Shift the Images with Holdout and ROC etc;

# %%
# Cell Block 1: Importing Libraries
import os
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold, train_test_split
import numpy as np
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Cell Block 2: Load Data and Preprocess

df = pd.read_csv('labels_augmented.csv')

df['filename'] = df['filename'].apply(lambda fn: os.path.join('rotations_flips', fn.strip()))

filepaths = df['filename'].values
labels = df['has_mite'].values

# %%
# Cell Block 3: Splitting Data

X_rest, X_holdout, y_rest, y_holdout = train_test_split(
    filepaths, labels,
    test_size=0.10,
    stratify=labels,
    random_state=42
)

# %%
# Cell Block 3: K-Fold Cross-Validation

# Early stopping callback
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    # min_delta=1e-4,
    restore_best_weights=True
)

k = 10  # Number of folds
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

fold = 1
all_test_accuracies = []
best_epochs = []

# Model creation function
def create_model():
    model = models.Sequential([
        layers.Input(shape=(224, 224, 3)),
        layers.Conv2D(32, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Preprocessing function
def preprocess(paths, labels):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    def load_img(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [224, 224])
        img = img / 255.0

        # 1) Boost blue channel
        img = tf.clip_by_value(img + [0.0, 0.0, 0.2], 0.0, 1.0)
        
        return img, label

    return ds.map(load_img).batch(32).prefetch(tf.data.AUTOTUNE)

for trainval_index, test_index in skf.split(filepaths, labels):
    print(f"\n🧪 Fold {fold} -----------------------------")

    # Split into trainval and test
    X_trainval, X_test = filepaths[trainval_index], filepaths[test_index]
    y_trainval, y_test = labels[trainval_index], labels[test_index]

    # Further split trainval into train and val (e.g. 80/20)
    val_split = int(0.8 * len(X_trainval))
    X_train, X_val = X_trainval[:val_split], X_trainval[val_split:]
    y_train, y_val = y_trainval[:val_split], y_trainval[val_split:]


    # Preprocess each split
    train_ds = preprocess(X_train, y_train)
    val_ds = preprocess(X_val, y_val)
    test_ds = preprocess(X_test, y_test)



    # Train model with early stopping
    model = create_model()
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[earlystop],
        verbose=1
    )

    # Record best epoch (smallest val_loss)
    best_epoch = np.argmin(history.history['val_loss']) + 1
    best_epochs.append(best_epoch)
    print(f"🏁 Best epoch for Fold {fold}: {best_epoch}")

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    all_test_accuracies.append(test_acc)
    print(f"✅ Fold {fold} test accuracy: {test_acc:.4f}")

    fold += 1

# Calculate mean best epoch
ep_mean = int(np.round(np.mean(best_epochs)))
print(f"\n📌 Mean optimal epoch across folds: {ep_mean}")
# Out:
# 🧪 Fold 1 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 409ms/step - accuracy: 0.5887 - loss: 0.8490 - val_accuracy: 0.5922 - val_loss: 0.6793
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6091 - loss: 0.6758 - val_accuracy: 0.5922 - val_loss: 0.6776
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.6091 - loss: 0.6744 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.6091 - loss: 0.6735 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.6017 - loss: 0.6734 - val_accuracy: 0.5922 - val_loss: 0.6882
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 396ms/step - accuracy: 0.6091 - loss: 0.6862 - val_accuracy: 0.5922 - val_loss: 0.6849
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 396ms/step - accuracy: 0.6091 - loss: 0.6824 - val_accuracy: 0.5922 - val_loss: 0.6825
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.6091 - loss: 0.6795 - val_accuracy: 0.5922 - val_loss: 0.6807
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 403ms/step - accuracy: 0.6091 - loss: 0.6773 - val_accuracy: 0.5922 - val_loss: 0.6793
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.6091 - loss: 0.6755 - val_accuracy: 0.5922 - val_loss: 0.6784
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 396ms/step - accuracy: 0.6091 - loss: 0.6741 - val_accuracy: 0.5922 - val_loss: 0.6776
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 396ms/step - accuracy: 0.6091 - loss: 0.6731 - val_accuracy: 0.5922 - val_loss: 0.6771
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.6091 - loss: 0.6723 - val_accuracy: 0.5922 - val_loss: 0.6767
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 395ms/step - accuracy: 0.6091 - loss: 0.6716 - val_accuracy: 0.5922 - val_loss: 0.6765
# 🏁 Best epoch for Fold 1: 4
# ✅ Fold 1 test accuracy: 0.6029
#
# 🧪 Fold 2 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 399ms/step - accuracy: 0.5843 - loss: 0.9066 - val_accuracy: 0.5868 - val_loss: 0.6783
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 402ms/step - accuracy: 0.6182 - loss: 0.6697 - val_accuracy: 0.5868 - val_loss: 0.6801
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.6182 - loss: 0.6701 - val_accuracy: 0.5868 - val_loss: 0.6837
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.6182 - loss: 0.6740 - val_accuracy: 0.5868 - val_loss: 0.6886
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.6182 - loss: 0.6857 - val_accuracy: 0.5868 - val_loss: 0.6855
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 396ms/step - accuracy: 0.6182 - loss: 0.6813 - val_accuracy: 0.5868 - val_loss: 0.6832
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 401ms/step - accuracy: 0.6182 - loss: 0.6780 - val_accuracy: 0.5868 - val_loss: 0.6815
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.6182 - loss: 0.6754 - val_accuracy: 0.5868 - val_loss: 0.6803
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 401ms/step - accuracy: 0.6182 - loss: 0.6733 - val_accuracy: 0.5868 - val_loss: 0.6795
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 403ms/step - accuracy: 0.6182 - loss: 0.6717 - val_accuracy: 0.5868 - val_loss: 0.6789
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.6182 - loss: 0.6704 - val_accuracy: 0.5868 - val_loss: 0.6785
# 🏁 Best epoch for Fold 2: 1
# ✅ Fold 2 test accuracy: 0.6029
#
# 🧪 Fold 3 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6159 - loss: 0.7636 - val_accuracy: 0.5828 - val_loss: 0.6801
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 421ms/step - accuracy: 0.6135 - loss: 0.6707 - val_accuracy: 0.5828 - val_loss: 0.6904
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 425ms/step - accuracy: 0.6173 - loss: 0.6879 - val_accuracy: 0.5828 - val_loss: 0.6871
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 416ms/step - accuracy: 0.6173 - loss: 0.6832 - val_accuracy: 0.5828 - val_loss: 0.6847
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 401ms/step - accuracy: 0.6173 - loss: 0.6796 - val_accuracy: 0.5828 - val_loss: 0.6829
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 370ms/step - accuracy: 0.6173 - loss: 0.6767 - val_accuracy: 0.5828 - val_loss: 0.6817
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6173 - loss: 0.6745 - val_accuracy: 0.5828 - val_loss: 0.6808
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6173 - loss: 0.6727 - val_accuracy: 0.5828 - val_loss: 0.6802
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6173 - loss: 0.6713 - val_accuracy: 0.5828 - val_loss: 0.6798
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6173 - loss: 0.6702 - val_accuracy: 0.5828 - val_loss: 0.6796
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 391ms/step - accuracy: 0.6173 - loss: 0.6693 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 403ms/step - accuracy: 0.6173 - loss: 0.6686 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 410ms/step - accuracy: 0.6173 - loss: 0.6680 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 411ms/step - accuracy: 0.6173 - loss: 0.6676 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6173 - loss: 0.6672 - val_accuracy: 0.5828 - val_loss: 0.6795
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 381ms/step - accuracy: 0.6173 - loss: 0.6669 - val_accuracy: 0.5828 - val_loss: 0.6796
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 392ms/step - accuracy: 0.6173 - loss: 0.6667 - val_accuracy: 0.5828 - val_loss: 0.6796
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 412ms/step - accuracy: 0.6173 - loss: 0.6665 - val_accuracy: 0.5828 - val_loss: 0.6797
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 426ms/step - accuracy: 0.6173 - loss: 0.6664 - val_accuracy: 0.5828 - val_loss: 0.6798
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 412ms/step - accuracy: 0.6173 - loss: 0.6662 - val_accuracy: 0.5828 - val_loss: 0.6799
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 394ms/step - accuracy: 0.6173 - loss: 0.6661 - val_accuracy: 0.5828 - val_loss: 0.6800
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 401ms/step - accuracy: 0.6173 - loss: 0.6661 - val_accuracy: 0.5828 - val_loss: 0.6800
# 🏁 Best epoch for Fold 3: 12
# ✅ Fold 3 test accuracy: 0.6029
#
# 🧪 Fold 4 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 408ms/step - accuracy: 0.5619 - loss: 0.8237 - val_accuracy: 0.5814 - val_loss: 0.6805
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 411ms/step - accuracy: 0.6009 - loss: 0.6717 - val_accuracy: 0.5814 - val_loss: 0.6811
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 415ms/step - accuracy: 0.6181 - loss: 0.6745 - val_accuracy: 0.5814 - val_loss: 0.6818
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 412ms/step - accuracy: 0.6480 - loss: 0.6637 - val_accuracy: 0.5814 - val_loss: 0.6800
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 420ms/step - accuracy: 0.6183 - loss: 0.6727 - val_accuracy: 0.5814 - val_loss: 0.6862
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 429ms/step - accuracy: 0.6183 - loss: 0.6734 - val_accuracy: 0.5814 - val_loss: 0.6805
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 412ms/step - accuracy: 0.6183 - loss: 0.6692 - val_accuracy: 0.5814 - val_loss: 0.6800
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 387ms/step - accuracy: 0.6183 - loss: 0.6705 - val_accuracy: 0.5814 - val_loss: 0.6806
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 407ms/step - accuracy: 0.6183 - loss: 0.6720 - val_accuracy: 0.5814 - val_loss: 0.6805
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 416ms/step - accuracy: 0.6183 - loss: 0.6707 - val_accuracy: 0.5814 - val_loss: 0.6798
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 407ms/step - accuracy: 0.6183 - loss: 0.6673 - val_accuracy: 0.5814 - val_loss: 0.6796
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.6320 - loss: 0.6526 - val_accuracy: 0.6447 - val_loss: 0.6456
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.7256 - loss: 0.5848 - val_accuracy: 0.7052 - val_loss: 0.5904
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 417ms/step - accuracy: 0.7669 - loss: 0.5181 - val_accuracy: 0.7362 - val_loss: 0.5566
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 406ms/step - accuracy: 0.8002 - loss: 0.4650 - val_accuracy: 0.7524 - val_loss: 0.5486
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 395ms/step - accuracy: 0.8101 - loss: 0.4547 - val_accuracy: 0.7281 - val_loss: 0.5581
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 408ms/step - accuracy: 0.8057 - loss: 0.4401 - val_accuracy: 0.7618 - val_loss: 0.5283
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.8248 - loss: 0.4138 - val_accuracy: 0.7645 - val_loss: 0.5214
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.8315 - loss: 0.3968 - val_accuracy: 0.7752 - val_loss: 0.5116
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.8368 - loss: 0.3833 - val_accuracy: 0.7860 - val_loss: 0.5084
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.8492 - loss: 0.3659 - val_accuracy: 0.7914 - val_loss: 0.5062
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 404ms/step - accuracy: 0.8545 - loss: 0.3509 - val_accuracy: 0.7806 - val_loss: 0.5192
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.8649 - loss: 0.3355 - val_accuracy: 0.8035 - val_loss: 0.4974
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 413ms/step - accuracy: 0.8781 - loss: 0.3041 - val_accuracy: 0.8062 - val_loss: 0.4798
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.8857 - loss: 0.2823 - val_accuracy: 0.8089 - val_loss: 0.5108
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 394ms/step - accuracy: 0.8874 - loss: 0.2831 - val_accuracy: 0.8048 - val_loss: 0.5164
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.8925 - loss: 0.2600 - val_accuracy: 0.8116 - val_loss: 0.5454
# Epoch 28/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 416ms/step - accuracy: 0.8945 - loss: 0.2530 - val_accuracy: 0.8102 - val_loss: 0.5511
# Epoch 29/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 393ms/step - accuracy: 0.9047 - loss: 0.2237 - val_accuracy: 0.8048 - val_loss: 0.5820
# Epoch 30/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.9005 - loss: 0.2331 - val_accuracy: 0.8102 - val_loss: 0.6300
# Epoch 31/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 386ms/step - accuracy: 0.9149 - loss: 0.2145 - val_accuracy: 0.8183 - val_loss: 0.6380
# Epoch 32/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 403ms/step - accuracy: 0.9221 - loss: 0.1942 - val_accuracy: 0.8197 - val_loss: 0.6697
# Epoch 33/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 401ms/step - accuracy: 0.9353 - loss: 0.1630 - val_accuracy: 0.8129 - val_loss: 0.7152
# Epoch 34/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.9389 - loss: 0.1435 - val_accuracy: 0.8089 - val_loss: 0.7177
# 🏁 Best epoch for Fold 4: 24
# ✅ Fold 4 test accuracy: 0.7966
#
# 🧪 Fold 5 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 392ms/step - accuracy: 0.5697 - loss: 0.7550 - val_accuracy: 0.5922 - val_loss: 0.6757
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 402ms/step - accuracy: 0.6102 - loss: 0.6733 - val_accuracy: 0.5922 - val_loss: 0.6797
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6099 - loss: 0.6754 - val_accuracy: 0.5922 - val_loss: 0.6879
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 416ms/step - accuracy: 0.6099 - loss: 0.6858 - val_accuracy: 0.5922 - val_loss: 0.6844
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 402ms/step - accuracy: 0.6099 - loss: 0.6817 - val_accuracy: 0.5922 - val_loss: 0.6819
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 388ms/step - accuracy: 0.6099 - loss: 0.6786 - val_accuracy: 0.5922 - val_loss: 0.6801
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 394ms/step - accuracy: 0.6099 - loss: 0.6763 - val_accuracy: 0.5922 - val_loss: 0.6788
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 395ms/step - accuracy: 0.6099 - loss: 0.6745 - val_accuracy: 0.5922 - val_loss: 0.6779
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.6099 - loss: 0.6732 - val_accuracy: 0.5922 - val_loss: 0.6772
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 415ms/step - accuracy: 0.6099 - loss: 0.6722 - val_accuracy: 0.5922 - val_loss: 0.6768
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 412ms/step - accuracy: 0.6099 - loss: 0.6714 - val_accuracy: 0.5922 - val_loss: 0.6765
# 🏁 Best epoch for Fold 5: 1
# ✅ Fold 5 test accuracy: 0.6029
#
# 🧪 Fold 6 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 395ms/step - accuracy: 0.5764 - loss: 0.8163 - val_accuracy: 0.5774 - val_loss: 0.6872
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 394ms/step - accuracy: 0.6124 - loss: 0.6715 - val_accuracy: 0.5774 - val_loss: 0.6872
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.6124 - loss: 0.6751 - val_accuracy: 0.5774 - val_loss: 0.6809
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.5949 - loss: 0.6735 - val_accuracy: 0.5774 - val_loss: 0.6892
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 402ms/step - accuracy: 0.6124 - loss: 0.6860 - val_accuracy: 0.5774 - val_loss: 0.6862
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 421ms/step - accuracy: 0.6124 - loss: 0.6814 - val_accuracy: 0.5774 - val_loss: 0.6841
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6124 - loss: 0.6780 - val_accuracy: 0.5774 - val_loss: 0.6828
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 403ms/step - accuracy: 0.6124 - loss: 0.6754 - val_accuracy: 0.5774 - val_loss: 0.6819
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6124 - loss: 0.6735 - val_accuracy: 0.5774 - val_loss: 0.6814
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6124 - loss: 0.6721 - val_accuracy: 0.5774 - val_loss: 0.6812
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 384ms/step - accuracy: 0.6124 - loss: 0.6710 - val_accuracy: 0.5774 - val_loss: 0.6811
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 401ms/step - accuracy: 0.6124 - loss: 0.6702 - val_accuracy: 0.5774 - val_loss: 0.6812
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 390ms/step - accuracy: 0.6124 - loss: 0.6696 - val_accuracy: 0.5774 - val_loss: 0.6813
# 🏁 Best epoch for Fold 6: 3
# ✅ Fold 6 test accuracy: 0.6019
#
# 🧪 Fold 7 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 389ms/step - accuracy: 0.5647 - loss: 0.7149 - val_accuracy: 0.5882 - val_loss: 0.6784
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 392ms/step - accuracy: 0.6191 - loss: 0.6697 - val_accuracy: 0.5882 - val_loss: 0.6780
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 401ms/step - accuracy: 0.6191 - loss: 0.6706 - val_accuracy: 0.5882 - val_loss: 0.6781
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6191 - loss: 0.6708 - val_accuracy: 0.5882 - val_loss: 0.6785
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 413ms/step - accuracy: 0.6172 - loss: 0.6717 - val_accuracy: 0.5882 - val_loss: 0.6817
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 406ms/step - accuracy: 0.6190 - loss: 0.6682 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 409ms/step - accuracy: 0.6191 - loss: 0.6698 - val_accuracy: 0.5882 - val_loss: 0.6774
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 402ms/step - accuracy: 0.6191 - loss: 0.6700 - val_accuracy: 0.5882 - val_loss: 0.6747
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.6203 - loss: 0.6601 - val_accuracy: 0.5882 - val_loss: 0.6720
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 402ms/step - accuracy: 0.6191 - loss: 0.6677 - val_accuracy: 0.5882 - val_loss: 0.6772
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6191 - loss: 0.6679 - val_accuracy: 0.5882 - val_loss: 0.6771
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 410ms/step - accuracy: 0.6191 - loss: 0.6678 - val_accuracy: 0.5882 - val_loss: 0.6769
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.6191 - loss: 0.6676 - val_accuracy: 0.5882 - val_loss: 0.6768
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 386ms/step - accuracy: 0.6191 - loss: 0.6675 - val_accuracy: 0.5882 - val_loss: 0.6772
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 387ms/step - accuracy: 0.6179 - loss: 0.6655 - val_accuracy: 0.5882 - val_loss: 0.6779
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 391ms/step - accuracy: 0.6191 - loss: 0.6681 - val_accuracy: 0.5882 - val_loss: 0.6709
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.6187 - loss: 0.6501 - val_accuracy: 0.6030 - val_loss: 0.6694
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 407ms/step - accuracy: 0.6387 - loss: 0.6358 - val_accuracy: 0.6258 - val_loss: 0.6570
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 415ms/step - accuracy: 0.6841 - loss: 0.6047 - val_accuracy: 0.6191 - val_loss: 0.6724
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 403ms/step - accuracy: 0.7310 - loss: 0.5650 - val_accuracy: 0.6285 - val_loss: 0.6631
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 404ms/step - accuracy: 0.7525 - loss: 0.5223 - val_accuracy: 0.6447 - val_loss: 0.6740
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.7772 - loss: 0.4664 - val_accuracy: 0.6366 - val_loss: 0.6924
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 392ms/step - accuracy: 0.8167 - loss: 0.3949 - val_accuracy: 0.6218 - val_loss: 0.7550
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 403ms/step - accuracy: 0.8651 - loss: 0.3249 - val_accuracy: 0.6326 - val_loss: 0.8342
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 399ms/step - accuracy: 0.9023 - loss: 0.2515 - val_accuracy: 0.6299 - val_loss: 0.8592
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.9038 - loss: 0.2559 - val_accuracy: 0.6245 - val_loss: 0.9084
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 401ms/step - accuracy: 0.9180 - loss: 0.2034 - val_accuracy: 0.6164 - val_loss: 0.8954
# Epoch 28/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 407ms/step - accuracy: 0.9572 - loss: 0.1339 - val_accuracy: 0.6366 - val_loss: 0.8802
# 🏁 Best epoch for Fold 7: 18
# ✅ Fold 7 test accuracy: 0.6189
#
# 🧪 Fold 8 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 406ms/step - accuracy: 0.6026 - loss: 0.8760 - val_accuracy: 0.5908 - val_loss: 0.6793
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 401ms/step - accuracy: 0.6060 - loss: 0.6720 - val_accuracy: 0.5908 - val_loss: 0.6908
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6148 - loss: 0.6889 - val_accuracy: 0.5908 - val_loss: 0.6868
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 369ms/step - accuracy: 0.6148 - loss: 0.6840 - val_accuracy: 0.5908 - val_loss: 0.6839
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 367ms/step - accuracy: 0.6148 - loss: 0.6802 - val_accuracy: 0.5908 - val_loss: 0.6817
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6148 - loss: 0.6773 - val_accuracy: 0.5908 - val_loss: 0.6801
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6148 - loss: 0.6750 - val_accuracy: 0.5908 - val_loss: 0.6790
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 369ms/step - accuracy: 0.6148 - loss: 0.6733 - val_accuracy: 0.5908 - val_loss: 0.6782
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 371ms/step - accuracy: 0.6148 - loss: 0.6719 - val_accuracy: 0.5908 - val_loss: 0.6776
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 367ms/step - accuracy: 0.6148 - loss: 0.6708 - val_accuracy: 0.5908 - val_loss: 0.6772
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 370ms/step - accuracy: 0.6148 - loss: 0.6700 - val_accuracy: 0.5908 - val_loss: 0.6769
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 371ms/step - accuracy: 0.6148 - loss: 0.6693 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 370ms/step - accuracy: 0.6148 - loss: 0.6688 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6148 - loss: 0.6684 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 408ms/step - accuracy: 0.6148 - loss: 0.6681 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 410ms/step - accuracy: 0.6148 - loss: 0.6678 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 414ms/step - accuracy: 0.6148 - loss: 0.6676 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 413ms/step - accuracy: 0.6148 - loss: 0.6675 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6148 - loss: 0.6674 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 406ms/step - accuracy: 0.6148 - loss: 0.6673 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 390ms/step - accuracy: 0.6148 - loss: 0.6672 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 403ms/step - accuracy: 0.6148 - loss: 0.6671 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.6148 - loss: 0.6671 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 401ms/step - accuracy: 0.6148 - loss: 0.6670 - val_accuracy: 0.5908 - val_loss: 0.6768
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 399ms/step - accuracy: 0.6148 - loss: 0.6670 - val_accuracy: 0.5908 - val_loss: 0.6768
# 🏁 Best epoch for Fold 8: 15
# ✅ Fold 8 test accuracy: 0.6019
#
# 🧪 Fold 9 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 399ms/step - accuracy: 0.6111 - loss: 0.8364 - val_accuracy: 0.5922 - val_loss: 0.6799
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 415ms/step - accuracy: 0.6206 - loss: 0.6761 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.6143 - loss: 0.6712 - val_accuracy: 0.5922 - val_loss: 0.6849
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 411ms/step - accuracy: 0.6206 - loss: 0.6704 - val_accuracy: 0.5922 - val_loss: 0.6773
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 396ms/step - accuracy: 0.5979 - loss: 0.6767 - val_accuracy: 0.5922 - val_loss: 0.6754
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 409ms/step - accuracy: 0.6206 - loss: 0.6704 - val_accuracy: 0.5922 - val_loss: 0.6817
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 389ms/step - accuracy: 0.6206 - loss: 0.6763 - val_accuracy: 0.5922 - val_loss: 0.6734
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 387ms/step - accuracy: 0.6217 - loss: 0.6607 - val_accuracy: 0.6003 - val_loss: 0.6665
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 388ms/step - accuracy: 0.6538 - loss: 0.6328 - val_accuracy: 0.6191 - val_loss: 0.6613
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 388ms/step - accuracy: 0.6732 - loss: 0.6127 - val_accuracy: 0.6124 - val_loss: 0.6598
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 388ms/step - accuracy: 0.7084 - loss: 0.5784 - val_accuracy: 0.6380 - val_loss: 0.6589
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 396ms/step - accuracy: 0.7294 - loss: 0.5413 - val_accuracy: 0.5949 - val_loss: 0.6710
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 389ms/step - accuracy: 0.7012 - loss: 0.5645 - val_accuracy: 0.5935 - val_loss: 0.6749
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 390ms/step - accuracy: 0.7037 - loss: 0.5532 - val_accuracy: 0.5882 - val_loss: 0.6725
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 386ms/step - accuracy: 0.7555 - loss: 0.4840 - val_accuracy: 0.5895 - val_loss: 0.6703
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 389ms/step - accuracy: 0.7930 - loss: 0.4483 - val_accuracy: 0.6016 - val_loss: 0.6791
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 388ms/step - accuracy: 0.8024 - loss: 0.4181 - val_accuracy: 0.5868 - val_loss: 0.6969
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 388ms/step - accuracy: 0.7931 - loss: 0.4150 - val_accuracy: 0.6003 - val_loss: 0.7738
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 390ms/step - accuracy: 0.8156 - loss: 0.3869 - val_accuracy: 0.5868 - val_loss: 1.2497
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 389ms/step - accuracy: 0.8313 - loss: 0.3773 - val_accuracy: 0.5841 - val_loss: 1.7289
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 390ms/step - accuracy: 0.8990 - loss: 0.2605 - val_accuracy: 0.6030 - val_loss: 1.9248
# 🏁 Best epoch for Fold 9: 11
# ✅ Fold 9 test accuracy: 0.6335
#
# 🧪 Fold 10 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 390ms/step - accuracy: 0.5707 - loss: 0.8297 - val_accuracy: 0.5922 - val_loss: 0.6774
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6145 - loss: 0.6768 - val_accuracy: 0.5922 - val_loss: 0.6897
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6145 - loss: 0.6876 - val_accuracy: 0.5922 - val_loss: 0.6859
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6145 - loss: 0.6830 - val_accuracy: 0.5922 - val_loss: 0.6831
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6145 - loss: 0.6794 - val_accuracy: 0.5922 - val_loss: 0.6810
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6145 - loss: 0.6766 - val_accuracy: 0.5922 - val_loss: 0.6795
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6145 - loss: 0.6745 - val_accuracy: 0.5922 - val_loss: 0.6784
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6145 - loss: 0.6728 - val_accuracy: 0.5922 - val_loss: 0.6776
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6145 - loss: 0.6716 - val_accuracy: 0.5922 - val_loss: 0.6770
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6145 - loss: 0.6706 - val_accuracy: 0.5922 - val_loss: 0.6766
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6145 - loss: 0.6698 - val_accuracy: 0.5922 - val_loss: 0.6764
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6145 - loss: 0.6692 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6145 - loss: 0.6687 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6145 - loss: 0.6684 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6145 - loss: 0.6681 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6145 - loss: 0.6679 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6145 - loss: 0.6677 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6145 - loss: 0.6675 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.6145 - loss: 0.6674 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6145 - loss: 0.6673 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6145 - loss: 0.6673 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6145 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6145 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6145 - loss: 0.6671 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6145 - loss: 0.6671 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6145 - loss: 0.6671 - val_accuracy: 0.5922 - val_loss: 0.6763
# 🏁 Best epoch for Fold 10: 16
# ✅ Fold 10 test accuracy: 0.6019
#
# 📌 Mean optimal epoch across folds: 10

# %%
# Cell Block 5: Final Model Training on data again, but for ep_mean Epochs (no validation needed)

# Build your TF datasets
train_final_ds = preprocess(X_rest, y_rest)        # ALL data used in K-Fold
test_final_ds  = preprocess(X_holdout, y_holdout)  # NEVER seen during CV

# Instantiate & train your final model
final_model = create_model()
final_model.fit(
    train_final_ds,
    epochs=ep_mean,
    verbose=1
)

# Evaluate once—only on the true hold-out set
final_results = final_model.evaluate(
    test_final_ds,
    verbose=1
)
print("Hold-out test loss & accuracy:", final_results)
# Out:
# Epoch 1/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 44s 373ms/step - accuracy: 0.5809 - loss: 0.7883
# Epoch 2/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 43s 371ms/step - accuracy: 0.6071 - loss: 0.6568
# Epoch 3/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 43s 371ms/step - accuracy: 0.7027 - loss: 0.5998
# Epoch 4/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 44s 375ms/step - accuracy: 0.7472 - loss: 0.5205
# Epoch 5/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 43s 374ms/step - accuracy: 0.8018 - loss: 0.4556
# Epoch 6/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 43s 373ms/step - accuracy: 0.8459 - loss: 0.3775
# Epoch 7/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 44s 375ms/step - accuracy: 0.8570 - loss: 0.3399
# Epoch 8/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 43s 373ms/step - accuracy: 0.8761 - loss: 0.3096
# Epoch 9/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 43s 374ms/step - accuracy: 0.8919 - loss: 0.2727
# Epoch 10/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 43s 373ms/step - accuracy: 0.8970 - loss: 0.2554
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.8122 - loss: 0.4776
# Hold-out test loss & accuracy: [0.44413527846336365, 0.8208232522010803]

# %%
# Cell Block 5: Final Evaluation

# Evaluate final model on the 20% test set
final_test_loss, final_test_acc = final_model.evaluate(test_final_ds, verbose=0)

# Report both results
print(f"\n📊 {k}-Fold Test Accuracy: {np.mean(all_test_accuracies):.4f} ± {np.std(all_test_accuracies):.4f}")
print(f"🏁 Final model test accuracy (trained on hold-out): {final_test_acc:.4f}")
# Out:
# 📊 10-Fold Test Accuracy: 0.6266 ± 0.0575
# 🏁 Final model test accuracy (trained on hold-out): 0.8208

# %%
import numpy as np
from sklearn.metrics import precision_score, roc_curve, auc, f1_score, recall_score
import matplotlib.pyplot as plt

# 1. Extract true labels and model scores from your hold-out dataset
y_true = np.concatenate([y.numpy() for x, y in test_final_ds], axis=0)
y_pred_prob = final_model.predict(test_final_ds)

# 2. If your model outputs two probabilities (one per class), take the “positive” class
if y_pred_prob.ndim > 1 and y_pred_prob.shape[1] > 1:
    y_scores = y_pred_prob[:, 1]
else:
    y_scores = y_pred_prob.ravel()

# 3. Compute ROC curve metrics
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# 4. Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr)               # ROC curve
plt.plot([0, 1], [0, 1], linestyle='--')  # chance line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (AUC = {roc_auc:.2f})')
plt.show()



# 1. Turn your predicted probabilities into binary preds (threshold = 0.5)
y_pred = (y_scores >= 0.5).astype(int)

# 2. Compute precision, recall, F1
precision = precision_score(y_true, y_pred)
recall    = recall_score(y_true, y_pred)
f1        = f1_score(y_true, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step
# Precision: 0.84
# Recall:    0.68
# F1 Score:  0.75
