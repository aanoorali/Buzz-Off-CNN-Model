# %% [markdown]
# Varroa Mite Detection 1.14 Only Blur

# %%
# Cell Block 1: Importing Libraries
import os
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold, train_test_split
import numpy as np
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Cell Block 2: Load Data and Preprocess

df = pd.read_csv('labels_augmented.csv')

df['filename'] = df['filename'].apply(lambda fn: os.path.join('rotations_flips', fn.strip()))

filepaths = df['filename'].values
labels = df['has_mite'].values

# %%
# Cell Block 3: Splitting Data

X_rest, X_holdout, y_rest, y_holdout = train_test_split(
    filepaths, labels,
    test_size=0.10,
    stratify=labels,
    random_state=42
)

# %%
# Cell Block 3: K-Fold Cross-Validation

# Early stopping callback
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    # min_delta=1e-4,
    restore_best_weights=True
)

k = 10  # Number of folds
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

fold = 1
all_test_accuracies = []
best_epochs = []

# Model creation function
def create_model():
    model = models.Sequential([
        layers.Input(shape=(224, 224, 3)),
        layers.Conv2D(32, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Guassian kernel function
def gaussian_kernel(size: int, sigma: float):
    x = tf.range(-size // 2 + 1, size // 2 + 1, dtype=tf.float32)
    xx, yy = tf.meshgrid(x, x)
    kernel = tf.exp(-(xx**2 + yy**2) / (2.0 * sigma**2))
    kernel = kernel / tf.reduce_sum(kernel)
    return kernel

def apply_gaussian_blur(image, kernel_size=5, sigma=1.0):
    kernel = gaussian_kernel(kernel_size, sigma)                 # [5, 5]
    kernel = kernel[:, :, tf.newaxis, tf.newaxis]                # [5, 5, 1, 1]
    kernel = tf.repeat(kernel, repeats=3, axis=2)                # [5, 5, 3, 1] ✅ CORRECT shape
    image = tf.expand_dims(image, 0)                             # [1, H, W, 3]
    blurred = tf.nn.depthwise_conv2d(image, kernel, strides=[1,1,1,1], padding='SAME')
    
    return tf.squeeze(blurred, axis=0)

# Preprocessing function
def preprocess(paths, labels):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    def load_img(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [224, 224])
        img = img / 255.0

        # 1) Apply Gaussian Blur
        img = apply_gaussian_blur(img, kernel_size=5, sigma=1.0)

        # # 2) Boost blue channel
        # img = tf.clip_by_value(img + [0.0, 0.0, 0.2], 0.0, 1.0) 

        # # 3) Increase contrast
        # img = tf.image.adjust_contrast(img, 2.0) 

        # # 4). Boost red channel
        # img = tf.clip_by_value(img + [0.2, 0.0, 0.0], 0.0, 1.0)
        
        return img, label

    return ds.map(load_img).batch(32).prefetch(tf.data.AUTOTUNE)

for trainval_index, test_index in skf.split(filepaths, labels):
    print(f"\n🧪 Fold {fold} -----------------------------")

    # Split into trainval and test
    X_trainval, X_test = filepaths[trainval_index], filepaths[test_index]
    y_trainval, y_test = labels[trainval_index], labels[test_index]

    # Further split trainval into train and val (e.g. 80/20)
    val_split = int(0.8 * len(X_trainval))
    X_train, X_val = X_trainval[:val_split], X_trainval[val_split:]
    y_train, y_val = y_trainval[:val_split], y_trainval[val_split:]


    # Preprocess each split
    train_ds = preprocess(X_train, y_train)
    val_ds = preprocess(X_val, y_val)
    test_ds = preprocess(X_test, y_test)



    # Train model with early stopping
    model = create_model()
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[earlystop],
        verbose=1
    )

    # Record best epoch (smallest val_loss)
    best_epoch = np.argmin(history.history['val_loss']) + 1
    best_epochs.append(best_epoch)
    print(f"🏁 Best epoch for Fold {fold}: {best_epoch}")

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    all_test_accuracies.append(test_acc)
    print(f"✅ Fold {fold} test accuracy: {test_acc:.4f}")

    fold += 1

# Calculate mean best epoch
ep_mean = int(np.round(np.mean(best_epochs)))
print(f"\n📌 Mean optimal epoch across folds: {ep_mean}")
# Out:
# 🧪 Fold 1 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 45s 469ms/step - accuracy: 0.5748 - loss: 0.8549 - val_accuracy: 0.5922 - val_loss: 0.6776
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 44s 471ms/step - accuracy: 0.6052 - loss: 0.6725 - val_accuracy: 0.5922 - val_loss: 0.6856
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 433ms/step - accuracy: 0.5934 - loss: 0.6755 - val_accuracy: 0.5922 - val_loss: 0.6779
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 44s 478ms/step - accuracy: 0.6091 - loss: 0.6748 - val_accuracy: 0.5922 - val_loss: 0.6766
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 440ms/step - accuracy: 0.6091 - loss: 0.6744 - val_accuracy: 0.5922 - val_loss: 0.6774
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 432ms/step - accuracy: 0.6091 - loss: 0.6731 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 440ms/step - accuracy: 0.6091 - loss: 0.6716 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 434ms/step - accuracy: 0.6091 - loss: 0.6666 - val_accuracy: 0.5922 - val_loss: 0.7022
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 433ms/step - accuracy: 0.6091 - loss: 0.6700 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 432ms/step - accuracy: 0.6091 - loss: 0.6709 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 433ms/step - accuracy: 0.6091 - loss: 0.6709 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 434ms/step - accuracy: 0.6091 - loss: 0.6709 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 440ms/step - accuracy: 0.6091 - loss: 0.6719 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 432ms/step - accuracy: 0.6091 - loss: 0.6710 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 407ms/step - accuracy: 0.6091 - loss: 0.6714 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 404ms/step - accuracy: 0.6091 - loss: 0.6705 - val_accuracy: 0.5922 - val_loss: 0.6769
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 403ms/step - accuracy: 0.6091 - loss: 0.6718 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 409ms/step - accuracy: 0.6091 - loss: 0.6730 - val_accuracy: 0.5922 - val_loss: 0.6768
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 403ms/step - accuracy: 0.6043 - loss: 0.6734 - val_accuracy: 0.5922 - val_loss: 0.6771
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 409ms/step - accuracy: 0.6091 - loss: 0.6746 - val_accuracy: 0.5922 - val_loss: 0.6761
# 🏁 Best epoch for Fold 1: 10
# ✅ Fold 1 test accuracy: 0.6029
#
# 🧪 Fold 2 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 405ms/step - accuracy: 0.6051 - loss: 0.7718 - val_accuracy: 0.5868 - val_loss: 0.6913
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.6182 - loss: 0.6894 - val_accuracy: 0.5868 - val_loss: 0.6876
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 408ms/step - accuracy: 0.6182 - loss: 0.6844 - val_accuracy: 0.5868 - val_loss: 0.6848
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.6182 - loss: 0.6805 - val_accuracy: 0.5868 - val_loss: 0.6828
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.6182 - loss: 0.6774 - val_accuracy: 0.5868 - val_loss: 0.6813
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.6182 - loss: 0.6749 - val_accuracy: 0.5868 - val_loss: 0.6802
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.6182 - loss: 0.6730 - val_accuracy: 0.5868 - val_loss: 0.6794
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 431ms/step - accuracy: 0.6182 - loss: 0.6715 - val_accuracy: 0.5868 - val_loss: 0.6788
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 432ms/step - accuracy: 0.6182 - loss: 0.6703 - val_accuracy: 0.5868 - val_loss: 0.6785
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 434ms/step - accuracy: 0.6182 - loss: 0.6693 - val_accuracy: 0.5868 - val_loss: 0.6782
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 432ms/step - accuracy: 0.6182 - loss: 0.6685 - val_accuracy: 0.5868 - val_loss: 0.6781
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 430ms/step - accuracy: 0.6182 - loss: 0.6679 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 432ms/step - accuracy: 0.6182 - loss: 0.6674 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 426ms/step - accuracy: 0.6182 - loss: 0.6670 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 428ms/step - accuracy: 0.6182 - loss: 0.6667 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 424ms/step - accuracy: 0.6182 - loss: 0.6665 - val_accuracy: 0.5868 - val_loss: 0.6781
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 422ms/step - accuracy: 0.6182 - loss: 0.6663 - val_accuracy: 0.5868 - val_loss: 0.6781
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 435ms/step - accuracy: 0.6182 - loss: 0.6661 - val_accuracy: 0.5868 - val_loss: 0.6782
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 428ms/step - accuracy: 0.6182 - loss: 0.6660 - val_accuracy: 0.5868 - val_loss: 0.6782
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 419ms/step - accuracy: 0.6182 - loss: 0.6659 - val_accuracy: 0.5868 - val_loss: 0.6783
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 422ms/step - accuracy: 0.6182 - loss: 0.6658 - val_accuracy: 0.5868 - val_loss: 0.6783
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 424ms/step - accuracy: 0.6182 - loss: 0.6657 - val_accuracy: 0.5868 - val_loss: 0.6784
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 421ms/step - accuracy: 0.6182 - loss: 0.6656 - val_accuracy: 0.5868 - val_loss: 0.6784
# 🏁 Best epoch for Fold 2: 13
# ✅ Fold 2 test accuracy: 0.6029
#
# 🧪 Fold 3 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 429ms/step - accuracy: 0.6004 - loss: 0.7734 - val_accuracy: 0.5828 - val_loss: 0.6879
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 418ms/step - accuracy: 0.6173 - loss: 0.6823 - val_accuracy: 0.5828 - val_loss: 0.6803
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 430ms/step - accuracy: 0.6141 - loss: 0.6855 - val_accuracy: 0.5828 - val_loss: 0.6797
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 422ms/step - accuracy: 0.6173 - loss: 0.6736 - val_accuracy: 0.5828 - val_loss: 0.6803
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 432ms/step - accuracy: 0.6169 - loss: 0.6729 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 418ms/step - accuracy: 0.6124 - loss: 0.6688 - val_accuracy: 0.5828 - val_loss: 0.6803
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 420ms/step - accuracy: 0.6173 - loss: 0.6770 - val_accuracy: 0.5828 - val_loss: 0.6797
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 422ms/step - accuracy: 0.6330 - loss: 0.6557 - val_accuracy: 0.6083 - val_loss: 0.6543
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 437ms/step - accuracy: 0.7323 - loss: 0.5622 - val_accuracy: 0.7712 - val_loss: 0.5674
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 420ms/step - accuracy: 0.8055 - loss: 0.4605 - val_accuracy: 0.8022 - val_loss: 0.4926
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 423ms/step - accuracy: 0.8347 - loss: 0.3970 - val_accuracy: 0.8062 - val_loss: 0.4686
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 423ms/step - accuracy: 0.8493 - loss: 0.3589 - val_accuracy: 0.7968 - val_loss: 0.5068
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 419ms/step - accuracy: 0.8600 - loss: 0.3381 - val_accuracy: 0.8048 - val_loss: 0.5195
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 421ms/step - accuracy: 0.8667 - loss: 0.3185 - val_accuracy: 0.8156 - val_loss: 0.5783
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 422ms/step - accuracy: 0.8802 - loss: 0.2979 - val_accuracy: 0.8143 - val_loss: 0.5511
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 422ms/step - accuracy: 0.8872 - loss: 0.2842 - val_accuracy: 0.8062 - val_loss: 0.5738
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 422ms/step - accuracy: 0.8920 - loss: 0.2559 - val_accuracy: 0.8022 - val_loss: 0.6767
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 418ms/step - accuracy: 0.9128 - loss: 0.2192 - val_accuracy: 0.8022 - val_loss: 0.8300
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 423ms/step - accuracy: 0.9194 - loss: 0.2000 - val_accuracy: 0.7900 - val_loss: 0.6840
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 420ms/step - accuracy: 0.9188 - loss: 0.2182 - val_accuracy: 0.7806 - val_loss: 0.7483
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 417ms/step - accuracy: 0.9185 - loss: 0.2083 - val_accuracy: 0.8156 - val_loss: 0.4552
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 422ms/step - accuracy: 0.8875 - loss: 0.2726 - val_accuracy: 0.7995 - val_loss: 0.5422
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 420ms/step - accuracy: 0.9197 - loss: 0.1872 - val_accuracy: 0.7995 - val_loss: 0.6833
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 418ms/step - accuracy: 0.9333 - loss: 0.1628 - val_accuracy: 0.7968 - val_loss: 0.7120
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 421ms/step - accuracy: 0.9377 - loss: 0.1757 - val_accuracy: 0.8102 - val_loss: 0.7427
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 435ms/step - accuracy: 0.9579 - loss: 0.1331 - val_accuracy: 0.8022 - val_loss: 0.9702
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 425ms/step - accuracy: 0.9566 - loss: 0.1170 - val_accuracy: 0.8102 - val_loss: 1.1555
# Epoch 28/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 424ms/step - accuracy: 0.9632 - loss: 0.1062 - val_accuracy: 0.8129 - val_loss: 1.1839
# Epoch 29/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 432ms/step - accuracy: 0.9823 - loss: 0.0633 - val_accuracy: 0.8156 - val_loss: 1.2658
# Epoch 30/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 424ms/step - accuracy: 0.9867 - loss: 0.0440 - val_accuracy: 0.8035 - val_loss: 1.4227
# Epoch 31/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 429ms/step - accuracy: 0.9851 - loss: 0.0445 - val_accuracy: 0.7954 - val_loss: 1.6394
# 🏁 Best epoch for Fold 3: 21
# ✅ Fold 3 test accuracy: 0.8402
#
# 🧪 Fold 4 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 420ms/step - accuracy: 0.5968 - loss: 0.8582 - val_accuracy: 0.5814 - val_loss: 0.6807
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 394ms/step - accuracy: 0.6183 - loss: 0.6743 - val_accuracy: 0.5814 - val_loss: 0.6910
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.6183 - loss: 0.6736 - val_accuracy: 0.5814 - val_loss: 0.6809
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 394ms/step - accuracy: 0.6183 - loss: 0.6745 - val_accuracy: 0.5814 - val_loss: 0.6805
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.6183 - loss: 0.6650 - val_accuracy: 0.5814 - val_loss: 0.6959
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.6183 - loss: 0.6788 - val_accuracy: 0.5814 - val_loss: 0.6822
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 395ms/step - accuracy: 0.6183 - loss: 0.6804 - val_accuracy: 0.5814 - val_loss: 0.6862
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.6183 - loss: 0.6733 - val_accuracy: 0.5814 - val_loss: 0.6804
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.6183 - loss: 0.6705 - val_accuracy: 0.5814 - val_loss: 0.6798
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.6183 - loss: 0.6683 - val_accuracy: 0.5814 - val_loss: 0.6803
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6183 - loss: 0.6692 - val_accuracy: 0.5814 - val_loss: 0.6767
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6205 - loss: 0.6530 - val_accuracy: 0.5814 - val_loss: 0.6801
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6221 - loss: 0.6683 - val_accuracy: 0.6083 - val_loss: 0.6672
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6489 - loss: 0.6400 - val_accuracy: 0.6043 - val_loss: 0.6614
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6734 - loss: 0.6096 - val_accuracy: 0.6151 - val_loss: 0.6680
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6902 - loss: 0.5852 - val_accuracy: 0.6447 - val_loss: 0.6872
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.7168 - loss: 0.5390 - val_accuracy: 0.6393 - val_loss: 0.7325
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.7409 - loss: 0.5048 - val_accuracy: 0.6231 - val_loss: 0.8814
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 371ms/step - accuracy: 0.7886 - loss: 0.4352 - val_accuracy: 0.6326 - val_loss: 0.9407
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.8115 - loss: 0.3688 - val_accuracy: 0.6312 - val_loss: 1.0056
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 371ms/step - accuracy: 0.8245 - loss: 0.3482 - val_accuracy: 0.6353 - val_loss: 1.0742
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 371ms/step - accuracy: 0.8443 - loss: 0.3006 - val_accuracy: 0.6299 - val_loss: 0.9191
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 392ms/step - accuracy: 0.8625 - loss: 0.2662 - val_accuracy: 0.6218 - val_loss: 0.8330
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.8847 - loss: 0.2325 - val_accuracy: 0.6299 - val_loss: 0.8860
# 🏁 Best epoch for Fold 4: 14
# ✅ Fold 4 test accuracy: 0.6271
#
# 🧪 Fold 5 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 374ms/step - accuracy: 0.5849 - loss: 0.7872 - val_accuracy: 0.5922 - val_loss: 0.6769
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6048 - loss: 0.6733 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6065 - loss: 0.6745 - val_accuracy: 0.5922 - val_loss: 0.6893
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6099 - loss: 0.6873 - val_accuracy: 0.5922 - val_loss: 0.6854
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6099 - loss: 0.6828 - val_accuracy: 0.5922 - val_loss: 0.6826
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.6099 - loss: 0.6795 - val_accuracy: 0.5922 - val_loss: 0.6806
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6099 - loss: 0.6770 - val_accuracy: 0.5922 - val_loss: 0.6792
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6099 - loss: 0.6751 - val_accuracy: 0.5922 - val_loss: 0.6781
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6099 - loss: 0.6736 - val_accuracy: 0.5922 - val_loss: 0.6774
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6099 - loss: 0.6725 - val_accuracy: 0.5922 - val_loss: 0.6769
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 374ms/step - accuracy: 0.6099 - loss: 0.6717 - val_accuracy: 0.5922 - val_loss: 0.6766
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6099 - loss: 0.6710 - val_accuracy: 0.5922 - val_loss: 0.6763
# 🏁 Best epoch for Fold 5: 2
# ✅ Fold 5 test accuracy: 0.6029
#
# 🧪 Fold 6 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 378ms/step - accuracy: 0.5974 - loss: 0.7834 - val_accuracy: 0.5774 - val_loss: 0.6965
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6140 - loss: 0.6746 - val_accuracy: 0.5774 - val_loss: 0.6905
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6124 - loss: 0.6747 - val_accuracy: 0.5774 - val_loss: 0.6809
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6124 - loss: 0.6698 - val_accuracy: 0.5774 - val_loss: 0.6964
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6124 - loss: 0.6793 - val_accuracy: 0.5774 - val_loss: 0.6838
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6139 - loss: 0.6697 - val_accuracy: 0.5774 - val_loss: 0.6824
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6124 - loss: 0.6443 - val_accuracy: 0.5774 - val_loss: 0.6532
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6124 - loss: 0.6021 - val_accuracy: 0.5774 - val_loss: 0.6307
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6455 - loss: 0.5654 - val_accuracy: 0.7335 - val_loss: 0.6275
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 371ms/step - accuracy: 0.8148 - loss: 0.5024 - val_accuracy: 0.8183 - val_loss: 0.5499
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.8227 - loss: 0.4848 - val_accuracy: 0.8129 - val_loss: 0.6010
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.8208 - loss: 0.4601 - val_accuracy: 0.7766 - val_loss: 0.6671
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 370ms/step - accuracy: 0.8407 - loss: 0.4379 - val_accuracy: 0.8035 - val_loss: 0.6067
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.8508 - loss: 0.4469 - val_accuracy: 0.8223 - val_loss: 0.5524
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.8544 - loss: 0.4069 - val_accuracy: 0.7281 - val_loss: 0.7098
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.8582 - loss: 0.3837 - val_accuracy: 0.7550 - val_loss: 0.7289
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 371ms/step - accuracy: 0.8630 - loss: 0.4129 - val_accuracy: 0.8156 - val_loss: 0.5159
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.8647 - loss: 0.3644 - val_accuracy: 0.8035 - val_loss: 0.5431
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.8872 - loss: 0.3336 - val_accuracy: 0.7995 - val_loss: 0.5699
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.8969 - loss: 0.3190 - val_accuracy: 0.7793 - val_loss: 0.7130
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.8987 - loss: 0.3005 - val_accuracy: 0.7927 - val_loss: 0.6687
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.9074 - loss: 0.2883 - val_accuracy: 0.8008 - val_loss: 0.6036
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.9031 - loss: 0.2929 - val_accuracy: 0.7873 - val_loss: 0.5502
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.9125 - loss: 0.2668 - val_accuracy: 0.7887 - val_loss: 0.6007
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.9202 - loss: 0.2249 - val_accuracy: 0.8022 - val_loss: 0.6189
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.9443 - loss: 0.1640 - val_accuracy: 0.8062 - val_loss: 0.6697
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.9599 - loss: 0.1269 - val_accuracy: 0.7873 - val_loss: 0.7788
# 🏁 Best epoch for Fold 6: 17
# ✅ Fold 6 test accuracy: 0.7743
#
# 🧪 Fold 7 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 379ms/step - accuracy: 0.5502 - loss: 0.7695 - val_accuracy: 0.5882 - val_loss: 0.6912
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6191 - loss: 0.6891 - val_accuracy: 0.5882 - val_loss: 0.6873
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6191 - loss: 0.6839 - val_accuracy: 0.5882 - val_loss: 0.6844
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6191 - loss: 0.6799 - val_accuracy: 0.5882 - val_loss: 0.6823
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6191 - loss: 0.6767 - val_accuracy: 0.5882 - val_loss: 0.6807
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6191 - loss: 0.6742 - val_accuracy: 0.5882 - val_loss: 0.6796
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6191 - loss: 0.6723 - val_accuracy: 0.5882 - val_loss: 0.6788
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6191 - loss: 0.6708 - val_accuracy: 0.5882 - val_loss: 0.6783
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6191 - loss: 0.6696 - val_accuracy: 0.5882 - val_loss: 0.6779
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6191 - loss: 0.6686 - val_accuracy: 0.5882 - val_loss: 0.6777
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6191 - loss: 0.6679 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6191 - loss: 0.6673 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6191 - loss: 0.6668 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6191 - loss: 0.6665 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6191 - loss: 0.6662 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6191 - loss: 0.6660 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.6191 - loss: 0.6658 - val_accuracy: 0.5882 - val_loss: 0.6777
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6191 - loss: 0.6656 - val_accuracy: 0.5882 - val_loss: 0.6777
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6191 - loss: 0.6655 - val_accuracy: 0.5882 - val_loss: 0.6778
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 371ms/step - accuracy: 0.6191 - loss: 0.6654 - val_accuracy: 0.5882 - val_loss: 0.6778
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 371ms/step - accuracy: 0.6191 - loss: 0.6653 - val_accuracy: 0.5882 - val_loss: 0.6778
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6191 - loss: 0.6653 - val_accuracy: 0.5882 - val_loss: 0.6779
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6191 - loss: 0.6652 - val_accuracy: 0.5882 - val_loss: 0.6779
# 🏁 Best epoch for Fold 7: 13
# ✅ Fold 7 test accuracy: 0.6019
#
# 🧪 Fold 8 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 374ms/step - accuracy: 0.5883 - loss: 0.8875 - val_accuracy: 0.5908 - val_loss: 0.6763
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6106 - loss: 0.6718 - val_accuracy: 0.5908 - val_loss: 0.6781
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6148 - loss: 0.6746 - val_accuracy: 0.5908 - val_loss: 0.6891
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6148 - loss: 0.6868 - val_accuracy: 0.5908 - val_loss: 0.6856
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6148 - loss: 0.6824 - val_accuracy: 0.5908 - val_loss: 0.6829
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 371ms/step - accuracy: 0.6148 - loss: 0.6790 - val_accuracy: 0.5908 - val_loss: 0.6810
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6148 - loss: 0.6763 - val_accuracy: 0.5908 - val_loss: 0.6796
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6148 - loss: 0.6743 - val_accuracy: 0.5908 - val_loss: 0.6786
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6148 - loss: 0.6727 - val_accuracy: 0.5908 - val_loss: 0.6779
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6148 - loss: 0.6714 - val_accuracy: 0.5908 - val_loss: 0.6774
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6148 - loss: 0.6704 - val_accuracy: 0.5908 - val_loss: 0.6771
# 🏁 Best epoch for Fold 8: 1
# ✅ Fold 8 test accuracy: 0.6019
#
# 🧪 Fold 9 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 374ms/step - accuracy: 0.5825 - loss: 0.7264 - val_accuracy: 0.5922 - val_loss: 0.6805
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6206 - loss: 0.6703 - val_accuracy: 0.5922 - val_loss: 0.6801
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6170 - loss: 0.6771 - val_accuracy: 0.5922 - val_loss: 0.6891
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6206 - loss: 0.6866 - val_accuracy: 0.5922 - val_loss: 0.6854
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6206 - loss: 0.6818 - val_accuracy: 0.5922 - val_loss: 0.6828
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6206 - loss: 0.6781 - val_accuracy: 0.5922 - val_loss: 0.6808
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6206 - loss: 0.6753 - val_accuracy: 0.5922 - val_loss: 0.6794
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6206 - loss: 0.6730 - val_accuracy: 0.5922 - val_loss: 0.6783
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6206 - loss: 0.6713 - val_accuracy: 0.5922 - val_loss: 0.6776
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6206 - loss: 0.6699 - val_accuracy: 0.5922 - val_loss: 0.6770
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6206 - loss: 0.6688 - val_accuracy: 0.5922 - val_loss: 0.6767
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6206 - loss: 0.6680 - val_accuracy: 0.5922 - val_loss: 0.6764
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 388ms/step - accuracy: 0.6206 - loss: 0.6673 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6206 - loss: 0.6667 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 399ms/step - accuracy: 0.6206 - loss: 0.6663 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 399ms/step - accuracy: 0.6206 - loss: 0.6659 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 417ms/step - accuracy: 0.6206 - loss: 0.6657 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.6206 - loss: 0.6654 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 439ms/step - accuracy: 0.6206 - loss: 0.6652 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 439ms/step - accuracy: 0.6206 - loss: 0.6651 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 437ms/step - accuracy: 0.6206 - loss: 0.6650 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 436ms/step - accuracy: 0.6206 - loss: 0.6649 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 435ms/step - accuracy: 0.6206 - loss: 0.6648 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 436ms/step - accuracy: 0.6206 - loss: 0.6647 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 444ms/step - accuracy: 0.6206 - loss: 0.6647 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 437ms/step - accuracy: 0.6206 - loss: 0.6646 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 42s 454ms/step - accuracy: 0.6206 - loss: 0.6646 - val_accuracy: 0.5922 - val_loss: 0.6763
# 🏁 Best epoch for Fold 9: 17
# ✅ Fold 9 test accuracy: 0.6019
#
# 🧪 Fold 10 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 45s 471ms/step - accuracy: 0.5926 - loss: 0.8428 - val_accuracy: 0.5922 - val_loss: 0.6766
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 43s 458ms/step - accuracy: 0.6145 - loss: 0.6762 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 43s 460ms/step - accuracy: 0.6129 - loss: 0.6733 - val_accuracy: 0.5922 - val_loss: 0.6892
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 42s 451ms/step - accuracy: 0.6145 - loss: 0.6870 - val_accuracy: 0.5922 - val_loss: 0.6855
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 433ms/step - accuracy: 0.6145 - loss: 0.6824 - val_accuracy: 0.5922 - val_loss: 0.6827
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 440ms/step - accuracy: 0.6145 - loss: 0.6789 - val_accuracy: 0.5922 - val_loss: 0.6807
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 43s 460ms/step - accuracy: 0.6145 - loss: 0.6762 - val_accuracy: 0.5922 - val_loss: 0.6792
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 42s 456ms/step - accuracy: 0.6145 - loss: 0.6742 - val_accuracy: 0.5922 - val_loss: 0.6782
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 42s 456ms/step - accuracy: 0.6145 - loss: 0.6726 - val_accuracy: 0.5922 - val_loss: 0.6775
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 43s 462ms/step - accuracy: 0.6145 - loss: 0.6714 - val_accuracy: 0.5922 - val_loss: 0.6769
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 43s 458ms/step - accuracy: 0.6145 - loss: 0.6704 - val_accuracy: 0.5922 - val_loss: 0.6766
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 42s 449ms/step - accuracy: 0.6145 - loss: 0.6697 - val_accuracy: 0.5922 - val_loss: 0.6764
# 🏁 Best epoch for Fold 10: 2
# ✅ Fold 10 test accuracy: 0.6019
#
# 📌 Mean optimal epoch across folds: 11

# %%
# Cell Block 5: Final Model Training on data again, but for ep_mean Epochs (no validation needed)

# Build your TF datasets
train_final_ds = preprocess(X_rest, y_rest)        # ALL data used in K-Fold
test_final_ds  = preprocess(X_holdout, y_holdout)  # NEVER seen during CV

# Instantiate & train your final model
final_model = create_model()
final_model.fit(
    train_final_ds,
    epochs=ep_mean,
    verbose=1
)

# Evaluate once—only on the true hold-out set
final_results = final_model.evaluate(
    test_final_ds,
    verbose=1
)
print("Hold-out test loss & accuracy:", final_results)
# Out:
# Epoch 1/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 48s 404ms/step - accuracy: 0.5619 - loss: 0.7925
# Epoch 2/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 48s 411ms/step - accuracy: 0.5990 - loss: 0.6741
# Epoch 3/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - accuracy: 0.5996 - loss: 0.6638
# Epoch 4/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 48s 416ms/step - accuracy: 0.6456 - loss: 0.6108
# Epoch 5/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 47s 403ms/step - accuracy: 0.7552 - loss: 0.5687
# Epoch 6/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 47s 407ms/step - accuracy: 0.7904 - loss: 0.5362
# Epoch 7/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 47s 404ms/step - accuracy: 0.8298 - loss: 0.4953
# Epoch 8/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 48s 410ms/step - accuracy: 0.8312 - loss: 0.4742
# Epoch 9/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 47s 407ms/step - accuracy: 0.8552 - loss: 0.4362
# Epoch 10/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 47s 404ms/step - accuracy: 0.8581 - loss: 0.4299
# Epoch 11/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 49s 422ms/step - accuracy: 0.8681 - loss: 0.3903
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.8112 - loss: 0.4893
# Hold-out test loss & accuracy: [0.47141748666763306, 0.8256658315658569]

# %%
# Cell Block 5: Final Evaluation

# Evaluate final model on the 20% test set
final_test_loss, final_test_acc = final_model.evaluate(test_final_ds, verbose=0)

# Report both results
print(f"\n📊 {k}-Fold Test Accuracy: {np.mean(all_test_accuracies):.4f} ± {np.std(all_test_accuracies):.4f}")
print(f"🏁 Final model test accuracy (trained on hold-out): {final_test_acc:.4f}")
# Out:
# 📊 10-Fold Test Accuracy: 0.6458 ± 0.0824
# 🏁 Final model test accuracy (trained on hold-out): 0.8257

# %%
import numpy as np
from sklearn.metrics import precision_score, roc_curve, auc, f1_score, recall_score
import matplotlib.pyplot as plt

# 1. Extract true labels and model scores from your hold-out dataset
y_true = np.concatenate([y.numpy() for x, y in test_final_ds], axis=0)
y_pred_prob = final_model.predict(test_final_ds)

# 2. If your model outputs two probabilities (one per class), take the “positive” class
if y_pred_prob.ndim > 1 and y_pred_prob.shape[1] > 1:
    y_scores = y_pred_prob[:, 1]
else:
    y_scores = y_pred_prob.ravel()

# 3. Compute ROC curve metrics
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# 4. Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr)               # ROC curve
plt.plot([0, 1], [0, 1], linestyle='--')  # chance line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (AUC = {roc_auc:.2f})')
plt.show()



# 1. Turn your predicted probabilities into binary preds (threshold = 0.5)
y_pred = (y_scores >= 0.5).astype(int)

# 2. Compute precision, recall, F1
precision = precision_score(y_true, y_pred)
recall    = recall_score(y_true, y_pred)
f1        = f1_score(y_true, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step
# Precision: 0.76
# Recall:    0.81
# F1 Score:  0.79
