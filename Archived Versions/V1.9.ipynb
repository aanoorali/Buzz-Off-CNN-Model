# %% [markdown]
# Varroa Mite Detection 1.9 Red S and Contrast

# %%
# Cell Block 1: Importing Libraries
import os
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold, train_test_split
import numpy as np
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Cell Block 2: Load Data and Preprocess

df = pd.read_csv('labels_augmented.csv')

df['filename'] = df['filename'].apply(lambda fn: os.path.join('rotations_flips', fn.strip()))

filepaths = df['filename'].values
labels = df['has_mite'].values

# %%
# Cell Block 3: Splitting Data

X_rest, X_holdout, y_rest, y_holdout = train_test_split(
    filepaths, labels,
    test_size=0.10,
    stratify=labels,
    random_state=42
)

# %%
# Cell Block 3: K-Fold Cross-Validation

# Early stopping callback
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    # min_delta=1e-4,
    restore_best_weights=True
)

k = 10  # Number of folds
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

fold = 1
all_test_accuracies = []
best_epochs = []

# Model creation function
def create_model():
    model = models.Sequential([
        layers.Input(shape=(224, 224, 3)),
        layers.Conv2D(32, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Preprocessing function
def preprocess(paths, labels):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    def load_img(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [224, 224])
        img = img / 255.0



        # 1) Boost blue channel
        # img = tf.clip_by_value(img + [0.0, 0.0, 0.2], 0.0, 1.0) 

        # 2) Increase contrast
        img = tf.image.adjust_contrast(img, 2.0) 

        # 3). Boost red channel
        img = tf.clip_by_value(img + [0.2, 0.0, 0.0], 0.0, 1.0)
  
        return img, label

    return ds.map(load_img).batch(32).prefetch(tf.data.AUTOTUNE)

for trainval_index, test_index in skf.split(filepaths, labels):
    print(f"\n🧪 Fold {fold} -----------------------------")

    # Split into trainval and test
    X_trainval, X_test = filepaths[trainval_index], filepaths[test_index]
    y_trainval, y_test = labels[trainval_index], labels[test_index]

    # Further split trainval into train and val (e.g. 80/20)
    val_split = int(0.8 * len(X_trainval))
    X_train, X_val = X_trainval[:val_split], X_trainval[val_split:]
    y_train, y_val = y_trainval[:val_split], y_trainval[val_split:]


    # Preprocess each split
    train_ds = preprocess(X_train, y_train)
    val_ds = preprocess(X_val, y_val)
    test_ds = preprocess(X_test, y_test)



    # Train model with early stopping
    model = create_model()
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[earlystop],
        verbose=1
    )

    # Record best epoch (smallest val_loss)
    best_epoch = np.argmin(history.history['val_loss']) + 1
    best_epochs.append(best_epoch)
    print(f"🏁 Best epoch for Fold {fold}: {best_epoch}")

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    all_test_accuracies.append(test_acc)
    print(f"✅ Fold {fold} test accuracy: {test_acc:.4f}")

    fold += 1

# Calculate mean best epoch
ep_mean = int(np.round(np.mean(best_epochs)))
print(f"\n📌 Mean optimal epoch across folds: {ep_mean}")
# Out:
# 🧪 Fold 1 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 362ms/step - accuracy: 0.5770 - loss: 0.8568 - val_accuracy: 0.5922 - val_loss: 0.6758
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.6091 - loss: 0.6748 - val_accuracy: 0.5922 - val_loss: 0.6847
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6166 - loss: 0.6683 - val_accuracy: 0.6245 - val_loss: 0.6620
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6475 - loss: 0.6436 - val_accuracy: 0.6205 - val_loss: 0.6491
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 384ms/step - accuracy: 0.6779 - loss: 0.6089 - val_accuracy: 0.6299 - val_loss: 0.6598
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.9209 - loss: 0.2064 - val_accuracy: 0.6164 - val_loss: 1.4112
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 333ms/step - accuracy: 0.9409 - loss: 0.1604 - val_accuracy: 0.6016 - val_loss: 1.5879
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 333ms/step - accuracy: 0.9603 - loss: 0.1040 - val_accuracy: 0.6218 - val_loss: 2.5466
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.9685 - loss: 0.0876 - val_accuracy: 0.6043 - val_loss: 2.9760
# Epoch 28/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 333ms/step - accuracy: 0.9670 - loss: 0.0998 - val_accuracy: 0.6083 - val_loss: 1.8738
# Epoch 29/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.9747 - loss: 0.0692 - val_accuracy: 0.6016 - val_loss: 2.0618
# 🏁 Best epoch for Fold 9: 19
# ✅ Fold 9 test accuracy: 0.6699
#
# 🧪 Fold 10 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 337ms/step - accuracy: 0.5590 - loss: 0.8195 - val_accuracy: 0.5922 - val_loss: 0.6797
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6123 - loss: 0.6736 - val_accuracy: 0.5922 - val_loss: 0.6775
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.6145 - loss: 0.6777 - val_accuracy: 0.5922 - val_loss: 0.6752
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6145 - loss: 0.6642 - val_accuracy: 0.5922 - val_loss: 0.6789
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.6145 - loss: 0.6780 - val_accuracy: 0.5922 - val_loss: 0.6765
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6145 - loss: 0.6712 - val_accuracy: 0.5922 - val_loss: 0.6764
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.6145 - loss: 0.6723 - val_accuracy: 0.5922 - val_loss: 0.6789
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.6145 - loss: 0.6702 - val_accuracy: 0.5922 - val_loss: 0.6764
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6130 - loss: 0.6662 - val_accuracy: 0.5922 - val_loss: 0.6645
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.6231 - loss: 0.6448 - val_accuracy: 0.6030 - val_loss: 0.6660
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6196 - loss: 0.6353 - val_accuracy: 0.5935 - val_loss: 0.6590
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 333ms/step - accuracy: 0.6284 - loss: 0.6209 - val_accuracy: 0.6003 - val_loss: 0.6585
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6447 - loss: 0.5892 - val_accuracy: 0.6003 - val_loss: 0.6591
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6565 - loss: 0.5649 - val_accuracy: 0.6057 - val_loss: 0.6520
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.6723 - loss: 0.5233 - val_accuracy: 0.6124 - val_loss: 0.6550
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6988 - loss: 0.4859 - val_accuracy: 0.6353 - val_loss: 0.6695
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.7213 - loss: 0.4510 - val_accuracy: 0.6070 - val_loss: 0.6940
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.7383 - loss: 0.4396 - val_accuracy: 0.6460 - val_loss: 0.6911
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.7472 - loss: 0.4242 - val_accuracy: 0.6178 - val_loss: 0.7200
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.7680 - loss: 0.4073 - val_accuracy: 0.5868 - val_loss: 0.7158
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.8313 - loss: 0.3638 - val_accuracy: 0.5935 - val_loss: 0.7392
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.8774 - loss: 0.2726 - val_accuracy: 0.5841 - val_loss: 0.7727
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.9020 - loss: 0.2523 - val_accuracy: 0.5868 - val_loss: 0.7992
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.9225 - loss: 0.1913 - val_accuracy: 0.6137 - val_loss: 0.9594
# 🏁 Best epoch for Fold 10: 14
# ✅ Fold 10 test accuracy: 0.6286
#
# 📌 Mean optimal epoch across folds: 11

# %%
# Cell Block 5: Final Model Training on data again, but for ep_mean Epochs (no validation needed)

# Build your TF datasets
train_final_ds = preprocess(X_rest, y_rest)        # ALL data used in K-Fold
test_final_ds  = preprocess(X_holdout, y_holdout)  # NEVER seen during CV

# Instantiate & train your final model
final_model = create_model()
final_model.fit(
    train_final_ds,
    epochs=ep_mean,
    verbose=1
)

# Evaluate once—only on the true hold-out set
final_results = final_model.evaluate(
    test_final_ds,
    verbose=1
)
print("Hold-out test loss & accuracy:", final_results)
# Out:
# Epoch 1/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 43s 364ms/step - accuracy: 0.5634 - loss: 0.8584
# Epoch 2/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 359ms/step - accuracy: 0.6067 - loss: 0.6490
# Epoch 3/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 357ms/step - accuracy: 0.6788 - loss: 0.6144
# Epoch 4/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 356ms/step - accuracy: 0.7158 - loss: 0.5898
# Epoch 5/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 359ms/step - accuracy: 0.7630 - loss: 0.5539
# Epoch 6/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 39s 335ms/step - accuracy: 0.7673 - loss: 0.5390
# Epoch 7/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 330ms/step - accuracy: 0.8091 - loss: 0.4879
# Epoch 8/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 331ms/step - accuracy: 0.8519 - loss: 0.4307
# Epoch 9/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 39s 332ms/step - accuracy: 0.8828 - loss: 0.3746
# Epoch 10/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 328ms/step - accuracy: 0.9026 - loss: 0.3236
# Epoch 11/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 39s 339ms/step - accuracy: 0.8987 - loss: 0.2618
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.7912 - loss: 0.5695
# Hold-out test loss & accuracy: [0.5536965727806091, 0.8062953948974609]

# %%
# Cell Block 5: Final Evaluation

# Evaluate final model on the 20% test set
final_test_loss, final_test_acc = final_model.evaluate(test_final_ds, verbose=0)

# Report both results
print(f"\n📊 {k}-Fold Test Accuracy: {np.mean(all_test_accuracies):.4f} ± {np.std(all_test_accuracies):.4f}")
print(f"🏁 Final model test accuracy (trained on hold-out): {final_test_acc:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Cell Block 5: Final Evaluation
#       2
#       3 # Evaluate final model on the 20% test set
# ----> 4 final_test_loss, final_test_acc = final_model.evaluate(test_final_ds, verbose=0)
#       6 # Report both results
#       7 print(f"\n📊 {k}-Fold Test Accuracy: {np.mean(all_test_accuracies):.4f} ± {np.std(all_test_accuracies):.4f}")
#
# NameError: name 'final_model' is not defined

# %%
import numpy as np
from sklearn.metrics import precision_score, roc_curve, auc, f1_score, recall_score
import matplotlib.pyplot as plt

# 1. Extract true labels and model scores from your hold-out dataset
y_true = np.concatenate([y.numpy() for x, y in test_final_ds], axis=0)
y_pred_prob = final_model.predict(test_final_ds)

# 2. If your model outputs two probabilities (one per class), take the “positive” class
if y_pred_prob.ndim > 1 and y_pred_prob.shape[1] > 1:
    y_scores = y_pred_prob[:, 1]
else:
    y_scores = y_pred_prob.ravel()

# 3. Compute ROC curve metrics
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# 4. Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr)               # ROC curve
plt.plot([0, 1], [0, 1], linestyle='--')  # chance line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (AUC = {roc_auc:.2f})')
plt.show()



# 1. Turn your predicted probabilities into binary preds (threshold = 0.5)
y_pred = (y_scores >= 0.5).astype(int)

# 2. Compute precision, recall, F1
precision = precision_score(y_true, y_pred)
recall    = recall_score(y_true, y_pred)
f1        = f1_score(y_true, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step
# Precision: 0.76
# Recall:    0.74
# F1 Score:  0.75
