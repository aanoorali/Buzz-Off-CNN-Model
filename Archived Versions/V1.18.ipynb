# %% [markdown]
# Varroa Mite Detection 1.18 Contrast and Blur

# %%
# Cell Block 1: Importing Libraries
import os
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold, train_test_split
import numpy as np
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Cell Block 2: Load Data and Preprocess

df = pd.read_csv('labels_augmented.csv')

df['filename'] = df['filename'].apply(lambda fn: os.path.join('rotations_flips', fn.strip()))

filepaths = df['filename'].values
labels = df['has_mite'].values

# %%
# Cell Block 3: Splitting Data

X_rest, X_holdout, y_rest, y_holdout = train_test_split(
    filepaths, labels,
    test_size=0.10,
    stratify=labels,
    random_state=42
)

# %%
# Cell Block 3: K-Fold Cross-Validation

# Early stopping callback
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    # min_delta=1e-4,
    restore_best_weights=True
)

k = 10  # Number of folds
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

fold = 1
all_test_accuracies = []
best_epochs = []

# Model creation function
def create_model():
    model = models.Sequential([
        layers.Input(shape=(224, 224, 3)),
        layers.Conv2D(32, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Guassian kernel function
def gaussian_kernel(size: int, sigma: float):
    x = tf.range(-size // 2 + 1, size // 2 + 1, dtype=tf.float32)
    xx, yy = tf.meshgrid(x, x)
    kernel = tf.exp(-(xx**2 + yy**2) / (2.0 * sigma**2))
    kernel = kernel / tf.reduce_sum(kernel)
    return kernel

def apply_gaussian_blur(image, kernel_size=5, sigma=1.0):
    kernel = gaussian_kernel(kernel_size, sigma)                 # [5, 5]
    kernel = kernel[:, :, tf.newaxis, tf.newaxis]                # [5, 5, 1, 1]
    kernel = tf.repeat(kernel, repeats=3, axis=2)                # [5, 5, 3, 1] ✅ CORRECT shape
    image = tf.expand_dims(image, 0)                             # [1, H, W, 3]
    blurred = tf.nn.depthwise_conv2d(image, kernel, strides=[1,1,1,1], padding='SAME')
    
    return tf.squeeze(blurred, axis=0)

# Preprocessing function
def preprocess(paths, labels):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    def load_img(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [224, 224])
        img = img / 255.0

        # 1) Apply Gaussian blur
        img = apply_gaussian_blur(img, kernel_size=5, sigma=1.0)

        # # 2) Boost blue channel
        # img = tf.clip_by_value(img + [0.0, 0.0, 0.2], 0.0, 1.0) 

        # 3) Increase contrast
        img = tf.image.adjust_contrast(img, 2.0) 

        # # 4) Boost red channel
        # img = tf.clip_by_value(img + [0.2, 0.0, 0.0], 0.0, 1.0)

        # # 5) Boost blue and red channel
        # img = tf.clip_by_value(img + [0.2, 0.0, 0.2], 0.0, 1.0)
        
        return img, label

    return ds.map(load_img).batch(32).prefetch(tf.data.AUTOTUNE)

for trainval_index, test_index in skf.split(filepaths, labels):
    print(f"\n🧪 Fold {fold} -----------------------------")

    # Split into trainval and test
    X_trainval, X_test = filepaths[trainval_index], filepaths[test_index]
    y_trainval, y_test = labels[trainval_index], labels[test_index]

    # Further split trainval into train and val (e.g. 80/20)
    val_split = int(0.8 * len(X_trainval))
    X_train, X_val = X_trainval[:val_split], X_trainval[val_split:]
    y_train, y_val = y_trainval[:val_split], y_trainval[val_split:]


    # Preprocess each split
    train_ds = preprocess(X_train, y_train)
    val_ds = preprocess(X_val, y_val)
    test_ds = preprocess(X_test, y_test)



    # Train model with early stopping
    model = create_model()
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[earlystop],
        verbose=1
    )

    # Record best epoch (smallest val_loss)
    best_epoch = np.argmin(history.history['val_loss']) + 1
    best_epochs.append(best_epoch)
    print(f"🏁 Best epoch for Fold {fold}: {best_epoch}")

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    all_test_accuracies.append(test_acc)
    print(f"✅ Fold {fold} test accuracy: {test_acc:.4f}")

    fold += 1

# Calculate mean best epoch
ep_mean = int(np.round(np.mean(best_epochs)))
print(f"\n📌 Mean optimal epoch across folds: {ep_mean}")
# Out:
# 🧪 Fold 1 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 42s 441ms/step - accuracy: 0.6009 - loss: 0.9009 - val_accuracy: 0.5922 - val_loss: 0.6756
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 443ms/step - accuracy: 0.6091 - loss: 0.6704 - val_accuracy: 0.5922 - val_loss: 0.6903
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 412ms/step - accuracy: 0.6091 - loss: 0.6886 - val_accuracy: 0.5922 - val_loss: 0.6866
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 360ms/step - accuracy: 0.6091 - loss: 0.6844 - val_accuracy: 0.5922 - val_loss: 0.6838
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 355ms/step - accuracy: 0.6091 - loss: 0.6811 - val_accuracy: 0.5922 - val_loss: 0.6817
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.6091 - loss: 0.6786 - val_accuracy: 0.5922 - val_loss: 0.6802
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 360ms/step - accuracy: 0.6091 - loss: 0.6766 - val_accuracy: 0.5922 - val_loss: 0.6790
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 355ms/step - accuracy: 0.6091 - loss: 0.6750 - val_accuracy: 0.5922 - val_loss: 0.6781
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 356ms/step - accuracy: 0.6091 - loss: 0.6738 - val_accuracy: 0.5922 - val_loss: 0.6774
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6091 - loss: 0.6728 - val_accuracy: 0.5922 - val_loss: 0.6770
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6091 - loss: 0.6720 - val_accuracy: 0.5922 - val_loss: 0.6766
# 🏁 Best epoch for Fold 1: 1
# ✅ Fold 1 test accuracy: 0.6029
#
# 🧪 Fold 2 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 359ms/step - accuracy: 0.6154 - loss: 0.9565 - val_accuracy: 0.5868 - val_loss: 0.6779
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6157 - loss: 0.6661 - val_accuracy: 0.5868 - val_loss: 0.6543
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 356ms/step - accuracy: 0.6183 - loss: 0.6640 - val_accuracy: 0.6555 - val_loss: 0.6292
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 355ms/step - accuracy: 0.6521 - loss: 0.6326 - val_accuracy: 0.6487 - val_loss: 0.6283
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 356ms/step - accuracy: 0.6926 - loss: 0.5998 - val_accuracy: 0.6353 - val_loss: 0.6557
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 356ms/step - accuracy: 0.7324 - loss: 0.5379 - val_accuracy: 0.6433 - val_loss: 0.8070
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 356ms/step - accuracy: 0.7889 - loss: 0.4458 - val_accuracy: 0.6595 - val_loss: 0.7769
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 355ms/step - accuracy: 0.8571 - loss: 0.3094 - val_accuracy: 0.7147 - val_loss: 0.8115
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 371ms/step - accuracy: 0.9188 - loss: 0.1879 - val_accuracy: 0.7160 - val_loss: 0.7592
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.9541 - loss: 0.1164 - val_accuracy: 0.7510 - val_loss: 0.8878
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.9624 - loss: 0.1044 - val_accuracy: 0.7376 - val_loss: 0.8931
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9811 - loss: 0.0535 - val_accuracy: 0.6891 - val_loss: 1.2059
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9840 - loss: 0.0452 - val_accuracy: 0.6703 - val_loss: 0.8219
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.9742 - loss: 0.0734 - val_accuracy: 0.7174 - val_loss: 1.1686
# 🏁 Best epoch for Fold 2: 4
# ✅ Fold 2 test accuracy: 0.6271
#
# 🧪 Fold 3 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.5919 - loss: 0.8031 - val_accuracy: 0.5828 - val_loss: 0.6763
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6151 - loss: 0.6643 - val_accuracy: 0.5935 - val_loss: 0.6539
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6463 - loss: 0.6344 - val_accuracy: 0.5828 - val_loss: 0.6793
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6189 - loss: 0.6626 - val_accuracy: 0.6380 - val_loss: 0.6258
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6804 - loss: 0.6119 - val_accuracy: 0.6622 - val_loss: 0.6170
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.7318 - loss: 0.5297 - val_accuracy: 0.7550 - val_loss: 0.5777
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.8317 - loss: 0.3947 - val_accuracy: 0.7456 - val_loss: 0.5096
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.8775 - loss: 0.2816 - val_accuracy: 0.7833 - val_loss: 0.6063
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.9091 - loss: 0.2200 - val_accuracy: 0.7699 - val_loss: 0.6101
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.9407 - loss: 0.1496 - val_accuracy: 0.7497 - val_loss: 0.7456
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.9479 - loss: 0.1159 - val_accuracy: 0.7147 - val_loss: 0.7474
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9432 - loss: 0.1226 - val_accuracy: 0.7712 - val_loss: 1.2290
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.9601 - loss: 0.0907 - val_accuracy: 0.7349 - val_loss: 1.0158
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.9584 - loss: 0.0718 - val_accuracy: 0.7524 - val_loss: 1.0114
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9687 - loss: 0.0481 - val_accuracy: 0.7039 - val_loss: 1.0565
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.9662 - loss: 0.0524 - val_accuracy: 0.6716 - val_loss: 1.4351
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9704 - loss: 0.0621 - val_accuracy: 0.6985 - val_loss: 1.1079
# 🏁 Best epoch for Fold 3: 7
# ✅ Fold 3 test accuracy: 0.8015
#
# 🧪 Fold 4 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6095 - loss: 0.8851 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6089 - loss: 0.6714 - val_accuracy: 0.5814 - val_loss: 0.6772
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6727 - loss: 0.6135 - val_accuracy: 0.7510 - val_loss: 0.5695
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.8189 - loss: 0.4287 - val_accuracy: 0.7873 - val_loss: 0.4839
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.8648 - loss: 0.3261 - val_accuracy: 0.8197 - val_loss: 0.4425
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.8835 - loss: 0.2996 - val_accuracy: 0.8250 - val_loss: 0.4226
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.8924 - loss: 0.2753 - val_accuracy: 0.8291 - val_loss: 0.4167
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.9128 - loss: 0.2216 - val_accuracy: 0.8358 - val_loss: 0.4299
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9319 - loss: 0.1715 - val_accuracy: 0.8197 - val_loss: 0.5733
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.9460 - loss: 0.1440 - val_accuracy: 0.7847 - val_loss: 1.0481
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.9554 - loss: 0.1304 - val_accuracy: 0.8102 - val_loss: 1.0475
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.9474 - loss: 0.1458 - val_accuracy: 0.8116 - val_loss: 0.6450
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9488 - loss: 0.1358 - val_accuracy: 0.7779 - val_loss: 0.6266
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.9485 - loss: 0.1178 - val_accuracy: 0.8237 - val_loss: 0.5732
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9704 - loss: 0.0894 - val_accuracy: 0.8116 - val_loss: 0.8504
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9818 - loss: 0.0651 - val_accuracy: 0.8425 - val_loss: 0.6259
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.9841 - loss: 0.0594 - val_accuracy: 0.7739 - val_loss: 0.6815
# 🏁 Best epoch for Fold 4: 7
# ✅ Fold 4 test accuracy: 0.8329
#
# 🧪 Fold 5 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.5397 - loss: 0.8754 - val_accuracy: 0.5922 - val_loss: 0.6755
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6052 - loss: 0.6687 - val_accuracy: 0.5922 - val_loss: 0.6742
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6095 - loss: 0.6609 - val_accuracy: 0.5922 - val_loss: 0.6466
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6099 - loss: 0.6383 - val_accuracy: 0.5922 - val_loss: 0.6525
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6099 - loss: 0.6409 - val_accuracy: 0.5922 - val_loss: 0.6354
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6102 - loss: 0.6218 - val_accuracy: 0.6353 - val_loss: 0.6398
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6338 - loss: 0.6049 - val_accuracy: 0.5922 - val_loss: 0.6392
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6201 - loss: 0.5681 - val_accuracy: 0.6433 - val_loss: 0.6571
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.7165 - loss: 0.5190 - val_accuracy: 0.6205 - val_loss: 0.6943
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.7563 - loss: 0.4497 - val_accuracy: 0.6164 - val_loss: 0.7045
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.7869 - loss: 0.4004 - val_accuracy: 0.6030 - val_loss: 0.6951
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.8087 - loss: 0.3400 - val_accuracy: 0.6380 - val_loss: 0.7355
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.8540 - loss: 0.3181 - val_accuracy: 0.6353 - val_loss: 0.7915
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.8678 - loss: 0.2764 - val_accuracy: 0.6258 - val_loss: 0.8460
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.8617 - loss: 0.2958 - val_accuracy: 0.6380 - val_loss: 0.8163
# 🏁 Best epoch for Fold 5: 5
# ✅ Fold 5 test accuracy: 0.6029
#
# 🧪 Fold 6 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.5795 - loss: 0.8580 - val_accuracy: 0.5774 - val_loss: 0.6802
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6287 - loss: 0.6665 - val_accuracy: 0.6003 - val_loss: 0.6559
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6230 - loss: 0.6492 - val_accuracy: 0.6083 - val_loss: 0.6571
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6654 - loss: 0.6275 - val_accuracy: 0.6555 - val_loss: 0.6487
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6979 - loss: 0.5862 - val_accuracy: 0.6595 - val_loss: 0.6700
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.7491 - loss: 0.5151 - val_accuracy: 0.6689 - val_loss: 0.7066
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.8133 - loss: 0.4134 - val_accuracy: 0.6393 - val_loss: 0.6676
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.8508 - loss: 0.3393 - val_accuracy: 0.6689 - val_loss: 0.8540
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.8973 - loss: 0.2417 - val_accuracy: 0.6555 - val_loss: 1.2131
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9388 - loss: 0.1483 - val_accuracy: 0.6460 - val_loss: 1.7273
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9346 - loss: 0.1471 - val_accuracy: 0.6447 - val_loss: 1.6399
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9486 - loss: 0.1211 - val_accuracy: 0.6622 - val_loss: 1.8004
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9584 - loss: 0.1000 - val_accuracy: 0.6460 - val_loss: 1.7896
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.9717 - loss: 0.0630 - val_accuracy: 0.6528 - val_loss: 1.3325
# 🏁 Best epoch for Fold 6: 4
# ✅ Fold 6 test accuracy: 0.6262
#
# 🧪 Fold 7 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 342ms/step - accuracy: 0.5937 - loss: 0.8576 - val_accuracy: 0.5882 - val_loss: 0.6770
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6182 - loss: 0.6689 - val_accuracy: 0.5882 - val_loss: 0.6609
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6169 - loss: 0.6652 - val_accuracy: 0.5882 - val_loss: 0.6593
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6448 - loss: 0.6370 - val_accuracy: 0.6514 - val_loss: 0.6157
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6994 - loss: 0.5890 - val_accuracy: 0.6420 - val_loss: 0.6537
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.7545 - loss: 0.5233 - val_accuracy: 0.6581 - val_loss: 0.6923
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.7985 - loss: 0.4276 - val_accuracy: 0.6528 - val_loss: 0.9864
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.8412 - loss: 0.3365 - val_accuracy: 0.6514 - val_loss: 0.8734
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.8708 - loss: 0.2889 - val_accuracy: 0.6635 - val_loss: 0.9037
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9206 - loss: 0.1904 - val_accuracy: 0.6393 - val_loss: 0.9176
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.9325 - loss: 0.1599 - val_accuracy: 0.6703 - val_loss: 1.0408
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9489 - loss: 0.1148 - val_accuracy: 0.6514 - val_loss: 1.3542
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9771 - loss: 0.0563 - val_accuracy: 0.6339 - val_loss: 1.6792
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.9826 - loss: 0.0313 - val_accuracy: 0.6622 - val_loss: 1.5400
# 🏁 Best epoch for Fold 7: 4
# ✅ Fold 7 test accuracy: 0.6602
#
# 🧪 Fold 8 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 343ms/step - accuracy: 0.5527 - loss: 0.8435 - val_accuracy: 0.5908 - val_loss: 0.6755
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6148 - loss: 0.6662 - val_accuracy: 0.5908 - val_loss: 0.6768
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6107 - loss: 0.6677 - val_accuracy: 0.5908 - val_loss: 0.6837
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6148 - loss: 0.6686 - val_accuracy: 0.5908 - val_loss: 0.6862
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6007 - loss: 0.6717 - val_accuracy: 0.5908 - val_loss: 0.6704
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6170 - loss: 0.6394 - val_accuracy: 0.6043 - val_loss: 0.6599
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6239 - loss: 0.6391 - val_accuracy: 0.6258 - val_loss: 0.6420
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6953 - loss: 0.5880 - val_accuracy: 0.6353 - val_loss: 0.6354
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.7146 - loss: 0.5604 - val_accuracy: 0.6420 - val_loss: 0.6603
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.7606 - loss: 0.4513 - val_accuracy: 0.6474 - val_loss: 0.6756
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.8059 - loss: 0.3726 - val_accuracy: 0.6568 - val_loss: 0.6979
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.8460 - loss: 0.3023 - val_accuracy: 0.6124 - val_loss: 1.0968
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.8566 - loss: 0.2572 - val_accuracy: 0.6137 - val_loss: 1.2654
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.8791 - loss: 0.2140 - val_accuracy: 0.6258 - val_loss: 1.3869
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.9000 - loss: 0.1673 - val_accuracy: 0.6205 - val_loss: 1.3188
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.9073 - loss: 0.1645 - val_accuracy: 0.6339 - val_loss: 1.1186
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9121 - loss: 0.1550 - val_accuracy: 0.6164 - val_loss: 1.6964
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.9251 - loss: 0.1231 - val_accuracy: 0.6164 - val_loss: 1.7147
# 🏁 Best epoch for Fold 8: 8
# ✅ Fold 8 test accuracy: 0.6335
#
# 🧪 Fold 9 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 346ms/step - accuracy: 0.6136 - loss: 0.8923 - val_accuracy: 0.5922 - val_loss: 0.6912
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6206 - loss: 0.6893 - val_accuracy: 0.5922 - val_loss: 0.6872
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.6206 - loss: 0.6842 - val_accuracy: 0.5922 - val_loss: 0.6842
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6206 - loss: 0.6802 - val_accuracy: 0.5922 - val_loss: 0.6819
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 369ms/step - accuracy: 0.6206 - loss: 0.6769 - val_accuracy: 0.5922 - val_loss: 0.6802
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6206 - loss: 0.6744 - val_accuracy: 0.5922 - val_loss: 0.6790
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6206 - loss: 0.6724 - val_accuracy: 0.5922 - val_loss: 0.6780
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6206 - loss: 0.6708 - val_accuracy: 0.5922 - val_loss: 0.6774
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6206 - loss: 0.6695 - val_accuracy: 0.5922 - val_loss: 0.6769
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6206 - loss: 0.6685 - val_accuracy: 0.5922 - val_loss: 0.6766
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6206 - loss: 0.6677 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6206 - loss: 0.6671 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6206 - loss: 0.6666 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6206 - loss: 0.6662 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6206 - loss: 0.6659 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6206 - loss: 0.6656 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6206 - loss: 0.6654 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6206 - loss: 0.6652 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6206 - loss: 0.6651 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6206 - loss: 0.6649 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6206 - loss: 0.6648 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6206 - loss: 0.6648 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 343ms/step - accuracy: 0.6206 - loss: 0.6647 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6206 - loss: 0.6646 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6206 - loss: 0.6646 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6206 - loss: 0.6646 - val_accuracy: 0.5922 - val_loss: 0.6763
# 🏁 Best epoch for Fold 9: 16
# ✅ Fold 9 test accuracy: 0.6019
#
# 🧪 Fold 10 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 344ms/step - accuracy: 0.5687 - loss: 0.7077 - val_accuracy: 0.5922 - val_loss: 0.6757
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6145 - loss: 0.6743 - val_accuracy: 0.5922 - val_loss: 0.6809
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6145 - loss: 0.6792 - val_accuracy: 0.5922 - val_loss: 0.6759
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6145 - loss: 0.6711 - val_accuracy: 0.5922 - val_loss: 0.6758
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6145 - loss: 0.6739 - val_accuracy: 0.5922 - val_loss: 0.6759
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6145 - loss: 0.6718 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6145 - loss: 0.6708 - val_accuracy: 0.5922 - val_loss: 0.6758
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6145 - loss: 0.6691 - val_accuracy: 0.5922 - val_loss: 0.6764
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6145 - loss: 0.6778 - val_accuracy: 0.5922 - val_loss: 0.6855
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6145 - loss: 0.6825 - val_accuracy: 0.5922 - val_loss: 0.6827
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6145 - loss: 0.6789 - val_accuracy: 0.5922 - val_loss: 0.6806
# 🏁 Best epoch for Fold 10: 1
# ✅ Fold 10 test accuracy: 0.6019
#
# 📌 Mean optimal epoch across folds: 6

# %%
# Cell Block 5: Final Model Training on data again, but for ep_mean Epochs (no validation needed)

# Build your TF datasets
train_final_ds = preprocess(X_rest, y_rest)        # ALL data used in K-Fold
test_final_ds  = preprocess(X_holdout, y_holdout)  # NEVER seen during CV

# Instantiate & train your final model
final_model = create_model()
final_model.fit(
    train_final_ds,
    epochs=ep_mean,
    verbose=1
)

# Evaluate once—only on the true hold-out set
final_results = final_model.evaluate(
    test_final_ds,
    verbose=1
)
print("Hold-out test loss & accuracy:", final_results)
# Out:
# Epoch 1/6
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 344ms/step - accuracy: 0.5866 - loss: 0.9388
# Epoch 2/6
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 40s 341ms/step - accuracy: 0.6143 - loss: 0.6361
# Epoch 3/6
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 39s 338ms/step - accuracy: 0.8328 - loss: 0.4225
# Epoch 4/6
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 39s 339ms/step - accuracy: 0.8685 - loss: 0.3363
# Epoch 5/6
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 39s 339ms/step - accuracy: 0.8801 - loss: 0.3058
# Epoch 6/6
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 39s 338ms/step - accuracy: 0.8844 - loss: 0.2771
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.8656 - loss: 0.3469
# Hold-out test loss & accuracy: [0.33141544461250305, 0.8765133023262024]

# %%
# Cell Block 5: Final Evaluation

# Evaluate final model on the 20% test set
final_test_loss, final_test_acc = final_model.evaluate(test_final_ds, verbose=0)

# Report both results
print(f"\n📊 {k}-Fold Test Accuracy: {np.mean(all_test_accuracies):.4f} ± {np.std(all_test_accuracies):.4f}")
print(f"🏁 Final model test accuracy (trained on hold-out): {final_test_acc:.4f}")
# Out:
# 📊 10-Fold Test Accuracy: 0.6591 ± 0.0813
# 🏁 Final model test accuracy (trained on hold-out): 0.8765

# %%
import numpy as np
from sklearn.metrics import precision_score, roc_curve, auc, f1_score, recall_score
import matplotlib.pyplot as plt

# 1. Extract true labels and model scores from your hold-out dataset
y_true = np.concatenate([y.numpy() for x, y in test_final_ds], axis=0)
y_pred_prob = final_model.predict(test_final_ds)

# 2. If your model outputs two probabilities (one per class), take the “positive” class
if y_pred_prob.ndim > 1 and y_pred_prob.shape[1] > 1:
    y_scores = y_pred_prob[:, 1]
else:
    y_scores = y_pred_prob.ravel()

# 3. Compute ROC curve metrics
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# 4. Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr)               # ROC curve
plt.plot([0, 1], [0, 1], linestyle='--')  # chance line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (AUC = {roc_auc:.2f})')
plt.show()



# 1. Turn your predicted probabilities into binary preds (threshold = 0.5)
y_pred = (y_scores >= 0.5).astype(int)

# 2. Compute precision, recall, F1
precision = precision_score(y_true, y_pred)
recall    = recall_score(y_true, y_pred)
f1        = f1_score(y_true, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step
# Precision: 0.88
# Recall:    0.79
# F1 Score:  0.84
