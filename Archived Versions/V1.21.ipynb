# %% [markdown]
# Varroa Mite Detection 1.21 Brightness and Blur

# %%
# Cell Block 1: Importing Libraries
import os
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold, train_test_split
import numpy as np
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Cell Block 2: Load Data and Preprocess

df = pd.read_csv('labels_augmented.csv')

df['filename'] = df['filename'].apply(lambda fn: os.path.join('rotations_flips', fn.strip()))

filepaths = df['filename'].values
labels = df['has_mite'].values

# %%
# Cell Block 3: Splitting Data

X_rest, X_holdout, y_rest, y_holdout = train_test_split(
    filepaths, labels,
    test_size=0.10,
    stratify=labels,
    random_state=42
)

# %%
# Cell Block 3: K-Fold Cross-Validation

# Early stopping callback
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    # min_delta=1e-4,
    restore_best_weights=True
)

k = 10  # Number of folds
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

fold = 1
all_test_accuracies = []
best_epochs = []

# Model creation function
def create_model():
    model = models.Sequential([
        layers.Input(shape=(224, 224, 3)),
        layers.Conv2D(32, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Guassian kernel function
def gaussian_kernel(size: int, sigma: float):
    x = tf.range(-size // 2 + 1, size // 2 + 1, dtype=tf.float32)
    xx, yy = tf.meshgrid(x, x)
    kernel = tf.exp(-(xx**2 + yy**2) / (2.0 * sigma**2))
    kernel = kernel / tf.reduce_sum(kernel)
    return kernel

def apply_gaussian_blur(image, kernel_size=5, sigma=1.0):
    kernel = gaussian_kernel(kernel_size, sigma)                 # [5, 5]
    kernel = kernel[:, :, tf.newaxis, tf.newaxis]                # [5, 5, 1, 1]
    kernel = tf.repeat(kernel, repeats=3, axis=2)                # [5, 5, 3, 1] ✅ CORRECT shape
    image = tf.expand_dims(image, 0)                             # [1, H, W, 3]
    blurred = tf.nn.depthwise_conv2d(image, kernel, strides=[1,1,1,1], padding='SAME')
    
    return tf.squeeze(blurred, axis=0)

# Preprocessing function
def preprocess(paths, labels):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    def load_img(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [224, 224])
        img = img / 255.0

        # 1) Apply Gaussian blur
        img = apply_gaussian_blur(img, kernel_size=5, sigma=1.0)

        # # 2) Boost blue channel
        # img = tf.clip_by_value(img + [0.0, 0.0, 0.2], 0.0, 1.0) 

        # # 3) Increase contrast
        # img = tf.image.adjust_contrast(img, 2.0) 

        # # 4) Boost red channel
        # img = tf.clip_by_value(img + [0.2, 0.0, 0.0], 0.0, 1.0)

        # # 5) Boost blue and red channel
        # img = tf.clip_by_value(img + [0.2, 0.0, 0.2], 0.0, 1.0)

        # 6) Boost the Brightness
        img = tf.image.adjust_brightness(img, delta=0.1)

        
        return img, label

    return ds.map(load_img).batch(32).prefetch(tf.data.AUTOTUNE)

for trainval_index, test_index in skf.split(filepaths, labels):
    print(f"\n🧪 Fold {fold} -----------------------------")

    # Split into trainval and test
    X_trainval, X_test = filepaths[trainval_index], filepaths[test_index]
    y_trainval, y_test = labels[trainval_index], labels[test_index]

    # Further split trainval into train and val (e.g. 80/20)
    val_split = int(0.8 * len(X_trainval))
    X_train, X_val = X_trainval[:val_split], X_trainval[val_split:]
    y_train, y_val = y_trainval[:val_split], y_trainval[val_split:]


    # Preprocess each split
    train_ds = preprocess(X_train, y_train)
    val_ds = preprocess(X_val, y_val)
    test_ds = preprocess(X_test, y_test)



    # Train model with early stopping
    model = create_model()
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[earlystop],
        verbose=1
    )

    # Record best epoch (smallest val_loss)
    best_epoch = np.argmin(history.history['val_loss']) + 1
    best_epochs.append(best_epoch)
    print(f"🏁 Best epoch for Fold {fold}: {best_epoch}")

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    all_test_accuracies.append(test_acc)
    print(f"✅ Fold {fold} test accuracy: {test_acc:.4f}")

    fold += 1

# Calculate mean best epoch
ep_mean = int(np.round(np.mean(best_epochs)))
print(f"\n📌 Mean optimal epoch across folds: {ep_mean}")
# Out:
# 🧪 Fold 1 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 428ms/step - accuracy: 0.5838 - loss: 0.7791 - val_accuracy: 0.5922 - val_loss: 0.6805
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 399ms/step - accuracy: 0.6091 - loss: 0.6758 - val_accuracy: 0.5922 - val_loss: 0.6900
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6091 - loss: 0.6883 - val_accuracy: 0.5922 - val_loss: 0.6864
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 408ms/step - accuracy: 0.6091 - loss: 0.6842 - val_accuracy: 0.5922 - val_loss: 0.6837
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 403ms/step - accuracy: 0.6091 - loss: 0.6810 - val_accuracy: 0.5922 - val_loss: 0.6816
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 401ms/step - accuracy: 0.6091 - loss: 0.6784 - val_accuracy: 0.5922 - val_loss: 0.6801
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 408ms/step - accuracy: 0.6091 - loss: 0.6765 - val_accuracy: 0.5922 - val_loss: 0.6789
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 406ms/step - accuracy: 0.6091 - loss: 0.6749 - val_accuracy: 0.5922 - val_loss: 0.6780
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 409ms/step - accuracy: 0.6091 - loss: 0.6737 - val_accuracy: 0.5922 - val_loss: 0.6774
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 404ms/step - accuracy: 0.6091 - loss: 0.6727 - val_accuracy: 0.5922 - val_loss: 0.6770
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 404ms/step - accuracy: 0.6091 - loss: 0.6720 - val_accuracy: 0.5922 - val_loss: 0.6766
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 406ms/step - accuracy: 0.6091 - loss: 0.6714 - val_accuracy: 0.5922 - val_loss: 0.6764
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 408ms/step - accuracy: 0.6091 - loss: 0.6710 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 406ms/step - accuracy: 0.6091 - loss: 0.6706 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 409ms/step - accuracy: 0.6091 - loss: 0.6703 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 406ms/step - accuracy: 0.6091 - loss: 0.6701 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6091 - loss: 0.6699 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 409ms/step - accuracy: 0.6091 - loss: 0.6698 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6091 - loss: 0.6697 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 406ms/step - accuracy: 0.6091 - loss: 0.6696 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 408ms/step - accuracy: 0.6091 - loss: 0.6695 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 409ms/step - accuracy: 0.6091 - loss: 0.6695 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.6091 - loss: 0.6694 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6091 - loss: 0.6694 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 381ms/step - accuracy: 0.6091 - loss: 0.6694 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6091 - loss: 0.6693 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 386ms/step - accuracy: 0.6091 - loss: 0.6693 - val_accuracy: 0.5922 - val_loss: 0.6762
# 🏁 Best epoch for Fold 1: 17
# ✅ Fold 1 test accuracy: 0.6029
#
# 🧪 Fold 2 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 399ms/step - accuracy: 0.5704 - loss: 0.7025 - val_accuracy: 0.5868 - val_loss: 0.6911
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 392ms/step - accuracy: 0.6182 - loss: 0.6890 - val_accuracy: 0.5868 - val_loss: 0.6798
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6068 - loss: 0.6699 - val_accuracy: 0.5868 - val_loss: 0.6747
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6117 - loss: 0.6694 - val_accuracy: 0.5868 - val_loss: 0.6787
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6182 - loss: 0.6687 - val_accuracy: 0.5868 - val_loss: 0.6788
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6266 - loss: 0.6631 - val_accuracy: 0.5868 - val_loss: 0.6845
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6182 - loss: 0.6800 - val_accuracy: 0.5868 - val_loss: 0.6825
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6182 - loss: 0.6769 - val_accuracy: 0.5868 - val_loss: 0.6810
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6182 - loss: 0.6745 - val_accuracy: 0.5868 - val_loss: 0.6800
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6182 - loss: 0.6726 - val_accuracy: 0.5868 - val_loss: 0.6792
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6182 - loss: 0.6711 - val_accuracy: 0.5868 - val_loss: 0.6787
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6182 - loss: 0.6700 - val_accuracy: 0.5868 - val_loss: 0.6784
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6182 - loss: 0.6691 - val_accuracy: 0.5868 - val_loss: 0.6782
# 🏁 Best epoch for Fold 2: 3
# ✅ Fold 2 test accuracy: 0.6029
#
# 🧪 Fold 3 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6092 - loss: 0.8286 - val_accuracy: 0.5828 - val_loss: 0.6832
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6116 - loss: 0.6739 - val_accuracy: 0.5828 - val_loss: 0.6798
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6173 - loss: 0.6704 - val_accuracy: 0.5828 - val_loss: 0.6798
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 422ms/step - accuracy: 0.6173 - loss: 0.6755 - val_accuracy: 0.5828 - val_loss: 0.6814
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.6125 - loss: 0.6706 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 399ms/step - accuracy: 0.6018 - loss: 0.6748 - val_accuracy: 0.5828 - val_loss: 0.6799
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.6173 - loss: 0.6705 - val_accuracy: 0.5828 - val_loss: 0.6815
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.6173 - loss: 0.6727 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.6173 - loss: 0.6680 - val_accuracy: 0.5828 - val_loss: 0.6796
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 385ms/step - accuracy: 0.6173 - loss: 0.6666 - val_accuracy: 0.5828 - val_loss: 0.6798
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6173 - loss: 0.6668 - val_accuracy: 0.5828 - val_loss: 0.6797
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 355ms/step - accuracy: 0.6173 - loss: 0.6885 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6173 - loss: 0.6679 - val_accuracy: 0.5828 - val_loss: 0.6797
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 356ms/step - accuracy: 0.6173 - loss: 0.6665 - val_accuracy: 0.5828 - val_loss: 0.6800
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.6173 - loss: 0.6661 - val_accuracy: 0.5828 - val_loss: 0.6802
# 🏁 Best epoch for Fold 3: 5
# ✅ Fold 3 test accuracy: 0.6029
#
# 🧪 Fold 4 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 362ms/step - accuracy: 0.5724 - loss: 0.7362 - val_accuracy: 0.5814 - val_loss: 0.6855
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 364ms/step - accuracy: 0.6183 - loss: 0.6742 - val_accuracy: 0.5814 - val_loss: 0.6857
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 362ms/step - accuracy: 0.6183 - loss: 0.6773 - val_accuracy: 0.5814 - val_loss: 0.6901
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 361ms/step - accuracy: 0.6183 - loss: 0.6874 - val_accuracy: 0.5814 - val_loss: 0.6869
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 362ms/step - accuracy: 0.6183 - loss: 0.6826 - val_accuracy: 0.5814 - val_loss: 0.6846
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.6183 - loss: 0.6790 - val_accuracy: 0.5814 - val_loss: 0.6829
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.6183 - loss: 0.6761 - val_accuracy: 0.5814 - val_loss: 0.6818
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 363ms/step - accuracy: 0.6183 - loss: 0.6739 - val_accuracy: 0.5814 - val_loss: 0.6810
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6183 - loss: 0.6721 - val_accuracy: 0.5814 - val_loss: 0.6804
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.6183 - loss: 0.6707 - val_accuracy: 0.5814 - val_loss: 0.6801
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6183 - loss: 0.6696 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6183 - loss: 0.6688 - val_accuracy: 0.5814 - val_loss: 0.6798
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6183 - loss: 0.6681 - val_accuracy: 0.5814 - val_loss: 0.6798
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6183 - loss: 0.6675 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.6183 - loss: 0.6671 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6183 - loss: 0.6667 - val_accuracy: 0.5814 - val_loss: 0.6800
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6183 - loss: 0.6665 - val_accuracy: 0.5814 - val_loss: 0.6801
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6183 - loss: 0.6662 - val_accuracy: 0.5814 - val_loss: 0.6802
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6183 - loss: 0.6661 - val_accuracy: 0.5814 - val_loss: 0.6803
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6183 - loss: 0.6659 - val_accuracy: 0.5814 - val_loss: 0.6804
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6183 - loss: 0.6658 - val_accuracy: 0.5814 - val_loss: 0.6805
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6183 - loss: 0.6657 - val_accuracy: 0.5814 - val_loss: 0.6806
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6183 - loss: 0.6656 - val_accuracy: 0.5814 - val_loss: 0.6806
# 🏁 Best epoch for Fold 4: 13
# ✅ Fold 4 test accuracy: 0.6029
#
# 🧪 Fold 5 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 343ms/step - accuracy: 0.5772 - loss: 0.8475 - val_accuracy: 0.5922 - val_loss: 0.6790
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6099 - loss: 0.6735 - val_accuracy: 0.5922 - val_loss: 0.6784
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6095 - loss: 0.6739 - val_accuracy: 0.5922 - val_loss: 0.6778
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6099 - loss: 0.6748 - val_accuracy: 0.5922 - val_loss: 0.6880
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6099 - loss: 0.6859 - val_accuracy: 0.5922 - val_loss: 0.6845
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 338ms/step - accuracy: 0.6099 - loss: 0.6817 - val_accuracy: 0.5922 - val_loss: 0.6819
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6099 - loss: 0.6786 - val_accuracy: 0.5922 - val_loss: 0.6801
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6099 - loss: 0.6763 - val_accuracy: 0.5922 - val_loss: 0.6788
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6099 - loss: 0.6746 - val_accuracy: 0.5922 - val_loss: 0.6779
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6099 - loss: 0.6732 - val_accuracy: 0.5922 - val_loss: 0.6772
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6099 - loss: 0.6722 - val_accuracy: 0.5922 - val_loss: 0.6768
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6099 - loss: 0.6714 - val_accuracy: 0.5922 - val_loss: 0.6765
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6099 - loss: 0.6709 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6099 - loss: 0.6704 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6099 - loss: 0.6701 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6099 - loss: 0.6698 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6099 - loss: 0.6696 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6099 - loss: 0.6695 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6099 - loss: 0.6694 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6099 - loss: 0.6693 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6099 - loss: 0.6692 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6099 - loss: 0.6691 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6099 - loss: 0.6691 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6099 - loss: 0.6691 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6099 - loss: 0.6690 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6099 - loss: 0.6690 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6099 - loss: 0.6690 - val_accuracy: 0.5922 - val_loss: 0.6763
# 🏁 Best epoch for Fold 5: 17
# ✅ Fold 5 test accuracy: 0.6029
#
# 🧪 Fold 6 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 344ms/step - accuracy: 0.5868 - loss: 0.8585 - val_accuracy: 0.5774 - val_loss: 0.6836
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6124 - loss: 0.6813 - val_accuracy: 0.5774 - val_loss: 0.6815
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6124 - loss: 0.6758 - val_accuracy: 0.5774 - val_loss: 0.6847
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6124 - loss: 0.6744 - val_accuracy: 0.5774 - val_loss: 0.6818
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6124 - loss: 0.6703 - val_accuracy: 0.5774 - val_loss: 0.6855
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6124 - loss: 0.6721 - val_accuracy: 0.5774 - val_loss: 0.6826
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6124 - loss: 0.6694 - val_accuracy: 0.5774 - val_loss: 0.6826
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6124 - loss: 0.6692 - val_accuracy: 0.5774 - val_loss: 0.6826
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6124 - loss: 0.6691 - val_accuracy: 0.5774 - val_loss: 0.6827
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6124 - loss: 0.6690 - val_accuracy: 0.5774 - val_loss: 0.6827
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6124 - loss: 0.6690 - val_accuracy: 0.5774 - val_loss: 0.6827
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6124 - loss: 0.6694 - val_accuracy: 0.5774 - val_loss: 0.6832
# 🏁 Best epoch for Fold 6: 2
# ✅ Fold 6 test accuracy: 0.6019
#
# 🧪 Fold 7 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.5539 - loss: 0.7319 - val_accuracy: 0.5882 - val_loss: 0.6802
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6191 - loss: 0.6693 - val_accuracy: 0.5882 - val_loss: 0.6796
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6191 - loss: 0.6733 - val_accuracy: 0.5882 - val_loss: 0.6792
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6202 - loss: 0.6692 - val_accuracy: 0.5882 - val_loss: 0.6877
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6191 - loss: 0.6844 - val_accuracy: 0.5882 - val_loss: 0.6845
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6191 - loss: 0.6800 - val_accuracy: 0.5882 - val_loss: 0.6823
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6191 - loss: 0.6767 - val_accuracy: 0.5882 - val_loss: 0.6807
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6191 - loss: 0.6742 - val_accuracy: 0.5882 - val_loss: 0.6796
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6191 - loss: 0.6722 - val_accuracy: 0.5882 - val_loss: 0.6788
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6191 - loss: 0.6707 - val_accuracy: 0.5882 - val_loss: 0.6783
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 391ms/step - accuracy: 0.6191 - loss: 0.6695 - val_accuracy: 0.5882 - val_loss: 0.6779
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 439ms/step - accuracy: 0.6191 - loss: 0.6685 - val_accuracy: 0.5882 - val_loss: 0.6777
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 42s 456ms/step - accuracy: 0.6191 - loss: 0.6678 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 444ms/step - accuracy: 0.6191 - loss: 0.6673 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 416ms/step - accuracy: 0.6191 - loss: 0.6668 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 417ms/step - accuracy: 0.6191 - loss: 0.6664 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 416ms/step - accuracy: 0.6191 - loss: 0.6662 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 424ms/step - accuracy: 0.6191 - loss: 0.6659 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 421ms/step - accuracy: 0.6191 - loss: 0.6658 - val_accuracy: 0.5882 - val_loss: 0.6777
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 419ms/step - accuracy: 0.6191 - loss: 0.6656 - val_accuracy: 0.5882 - val_loss: 0.6777
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 425ms/step - accuracy: 0.6191 - loss: 0.6655 - val_accuracy: 0.5882 - val_loss: 0.6778
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 417ms/step - accuracy: 0.6191 - loss: 0.6654 - val_accuracy: 0.5882 - val_loss: 0.6778
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 415ms/step - accuracy: 0.6191 - loss: 0.6653 - val_accuracy: 0.5882 - val_loss: 0.6778
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 418ms/step - accuracy: 0.6191 - loss: 0.6652 - val_accuracy: 0.5882 - val_loss: 0.6779
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 417ms/step - accuracy: 0.6191 - loss: 0.6652 - val_accuracy: 0.5882 - val_loss: 0.6779
# 🏁 Best epoch for Fold 7: 15
# ✅ Fold 7 test accuracy: 0.6019
#
# 🧪 Fold 8 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 417ms/step - accuracy: 0.5784 - loss: 0.9546 - val_accuracy: 0.5908 - val_loss: 0.6779
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 425ms/step - accuracy: 0.6109 - loss: 0.6713 - val_accuracy: 0.5908 - val_loss: 0.6784
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 420ms/step - accuracy: 0.6164 - loss: 0.6737 - val_accuracy: 0.5908 - val_loss: 0.6764
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 418ms/step - accuracy: 0.6088 - loss: 0.6701 - val_accuracy: 0.5908 - val_loss: 0.6726
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 415ms/step - accuracy: 0.6206 - loss: 0.6629 - val_accuracy: 0.5908 - val_loss: 0.6797
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 413ms/step - accuracy: 0.6450 - loss: 0.6544 - val_accuracy: 0.6918 - val_loss: 0.6065
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 435ms/step - accuracy: 0.7339 - loss: 0.5631 - val_accuracy: 0.6918 - val_loss: 0.6230
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 420ms/step - accuracy: 0.7597 - loss: 0.5305 - val_accuracy: 0.7725 - val_loss: 0.5226
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 418ms/step - accuracy: 0.8114 - loss: 0.4223 - val_accuracy: 0.7214 - val_loss: 0.5646
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 416ms/step - accuracy: 0.7901 - loss: 0.4718 - val_accuracy: 0.7914 - val_loss: 0.4654
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 402ms/step - accuracy: 0.8496 - loss: 0.3481 - val_accuracy: 0.7699 - val_loss: 0.4873
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.8529 - loss: 0.3354 - val_accuracy: 0.8089 - val_loss: 0.4199
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.8722 - loss: 0.2961 - val_accuracy: 0.8062 - val_loss: 0.4515
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.8687 - loss: 0.3059 - val_accuracy: 0.8520 - val_loss: 0.4220
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.8903 - loss: 0.2653 - val_accuracy: 0.8156 - val_loss: 0.4207
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.8952 - loss: 0.2625 - val_accuracy: 0.8183 - val_loss: 0.5030
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.9022 - loss: 0.2402 - val_accuracy: 0.8291 - val_loss: 0.5020
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.9108 - loss: 0.2166 - val_accuracy: 0.8439 - val_loss: 0.4649
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.9245 - loss: 0.2008 - val_accuracy: 0.8412 - val_loss: 0.5623
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.9242 - loss: 0.1908 - val_accuracy: 0.8197 - val_loss: 0.5332
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.9147 - loss: 0.1991 - val_accuracy: 0.8250 - val_loss: 0.6290
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.9300 - loss: 0.1681 - val_accuracy: 0.8197 - val_loss: 0.5783
# 🏁 Best epoch for Fold 8: 12
# ✅ Fold 8 test accuracy: 0.8422
#
# 🧪 Fold 9 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.5687 - loss: 0.8596 - val_accuracy: 0.5922 - val_loss: 0.6810
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6148 - loss: 0.6726 - val_accuracy: 0.5922 - val_loss: 0.6768
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6206 - loss: 0.6788 - val_accuracy: 0.5922 - val_loss: 0.6769
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6206 - loss: 0.6690 - val_accuracy: 0.5922 - val_loss: 0.6764
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6206 - loss: 0.6687 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6206 - loss: 0.6681 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6206 - loss: 0.6677 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6206 - loss: 0.6676 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6206 - loss: 0.6686 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6206 - loss: 0.6679 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 349ms/step - accuracy: 0.6206 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6206 - loss: 0.6671 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6206 - loss: 0.6670 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6206 - loss: 0.6669 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6206 - loss: 0.6671 - val_accuracy: 0.5922 - val_loss: 0.6765
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6206 - loss: 0.6686 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6206 - loss: 0.6671 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 349ms/step - accuracy: 0.6206 - loss: 0.6667 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6206 - loss: 0.6667 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6206 - loss: 0.6666 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6206 - loss: 0.6666 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6206 - loss: 0.6665 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6206 - loss: 0.6665 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6206 - loss: 0.6665 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6206 - loss: 0.6664 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6206 - loss: 0.6663 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6206 - loss: 0.6664 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 28/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 349ms/step - accuracy: 0.6206 - loss: 0.6663 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 29/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6206 - loss: 0.6663 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 30/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6206 - loss: 0.6662 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 31/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6206 - loss: 0.6662 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 32/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6206 - loss: 0.6662 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 33/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6184 - loss: 0.6776 - val_accuracy: 0.5922 - val_loss: 0.6772
# Epoch 34/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6206 - loss: 0.6689 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 35/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6206 - loss: 0.6662 - val_accuracy: 0.5922 - val_loss: 0.6761
# 🏁 Best epoch for Fold 9: 25
# ✅ Fold 9 test accuracy: 0.6019
#
# 🧪 Fold 10 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6013 - loss: 0.9145 - val_accuracy: 0.5922 - val_loss: 0.6781
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6143 - loss: 0.6770 - val_accuracy: 0.5922 - val_loss: 0.6766
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6135 - loss: 0.6712 - val_accuracy: 0.5922 - val_loss: 0.6750
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6140 - loss: 0.6720 - val_accuracy: 0.5922 - val_loss: 0.6769
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6145 - loss: 0.6733 - val_accuracy: 0.5989 - val_loss: 0.6720
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 355ms/step - accuracy: 0.6439 - loss: 0.6582 - val_accuracy: 0.5922 - val_loss: 0.6642
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6381 - loss: 0.6338 - val_accuracy: 0.6904 - val_loss: 0.6441
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.7211 - loss: 0.5768 - val_accuracy: 0.7254 - val_loss: 0.6142
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.7580 - loss: 0.5326 - val_accuracy: 0.7456 - val_loss: 0.6245
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.7679 - loss: 0.5335 - val_accuracy: 0.7335 - val_loss: 0.6018
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.7473 - loss: 0.5433 - val_accuracy: 0.8075 - val_loss: 0.5236
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.8155 - loss: 0.4259 - val_accuracy: 0.7645 - val_loss: 0.5540
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 355ms/step - accuracy: 0.8329 - loss: 0.4064 - val_accuracy: 0.8264 - val_loss: 0.4735
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.8530 - loss: 0.3549 - val_accuracy: 0.8156 - val_loss: 0.4988
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.8572 - loss: 0.3431 - val_accuracy: 0.7981 - val_loss: 0.4762
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.8718 - loss: 0.3141 - val_accuracy: 0.8183 - val_loss: 0.4567
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.8902 - loss: 0.2698 - val_accuracy: 0.8102 - val_loss: 0.4871
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 356ms/step - accuracy: 0.8875 - loss: 0.2706 - val_accuracy: 0.7308 - val_loss: 0.7003
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.8954 - loss: 0.2679 - val_accuracy: 0.8048 - val_loss: 0.6351
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.9126 - loss: 0.2165 - val_accuracy: 0.7833 - val_loss: 0.4903
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.9377 - loss: 0.1746 - val_accuracy: 0.7941 - val_loss: 0.6118
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.9359 - loss: 0.1641 - val_accuracy: 0.7120 - val_loss: 0.6629
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.8367 - loss: 0.3628 - val_accuracy: 0.7954 - val_loss: 0.5758
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.9407 - loss: 0.1512 - val_accuracy: 0.7685 - val_loss: 0.5518
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 355ms/step - accuracy: 0.9386 - loss: 0.1584 - val_accuracy: 0.7752 - val_loss: 0.7628
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.9342 - loss: 0.1667 - val_accuracy: 0.7806 - val_loss: 0.8629
# 🏁 Best epoch for Fold 10: 16
# ✅ Fold 10 test accuracy: 0.8374
#
# 📌 Mean optimal epoch across folds: 12

# %%
# Cell Block 5: Final Model Training on data again, but for ep_mean Epochs (no validation needed)

# Build your TF datasets
train_final_ds = preprocess(X_rest, y_rest)        # ALL data used in K-Fold
test_final_ds  = preprocess(X_holdout, y_holdout)  # NEVER seen during CV

# Instantiate & train your final model
final_model = create_model()
final_model.fit(
    train_final_ds,
    epochs=ep_mean,
    verbose=1
)

# Evaluate once—only on the true hold-out set
final_results = final_model.evaluate(
    test_final_ds,
    verbose=1
)
print("Hold-out test loss & accuracy:", final_results)
# Out:
# Epoch 1/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 39s 327ms/step - accuracy: 0.5598 - loss: 0.7923
# Epoch 2/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 326ms/step - accuracy: 0.5996 - loss: 0.6712
# Epoch 3/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 325ms/step - accuracy: 0.5996 - loss: 0.6618
# Epoch 4/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 325ms/step - accuracy: 0.6453 - loss: 0.6151
# Epoch 5/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 328ms/step - accuracy: 0.6917 - loss: 0.6005
# Epoch 6/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 328ms/step - accuracy: 0.7539 - loss: 0.5583
# Epoch 7/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 330ms/step - accuracy: 0.7913 - loss: 0.4882
# Epoch 8/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 326ms/step - accuracy: 0.8316 - loss: 0.4040
# Epoch 9/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 327ms/step - accuracy: 0.8611 - loss: 0.3495
# Epoch 10/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 324ms/step - accuracy: 0.8721 - loss: 0.3236
# Epoch 11/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 327ms/step - accuracy: 0.8856 - loss: 0.3024
# Epoch 12/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 326ms/step - accuracy: 0.8969 - loss: 0.2596
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8065 - loss: 0.5101
# Hold-out test loss & accuracy: [0.46968814730644226, 0.8062953948974609]

# %%
# Cell Block 5: Final Evaluation

# Evaluate final model on the 20% test set
final_test_loss, final_test_acc = final_model.evaluate(test_final_ds, verbose=0)

# Report both results
print(f"\n📊 {k}-Fold Test Accuracy: {np.mean(all_test_accuracies):.4f} ± {np.std(all_test_accuracies):.4f}")
print(f"🏁 Final model test accuracy (trained on hold-out): {final_test_acc:.4f}")
# Out:
# 📊 10-Fold Test Accuracy: 0.6500 ± 0.0949
# 🏁 Final model test accuracy (trained on hold-out): 0.8063

# %%
import numpy as np
from sklearn.metrics import precision_score, roc_curve, auc, f1_score, recall_score
import matplotlib.pyplot as plt

# 1. Extract true labels and model scores from your hold-out dataset
y_true = np.concatenate([y.numpy() for x, y in test_final_ds], axis=0)
y_pred_prob = final_model.predict(test_final_ds)

# 2. If your model outputs two probabilities (one per class), take the “positive” class
if y_pred_prob.ndim > 1 and y_pred_prob.shape[1] > 1:
    y_scores = y_pred_prob[:, 1]
else:
    y_scores = y_pred_prob.ravel()

# 3. Compute ROC curve metrics
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# 4. Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr)               # ROC curve
plt.plot([0, 1], [0, 1], linestyle='--')  # chance line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (AUC = {roc_auc:.2f})')
plt.show()



# 1. Turn your predicted probabilities into binary preds (threshold = 0.5)
y_pred = (y_scores >= 0.5).astype(int)

# 2. Compute precision, recall, F1
precision = precision_score(y_true, y_pred)
recall    = recall_score(y_true, y_pred)
f1        = f1_score(y_true, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step
# Precision: 0.80
# Recall:    0.68
# F1 Score:  0.74
