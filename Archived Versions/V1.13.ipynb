# %% [markdown]
# Varroa Mite Detection 1.13 Blue Shift with Contrast and Blur

# %%
# Cell Block 1: Importing Libraries
import os
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold, train_test_split
import numpy as np
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Cell Block 2: Load Data and Preprocess

df = pd.read_csv('labels_augmented.csv')

df['filename'] = df['filename'].apply(lambda fn: os.path.join('rotations_flips', fn.strip()))

filepaths = df['filename'].values
labels = df['has_mite'].values

# %%
# Cell Block 3: Splitting Data

X_rest, X_holdout, y_rest, y_holdout = train_test_split(
    filepaths, labels,
    test_size=0.10,
    stratify=labels,
    random_state=42
)

# %%
# Cell Block 3: K-Fold Cross-Validation

# Early stopping callback
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    # min_delta=1e-4,
    restore_best_weights=True
)

k = 10  # Number of folds
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

fold = 1
all_test_accuracies = []
best_epochs = []

# Model creation function
def create_model():
    model = models.Sequential([
        layers.Input(shape=(224, 224, 3)),
        layers.Conv2D(32, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Guassian kernel function
def gaussian_kernel(size: int, sigma: float):
    x = tf.range(-size // 2 + 1, size // 2 + 1, dtype=tf.float32)
    xx, yy = tf.meshgrid(x, x)
    kernel = tf.exp(-(xx**2 + yy**2) / (2.0 * sigma**2))
    kernel = kernel / tf.reduce_sum(kernel)
    return kernel

def apply_gaussian_blur(image, kernel_size=5, sigma=1.0):
    kernel = gaussian_kernel(kernel_size, sigma)                 # [5, 5]
    kernel = kernel[:, :, tf.newaxis, tf.newaxis]                # [5, 5, 1, 1]
    kernel = tf.repeat(kernel, repeats=3, axis=2)                # [5, 5, 3, 1] ✅ CORRECT shape
    image = tf.expand_dims(image, 0)                             # [1, H, W, 3]
    blurred = tf.nn.depthwise_conv2d(image, kernel, strides=[1,1,1,1], padding='SAME')
    
    return tf.squeeze(blurred, axis=0)

# Preprocessing function
def preprocess(paths, labels):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    def load_img(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [224, 224])
        img = img / 255.0

        # 1) Gaussian Blur
        img = apply_gaussian_blur(img, kernel_size=5, sigma=1.0)

        # 2) Boost blue channel
        img = tf.clip_by_value(img + [0.0, 0.0, 0.2], 0.0, 1.0) 

        # 3) Increase contrast
        img = tf.image.adjust_contrast(img, 2.0) 

        # 4) Boost red channel
        # img = tf.clip_by_value(img + [0.2, 0.0, 0.0], 0.0, 1.0)
        
        return img, label

    return ds.map(load_img).batch(32).prefetch(tf.data.AUTOTUNE)

for trainval_index, test_index in skf.split(filepaths, labels):
    print(f"\n🧪 Fold {fold} -----------------------------")

    # Split into trainval and test
    X_trainval, X_test = filepaths[trainval_index], filepaths[test_index]
    y_trainval, y_test = labels[trainval_index], labels[test_index]

    # Further split trainval into train and val (e.g. 80/20)
    val_split = int(0.8 * len(X_trainval))
    X_train, X_val = X_trainval[:val_split], X_trainval[val_split:]
    y_train, y_val = y_trainval[:val_split], y_trainval[val_split:]


    # Preprocess each split
    train_ds = preprocess(X_train, y_train)
    val_ds = preprocess(X_val, y_val)
    test_ds = preprocess(X_test, y_test)



    # Train model with early stopping
    model = create_model()
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[earlystop],
        verbose=1
    )

    # Record best epoch (smallest val_loss)
    best_epoch = np.argmin(history.history['val_loss']) + 1
    best_epochs.append(best_epoch)
    print(f"🏁 Best epoch for Fold {fold}: {best_epoch}")

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    all_test_accuracies.append(test_acc)
    print(f"✅ Fold {fold} test accuracy: {test_acc:.4f}")

    fold += 1

# Calculate mean best epoch
ep_mean = int(np.round(np.mean(best_epochs)))
print(f"\n📌 Mean optimal epoch across folds: {ep_mean}")
# Out:
# 🧪 Fold 1 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 407ms/step - accuracy: 0.6127 - loss: 1.1115 - val_accuracy: 0.5922 - val_loss: 0.6754
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 399ms/step - accuracy: 0.6019 - loss: 0.6664 - val_accuracy: 0.6178 - val_loss: 0.6554
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 407ms/step - accuracy: 0.6507 - loss: 0.6302 - val_accuracy: 0.6689 - val_loss: 0.6474
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 406ms/step - accuracy: 0.6945 - loss: 0.5847 - val_accuracy: 0.6797 - val_loss: 0.6371
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 419ms/step - accuracy: 0.7377 - loss: 0.5229 - val_accuracy: 0.6837 - val_loss: 0.6734
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 411ms/step - accuracy: 0.7839 - loss: 0.4536 - val_accuracy: 0.7012 - val_loss: 0.6754
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 399ms/step - accuracy: 0.8221 - loss: 0.3730 - val_accuracy: 0.7052 - val_loss: 0.7142
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 402ms/step - accuracy: 0.8568 - loss: 0.3108 - val_accuracy: 0.6904 - val_loss: 0.7940
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 399ms/step - accuracy: 0.9010 - loss: 0.2166 - val_accuracy: 0.6716 - val_loss: 0.8416
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 394ms/step - accuracy: 0.9247 - loss: 0.1697 - val_accuracy: 0.6864 - val_loss: 0.8822
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.9281 - loss: 0.1606 - val_accuracy: 0.6689 - val_loss: 1.0622
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 394ms/step - accuracy: 0.9168 - loss: 0.1595 - val_accuracy: 0.6676 - val_loss: 1.3944
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 387ms/step - accuracy: 0.9098 - loss: 0.1624 - val_accuracy: 0.6635 - val_loss: 1.5778
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 384ms/step - accuracy: 0.9246 - loss: 0.1462 - val_accuracy: 0.6703 - val_loss: 2.0632
# 🏁 Best epoch for Fold 1: 4
# ✅ Fold 1 test accuracy: 0.6610
#
# 🧪 Fold 2 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 383ms/step - accuracy: 0.5624 - loss: 0.8780 - val_accuracy: 0.5868 - val_loss: 0.6916
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6182 - loss: 0.6897 - val_accuracy: 0.5868 - val_loss: 0.6878
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6182 - loss: 0.6847 - val_accuracy: 0.5868 - val_loss: 0.6850
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6182 - loss: 0.6807 - val_accuracy: 0.5868 - val_loss: 0.6829
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6182 - loss: 0.6776 - val_accuracy: 0.5868 - val_loss: 0.6814
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6182 - loss: 0.6751 - val_accuracy: 0.5868 - val_loss: 0.6802
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6182 - loss: 0.6731 - val_accuracy: 0.5868 - val_loss: 0.6794
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6182 - loss: 0.6716 - val_accuracy: 0.5868 - val_loss: 0.6789
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6182 - loss: 0.6703 - val_accuracy: 0.5868 - val_loss: 0.6785
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6182 - loss: 0.6694 - val_accuracy: 0.5868 - val_loss: 0.6783
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6182 - loss: 0.6686 - val_accuracy: 0.5868 - val_loss: 0.6781
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6182 - loss: 0.6680 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6182 - loss: 0.6675 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6182 - loss: 0.6671 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6182 - loss: 0.6668 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 333ms/step - accuracy: 0.6182 - loss: 0.6665 - val_accuracy: 0.5868 - val_loss: 0.6781
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6182 - loss: 0.6663 - val_accuracy: 0.5868 - val_loss: 0.6781
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6182 - loss: 0.6661 - val_accuracy: 0.5868 - val_loss: 0.6782
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6182 - loss: 0.6660 - val_accuracy: 0.5868 - val_loss: 0.6782
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6182 - loss: 0.6659 - val_accuracy: 0.5868 - val_loss: 0.6783
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6182 - loss: 0.6658 - val_accuracy: 0.5868 - val_loss: 0.6783
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.6182 - loss: 0.6657 - val_accuracy: 0.5868 - val_loss: 0.6784
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.6182 - loss: 0.6656 - val_accuracy: 0.5868 - val_loss: 0.6784
# 🏁 Best epoch for Fold 2: 13
# ✅ Fold 2 test accuracy: 0.6029
#
# 🧪 Fold 3 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 324ms/step - accuracy: 0.5708 - loss: 0.7445 - val_accuracy: 0.5828 - val_loss: 0.6816
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.6156 - loss: 0.6697 - val_accuracy: 0.5828 - val_loss: 0.6777
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.6114 - loss: 0.6656 - val_accuracy: 0.5828 - val_loss: 0.6780
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6257 - loss: 0.6591 - val_accuracy: 0.6151 - val_loss: 0.6546
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.6456 - loss: 0.6426 - val_accuracy: 0.6366 - val_loss: 0.6484
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6708 - loss: 0.6090 - val_accuracy: 0.6393 - val_loss: 0.6833
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 322ms/step - accuracy: 0.7267 - loss: 0.5520 - val_accuracy: 0.6231 - val_loss: 0.8122
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.7784 - loss: 0.4646 - val_accuracy: 0.6366 - val_loss: 1.0131
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.8316 - loss: 0.3420 - val_accuracy: 0.6003 - val_loss: 1.3628
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 322ms/step - accuracy: 0.8716 - loss: 0.2641 - val_accuracy: 0.6030 - val_loss: 1.4095
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 322ms/step - accuracy: 0.9033 - loss: 0.2287 - val_accuracy: 0.6016 - val_loss: 1.4227
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.9112 - loss: 0.1727 - val_accuracy: 0.5949 - val_loss: 1.5685
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 322ms/step - accuracy: 0.9222 - loss: 0.1584 - val_accuracy: 0.6097 - val_loss: 1.6004
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.9346 - loss: 0.1121 - val_accuracy: 0.6258 - val_loss: 1.4585
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.9481 - loss: 0.0892 - val_accuracy: 0.6231 - val_loss: 2.0627
# 🏁 Best epoch for Fold 3: 5
# ✅ Fold 3 test accuracy: 0.6586
#
# 🧪 Fold 4 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 326ms/step - accuracy: 0.5939 - loss: 0.8715 - val_accuracy: 0.5814 - val_loss: 0.6856
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.6185 - loss: 0.6740 - val_accuracy: 0.5855 - val_loss: 0.6686
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 322ms/step - accuracy: 0.5960 - loss: 0.6723 - val_accuracy: 0.6137 - val_loss: 0.6761
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 322ms/step - accuracy: 0.6126 - loss: 0.6612 - val_accuracy: 0.6231 - val_loss: 0.6716
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.6303 - loss: 0.6484 - val_accuracy: 0.5828 - val_loss: 0.6705
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6644 - loss: 0.6184 - val_accuracy: 0.6608 - val_loss: 0.6369
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6987 - loss: 0.5725 - val_accuracy: 0.6689 - val_loss: 0.6573
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 322ms/step - accuracy: 0.7477 - loss: 0.5027 - val_accuracy: 0.6231 - val_loss: 0.8145
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.7912 - loss: 0.4420 - val_accuracy: 0.6110 - val_loss: 1.0554
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.8296 - loss: 0.3346 - val_accuracy: 0.5962 - val_loss: 1.3162
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.8466 - loss: 0.2815 - val_accuracy: 0.6083 - val_loss: 1.2990
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.8672 - loss: 0.2496 - val_accuracy: 0.6124 - val_loss: 1.3379
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.9044 - loss: 0.1709 - val_accuracy: 0.6030 - val_loss: 1.4492
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 322ms/step - accuracy: 0.9198 - loss: 0.1329 - val_accuracy: 0.5962 - val_loss: 1.5869
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.9124 - loss: 0.1312 - val_accuracy: 0.5908 - val_loss: 1.5895
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.9284 - loss: 0.1124 - val_accuracy: 0.6083 - val_loss: 1.4243
# 🏁 Best epoch for Fold 4: 6
# ✅ Fold 4 test accuracy: 0.6320
#
# 🧪 Fold 5 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 323ms/step - accuracy: 0.5932 - loss: 0.8310 - val_accuracy: 0.5922 - val_loss: 0.6776
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 322ms/step - accuracy: 0.6099 - loss: 0.6695 - val_accuracy: 0.5922 - val_loss: 0.6636
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.6099 - loss: 0.6520 - val_accuracy: 0.5922 - val_loss: 0.6578
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6099 - loss: 0.6320 - val_accuracy: 0.5922 - val_loss: 0.6511
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6220 - loss: 0.5995 - val_accuracy: 0.6030 - val_loss: 0.6562
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 322ms/step - accuracy: 0.6821 - loss: 0.5750 - val_accuracy: 0.5895 - val_loss: 0.6837
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.7025 - loss: 0.5551 - val_accuracy: 0.6393 - val_loss: 0.6969
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.7495 - loss: 0.5177 - val_accuracy: 0.6460 - val_loss: 0.6721
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.7906 - loss: 0.4548 - val_accuracy: 0.6810 - val_loss: 0.7290
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.8444 - loss: 0.4106 - val_accuracy: 0.7268 - val_loss: 0.6167
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.8581 - loss: 0.4054 - val_accuracy: 0.7335 - val_loss: 0.6095
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.8707 - loss: 0.3082 - val_accuracy: 0.7900 - val_loss: 0.5936
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.9186 - loss: 0.1920 - val_accuracy: 0.8008 - val_loss: 0.6982
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.9512 - loss: 0.1368 - val_accuracy: 0.8089 - val_loss: 0.7626
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.9672 - loss: 0.0944 - val_accuracy: 0.7618 - val_loss: 0.6676
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.9682 - loss: 0.0802 - val_accuracy: 0.7322 - val_loss: 0.8031
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.9780 - loss: 0.0774 - val_accuracy: 0.7456 - val_loss: 1.2795
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.9742 - loss: 0.0759 - val_accuracy: 0.7160 - val_loss: 1.1629
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.9834 - loss: 0.0579 - val_accuracy: 0.7456 - val_loss: 0.8677
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.9880 - loss: 0.0476 - val_accuracy: 0.7295 - val_loss: 1.1125
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.9872 - loss: 0.0411 - val_accuracy: 0.7322 - val_loss: 1.1895
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9961 - loss: 0.0169 - val_accuracy: 0.7739 - val_loss: 1.6002
# 🏁 Best epoch for Fold 5: 12
# ✅ Fold 5 test accuracy: 0.8354
#
# 🧪 Fold 6 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 325ms/step - accuracy: 0.5842 - loss: 0.8201 - val_accuracy: 0.5774 - val_loss: 0.6912
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.6124 - loss: 0.6889 - val_accuracy: 0.5774 - val_loss: 0.6877
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.6124 - loss: 0.6838 - val_accuracy: 0.5774 - val_loss: 0.6852
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.6124 - loss: 0.6799 - val_accuracy: 0.5774 - val_loss: 0.6835
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.6124 - loss: 0.6770 - val_accuracy: 0.5774 - val_loss: 0.6824
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6124 - loss: 0.6747 - val_accuracy: 0.5774 - val_loss: 0.6817
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.6124 - loss: 0.6730 - val_accuracy: 0.5774 - val_loss: 0.6813
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6124 - loss: 0.6717 - val_accuracy: 0.5774 - val_loss: 0.6812
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6124 - loss: 0.6707 - val_accuracy: 0.5774 - val_loss: 0.6811
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.6124 - loss: 0.6700 - val_accuracy: 0.5774 - val_loss: 0.6812
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6124 - loss: 0.6695 - val_accuracy: 0.5774 - val_loss: 0.6813
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6124 - loss: 0.6691 - val_accuracy: 0.5774 - val_loss: 0.6814
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6124 - loss: 0.6687 - val_accuracy: 0.5774 - val_loss: 0.6816
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6124 - loss: 0.6685 - val_accuracy: 0.5774 - val_loss: 0.6818
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6124 - loss: 0.6683 - val_accuracy: 0.5774 - val_loss: 0.6819
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6124 - loss: 0.6682 - val_accuracy: 0.5774 - val_loss: 0.6821
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6124 - loss: 0.6681 - val_accuracy: 0.5774 - val_loss: 0.6822
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6124 - loss: 0.6680 - val_accuracy: 0.5774 - val_loss: 0.6823
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6124 - loss: 0.6680 - val_accuracy: 0.5774 - val_loss: 0.6825
# 🏁 Best epoch for Fold 6: 9
# ✅ Fold 6 test accuracy: 0.6019
#
# 🧪 Fold 7 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 333ms/step - accuracy: 0.5975 - loss: 0.9176 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.6191 - loss: 0.6690 - val_accuracy: 0.5882 - val_loss: 0.6542
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.6129 - loss: 0.6563 - val_accuracy: 0.5922 - val_loss: 0.6523
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6174 - loss: 0.6473 - val_accuracy: 0.5882 - val_loss: 0.6602
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6307 - loss: 0.6142 - val_accuracy: 0.5976 - val_loss: 0.6679
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.6595 - loss: 0.5863 - val_accuracy: 0.6272 - val_loss: 0.6623
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6899 - loss: 0.5474 - val_accuracy: 0.6581 - val_loss: 0.7258
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.7431 - loss: 0.4802 - val_accuracy: 0.6178 - val_loss: 1.0585
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.8192 - loss: 0.3523 - val_accuracy: 0.6164 - val_loss: 1.5955
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.9041 - loss: 0.2139 - val_accuracy: 0.6003 - val_loss: 1.8022
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.9355 - loss: 0.1542 - val_accuracy: 0.5922 - val_loss: 2.7383
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.9541 - loss: 0.1192 - val_accuracy: 0.6124 - val_loss: 2.0299
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.9345 - loss: 0.1742 - val_accuracy: 0.5989 - val_loss: 2.1484
# 🏁 Best epoch for Fold 7: 3
# ✅ Fold 7 test accuracy: 0.6068
#
# 🧪 Fold 8 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 325ms/step - accuracy: 0.5763 - loss: 0.9091 - val_accuracy: 0.5908 - val_loss: 0.6913
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.6148 - loss: 0.6895 - val_accuracy: 0.5908 - val_loss: 0.6874
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6148 - loss: 0.6847 - val_accuracy: 0.5908 - val_loss: 0.6844
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6148 - loss: 0.6809 - val_accuracy: 0.5908 - val_loss: 0.6821
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6148 - loss: 0.6779 - val_accuracy: 0.5908 - val_loss: 0.6805
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6148 - loss: 0.6755 - val_accuracy: 0.5908 - val_loss: 0.6792
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.6148 - loss: 0.6737 - val_accuracy: 0.5908 - val_loss: 0.6783
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.6148 - loss: 0.6722 - val_accuracy: 0.5908 - val_loss: 0.6777
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6148 - loss: 0.6711 - val_accuracy: 0.5908 - val_loss: 0.6773
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.6148 - loss: 0.6702 - val_accuracy: 0.5908 - val_loss: 0.6770
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6148 - loss: 0.6695 - val_accuracy: 0.5908 - val_loss: 0.6768
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6148 - loss: 0.6689 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.6148 - loss: 0.6685 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.6148 - loss: 0.6682 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6148 - loss: 0.6679 - val_accuracy: 0.5908 - val_loss: 0.6765
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 42s 330ms/step - accuracy: 0.6148 - loss: 0.6677 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6148 - loss: 0.6675 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.6148 - loss: 0.6674 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6148 - loss: 0.6673 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.6148 - loss: 0.6672 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.6148 - loss: 0.6671 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.6148 - loss: 0.6671 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6148 - loss: 0.6670 - val_accuracy: 0.5908 - val_loss: 0.6768
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.6148 - loss: 0.6670 - val_accuracy: 0.5908 - val_loss: 0.6768
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6148 - loss: 0.6670 - val_accuracy: 0.5908 - val_loss: 0.6768
# 🏁 Best epoch for Fold 8: 15
# ✅ Fold 8 test accuracy: 0.6019
#
# 🧪 Fold 9 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 325ms/step - accuracy: 0.5663 - loss: 0.7513 - val_accuracy: 0.5922 - val_loss: 0.6754
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6162 - loss: 0.6644 - val_accuracy: 0.5922 - val_loss: 0.6726
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6099 - loss: 0.6639 - val_accuracy: 0.5922 - val_loss: 0.6767
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.6086 - loss: 0.6713 - val_accuracy: 0.5922 - val_loss: 0.6616
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.6348 - loss: 0.6428 - val_accuracy: 0.5922 - val_loss: 0.6787
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6243 - loss: 0.6641 - val_accuracy: 0.6083 - val_loss: 0.6508
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6510 - loss: 0.6371 - val_accuracy: 0.6353 - val_loss: 0.6511
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.6616 - loss: 0.6160 - val_accuracy: 0.6783 - val_loss: 0.6319
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.6906 - loss: 0.5621 - val_accuracy: 0.6406 - val_loss: 0.6365
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.7361 - loss: 0.4951 - val_accuracy: 0.6151 - val_loss: 0.6804
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.7977 - loss: 0.3931 - val_accuracy: 0.6164 - val_loss: 0.8688
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.8713 - loss: 0.2598 - val_accuracy: 0.6191 - val_loss: 1.1116
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.8808 - loss: 0.2414 - val_accuracy: 0.5908 - val_loss: 1.2323
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.9136 - loss: 0.1718 - val_accuracy: 0.5787 - val_loss: 1.5124
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.9150 - loss: 0.1480 - val_accuracy: 0.6083 - val_loss: 1.6475
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.9280 - loss: 0.1237 - val_accuracy: 0.6205 - val_loss: 1.9049
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.9350 - loss: 0.1061 - val_accuracy: 0.6003 - val_loss: 1.8576
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.9463 - loss: 0.1016 - val_accuracy: 0.6110 - val_loss: 1.9488
# 🏁 Best epoch for Fold 9: 8
# ✅ Fold 9 test accuracy: 0.6238
#
# 🧪 Fold 10 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 325ms/step - accuracy: 0.5759 - loss: 0.8357 - val_accuracy: 0.5922 - val_loss: 0.6781
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6145 - loss: 0.6779 - val_accuracy: 0.5922 - val_loss: 0.6783
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6145 - loss: 0.6750 - val_accuracy: 0.5922 - val_loss: 0.6775
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6145 - loss: 0.6753 - val_accuracy: 0.5922 - val_loss: 0.6734
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.6145 - loss: 0.6589 - val_accuracy: 0.5922 - val_loss: 0.6469
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6145 - loss: 0.6319 - val_accuracy: 0.5922 - val_loss: 0.6469
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6272 - loss: 0.6004 - val_accuracy: 0.5922 - val_loss: 0.6500
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6514 - loss: 0.5561 - val_accuracy: 0.7362 - val_loss: 0.5930
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.8039 - loss: 0.4582 - val_accuracy: 0.7860 - val_loss: 0.5272
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.8517 - loss: 0.3332 - val_accuracy: 0.7968 - val_loss: 0.5384
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.9047 - loss: 0.2364 - val_accuracy: 0.7941 - val_loss: 0.6091
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9349 - loss: 0.1664 - val_accuracy: 0.6931 - val_loss: 0.9779
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.9445 - loss: 0.1469 - val_accuracy: 0.6918 - val_loss: 1.2002
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.9451 - loss: 0.1479 - val_accuracy: 0.7456 - val_loss: 1.3988
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.9659 - loss: 0.0855 - val_accuracy: 0.7470 - val_loss: 1.5530
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.9579 - loss: 0.0981 - val_accuracy: 0.7322 - val_loss: 1.1834
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.9805 - loss: 0.0636 - val_accuracy: 0.7052 - val_loss: 1.3224
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.9801 - loss: 0.0459 - val_accuracy: 0.7362 - val_loss: 1.2284
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.9962 - loss: 0.0173 - val_accuracy: 0.7241 - val_loss: 1.6061
# 🏁 Best epoch for Fold 10: 9
# ✅ Fold 10 test accuracy: 0.7840
#
# 📌 Mean optimal epoch across folds: 8

# %%
# Cell Block 5: Final Model Training on data again, but for ep_mean Epochs (no validation needed)

# Build your TF datasets
train_final_ds = preprocess(X_rest, y_rest)        # ALL data used in K-Fold
test_final_ds  = preprocess(X_holdout, y_holdout)  # NEVER seen during CV

# Instantiate & train your final model
final_model = create_model()
final_model.fit(
    train_final_ds,
    epochs=ep_mean,
    verbose=1
)

# Evaluate once—only on the true hold-out set
final_results = final_model.evaluate(
    test_final_ds,
    verbose=1
)
print("Hold-out test loss & accuracy:", final_results)
# Out:
# Epoch 1/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 44s 375ms/step - accuracy: 0.5737 - loss: 0.9743
# Epoch 2/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 44s 383ms/step - accuracy: 0.6008 - loss: 0.6470
# Epoch 3/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 45s 390ms/step - accuracy: 0.7008 - loss: 0.5943
# Epoch 4/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 45s 390ms/step - accuracy: 0.8325 - loss: 0.4182
# Epoch 5/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 45s 388ms/step - accuracy: 0.8693 - loss: 0.3401
# Epoch 6/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 45s 388ms/step - accuracy: 0.8836 - loss: 0.2900
# Epoch 7/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 43s 374ms/step - accuracy: 0.9055 - loss: 0.2399
# Epoch 8/8
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 44s 376ms/step - accuracy: 0.9222 - loss: 0.2014
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.8190 - loss: 0.4293
# Hold-out test loss & accuracy: [0.4079667031764984, 0.8280871510505676]

# %%
# Cell Block 5: Final Evaluation

# Evaluate final model on the 20% test set
final_test_loss, final_test_acc = final_model.evaluate(test_final_ds, verbose=0)

# Report both results
print(f"\n📊 {k}-Fold Test Accuracy: {np.mean(all_test_accuracies):.4f} ± {np.std(all_test_accuracies):.4f}")
print(f"🏁 Final model test accuracy (trained on hold-out): {final_test_acc:.4f}")
# Out:
# 📊 10-Fold Test Accuracy: 0.6608 ± 0.0781
# 🏁 Final model test accuracy (trained on hold-out): 0.8281

# %%
import numpy as np
from sklearn.metrics import precision_score, roc_curve, auc, f1_score, recall_score
import matplotlib.pyplot as plt

# 1. Extract true labels and model scores from your hold-out dataset
y_true = np.concatenate([y.numpy() for x, y in test_final_ds], axis=0)
y_pred_prob = final_model.predict(test_final_ds)

# 2. If your model outputs two probabilities (one per class), take the “positive” class
if y_pred_prob.ndim > 1 and y_pred_prob.shape[1] > 1:
    y_scores = y_pred_prob[:, 1]
else:
    y_scores = y_pred_prob.ravel()

# 3. Compute ROC curve metrics
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# 4. Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr)               # ROC curve
plt.plot([0, 1], [0, 1], linestyle='--')  # chance line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (AUC = {roc_auc:.2f})')
plt.show()



# 1. Turn your predicted probabilities into binary preds (threshold = 0.5)
y_pred = (y_scores >= 0.5).astype(int)

# 2. Compute precision, recall, F1
precision = precision_score(y_true, y_pred)
recall    = recall_score(y_true, y_pred)
f1        = f1_score(y_true, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step
# Precision: 0.78
# Recall:    0.80
# F1 Score:  0.79
