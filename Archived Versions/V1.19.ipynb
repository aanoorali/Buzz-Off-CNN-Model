# %% [markdown]
# Varroa Mite Detection 1.19 Contrast and Brightness

# %%
# Cell Block 1: Importing Libraries
import os
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold, train_test_split
import numpy as np
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Cell Block 2: Load Data and Preprocess

df = pd.read_csv('labels_augmented.csv')

df['filename'] = df['filename'].apply(lambda fn: os.path.join('rotations_flips', fn.strip()))

filepaths = df['filename'].values
labels = df['has_mite'].values

# %%
# Cell Block 3: Splitting Data

X_rest, X_holdout, y_rest, y_holdout = train_test_split(
    filepaths, labels,
    test_size=0.10,
    stratify=labels,
    random_state=42
)

# %%
# Cell Block 3: K-Fold Cross-Validation

# Early stopping callback
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    # min_delta=1e-4,
    restore_best_weights=True
)

k = 10  # Number of folds
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

fold = 1
all_test_accuracies = []
best_epochs = []

# Model creation function
def create_model():
    model = models.Sequential([
        layers.Input(shape=(224, 224, 3)),
        layers.Conv2D(32, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Guassian kernel function
def gaussian_kernel(size: int, sigma: float):
    x = tf.range(-size // 2 + 1, size // 2 + 1, dtype=tf.float32)
    xx, yy = tf.meshgrid(x, x)
    kernel = tf.exp(-(xx**2 + yy**2) / (2.0 * sigma**2))
    kernel = kernel / tf.reduce_sum(kernel)
    return kernel

def apply_gaussian_blur(image, kernel_size=5, sigma=1.0):
    kernel = gaussian_kernel(kernel_size, sigma)                 # [5, 5]
    kernel = kernel[:, :, tf.newaxis, tf.newaxis]                # [5, 5, 1, 1]
    kernel = tf.repeat(kernel, repeats=3, axis=2)                # [5, 5, 3, 1] ✅ CORRECT shape
    image = tf.expand_dims(image, 0)                             # [1, H, W, 3]
    blurred = tf.nn.depthwise_conv2d(image, kernel, strides=[1,1,1,1], padding='SAME')
    
    return tf.squeeze(blurred, axis=0)

# Preprocessing function
def preprocess(paths, labels):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    def load_img(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [224, 224])
        img = img / 255.0

        # # 1) Apply Gaussian blur
        # img = apply_gaussian_blur(img, kernel_size=5, sigma=1.0)

        # # 2) Boost blue channel
        # img = tf.clip_by_value(img + [0.0, 0.0, 0.2], 0.0, 1.0) 

        # 3) Increase contrast
        img = tf.image.adjust_contrast(img, 2.0) 

        # # 4) Boost red channel
        # img = tf.clip_by_value(img + [0.2, 0.0, 0.0], 0.0, 1.0)

        # # 5) Boost blue and red channel
        # img = tf.clip_by_value(img + [0.2, 0.0, 0.2], 0.0, 1.0)

        # 6) Boost the Brightness
        img = tf.image.adjust_brightness(img, delta=0.1)

        
        return img, label

    return ds.map(load_img).batch(32).prefetch(tf.data.AUTOTUNE)

for trainval_index, test_index in skf.split(filepaths, labels):
    print(f"\n🧪 Fold {fold} -----------------------------")

    # Split into trainval and test
    X_trainval, X_test = filepaths[trainval_index], filepaths[test_index]
    y_trainval, y_test = labels[trainval_index], labels[test_index]

    # Further split trainval into train and val (e.g. 80/20)
    val_split = int(0.8 * len(X_trainval))
    X_train, X_val = X_trainval[:val_split], X_trainval[val_split:]
    y_train, y_val = y_trainval[:val_split], y_trainval[val_split:]


    # Preprocess each split
    train_ds = preprocess(X_train, y_train)
    val_ds = preprocess(X_val, y_val)
    test_ds = preprocess(X_test, y_test)



    # Train model with early stopping
    model = create_model()
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[earlystop],
        verbose=1
    )

    # Record best epoch (smallest val_loss)
    best_epoch = np.argmin(history.history['val_loss']) + 1
    best_epochs.append(best_epoch)
    print(f"🏁 Best epoch for Fold {fold}: {best_epoch}")

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    all_test_accuracies.append(test_acc)
    print(f"✅ Fold {fold} test accuracy: {test_acc:.4f}")

    fold += 1

# Calculate mean best epoch
ep_mean = int(np.round(np.mean(best_epochs)))
print(f"\n📌 Mean optimal epoch across folds: {ep_mean}")
# Out:
# 🧪 Fold 1 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 363ms/step - accuracy: 0.5787 - loss: 0.8476 - val_accuracy: 0.5922 - val_loss: 0.6781
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 349ms/step - accuracy: 0.6021 - loss: 0.6734 - val_accuracy: 0.5814 - val_loss: 0.6580
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.6106 - loss: 0.6560 - val_accuracy: 0.5922 - val_loss: 0.6629
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6262 - loss: 0.6402 - val_accuracy: 0.6030 - val_loss: 0.6529
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.6908 - loss: 0.5847 - val_accuracy: 0.6797 - val_loss: 0.6269
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.7541 - loss: 0.5064 - val_accuracy: 0.7550 - val_loss: 0.5723
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.8552 - loss: 0.3444 - val_accuracy: 0.8116 - val_loss: 0.4636
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.8968 - loss: 0.2542 - val_accuracy: 0.8089 - val_loss: 0.4958
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.9160 - loss: 0.2184 - val_accuracy: 0.8035 - val_loss: 0.5924
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.9334 - loss: 0.1799 - val_accuracy: 0.8035 - val_loss: 0.6908
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 362ms/step - accuracy: 0.9699 - loss: 0.0944 - val_accuracy: 0.8116 - val_loss: 0.8363
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.9889 - loss: 0.0387 - val_accuracy: 0.7900 - val_loss: 1.0111
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.9948 - loss: 0.0285 - val_accuracy: 0.7429 - val_loss: 1.0236
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.9788 - loss: 0.0579 - val_accuracy: 0.7591 - val_loss: 1.2059
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.9943 - loss: 0.0232 - val_accuracy: 0.7779 - val_loss: 1.5628
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.9824 - loss: 0.0477 - val_accuracy: 0.7914 - val_loss: 1.1237
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 356ms/step - accuracy: 0.9956 - loss: 0.0171 - val_accuracy: 0.7995 - val_loss: 1.2274
# 🏁 Best epoch for Fold 1: 7
# ✅ Fold 1 test accuracy: 0.8717
#
# 🧪 Fold 2 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 354ms/step - accuracy: 0.6053 - loss: 0.8516 - val_accuracy: 0.5868 - val_loss: 0.6794
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6182 - loss: 0.6699 - val_accuracy: 0.5868 - val_loss: 0.6778
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6155 - loss: 0.6667 - val_accuracy: 0.5868 - val_loss: 0.6889
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 355ms/step - accuracy: 0.6182 - loss: 0.6860 - val_accuracy: 0.5868 - val_loss: 0.6857
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6182 - loss: 0.6816 - val_accuracy: 0.5868 - val_loss: 0.6833
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6182 - loss: 0.6782 - val_accuracy: 0.5868 - val_loss: 0.6816
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6182 - loss: 0.6755 - val_accuracy: 0.5868 - val_loss: 0.6804
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6182 - loss: 0.6735 - val_accuracy: 0.5868 - val_loss: 0.6796
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6182 - loss: 0.6718 - val_accuracy: 0.5868 - val_loss: 0.6790
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6182 - loss: 0.6705 - val_accuracy: 0.5868 - val_loss: 0.6785
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6182 - loss: 0.6695 - val_accuracy: 0.5868 - val_loss: 0.6783
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6182 - loss: 0.6687 - val_accuracy: 0.5868 - val_loss: 0.6781
# 🏁 Best epoch for Fold 2: 2
# ✅ Fold 2 test accuracy: 0.6029
#
# 🧪 Fold 3 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 356ms/step - accuracy: 0.5776 - loss: 0.7997 - val_accuracy: 0.5828 - val_loss: 0.6791
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6173 - loss: 0.6725 - val_accuracy: 0.5828 - val_loss: 0.6781
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6185 - loss: 0.6641 - val_accuracy: 0.6110 - val_loss: 0.6581
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6413 - loss: 0.6331 - val_accuracy: 0.6366 - val_loss: 0.6516
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6796 - loss: 0.5980 - val_accuracy: 0.6555 - val_loss: 0.6578
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.7219 - loss: 0.5550 - val_accuracy: 0.6393 - val_loss: 0.6938
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.7541 - loss: 0.4840 - val_accuracy: 0.6164 - val_loss: 0.7861
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.7954 - loss: 0.4025 - val_accuracy: 0.6164 - val_loss: 1.0754
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.8345 - loss: 0.3300 - val_accuracy: 0.6110 - val_loss: 1.4132
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 355ms/step - accuracy: 0.8461 - loss: 0.2955 - val_accuracy: 0.6030 - val_loss: 1.6153
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.8726 - loss: 0.2474 - val_accuracy: 0.5868 - val_loss: 0.9118
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.8867 - loss: 0.2199 - val_accuracy: 0.6110 - val_loss: 1.3264
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.9079 - loss: 0.1489 - val_accuracy: 0.6110 - val_loss: 1.6650
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.9236 - loss: 0.1154 - val_accuracy: 0.5962 - val_loss: 2.0801
# 🏁 Best epoch for Fold 3: 4
# ✅ Fold 3 test accuracy: 0.6465
#
# 🧪 Fold 4 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.5839 - loss: 0.8366 - val_accuracy: 0.5814 - val_loss: 0.6822
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6186 - loss: 0.6705 - val_accuracy: 0.5814 - val_loss: 0.6829
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6183 - loss: 0.6742 - val_accuracy: 0.5814 - val_loss: 0.6811
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6239 - loss: 0.6585 - val_accuracy: 0.6137 - val_loss: 0.6616
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.6655 - loss: 0.6387 - val_accuracy: 0.6245 - val_loss: 0.6478
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6688 - loss: 0.6149 - val_accuracy: 0.6433 - val_loss: 0.6616
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6969 - loss: 0.5726 - val_accuracy: 0.6380 - val_loss: 0.6927
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.7450 - loss: 0.4981 - val_accuracy: 0.6555 - val_loss: 0.7147
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.8124 - loss: 0.3788 - val_accuracy: 0.6501 - val_loss: 0.9067
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.8555 - loss: 0.2761 - val_accuracy: 0.6151 - val_loss: 1.1173
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.8824 - loss: 0.2379 - val_accuracy: 0.6043 - val_loss: 1.2817
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.8980 - loss: 0.2065 - val_accuracy: 0.6016 - val_loss: 1.2082
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.9022 - loss: 0.2023 - val_accuracy: 0.6043 - val_loss: 1.0777
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.9209 - loss: 0.1588 - val_accuracy: 0.6057 - val_loss: 1.0917
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.9216 - loss: 0.1622 - val_accuracy: 0.6299 - val_loss: 1.2724
# 🏁 Best epoch for Fold 4: 5
# ✅ Fold 4 test accuracy: 0.6368
#
# 🧪 Fold 5 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 354ms/step - accuracy: 0.5549 - loss: 0.9390 - val_accuracy: 0.5922 - val_loss: 0.6791
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6099 - loss: 0.6739 - val_accuracy: 0.5922 - val_loss: 0.6765
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6099 - loss: 0.6702 - val_accuracy: 0.5922 - val_loss: 0.6758
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6098 - loss: 0.6693 - val_accuracy: 0.6003 - val_loss: 0.6534
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6004 - loss: 0.6650 - val_accuracy: 0.5922 - val_loss: 0.6727
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6369 - loss: 0.6474 - val_accuracy: 0.6339 - val_loss: 0.6546
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6552 - loss: 0.6222 - val_accuracy: 0.6218 - val_loss: 0.6442
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.6711 - loss: 0.5942 - val_accuracy: 0.6460 - val_loss: 0.6435
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 362ms/step - accuracy: 0.7070 - loss: 0.5471 - val_accuracy: 0.6393 - val_loss: 0.6525
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.7722 - loss: 0.4741 - val_accuracy: 0.6151 - val_loss: 0.6508
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 389ms/step - accuracy: 0.7582 - loss: 0.4643 - val_accuracy: 0.6433 - val_loss: 0.6530
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 391ms/step - accuracy: 0.7917 - loss: 0.3969 - val_accuracy: 0.6124 - val_loss: 0.7075
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.8163 - loss: 0.3460 - val_accuracy: 0.6191 - val_loss: 0.8470
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 369ms/step - accuracy: 0.8437 - loss: 0.2840 - val_accuracy: 0.6057 - val_loss: 0.9698
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.8690 - loss: 0.2222 - val_accuracy: 0.6043 - val_loss: 1.0194
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 402ms/step - accuracy: 0.8959 - loss: 0.1965 - val_accuracy: 0.6178 - val_loss: 1.0641
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.9196 - loss: 0.1517 - val_accuracy: 0.5841 - val_loss: 0.9933
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.9375 - loss: 0.1411 - val_accuracy: 0.6151 - val_loss: 1.1155
# 🏁 Best epoch for Fold 5: 8
# ✅ Fold 5 test accuracy: 0.6247
#
# 🧪 Fold 6 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 380ms/step - accuracy: 0.5913 - loss: 0.8441 - val_accuracy: 0.5774 - val_loss: 0.6844
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6124 - loss: 0.6770 - val_accuracy: 0.5774 - val_loss: 0.6864
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.6110 - loss: 0.6739 - val_accuracy: 0.5774 - val_loss: 0.6921
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6124 - loss: 0.6778 - val_accuracy: 0.5774 - val_loss: 0.7029
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6124 - loss: 0.6773 - val_accuracy: 0.5774 - val_loss: 0.6829
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6124 - loss: 0.6700 - val_accuracy: 0.5774 - val_loss: 0.6820
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6124 - loss: 0.6693 - val_accuracy: 0.5774 - val_loss: 0.6798
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6124 - loss: 0.6646 - val_accuracy: 0.5774 - val_loss: 0.6870
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6124 - loss: 0.6826 - val_accuracy: 0.5774 - val_loss: 0.6846
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6124 - loss: 0.6787 - val_accuracy: 0.5774 - val_loss: 0.6830
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6124 - loss: 0.6759 - val_accuracy: 0.5774 - val_loss: 0.6821
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6124 - loss: 0.6738 - val_accuracy: 0.5774 - val_loss: 0.6815
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6124 - loss: 0.6723 - val_accuracy: 0.5774 - val_loss: 0.6812
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 399ms/step - accuracy: 0.6124 - loss: 0.6711 - val_accuracy: 0.5774 - val_loss: 0.6811
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6124 - loss: 0.6703 - val_accuracy: 0.5774 - val_loss: 0.6811
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6124 - loss: 0.6697 - val_accuracy: 0.5774 - val_loss: 0.6812
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6124 - loss: 0.6692 - val_accuracy: 0.5774 - val_loss: 0.6814
# 🏁 Best epoch for Fold 6: 7
# ✅ Fold 6 test accuracy: 0.6019
#
# 🧪 Fold 7 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 378ms/step - accuracy: 0.5633 - loss: 0.8835 - val_accuracy: 0.5882 - val_loss: 0.6779
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6191 - loss: 0.6715 - val_accuracy: 0.5882 - val_loss: 0.6907
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6191 - loss: 0.6884 - val_accuracy: 0.5882 - val_loss: 0.6868
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6191 - loss: 0.6833 - val_accuracy: 0.5882 - val_loss: 0.6840
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6191 - loss: 0.6793 - val_accuracy: 0.5882 - val_loss: 0.6820
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6191 - loss: 0.6762 - val_accuracy: 0.5882 - val_loss: 0.6805
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.6191 - loss: 0.6738 - val_accuracy: 0.5882 - val_loss: 0.6794
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6191 - loss: 0.6720 - val_accuracy: 0.5882 - val_loss: 0.6787
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6191 - loss: 0.6705 - val_accuracy: 0.5882 - val_loss: 0.6782
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 371ms/step - accuracy: 0.6191 - loss: 0.6694 - val_accuracy: 0.5882 - val_loss: 0.6779
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6191 - loss: 0.6685 - val_accuracy: 0.5882 - val_loss: 0.6777
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6191 - loss: 0.6678 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6191 - loss: 0.6672 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 368ms/step - accuracy: 0.6191 - loss: 0.6668 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6191 - loss: 0.6664 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6191 - loss: 0.6661 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6191 - loss: 0.6659 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6191 - loss: 0.6657 - val_accuracy: 0.5882 - val_loss: 0.6777
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6191 - loss: 0.6656 - val_accuracy: 0.5882 - val_loss: 0.6777
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.6191 - loss: 0.6655 - val_accuracy: 0.5882 - val_loss: 0.6778
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6191 - loss: 0.6654 - val_accuracy: 0.5882 - val_loss: 0.6778
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6191 - loss: 0.6653 - val_accuracy: 0.5882 - val_loss: 0.6779
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6191 - loss: 0.6652 - val_accuracy: 0.5882 - val_loss: 0.6779
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6191 - loss: 0.6652 - val_accuracy: 0.5882 - val_loss: 0.6779
# 🏁 Best epoch for Fold 7: 14
# ✅ Fold 7 test accuracy: 0.6019
#
# 🧪 Fold 8 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.5790 - loss: 0.8577 - val_accuracy: 0.5908 - val_loss: 0.6781
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6148 - loss: 0.6722 - val_accuracy: 0.5908 - val_loss: 0.6757
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6146 - loss: 0.6658 - val_accuracy: 0.5908 - val_loss: 0.6735
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 349ms/step - accuracy: 0.6202 - loss: 0.6557 - val_accuracy: 0.5908 - val_loss: 0.6661
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6370 - loss: 0.6363 - val_accuracy: 0.5976 - val_loss: 0.6553
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6706 - loss: 0.6029 - val_accuracy: 0.6218 - val_loss: 0.6494
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6872 - loss: 0.5922 - val_accuracy: 0.6326 - val_loss: 0.6640
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.7437 - loss: 0.5265 - val_accuracy: 0.6528 - val_loss: 0.6684
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.7786 - loss: 0.4369 - val_accuracy: 0.6312 - val_loss: 0.7126
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.8208 - loss: 0.3389 - val_accuracy: 0.6339 - val_loss: 0.7711
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.8511 - loss: 0.2920 - val_accuracy: 0.6272 - val_loss: 0.8565
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.8828 - loss: 0.2307 - val_accuracy: 0.6164 - val_loss: 0.8542
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.9097 - loss: 0.1687 - val_accuracy: 0.6030 - val_loss: 1.0978
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.9375 - loss: 0.1328 - val_accuracy: 0.6137 - val_loss: 1.5169
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 349ms/step - accuracy: 0.9522 - loss: 0.0871 - val_accuracy: 0.6110 - val_loss: 1.5811
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.9562 - loss: 0.0850 - val_accuracy: 0.6191 - val_loss: 1.9937
# 🏁 Best epoch for Fold 8: 6
# ✅ Fold 8 test accuracy: 0.6141
#
# 🧪 Fold 9 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 348ms/step - accuracy: 0.5612 - loss: 1.0672 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 333ms/step - accuracy: 0.6206 - loss: 0.6680 - val_accuracy: 0.5922 - val_loss: 0.6699
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.6136 - loss: 0.6607 - val_accuracy: 0.6003 - val_loss: 0.6625
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6302 - loss: 0.6384 - val_accuracy: 0.6581 - val_loss: 0.6411
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6826 - loss: 0.5978 - val_accuracy: 0.6030 - val_loss: 0.6500
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.7332 - loss: 0.5270 - val_accuracy: 0.5868 - val_loss: 0.7062
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 333ms/step - accuracy: 0.7857 - loss: 0.4436 - val_accuracy: 0.5828 - val_loss: 0.9270
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.8089 - loss: 0.3798 - val_accuracy: 0.6164 - val_loss: 0.9772
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.8490 - loss: 0.2902 - val_accuracy: 0.6137 - val_loss: 0.9662
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.8537 - loss: 0.2789 - val_accuracy: 0.6016 - val_loss: 1.0075
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.8900 - loss: 0.2112 - val_accuracy: 0.5895 - val_loss: 1.1260
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.8983 - loss: 0.1985 - val_accuracy: 0.5828 - val_loss: 1.1286
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.9219 - loss: 0.1379 - val_accuracy: 0.5976 - val_loss: 1.6176
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.9251 - loss: 0.1151 - val_accuracy: 0.6083 - val_loss: 1.5759
# 🏁 Best epoch for Fold 9: 4
# ✅ Fold 9 test accuracy: 0.6189
#
# 🧪 Fold 10 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 338ms/step - accuracy: 0.5789 - loss: 0.8823 - val_accuracy: 0.5922 - val_loss: 0.6910
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6145 - loss: 0.6891 - val_accuracy: 0.5922 - val_loss: 0.6869
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.6145 - loss: 0.6843 - val_accuracy: 0.5922 - val_loss: 0.6839
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6145 - loss: 0.6804 - val_accuracy: 0.5922 - val_loss: 0.6816
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.6145 - loss: 0.6775 - val_accuracy: 0.5922 - val_loss: 0.6799
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6145 - loss: 0.6752 - val_accuracy: 0.5922 - val_loss: 0.6787
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6145 - loss: 0.6734 - val_accuracy: 0.5922 - val_loss: 0.6778
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.6145 - loss: 0.6720 - val_accuracy: 0.5922 - val_loss: 0.6772
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.6145 - loss: 0.6709 - val_accuracy: 0.5922 - val_loss: 0.6768
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6145 - loss: 0.6700 - val_accuracy: 0.5922 - val_loss: 0.6765
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6145 - loss: 0.6694 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.6145 - loss: 0.6689 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6145 - loss: 0.6685 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6145 - loss: 0.6682 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6145 - loss: 0.6679 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6145 - loss: 0.6677 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6145 - loss: 0.6676 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6145 - loss: 0.6675 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6145 - loss: 0.6674 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6145 - loss: 0.6673 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6145 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.6145 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.6145 - loss: 0.6671 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6145 - loss: 0.6671 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6145 - loss: 0.6671 - val_accuracy: 0.5922 - val_loss: 0.6763
# 🏁 Best epoch for Fold 10: 15
# ✅ Fold 10 test accuracy: 0.6019
#
# 📌 Mean optimal epoch across folds: 7

# %%
# Cell Block 5: Final Model Training on data again, but for ep_mean Epochs (no validation needed)

# Build your TF datasets
train_final_ds = preprocess(X_rest, y_rest)        # ALL data used in K-Fold
test_final_ds  = preprocess(X_holdout, y_holdout)  # NEVER seen during CV

# Instantiate & train your final model
final_model = create_model()
final_model.fit(
    train_final_ds,
    epochs=ep_mean,
    verbose=1
)

# Evaluate once—only on the true hold-out set
final_results = final_model.evaluate(
    test_final_ds,
    verbose=1
)
print("Hold-out test loss & accuracy:", final_results)
# Out:
# Epoch 1/7
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 317ms/step - accuracy: 0.5676 - loss: 1.1013
# Epoch 2/7
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 314ms/step - accuracy: 0.5997 - loss: 0.6695
# Epoch 3/7
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 37s 318ms/step - accuracy: 0.6089 - loss: 0.6331
# Epoch 4/7
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 37s 315ms/step - accuracy: 0.6729 - loss: 0.6246
# Epoch 5/7
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 314ms/step - accuracy: 0.7017 - loss: 0.5956
# Epoch 6/7
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 37s 316ms/step - accuracy: 0.7362 - loss: 0.5496
# Epoch 7/7
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 36s 313ms/step - accuracy: 0.7507 - loss: 0.5223
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.7305 - loss: 0.7048
# Hold-out test loss & accuracy: [0.6519708037376404, 0.7506053447723389]

# %%
# Cell Block 5: Final Evaluation

# Evaluate final model on the 20% test set
final_test_loss, final_test_acc = final_model.evaluate(test_final_ds, verbose=0)

# Report both results
print(f"\n📊 {k}-Fold Test Accuracy: {np.mean(all_test_accuracies):.4f} ± {np.std(all_test_accuracies):.4f}")
print(f"🏁 Final model test accuracy (trained on hold-out): {final_test_acc:.4f}")
# Out:
# 📊 10-Fold Test Accuracy: 0.6421 ± 0.0779
# 🏁 Final model test accuracy (trained on hold-out): 0.7506

# %%
import numpy as np
from sklearn.metrics import precision_score, roc_curve, auc, f1_score, recall_score
import matplotlib.pyplot as plt

# 1. Extract true labels and model scores from your hold-out dataset
y_true = np.concatenate([y.numpy() for x, y in test_final_ds], axis=0)
y_pred_prob = final_model.predict(test_final_ds)

# 2. If your model outputs two probabilities (one per class), take the “positive” class
if y_pred_prob.ndim > 1 and y_pred_prob.shape[1] > 1:
    y_scores = y_pred_prob[:, 1]
else:
    y_scores = y_pred_prob.ravel()

# 3. Compute ROC curve metrics
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# 4. Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr)               # ROC curve
plt.plot([0, 1], [0, 1], linestyle='--')  # chance line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (AUC = {roc_auc:.2f})')
plt.show()



# 1. Turn your predicted probabilities into binary preds (threshold = 0.5)
y_pred = (y_scores >= 0.5).astype(int)

# 2. Compute precision, recall, F1
precision = precision_score(y_true, y_pred)
recall    = recall_score(y_true, y_pred)
f1        = f1_score(y_true, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# Precision: 0.72
# Recall:    0.62
# F1 Score:  0.66
