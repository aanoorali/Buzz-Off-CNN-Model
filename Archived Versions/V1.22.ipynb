# %% [markdown]
# Varroa Mite Detection 1.22 Brightness and Blur

# %%
# Cell Block 1: Importing Libraries
import os
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold, train_test_split
import numpy as np
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Cell Block 2: Load Data and Preprocess

df = pd.read_csv('labels_augmented.csv')

df['filename'] = df['filename'].apply(lambda fn: os.path.join('rotations_flips', fn.strip()))

filepaths = df['filename'].values
labels = df['has_mite'].values

# %%
# Cell Block 3: Splitting Data

X_rest, X_holdout, y_rest, y_holdout = train_test_split(
    filepaths, labels,
    test_size=0.10,
    stratify=labels,
    random_state=42
)

# %%
# Cell Block 3: K-Fold Cross-Validation

# Early stopping callback
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    # min_delta=1e-4,
    restore_best_weights=True
)

k = 10  # Number of folds
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

fold = 1
all_test_accuracies = []
best_epochs = []

# Model creation function
def create_model():
    model = models.Sequential([
        layers.Input(shape=(224, 224, 3)),
        layers.Conv2D(32, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Guassian kernel function
def gaussian_kernel(size: int, sigma: float):
    x = tf.range(-size // 2 + 1, size // 2 + 1, dtype=tf.float32)
    xx, yy = tf.meshgrid(x, x)
    kernel = tf.exp(-(xx**2 + yy**2) / (2.0 * sigma**2))
    kernel = kernel / tf.reduce_sum(kernel)
    return kernel

def apply_gaussian_blur(image, kernel_size=5, sigma=1.0):
    kernel = gaussian_kernel(kernel_size, sigma)                 # [5, 5]
    kernel = kernel[:, :, tf.newaxis, tf.newaxis]                # [5, 5, 1, 1]
    kernel = tf.repeat(kernel, repeats=3, axis=2)                # [5, 5, 3, 1] ✅ CORRECT shape
    image = tf.expand_dims(image, 0)                             # [1, H, W, 3]
    blurred = tf.nn.depthwise_conv2d(image, kernel, strides=[1,1,1,1], padding='SAME')
    
    return tf.squeeze(blurred, axis=0)

# Preprocessing function
def preprocess(paths, labels):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    def load_img(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [224, 224])
        img = img / 255.0

        # 1) Apply Gaussian blur
        img = apply_gaussian_blur(img, kernel_size=5, sigma=1.0)

        # # 2) Boost blue channel
        # img = tf.clip_by_value(img + [0.0, 0.0, 0.2], 0.0, 1.0) 

        # # 3) Increase contrast
        # img = tf.image.adjust_contrast(img, 2.0) 

        # # 4) Boost red channel
        # img = tf.clip_by_value(img + [0.2, 0.0, 0.0], 0.0, 1.0)

        # # 5) Boost blue and red channel
        # img = tf.clip_by_value(img + [0.2, 0.0, 0.2], 0.0, 1.0)

        # 6) Boost the Brightness
        img = tf.image.adjust_brightness(img, delta=0.1)

        
        return img, label

    return ds.map(load_img).batch(32).prefetch(tf.data.AUTOTUNE)

for trainval_index, test_index in skf.split(filepaths, labels):
    print(f"\n🧪 Fold {fold} -----------------------------")

    # Split into trainval and test
    X_trainval, X_test = filepaths[trainval_index], filepaths[test_index]
    y_trainval, y_test = labels[trainval_index], labels[test_index]

    # Further split trainval into train and val (e.g. 80/20)
    val_split = int(0.8 * len(X_trainval))
    X_train, X_val = X_trainval[:val_split], X_trainval[val_split:]
    y_train, y_val = y_trainval[:val_split], y_trainval[val_split:]


    # Preprocess each split
    train_ds = preprocess(X_train, y_train)
    val_ds = preprocess(X_val, y_val)
    test_ds = preprocess(X_test, y_test)



    # Train model with early stopping
    model = create_model()
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[earlystop],
        verbose=1
    )

    # Record best epoch (smallest val_loss)
    best_epoch = np.argmin(history.history['val_loss']) + 1
    best_epochs.append(best_epoch)
    print(f"🏁 Best epoch for Fold {fold}: {best_epoch}")

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    all_test_accuracies.append(test_acc)
    print(f"✅ Fold {fold} test accuracy: {test_acc:.4f}")

    fold += 1

# Calculate mean best epoch
ep_mean = int(np.round(np.mean(best_epochs)))
print(f"\n📌 Mean optimal epoch across folds: {ep_mean}")
# Out:
# 🧪 Fold 1 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 415ms/step - accuracy: 0.5627 - loss: 0.7586 - val_accuracy: 0.5922 - val_loss: 0.6772
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 420ms/step - accuracy: 0.6052 - loss: 0.6768 - val_accuracy: 0.5922 - val_loss: 0.6795
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 371ms/step - accuracy: 0.6091 - loss: 0.6728 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 363ms/step - accuracy: 0.6091 - loss: 0.6745 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 367ms/step - accuracy: 0.6091 - loss: 0.6731 - val_accuracy: 0.5922 - val_loss: 0.6758
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 364ms/step - accuracy: 0.6087 - loss: 0.6738 - val_accuracy: 0.5922 - val_loss: 0.6769
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 363ms/step - accuracy: 0.6035 - loss: 0.6738 - val_accuracy: 0.5922 - val_loss: 0.6795
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 364ms/step - accuracy: 0.6033 - loss: 0.6735 - val_accuracy: 0.5922 - val_loss: 0.6814
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 363ms/step - accuracy: 0.6091 - loss: 0.6745 - val_accuracy: 0.5922 - val_loss: 0.6764
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 360ms/step - accuracy: 0.6091 - loss: 0.6754 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 363ms/step - accuracy: 0.6091 - loss: 0.6753 - val_accuracy: 0.5922 - val_loss: 0.6765
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 365ms/step - accuracy: 0.6091 - loss: 0.6715 - val_accuracy: 0.5922 - val_loss: 0.6759
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 362ms/step - accuracy: 0.6091 - loss: 0.6712 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 368ms/step - accuracy: 0.6091 - loss: 0.6706 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.6091 - loss: 0.6704 - val_accuracy: 0.5922 - val_loss: 0.6760
# 🏁 Best epoch for Fold 1: 5
# ✅ Fold 1 test accuracy: 0.6029
#
# 🧪 Fold 2 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 363ms/step - accuracy: 0.6154 - loss: 0.8442 - val_accuracy: 0.5868 - val_loss: 0.6912
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.6182 - loss: 0.6892 - val_accuracy: 0.5868 - val_loss: 0.6876
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 362ms/step - accuracy: 0.6182 - loss: 0.6844 - val_accuracy: 0.5868 - val_loss: 0.6849
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.6182 - loss: 0.6805 - val_accuracy: 0.5868 - val_loss: 0.6828
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.6182 - loss: 0.6774 - val_accuracy: 0.5868 - val_loss: 0.6813
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6182 - loss: 0.6750 - val_accuracy: 0.5868 - val_loss: 0.6802
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6182 - loss: 0.6731 - val_accuracy: 0.5868 - val_loss: 0.6794
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6182 - loss: 0.6715 - val_accuracy: 0.5868 - val_loss: 0.6789
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.6182 - loss: 0.6703 - val_accuracy: 0.5868 - val_loss: 0.6785
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6182 - loss: 0.6693 - val_accuracy: 0.5868 - val_loss: 0.6782
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6182 - loss: 0.6686 - val_accuracy: 0.5868 - val_loss: 0.6781
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 349ms/step - accuracy: 0.6182 - loss: 0.6679 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6182 - loss: 0.6675 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6182 - loss: 0.6671 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.6182 - loss: 0.6667 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6182 - loss: 0.6665 - val_accuracy: 0.5868 - val_loss: 0.6781
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6182 - loss: 0.6663 - val_accuracy: 0.5868 - val_loss: 0.6781
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6182 - loss: 0.6661 - val_accuracy: 0.5868 - val_loss: 0.6782
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6182 - loss: 0.6660 - val_accuracy: 0.5868 - val_loss: 0.6782
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.6182 - loss: 0.6659 - val_accuracy: 0.5868 - val_loss: 0.6783
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6182 - loss: 0.6658 - val_accuracy: 0.5868 - val_loss: 0.6783
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.6182 - loss: 0.6657 - val_accuracy: 0.5868 - val_loss: 0.6784
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 349ms/step - accuracy: 0.6182 - loss: 0.6656 - val_accuracy: 0.5868 - val_loss: 0.6784
# 🏁 Best epoch for Fold 2: 13
# ✅ Fold 2 test accuracy: 0.6029
#
# 🧪 Fold 3 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 354ms/step - accuracy: 0.5704 - loss: 0.8584 - val_accuracy: 0.5828 - val_loss: 0.6852
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.6173 - loss: 0.6740 - val_accuracy: 0.5828 - val_loss: 0.6809
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.6118 - loss: 0.6746 - val_accuracy: 0.5828 - val_loss: 0.6901
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6173 - loss: 0.6875 - val_accuracy: 0.5828 - val_loss: 0.6868
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.6173 - loss: 0.6829 - val_accuracy: 0.5828 - val_loss: 0.6845
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6173 - loss: 0.6793 - val_accuracy: 0.5828 - val_loss: 0.6828
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6173 - loss: 0.6765 - val_accuracy: 0.5828 - val_loss: 0.6816
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6173 - loss: 0.6743 - val_accuracy: 0.5828 - val_loss: 0.6808
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.6173 - loss: 0.6725 - val_accuracy: 0.5828 - val_loss: 0.6802
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6173 - loss: 0.6712 - val_accuracy: 0.5828 - val_loss: 0.6798
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 349ms/step - accuracy: 0.6173 - loss: 0.6701 - val_accuracy: 0.5828 - val_loss: 0.6796
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6173 - loss: 0.6692 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6173 - loss: 0.6685 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6173 - loss: 0.6680 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.6173 - loss: 0.6675 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6173 - loss: 0.6672 - val_accuracy: 0.5828 - val_loss: 0.6795
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6173 - loss: 0.6669 - val_accuracy: 0.5828 - val_loss: 0.6796
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 349ms/step - accuracy: 0.6173 - loss: 0.6667 - val_accuracy: 0.5828 - val_loss: 0.6797
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6173 - loss: 0.6665 - val_accuracy: 0.5828 - val_loss: 0.6797
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 401ms/step - accuracy: 0.6173 - loss: 0.6663 - val_accuracy: 0.5828 - val_loss: 0.6798
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 435ms/step - accuracy: 0.6173 - loss: 0.6662 - val_accuracy: 0.5828 - val_loss: 0.6799
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 42s 455ms/step - accuracy: 0.6173 - loss: 0.6661 - val_accuracy: 0.5828 - val_loss: 0.6800
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 42s 456ms/step - accuracy: 0.6173 - loss: 0.6661 - val_accuracy: 0.5828 - val_loss: 0.6800
# 🏁 Best epoch for Fold 3: 13
# ✅ Fold 3 test accuracy: 0.6029
#
# 🧪 Fold 4 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 436ms/step - accuracy: 0.5989 - loss: 0.7748 - val_accuracy: 0.5814 - val_loss: 0.6819
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 442ms/step - accuracy: 0.6183 - loss: 0.6792 - val_accuracy: 0.5814 - val_loss: 0.6806
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 439ms/step - accuracy: 0.6183 - loss: 0.6742 - val_accuracy: 0.5814 - val_loss: 0.6800
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 445ms/step - accuracy: 0.6183 - loss: 0.6720 - val_accuracy: 0.5814 - val_loss: 0.6857
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 436ms/step - accuracy: 0.6183 - loss: 0.6743 - val_accuracy: 0.5814 - val_loss: 0.6798
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 47s 505ms/step - accuracy: 0.6183 - loss: 0.6696 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 43s 465ms/step - accuracy: 0.6183 - loss: 0.6697 - val_accuracy: 0.5814 - val_loss: 0.6800
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 439ms/step - accuracy: 0.6183 - loss: 0.6698 - val_accuracy: 0.5814 - val_loss: 0.6800
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 42s 455ms/step - accuracy: 0.6183 - loss: 0.6718 - val_accuracy: 0.5814 - val_loss: 0.6813
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 385ms/step - accuracy: 0.6183 - loss: 0.6779 - val_accuracy: 0.5814 - val_loss: 0.6833
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.6233 - loss: 0.6767 - val_accuracy: 0.5814 - val_loss: 0.6803
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 363ms/step - accuracy: 0.6183 - loss: 0.6678 - val_accuracy: 0.5814 - val_loss: 0.6800
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 360ms/step - accuracy: 0.6183 - loss: 0.6677 - val_accuracy: 0.5814 - val_loss: 0.6801
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 361ms/step - accuracy: 0.6183 - loss: 0.6675 - val_accuracy: 0.5814 - val_loss: 0.6801
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 363ms/step - accuracy: 0.6183 - loss: 0.6673 - val_accuracy: 0.5814 - val_loss: 0.6802
# 🏁 Best epoch for Fold 4: 5
# ✅ Fold 4 test accuracy: 0.6029
#
# 🧪 Fold 5 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 362ms/step - accuracy: 0.6037 - loss: 0.8004 - val_accuracy: 0.5922 - val_loss: 0.6766
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 361ms/step - accuracy: 0.6099 - loss: 0.6745 - val_accuracy: 0.5922 - val_loss: 0.6785
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 361ms/step - accuracy: 0.5993 - loss: 0.6770 - val_accuracy: 0.5922 - val_loss: 0.6779
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.6077 - loss: 0.6758 - val_accuracy: 0.5922 - val_loss: 0.6787
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 362ms/step - accuracy: 0.6035 - loss: 0.6715 - val_accuracy: 0.5922 - val_loss: 0.6786
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 360ms/step - accuracy: 0.6099 - loss: 0.6742 - val_accuracy: 0.5922 - val_loss: 0.6769
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 361ms/step - accuracy: 0.6099 - loss: 0.6724 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 360ms/step - accuracy: 0.6099 - loss: 0.6720 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 361ms/step - accuracy: 0.6099 - loss: 0.6711 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 362ms/step - accuracy: 0.6099 - loss: 0.6710 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 361ms/step - accuracy: 0.6099 - loss: 0.6708 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6099 - loss: 0.6707 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6099 - loss: 0.6707 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.6099 - loss: 0.6706 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6099 - loss: 0.6706 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6099 - loss: 0.6705 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6099 - loss: 0.6705 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6099 - loss: 0.6704 - val_accuracy: 0.5922 - val_loss: 0.6761
# 🏁 Best epoch for Fold 5: 8
# ✅ Fold 5 test accuracy: 0.6029
#
# 🧪 Fold 6 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 346ms/step - accuracy: 0.5983 - loss: 0.8946 - val_accuracy: 0.5774 - val_loss: 0.6874
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6124 - loss: 0.6814 - val_accuracy: 0.5774 - val_loss: 0.6819
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6124 - loss: 0.6726 - val_accuracy: 0.5774 - val_loss: 0.6811
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.6105 - loss: 0.6708 - val_accuracy: 0.5774 - val_loss: 0.6893
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6124 - loss: 0.6733 - val_accuracy: 0.5774 - val_loss: 0.6865
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6124 - loss: 0.6726 - val_accuracy: 0.5774 - val_loss: 0.6819
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6124 - loss: 0.6685 - val_accuracy: 0.5774 - val_loss: 0.6826
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6124 - loss: 0.6682 - val_accuracy: 0.5774 - val_loss: 0.6931
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6076 - loss: 0.6704 - val_accuracy: 0.5774 - val_loss: 0.6851
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6124 - loss: 0.6716 - val_accuracy: 0.5774 - val_loss: 0.6830
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.6121 - loss: 0.6685 - val_accuracy: 0.5774 - val_loss: 0.6912
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6428 - loss: 0.6469 - val_accuracy: 0.7820 - val_loss: 0.5172
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.8009 - loss: 0.4665 - val_accuracy: 0.7456 - val_loss: 0.5132
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.7990 - loss: 0.4618 - val_accuracy: 0.8277 - val_loss: 0.4103
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.8429 - loss: 0.3656 - val_accuracy: 0.8156 - val_loss: 0.4246
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.8486 - loss: 0.3562 - val_accuracy: 0.8143 - val_loss: 0.4408
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.8559 - loss: 0.3568 - val_accuracy: 0.8022 - val_loss: 0.4526
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.8598 - loss: 0.3531 - val_accuracy: 0.8089 - val_loss: 0.4699
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.8685 - loss: 0.3380 - val_accuracy: 0.8075 - val_loss: 0.4598
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.8711 - loss: 0.3292 - val_accuracy: 0.8291 - val_loss: 0.4263
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.8805 - loss: 0.3099 - val_accuracy: 0.8277 - val_loss: 0.4381
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.8844 - loss: 0.3000 - val_accuracy: 0.8143 - val_loss: 0.4638
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.8816 - loss: 0.3194 - val_accuracy: 0.8264 - val_loss: 0.4405
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.8899 - loss: 0.2832 - val_accuracy: 0.8223 - val_loss: 0.4746
# 🏁 Best epoch for Fold 6: 14
# ✅ Fold 6 test accuracy: 0.8422
#
# 🧪 Fold 7 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 347ms/step - accuracy: 0.5486 - loss: 0.7488 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6191 - loss: 0.6701 - val_accuracy: 0.5882 - val_loss: 0.6812
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6143 - loss: 0.6692 - val_accuracy: 0.5882 - val_loss: 0.6822
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6339 - loss: 0.6603 - val_accuracy: 0.6433 - val_loss: 0.6315
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.7505 - loss: 0.5457 - val_accuracy: 0.7604 - val_loss: 0.5327
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.8170 - loss: 0.4392 - val_accuracy: 0.7954 - val_loss: 0.4772
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.8342 - loss: 0.3860 - val_accuracy: 0.8048 - val_loss: 0.4519
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.8500 - loss: 0.3575 - val_accuracy: 0.8062 - val_loss: 0.4466
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.8530 - loss: 0.3404 - val_accuracy: 0.8089 - val_loss: 0.4396
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.8603 - loss: 0.3283 - val_accuracy: 0.8197 - val_loss: 0.4259
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.8792 - loss: 0.2932 - val_accuracy: 0.8170 - val_loss: 0.4506
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 363ms/step - accuracy: 0.8889 - loss: 0.2694 - val_accuracy: 0.8129 - val_loss: 0.4933
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 362ms/step - accuracy: 0.8929 - loss: 0.2525 - val_accuracy: 0.8022 - val_loss: 0.5294
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.8954 - loss: 0.2371 - val_accuracy: 0.7927 - val_loss: 0.5749
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.8963 - loss: 0.2429 - val_accuracy: 0.7739 - val_loss: 0.5760
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.8794 - loss: 0.2664 - val_accuracy: 0.7820 - val_loss: 0.6450
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.8971 - loss: 0.2401 - val_accuracy: 0.7604 - val_loss: 0.7375
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.8907 - loss: 0.2461 - val_accuracy: 0.7739 - val_loss: 0.7101
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.9068 - loss: 0.2045 - val_accuracy: 0.7793 - val_loss: 0.6920
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.9272 - loss: 0.1752 - val_accuracy: 0.7900 - val_loss: 0.7779
# 🏁 Best epoch for Fold 7: 10
# ✅ Fold 7 test accuracy: 0.8252
#
# 🧪 Fold 8 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 349ms/step - accuracy: 0.5832 - loss: 0.7400 - val_accuracy: 0.5908 - val_loss: 0.6790
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6176 - loss: 0.6716 - val_accuracy: 0.5908 - val_loss: 0.6778
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 343ms/step - accuracy: 0.6214 - loss: 0.6690 - val_accuracy: 0.5908 - val_loss: 0.6762
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6148 - loss: 0.6715 - val_accuracy: 0.5908 - val_loss: 0.6768
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6148 - loss: 0.6732 - val_accuracy: 0.5908 - val_loss: 0.6798
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6148 - loss: 0.6748 - val_accuracy: 0.5908 - val_loss: 0.6797
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6148 - loss: 0.6724 - val_accuracy: 0.5908 - val_loss: 0.6838
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6148 - loss: 0.6786 - val_accuracy: 0.5908 - val_loss: 0.6775
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6148 - loss: 0.6722 - val_accuracy: 0.5908 - val_loss: 0.6772
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6148 - loss: 0.6717 - val_accuracy: 0.5908 - val_loss: 0.6805
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6148 - loss: 0.6742 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6148 - loss: 0.6698 - val_accuracy: 0.5908 - val_loss: 0.6771
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.6148 - loss: 0.6713 - val_accuracy: 0.5908 - val_loss: 0.6767
# 🏁 Best epoch for Fold 8: 3
# ✅ Fold 8 test accuracy: 0.6019
#
# 🧪 Fold 9 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 347ms/step - accuracy: 0.6096 - loss: 0.8357 - val_accuracy: 0.5922 - val_loss: 0.6907
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 347ms/step - accuracy: 0.6206 - loss: 0.6748 - val_accuracy: 0.5922 - val_loss: 0.6888
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6206 - loss: 0.6862 - val_accuracy: 0.5922 - val_loss: 0.6853
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.6206 - loss: 0.6816 - val_accuracy: 0.5922 - val_loss: 0.6827
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6206 - loss: 0.6780 - val_accuracy: 0.5922 - val_loss: 0.6807
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6206 - loss: 0.6752 - val_accuracy: 0.5922 - val_loss: 0.6793
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6206 - loss: 0.6730 - val_accuracy: 0.5922 - val_loss: 0.6783
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6206 - loss: 0.6712 - val_accuracy: 0.5922 - val_loss: 0.6775
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6206 - loss: 0.6699 - val_accuracy: 0.5922 - val_loss: 0.6770
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6206 - loss: 0.6688 - val_accuracy: 0.5922 - val_loss: 0.6766
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6206 - loss: 0.6679 - val_accuracy: 0.5922 - val_loss: 0.6764
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6206 - loss: 0.6673 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.6206 - loss: 0.6667 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6206 - loss: 0.6663 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 399ms/step - accuracy: 0.6206 - loss: 0.6659 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 422ms/step - accuracy: 0.6206 - loss: 0.6657 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 422ms/step - accuracy: 0.6206 - loss: 0.6654 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 424ms/step - accuracy: 0.6206 - loss: 0.6652 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.6206 - loss: 0.6651 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.6206 - loss: 0.6650 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 401ms/step - accuracy: 0.6206 - loss: 0.6649 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 365ms/step - accuracy: 0.6206 - loss: 0.6648 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 367ms/step - accuracy: 0.6206 - loss: 0.6647 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.6206 - loss: 0.6647 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.6206 - loss: 0.6646 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 368ms/step - accuracy: 0.6206 - loss: 0.6646 - val_accuracy: 0.5922 - val_loss: 0.6763
# 🏁 Best epoch for Fold 9: 16
# ✅ Fold 9 test accuracy: 0.6019
#
# 🧪 Fold 10 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 367ms/step - accuracy: 0.5726 - loss: 0.7604 - val_accuracy: 0.5922 - val_loss: 0.6768
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6145 - loss: 0.6768 - val_accuracy: 0.5922 - val_loss: 0.6768
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 367ms/step - accuracy: 0.6145 - loss: 0.6790 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 368ms/step - accuracy: 0.6145 - loss: 0.6710 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 369ms/step - accuracy: 0.6143 - loss: 0.6711 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.6009 - loss: 0.6743 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 367ms/step - accuracy: 0.6145 - loss: 0.6690 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 365ms/step - accuracy: 0.6145 - loss: 0.6686 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 371ms/step - accuracy: 0.6145 - loss: 0.6686 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 367ms/step - accuracy: 0.6145 - loss: 0.6685 - val_accuracy: 0.5922 - val_loss: 0.6757
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.6145 - loss: 0.6686 - val_accuracy: 0.5922 - val_loss: 0.6758
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 363ms/step - accuracy: 0.6145 - loss: 0.6687 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6145 - loss: 0.6684 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6145 - loss: 0.6684 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 350ms/step - accuracy: 0.6145 - loss: 0.6683 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.6145 - loss: 0.6683 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6145 - loss: 0.6683 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 365ms/step - accuracy: 0.6145 - loss: 0.6724 - val_accuracy: 0.5922 - val_loss: 0.6859
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.6219 - loss: 0.6819 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6145 - loss: 0.6720 - val_accuracy: 0.5922 - val_loss: 0.6770
# 🏁 Best epoch for Fold 10: 10
# ✅ Fold 10 test accuracy: 0.6019
#
# 📌 Mean optimal epoch across folds: 10

# %%
# Cell Block 5: Final Model Training on data again, but for ep_mean Epochs (no validation needed)

# Build your TF datasets
train_final_ds = preprocess(X_rest, y_rest)        # ALL data used in K-Fold
test_final_ds  = preprocess(X_holdout, y_holdout)  # NEVER seen during CV

# Instantiate & train your final model
final_model = create_model()
final_model.fit(
    train_final_ds,
    epochs=ep_mean,
    verbose=1
)

# Evaluate once—only on the true hold-out set
final_results = final_model.evaluate(
    test_final_ds,
    verbose=1
)
print("Hold-out test loss & accuracy:", final_results)
# Out:
# Epoch 1/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 39s 326ms/step - accuracy: 0.5699 - loss: 0.7522
# Epoch 2/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 325ms/step - accuracy: 0.5996 - loss: 0.6658
# Epoch 3/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 328ms/step - accuracy: 0.5996 - loss: 0.6751
# Epoch 4/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 37s 322ms/step - accuracy: 0.5935 - loss: 0.6683
# Epoch 5/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 324ms/step - accuracy: 0.6160 - loss: 0.6507
# Epoch 6/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 39s 332ms/step - accuracy: 0.6697 - loss: 0.6199
# Epoch 7/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 326ms/step - accuracy: 0.7173 - loss: 0.5694
# Epoch 8/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 325ms/step - accuracy: 0.7332 - loss: 0.5332
# Epoch 9/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 328ms/step - accuracy: 0.8028 - loss: 0.4649
# Epoch 10/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 325ms/step - accuracy: 0.8146 - loss: 0.4248
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8064 - loss: 0.4650
# Hold-out test loss & accuracy: [0.4578340947628021, 0.8135592937469482]

# %%
# Cell Block 5: Final Evaluation

# Evaluate final model on the 20% test set
final_test_loss, final_test_acc = final_model.evaluate(test_final_ds, verbose=0)

# Report both results
print(f"\n📊 {k}-Fold Test Accuracy: {np.mean(all_test_accuracies):.4f} ± {np.std(all_test_accuracies):.4f}")
print(f"🏁 Final model test accuracy (trained on hold-out): {final_test_acc:.4f}")
# Out:
# 📊 10-Fold Test Accuracy: 0.6488 ± 0.0926
# 🏁 Final model test accuracy (trained on hold-out): 0.8136

# %%
import numpy as np
from sklearn.metrics import precision_score, roc_curve, auc, f1_score, recall_score
import matplotlib.pyplot as plt

# 1. Extract true labels and model scores from your hold-out dataset
y_true = np.concatenate([y.numpy() for x, y in test_final_ds], axis=0)
y_pred_prob = final_model.predict(test_final_ds)

# 2. If your model outputs two probabilities (one per class), take the “positive” class
if y_pred_prob.ndim > 1 and y_pred_prob.shape[1] > 1:
    y_scores = y_pred_prob[:, 1]
else:
    y_scores = y_pred_prob.ravel()

# 3. Compute ROC curve metrics
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# 4. Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr)               # ROC curve
plt.plot([0, 1], [0, 1], linestyle='--')  # chance line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (AUC = {roc_auc:.2f})')
plt.show()



# 1. Turn your predicted probabilities into binary preds (threshold = 0.5)
y_pred = (y_scores >= 0.5).astype(int)

# 2. Compute precision, recall, F1
precision = precision_score(y_true, y_pred)
recall    = recall_score(y_true, y_pred)
f1        = f1_score(y_true, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# Precision: 0.90
# Recall:    0.60
# F1 Score:  0.72
