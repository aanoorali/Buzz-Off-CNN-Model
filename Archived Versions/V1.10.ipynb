# %% [markdown]
# Varroa Mite Detection 1.10 Red S Only

# %%
# Cell Block 1: Importing Libraries
import os
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold, train_test_split
import numpy as np
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Cell Block 2: Load Data and Preprocess

df = pd.read_csv('labels_augmented.csv')

df['filename'] = df['filename'].apply(lambda fn: os.path.join('rotations_flips', fn.strip()))

filepaths = df['filename'].values
labels = df['has_mite'].values

# %%
# Cell Block 3: Splitting Data

X_rest, X_holdout, y_rest, y_holdout = train_test_split(
    filepaths, labels,
    test_size=0.10,
    stratify=labels,
    random_state=42
)

# %%
# Cell Block 3: K-Fold Cross-Validation

# Early stopping callback
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    # min_delta=1e-4,
    restore_best_weights=True
)

k = 10  # Number of folds
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

fold = 1
all_test_accuracies = []
best_epochs = []

# Model creation function
def create_model():
    model = models.Sequential([
        layers.Input(shape=(224, 224, 3)),
        layers.Conv2D(32, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Preprocessing function
def preprocess(paths, labels):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    def load_img(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [224, 224])
        img = img / 255.0


        # 1) Boost blue channel
        # img = tf.clip_by_value(img + [0.0, 0.0, 0.2], 0.0, 1.0) 

        # 2) Increase contrast
        # img = tf.image.adjust_contrast(img, 2.0) 

        # 3) Boost red channel
        img = tf.clip_by_value(img + [0.2, 0.0, 0.0], 0.0, 1.0)

   
        return img, label

    return ds.map(load_img).batch(32).prefetch(tf.data.AUTOTUNE)

for trainval_index, test_index in skf.split(filepaths, labels):
    print(f"\n🧪 Fold {fold} -----------------------------")

    # Split into trainval and test
    X_trainval, X_test = filepaths[trainval_index], filepaths[test_index]
    y_trainval, y_test = labels[trainval_index], labels[test_index]

    # Further split trainval into train and val (e.g. 80/20)
    val_split = int(0.8 * len(X_trainval))
    X_train, X_val = X_trainval[:val_split], X_trainval[val_split:]
    y_train, y_val = y_trainval[:val_split], y_trainval[val_split:]


    # Preprocess each split
    train_ds = preprocess(X_train, y_train)
    val_ds = preprocess(X_val, y_val)
    test_ds = preprocess(X_test, y_test)



    # Train model with early stopping
    model = create_model()
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[earlystop],
        verbose=1
    )

    # Record best epoch (smallest val_loss)
    best_epoch = np.argmin(history.history['val_loss']) + 1
    best_epochs.append(best_epoch)
    print(f"🏁 Best epoch for Fold {fold}: {best_epoch}")

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    all_test_accuracies.append(test_acc)
    print(f"✅ Fold {fold} test accuracy: {test_acc:.4f}")

    fold += 1

# Calculate mean best epoch
ep_mean = int(np.round(np.mean(best_epochs)))
print(f"\n📌 Mean optimal epoch across folds: {ep_mean}")
# Out:
# 🧪 Fold 1 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 368ms/step - accuracy: 0.5734 - loss: 0.8078 - val_accuracy: 0.5922 - val_loss: 0.6831
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6091 - loss: 0.6759 - val_accuracy: 0.5922 - val_loss: 0.6902
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 336ms/step - accuracy: 0.6091 - loss: 0.6885 - val_accuracy: 0.5922 - val_loss: 0.6865
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.6091 - loss: 0.6843 - val_accuracy: 0.5922 - val_loss: 0.6837
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6091 - loss: 0.6810 - val_accuracy: 0.5922 - val_loss: 0.6817
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6091 - loss: 0.6785 - val_accuracy: 0.5922 - val_loss: 0.6801
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6091 - loss: 0.6765 - val_accuracy: 0.5922 - val_loss: 0.6789
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 333ms/step - accuracy: 0.6091 - loss: 0.6749 - val_accuracy: 0.5922 - val_loss: 0.6780
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 333ms/step - accuracy: 0.6091 - loss: 0.6737 - val_accuracy: 0.5922 - val_loss: 0.6774
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 333ms/step - accuracy: 0.6091 - loss: 0.6727 - val_accuracy: 0.5922 - val_loss: 0.6770
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6091 - loss: 0.6720 - val_accuracy: 0.5922 - val_loss: 0.6766
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6091 - loss: 0.6714 - val_accuracy: 0.5922 - val_loss: 0.6764
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6091 - loss: 0.6710 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6091 - loss: 0.6706 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6091 - loss: 0.6703 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6091 - loss: 0.6701 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.6091 - loss: 0.6699 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6091 - loss: 0.6698 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.6091 - loss: 0.6697 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 333ms/step - accuracy: 0.6091 - loss: 0.6696 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6091 - loss: 0.6695 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6091 - loss: 0.6695 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6091 - loss: 0.6694 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6091 - loss: 0.6694 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6091 - loss: 0.6694 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6091 - loss: 0.6693 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 337ms/step - accuracy: 0.6091 - loss: 0.6693 - val_accuracy: 0.5922 - val_loss: 0.6762
# 🏁 Best epoch for Fold 1: 17
# ✅ Fold 1 test accuracy: 0.6029
#
# 🧪 Fold 2 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.5632 - loss: 0.7482 - val_accuracy: 0.5868 - val_loss: 0.6838
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.6182 - loss: 0.6693 - val_accuracy: 0.5868 - val_loss: 0.6814
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6182 - loss: 0.6708 - val_accuracy: 0.5868 - val_loss: 0.6822
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6182 - loss: 0.6706 - val_accuracy: 0.5868 - val_loss: 0.6797
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.6182 - loss: 0.6684 - val_accuracy: 0.5868 - val_loss: 0.6794
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.6182 - loss: 0.6720 - val_accuracy: 0.5868 - val_loss: 0.6875
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 317ms/step - accuracy: 0.6182 - loss: 0.6842 - val_accuracy: 0.5868 - val_loss: 0.6846
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 315ms/step - accuracy: 0.6182 - loss: 0.6801 - val_accuracy: 0.5868 - val_loss: 0.6825
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.6182 - loss: 0.6770 - val_accuracy: 0.5868 - val_loss: 0.6811
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6182 - loss: 0.6746 - val_accuracy: 0.5868 - val_loss: 0.6800
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 315ms/step - accuracy: 0.6182 - loss: 0.6727 - val_accuracy: 0.5868 - val_loss: 0.6793
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6182 - loss: 0.6712 - val_accuracy: 0.5868 - val_loss: 0.6787
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 315ms/step - accuracy: 0.6182 - loss: 0.6700 - val_accuracy: 0.5868 - val_loss: 0.6784
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 315ms/step - accuracy: 0.6182 - loss: 0.6691 - val_accuracy: 0.5868 - val_loss: 0.6782
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 314ms/step - accuracy: 0.6182 - loss: 0.6684 - val_accuracy: 0.5868 - val_loss: 0.6781
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 317ms/step - accuracy: 0.6182 - loss: 0.6678 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 317ms/step - accuracy: 0.6182 - loss: 0.6673 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.6182 - loss: 0.6669 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 314ms/step - accuracy: 0.6182 - loss: 0.6667 - val_accuracy: 0.5868 - val_loss: 0.6780
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6182 - loss: 0.6664 - val_accuracy: 0.5868 - val_loss: 0.6781
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 315ms/step - accuracy: 0.6182 - loss: 0.6662 - val_accuracy: 0.5868 - val_loss: 0.6781
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6182 - loss: 0.6661 - val_accuracy: 0.5868 - val_loss: 0.6782
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 314ms/step - accuracy: 0.6182 - loss: 0.6659 - val_accuracy: 0.5868 - val_loss: 0.6783
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 315ms/step - accuracy: 0.6182 - loss: 0.6658 - val_accuracy: 0.5868 - val_loss: 0.6783
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6182 - loss: 0.6657 - val_accuracy: 0.5868 - val_loss: 0.6784
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 314ms/step - accuracy: 0.6182 - loss: 0.6657 - val_accuracy: 0.5868 - val_loss: 0.6784
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 314ms/step - accuracy: 0.6182 - loss: 0.6656 - val_accuracy: 0.5868 - val_loss: 0.6784
# 🏁 Best epoch for Fold 2: 17
# ✅ Fold 2 test accuracy: 0.6029
#
# 🧪 Fold 3 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 317ms/step - accuracy: 0.5739 - loss: 0.8031 - val_accuracy: 0.5828 - val_loss: 0.6821
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 315ms/step - accuracy: 0.6173 - loss: 0.6742 - val_accuracy: 0.5828 - val_loss: 0.6907
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 321ms/step - accuracy: 0.6173 - loss: 0.6883 - val_accuracy: 0.5828 - val_loss: 0.6873
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 315ms/step - accuracy: 0.6173 - loss: 0.6835 - val_accuracy: 0.5828 - val_loss: 0.6848
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6173 - loss: 0.6798 - val_accuracy: 0.5828 - val_loss: 0.6831
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.6173 - loss: 0.6769 - val_accuracy: 0.5828 - val_loss: 0.6818
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.6173 - loss: 0.6746 - val_accuracy: 0.5828 - val_loss: 0.6809
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 317ms/step - accuracy: 0.6173 - loss: 0.6728 - val_accuracy: 0.5828 - val_loss: 0.6802
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6173 - loss: 0.6714 - val_accuracy: 0.5828 - val_loss: 0.6798
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 314ms/step - accuracy: 0.6173 - loss: 0.6702 - val_accuracy: 0.5828 - val_loss: 0.6796
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.6173 - loss: 0.6693 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 313ms/step - accuracy: 0.6173 - loss: 0.6686 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6173 - loss: 0.6680 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6173 - loss: 0.6676 - val_accuracy: 0.5828 - val_loss: 0.6794
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6173 - loss: 0.6672 - val_accuracy: 0.5828 - val_loss: 0.6795
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 314ms/step - accuracy: 0.6173 - loss: 0.6669 - val_accuracy: 0.5828 - val_loss: 0.6796
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 315ms/step - accuracy: 0.6173 - loss: 0.6667 - val_accuracy: 0.5828 - val_loss: 0.6796
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 317ms/step - accuracy: 0.6173 - loss: 0.6665 - val_accuracy: 0.5828 - val_loss: 0.6797
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 317ms/step - accuracy: 0.6173 - loss: 0.6664 - val_accuracy: 0.5828 - val_loss: 0.6798
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.6173 - loss: 0.6662 - val_accuracy: 0.5828 - val_loss: 0.6799
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.6173 - loss: 0.6661 - val_accuracy: 0.5828 - val_loss: 0.6800
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 315ms/step - accuracy: 0.6173 - loss: 0.6661 - val_accuracy: 0.5828 - val_loss: 0.6800
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.6173 - loss: 0.6660 - val_accuracy: 0.5828 - val_loss: 0.6801
# 🏁 Best epoch for Fold 3: 13
# ✅ Fold 3 test accuracy: 0.6029
#
# 🧪 Fold 4 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 324ms/step - accuracy: 0.5633 - loss: 0.7883 - val_accuracy: 0.5814 - val_loss: 0.6829
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.6183 - loss: 0.6732 - val_accuracy: 0.5814 - val_loss: 0.6901
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 321ms/step - accuracy: 0.6183 - loss: 0.6874 - val_accuracy: 0.5814 - val_loss: 0.6869
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 317ms/step - accuracy: 0.6183 - loss: 0.6827 - val_accuracy: 0.5814 - val_loss: 0.6846
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 315ms/step - accuracy: 0.6183 - loss: 0.6791 - val_accuracy: 0.5814 - val_loss: 0.6830
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 317ms/step - accuracy: 0.6183 - loss: 0.6762 - val_accuracy: 0.5814 - val_loss: 0.6818
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 317ms/step - accuracy: 0.6183 - loss: 0.6740 - val_accuracy: 0.5814 - val_loss: 0.6810
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 317ms/step - accuracy: 0.6183 - loss: 0.6722 - val_accuracy: 0.5814 - val_loss: 0.6805
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 315ms/step - accuracy: 0.6183 - loss: 0.6708 - val_accuracy: 0.5814 - val_loss: 0.6801
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 317ms/step - accuracy: 0.6183 - loss: 0.6697 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.6183 - loss: 0.6688 - val_accuracy: 0.5814 - val_loss: 0.6798
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6183 - loss: 0.6681 - val_accuracy: 0.5814 - val_loss: 0.6798
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 321ms/step - accuracy: 0.6183 - loss: 0.6676 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.6183 - loss: 0.6671 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.6183 - loss: 0.6668 - val_accuracy: 0.5814 - val_loss: 0.6800
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 321ms/step - accuracy: 0.6183 - loss: 0.6665 - val_accuracy: 0.5814 - val_loss: 0.6801
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.6183 - loss: 0.6663 - val_accuracy: 0.5814 - val_loss: 0.6802
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6183 - loss: 0.6661 - val_accuracy: 0.5814 - val_loss: 0.6803
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 317ms/step - accuracy: 0.6183 - loss: 0.6659 - val_accuracy: 0.5814 - val_loss: 0.6804
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 317ms/step - accuracy: 0.6183 - loss: 0.6658 - val_accuracy: 0.5814 - val_loss: 0.6805
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 322ms/step - accuracy: 0.6183 - loss: 0.6657 - val_accuracy: 0.5814 - val_loss: 0.6806
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6183 - loss: 0.6656 - val_accuracy: 0.5814 - val_loss: 0.6806
# 🏁 Best epoch for Fold 4: 12
# ✅ Fold 4 test accuracy: 0.6029
#
# 🧪 Fold 5 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.6070 - loss: 0.9372 - val_accuracy: 0.5922 - val_loss: 0.6770
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6029 - loss: 0.6721 - val_accuracy: 0.5922 - val_loss: 0.6787
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 317ms/step - accuracy: 0.6099 - loss: 0.6760 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6099 - loss: 0.6756 - val_accuracy: 0.5922 - val_loss: 0.6776
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.6099 - loss: 0.6730 - val_accuracy: 0.5922 - val_loss: 0.6878
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.6099 - loss: 0.6856 - val_accuracy: 0.5922 - val_loss: 0.6843
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.6099 - loss: 0.6815 - val_accuracy: 0.5922 - val_loss: 0.6818
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 317ms/step - accuracy: 0.6099 - loss: 0.6785 - val_accuracy: 0.5922 - val_loss: 0.6800
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 321ms/step - accuracy: 0.6099 - loss: 0.6762 - val_accuracy: 0.5922 - val_loss: 0.6787
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6099 - loss: 0.6744 - val_accuracy: 0.5922 - val_loss: 0.6778
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6099 - loss: 0.6731 - val_accuracy: 0.5922 - val_loss: 0.6772
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.6099 - loss: 0.6721 - val_accuracy: 0.5922 - val_loss: 0.6767
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.6099 - loss: 0.6714 - val_accuracy: 0.5922 - val_loss: 0.6764
# 🏁 Best epoch for Fold 5: 3
# ✅ Fold 5 test accuracy: 0.6029
#
# 🧪 Fold 6 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 315ms/step - accuracy: 0.5823 - loss: 0.7450 - val_accuracy: 0.5774 - val_loss: 0.6900
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6124 - loss: 0.6732 - val_accuracy: 0.5774 - val_loss: 0.6919
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6063 - loss: 0.6750 - val_accuracy: 0.5774 - val_loss: 0.6897
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6124 - loss: 0.6868 - val_accuracy: 0.5774 - val_loss: 0.6865
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 321ms/step - accuracy: 0.6124 - loss: 0.6819 - val_accuracy: 0.5774 - val_loss: 0.6843
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.6124 - loss: 0.6783 - val_accuracy: 0.5774 - val_loss: 0.6829
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.6124 - loss: 0.6757 - val_accuracy: 0.5774 - val_loss: 0.6820
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.6124 - loss: 0.6737 - val_accuracy: 0.5774 - val_loss: 0.6815
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 317ms/step - accuracy: 0.6124 - loss: 0.6722 - val_accuracy: 0.5774 - val_loss: 0.6812
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 323ms/step - accuracy: 0.6124 - loss: 0.6711 - val_accuracy: 0.5774 - val_loss: 0.6811
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 321ms/step - accuracy: 0.6124 - loss: 0.6703 - val_accuracy: 0.5774 - val_loss: 0.6811
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 317ms/step - accuracy: 0.6124 - loss: 0.6697 - val_accuracy: 0.5774 - val_loss: 0.6812
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6124 - loss: 0.6692 - val_accuracy: 0.5774 - val_loss: 0.6814
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.6124 - loss: 0.6689 - val_accuracy: 0.5774 - val_loss: 0.6815
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 317ms/step - accuracy: 0.6124 - loss: 0.6686 - val_accuracy: 0.5774 - val_loss: 0.6817
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.6124 - loss: 0.6684 - val_accuracy: 0.5774 - val_loss: 0.6819
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 317ms/step - accuracy: 0.6124 - loss: 0.6683 - val_accuracy: 0.5774 - val_loss: 0.6820
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6124 - loss: 0.6681 - val_accuracy: 0.5774 - val_loss: 0.6822
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 317ms/step - accuracy: 0.6124 - loss: 0.6681 - val_accuracy: 0.5774 - val_loss: 0.6823
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6124 - loss: 0.6680 - val_accuracy: 0.5774 - val_loss: 0.6824
# 🏁 Best epoch for Fold 6: 10
# ✅ Fold 6 test accuracy: 0.6019
#
# 🧪 Fold 7 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 321ms/step - accuracy: 0.5666 - loss: 0.7322 - val_accuracy: 0.5882 - val_loss: 0.6782
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 317ms/step - accuracy: 0.6172 - loss: 0.6710 - val_accuracy: 0.5882 - val_loss: 0.6897
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.6191 - loss: 0.6871 - val_accuracy: 0.5882 - val_loss: 0.6860
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 317ms/step - accuracy: 0.6191 - loss: 0.6822 - val_accuracy: 0.5882 - val_loss: 0.6834
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6191 - loss: 0.6784 - val_accuracy: 0.5882 - val_loss: 0.6815
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 322ms/step - accuracy: 0.6191 - loss: 0.6755 - val_accuracy: 0.5882 - val_loss: 0.6802
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 315ms/step - accuracy: 0.6191 - loss: 0.6733 - val_accuracy: 0.5882 - val_loss: 0.6792
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 321ms/step - accuracy: 0.6191 - loss: 0.6715 - val_accuracy: 0.5882 - val_loss: 0.6786
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6191 - loss: 0.6702 - val_accuracy: 0.5882 - val_loss: 0.6781
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6191 - loss: 0.6691 - val_accuracy: 0.5882 - val_loss: 0.6778
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6191 - loss: 0.6682 - val_accuracy: 0.5882 - val_loss: 0.6777
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6191 - loss: 0.6676 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.6191 - loss: 0.6671 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6191 - loss: 0.6667 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6191 - loss: 0.6663 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 322ms/step - accuracy: 0.6191 - loss: 0.6661 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6191 - loss: 0.6659 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 317ms/step - accuracy: 0.6191 - loss: 0.6657 - val_accuracy: 0.5882 - val_loss: 0.6777
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 322ms/step - accuracy: 0.6191 - loss: 0.6656 - val_accuracy: 0.5882 - val_loss: 0.6777
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6191 - loss: 0.6654 - val_accuracy: 0.5882 - val_loss: 0.6778
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.6191 - loss: 0.6654 - val_accuracy: 0.5882 - val_loss: 0.6778
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 321ms/step - accuracy: 0.6191 - loss: 0.6653 - val_accuracy: 0.5882 - val_loss: 0.6779
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.6191 - loss: 0.6652 - val_accuracy: 0.5882 - val_loss: 0.6779
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 317ms/step - accuracy: 0.6191 - loss: 0.6652 - val_accuracy: 0.5882 - val_loss: 0.6779
# 🏁 Best epoch for Fold 7: 14
# ✅ Fold 7 test accuracy: 0.6019
#
# 🧪 Fold 8 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6052 - loss: 0.7714 - val_accuracy: 0.5908 - val_loss: 0.6793
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 322ms/step - accuracy: 0.6028 - loss: 0.6700 - val_accuracy: 0.5908 - val_loss: 0.6778
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6148 - loss: 0.6712 - val_accuracy: 0.5922 - val_loss: 0.6518
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 321ms/step - accuracy: 0.6565 - loss: 0.6248 - val_accuracy: 0.6555 - val_loss: 0.6390
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.7244 - loss: 0.5736 - val_accuracy: 0.7147 - val_loss: 0.5978
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.7739 - loss: 0.4874 - val_accuracy: 0.7618 - val_loss: 0.5924
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 317ms/step - accuracy: 0.8122 - loss: 0.4503 - val_accuracy: 0.7900 - val_loss: 0.5578
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.8291 - loss: 0.3989 - val_accuracy: 0.7954 - val_loss: 0.5002
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.8402 - loss: 0.3641 - val_accuracy: 0.8116 - val_loss: 0.4927
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.8601 - loss: 0.3180 - val_accuracy: 0.8183 - val_loss: 0.4478
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.8837 - loss: 0.2892 - val_accuracy: 0.8129 - val_loss: 0.4727
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 321ms/step - accuracy: 0.8947 - loss: 0.2607 - val_accuracy: 0.8102 - val_loss: 0.4808
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 317ms/step - accuracy: 0.8987 - loss: 0.2454 - val_accuracy: 0.8035 - val_loss: 0.5188
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 317ms/step - accuracy: 0.9063 - loss: 0.2270 - val_accuracy: 0.7699 - val_loss: 0.6316
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.9125 - loss: 0.2010 - val_accuracy: 0.7577 - val_loss: 0.7728
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.8870 - loss: 0.2518 - val_accuracy: 0.7806 - val_loss: 0.6170
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 317ms/step - accuracy: 0.9169 - loss: 0.2092 - val_accuracy: 0.7564 - val_loss: 0.6528
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.9214 - loss: 0.1944 - val_accuracy: 0.7618 - val_loss: 0.7343
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.9440 - loss: 0.1469 - val_accuracy: 0.7591 - val_loss: 0.9582
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.9523 - loss: 0.1147 - val_accuracy: 0.7873 - val_loss: 1.1706
# 🏁 Best epoch for Fold 8: 10
# ✅ Fold 8 test accuracy: 0.8350
#
# 🧪 Fold 9 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.5927 - loss: 0.7987 - val_accuracy: 0.5922 - val_loss: 0.6915
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6206 - loss: 0.6896 - val_accuracy: 0.5922 - val_loss: 0.6873
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6206 - loss: 0.6843 - val_accuracy: 0.5922 - val_loss: 0.6842
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6206 - loss: 0.6802 - val_accuracy: 0.5922 - val_loss: 0.6819
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6206 - loss: 0.6769 - val_accuracy: 0.5922 - val_loss: 0.6802
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6206 - loss: 0.6744 - val_accuracy: 0.5922 - val_loss: 0.6789
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.6206 - loss: 0.6724 - val_accuracy: 0.5922 - val_loss: 0.6780
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 321ms/step - accuracy: 0.6206 - loss: 0.6708 - val_accuracy: 0.5922 - val_loss: 0.6773
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6206 - loss: 0.6695 - val_accuracy: 0.5922 - val_loss: 0.6769
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.6206 - loss: 0.6685 - val_accuracy: 0.5922 - val_loss: 0.6766
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.6206 - loss: 0.6677 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 322ms/step - accuracy: 0.6206 - loss: 0.6671 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6206 - loss: 0.6666 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6206 - loss: 0.6662 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6206 - loss: 0.6658 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.6206 - loss: 0.6656 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 321ms/step - accuracy: 0.6206 - loss: 0.6654 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6206 - loss: 0.6652 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 317ms/step - accuracy: 0.6206 - loss: 0.6650 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.6206 - loss: 0.6649 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 29s 316ms/step - accuracy: 0.6206 - loss: 0.6648 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.6206 - loss: 0.6648 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6206 - loss: 0.6647 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6206 - loss: 0.6646 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.6206 - loss: 0.6646 - val_accuracy: 0.5922 - val_loss: 0.6762
# 🏁 Best epoch for Fold 9: 15
# ✅ Fold 9 test accuracy: 0.6019
#
# 🧪 Fold 10 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.5952 - loss: 0.8466 - val_accuracy: 0.5922 - val_loss: 0.6765
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 317ms/step - accuracy: 0.6145 - loss: 0.6775 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 317ms/step - accuracy: 0.6145 - loss: 0.6782 - val_accuracy: 0.5922 - val_loss: 0.6900
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.6145 - loss: 0.6879 - val_accuracy: 0.5922 - val_loss: 0.6860
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 318ms/step - accuracy: 0.6145 - loss: 0.6831 - val_accuracy: 0.5922 - val_loss: 0.6831
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 319ms/step - accuracy: 0.6145 - loss: 0.6794 - val_accuracy: 0.5922 - val_loss: 0.6810
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.6145 - loss: 0.6766 - val_accuracy: 0.5922 - val_loss: 0.6795
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 324ms/step - accuracy: 0.6145 - loss: 0.6745 - val_accuracy: 0.5922 - val_loss: 0.6784
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.6145 - loss: 0.6728 - val_accuracy: 0.5922 - val_loss: 0.6776
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 321ms/step - accuracy: 0.6145 - loss: 0.6715 - val_accuracy: 0.5922 - val_loss: 0.6770
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 321ms/step - accuracy: 0.6145 - loss: 0.6705 - val_accuracy: 0.5922 - val_loss: 0.6766
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 320ms/step - accuracy: 0.6145 - loss: 0.6698 - val_accuracy: 0.5922 - val_loss: 0.6764
# 🏁 Best epoch for Fold 10: 2
# ✅ Fold 10 test accuracy: 0.6019
#
# 📌 Mean optimal epoch across folds: 11

# %%
# Cell Block 5: Final Model Training on data again, but for ep_mean Epochs (no validation needed)

# Build your TF datasets
train_final_ds = preprocess(X_rest, y_rest)        # ALL data used in K-Fold
test_final_ds  = preprocess(X_holdout, y_holdout)  # NEVER seen during CV

# Instantiate & train your final model
final_model = create_model()
final_model.fit(
    train_final_ds,
    epochs=ep_mean,
    verbose=1
)

# Evaluate once—only on the true hold-out set
final_results = final_model.evaluate(
    test_final_ds,
    verbose=1
)
print("Hold-out test loss & accuracy:", final_results)
# Out:
# Epoch 1/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 47s 403ms/step - accuracy: 0.5752 - loss: 0.7778
# Epoch 2/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 47s 406ms/step - accuracy: 0.6004 - loss: 0.6646
# Epoch 3/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 43s 369ms/step - accuracy: 0.6836 - loss: 0.6149
# Epoch 4/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 361ms/step - accuracy: 0.7468 - loss: 0.5355
# Epoch 5/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 359ms/step - accuracy: 0.7949 - loss: 0.4612
# Epoch 6/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 358ms/step - accuracy: 0.8421 - loss: 0.3917
# Epoch 7/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 362ms/step - accuracy: 0.8501 - loss: 0.3604
# Epoch 8/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 40s 342ms/step - accuracy: 0.8775 - loss: 0.3033
# Epoch 9/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 330ms/step - accuracy: 0.8992 - loss: 0.2532
# Epoch 10/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 329ms/step - accuracy: 0.9005 - loss: 0.2459
# Epoch 11/11
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 329ms/step - accuracy: 0.9240 - loss: 0.1824
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.6608 - loss: 0.7358
# Hold-out test loss & accuracy: [0.7260568737983704, 0.6537530422210693]

# %%
# Cell Block 5: Final Evaluation

# Evaluate final model on the 20% test set
final_test_loss, final_test_acc = final_model.evaluate(test_final_ds, verbose=0)

# Report both results
print(f"\n📊 {k}-Fold Test Accuracy: {np.mean(all_test_accuracies):.4f} ± {np.std(all_test_accuracies):.4f}")
print(f"🏁 Final model test accuracy (trained on hold-out): {final_test_acc:.4f}")
# Out:
# 📊 10-Fold Test Accuracy: 0.6257 ± 0.0697
# 🏁 Final model test accuracy (trained on hold-out): 0.6538

# %%
import numpy as np
from sklearn.metrics import precision_score, roc_curve, auc, f1_score, recall_score
import matplotlib.pyplot as plt

# 1. Extract true labels and model scores from your hold-out dataset
y_true = np.concatenate([y.numpy() for x, y in test_final_ds], axis=0)
y_pred_prob = final_model.predict(test_final_ds)

# 2. If your model outputs two probabilities (one per class), take the “positive” class
if y_pred_prob.ndim > 1 and y_pred_prob.shape[1] > 1:
    y_scores = y_pred_prob[:, 1]
else:
    y_scores = y_pred_prob.ravel()

# 3. Compute ROC curve metrics
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# 4. Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr)               # ROC curve
plt.plot([0, 1], [0, 1], linestyle='--')  # chance line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (AUC = {roc_auc:.2f})')
plt.show()



# 1. Turn your predicted probabilities into binary preds (threshold = 0.5)
y_pred = (y_scores >= 0.5).astype(int)

# 2. Compute precision, recall, F1
precision = precision_score(y_true, y_pred)
recall    = recall_score(y_true, y_pred)
f1        = f1_score(y_true, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step
# Precision: 0.54
# Recall:    0.79
# F1 Score:  0.65
