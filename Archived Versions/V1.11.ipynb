# %% [markdown]
# Varroa Mite Detection 1.11 Only Contrast

# %%
# Cell Block 1: Importing Libraries
import os
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold, train_test_split
import numpy as np
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Cell Block 2: Load Data and Preprocess

df = pd.read_csv('labels_augmented.csv')

df['filename'] = df['filename'].apply(lambda fn: os.path.join('rotations_flips', fn.strip()))

filepaths = df['filename'].values
labels = df['has_mite'].values

# %%
# Cell Block 3: Splitting Data

X_rest, X_holdout, y_rest, y_holdout = train_test_split(
    filepaths, labels,
    test_size=0.10,
    stratify=labels,
    random_state=42
)

# %%
# Cell Block 3: K-Fold Cross-Validation

# Early stopping callback
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    # min_delta=1e-4,
    restore_best_weights=True
)

k = 10  # Number of folds
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

fold = 1
all_test_accuracies = []
best_epochs = []

# Model creation function
def create_model():
    model = models.Sequential([
        layers.Input(shape=(224, 224, 3)),
        layers.Conv2D(32, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Preprocessing function
def preprocess(paths, labels):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    def load_img(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [224, 224])
        img = img / 255.0


        # 1) Boost blue channel
        # img = tf.clip_by_value(img + [0.0, 0.0, 0.2], 0.0, 1.0) 

        # 2) Increase contrast
        img = tf.image.adjust_contrast(img, 2.0) 

        # 3) Boost red channel
        # img = tf.clip_by_value(img + [0.2, 0.0, 0.0], 0.0, 1.0)

 
        return img, label

    return ds.map(load_img).batch(32).prefetch(tf.data.AUTOTUNE)

for trainval_index, test_index in skf.split(filepaths, labels):
    print(f"\n🧪 Fold {fold} -----------------------------")

    # Split into trainval and test
    X_trainval, X_test = filepaths[trainval_index], filepaths[test_index]
    y_trainval, y_test = labels[trainval_index], labels[test_index]

    # Further split trainval into train and val (e.g. 80/20)
    val_split = int(0.8 * len(X_trainval))
    X_train, X_val = X_trainval[:val_split], X_trainval[val_split:]
    y_train, y_val = y_trainval[:val_split], y_trainval[val_split:]


    # Preprocess each split
    train_ds = preprocess(X_train, y_train)
    val_ds = preprocess(X_val, y_val)
    test_ds = preprocess(X_test, y_test)



    # Train model with early stopping
    model = create_model()
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[earlystop],
        verbose=1
    )

    # Record best epoch (smallest val_loss)
    best_epoch = np.argmin(history.history['val_loss']) + 1
    best_epochs.append(best_epoch)
    print(f"🏁 Best epoch for Fold {fold}: {best_epoch}")

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    all_test_accuracies.append(test_acc)
    print(f"✅ Fold {fold} test accuracy: {test_acc:.4f}")

    fold += 1

# Calculate mean best epoch
ep_mean = int(np.round(np.mean(best_epochs)))
print(f"\n📌 Mean optimal epoch across folds: {ep_mean}")
# Out:
# 🧪 Fold 1 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 371ms/step - accuracy: 0.5711 - loss: 0.8435 - val_accuracy: 0.5922 - val_loss: 0.6765
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 370ms/step - accuracy: 0.5897 - loss: 0.6705 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.5985 - loss: 0.6705 - val_accuracy: 0.5922 - val_loss: 0.6633
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.6127 - loss: 0.6622 - val_accuracy: 0.5935 - val_loss: 0.6587
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 339ms/step - accuracy: 0.6338 - loss: 0.6483 - val_accuracy: 0.6070 - val_loss: 0.6552
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6619 - loss: 0.6143 - val_accuracy: 0.6514 - val_loss: 0.6608
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.7097 - loss: 0.5631 - val_accuracy: 0.6124 - val_loss: 0.7294
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.7608 - loss: 0.4738 - val_accuracy: 0.6097 - val_loss: 0.8159
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.8204 - loss: 0.3764 - val_accuracy: 0.6164 - val_loss: 1.3571
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.8569 - loss: 0.3109 - val_accuracy: 0.5962 - val_loss: 1.4883
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - accuracy: 0.8840 - loss: 0.2350 - val_accuracy: 0.6164 - val_loss: 1.7737
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.9280 - loss: 0.1708 - val_accuracy: 0.6474 - val_loss: 2.5318
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 339ms/step - accuracy: 0.9392 - loss: 0.1549 - val_accuracy: 0.6124 - val_loss: 2.1334
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.9249 - loss: 0.1653 - val_accuracy: 0.5734 - val_loss: 1.7645
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.9325 - loss: 0.1523 - val_accuracy: 0.5962 - val_loss: 2.0194
# 🏁 Best epoch for Fold 1: 5
# ✅ Fold 1 test accuracy: 0.6126
#
# 🧪 Fold 2 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6062 - loss: 0.9938 - val_accuracy: 0.5868 - val_loss: 0.6816
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 345ms/step - accuracy: 0.6182 - loss: 0.6703 - val_accuracy: 0.5868 - val_loss: 0.6773
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6179 - loss: 0.6603 - val_accuracy: 0.5868 - val_loss: 0.6624
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6188 - loss: 0.6496 - val_accuracy: 0.5855 - val_loss: 0.6408
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 340ms/step - accuracy: 0.6173 - loss: 0.6299 - val_accuracy: 0.5868 - val_loss: 0.6443
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6182 - loss: 0.6209 - val_accuracy: 0.5868 - val_loss: 0.6346
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 341ms/step - accuracy: 0.6154 - loss: 0.6027 - val_accuracy: 0.5868 - val_loss: 0.6194
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.6568 - loss: 0.5722 - val_accuracy: 0.7026 - val_loss: 0.6110
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.7740 - loss: 0.4902 - val_accuracy: 0.8129 - val_loss: 0.4767
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.8672 - loss: 0.3268 - val_accuracy: 0.8089 - val_loss: 0.4398
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.8981 - loss: 0.2573 - val_accuracy: 0.8183 - val_loss: 0.4897
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.9211 - loss: 0.2026 - val_accuracy: 0.7672 - val_loss: 0.8278
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.9058 - loss: 0.2355 - val_accuracy: 0.7322 - val_loss: 1.0658
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.9152 - loss: 0.2129 - val_accuracy: 0.7779 - val_loss: 0.9526
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.9357 - loss: 0.1703 - val_accuracy: 0.7685 - val_loss: 0.7858
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9502 - loss: 0.1172 - val_accuracy: 0.7833 - val_loss: 0.8656
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.9662 - loss: 0.0871 - val_accuracy: 0.7550 - val_loss: 0.8045
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.9768 - loss: 0.0635 - val_accuracy: 0.7793 - val_loss: 0.8109
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.9681 - loss: 0.0876 - val_accuracy: 0.6770 - val_loss: 1.0169
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.9792 - loss: 0.0578 - val_accuracy: 0.7147 - val_loss: 1.0236
# 🏁 Best epoch for Fold 2: 10
# ✅ Fold 2 test accuracy: 0.8257
#
# 🧪 Fold 3 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 332ms/step - accuracy: 0.5618 - loss: 0.7414 - val_accuracy: 0.5828 - val_loss: 0.6822
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6173 - loss: 0.6754 - val_accuracy: 0.5828 - val_loss: 0.6798
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6197 - loss: 0.6703 - val_accuracy: 0.5828 - val_loss: 0.6828
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.6302 - loss: 0.6543 - val_accuracy: 0.6043 - val_loss: 0.6491
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.7607 - loss: 0.5264 - val_accuracy: 0.8102 - val_loss: 0.4184
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.8575 - loss: 0.3477 - val_accuracy: 0.8116 - val_loss: 0.4538
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.8598 - loss: 0.3307 - val_accuracy: 0.8291 - val_loss: 0.4112
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.8825 - loss: 0.2877 - val_accuracy: 0.8197 - val_loss: 0.4445
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.8916 - loss: 0.2627 - val_accuracy: 0.8291 - val_loss: 0.4593
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9126 - loss: 0.2157 - val_accuracy: 0.8264 - val_loss: 0.5792
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.9449 - loss: 0.1536 - val_accuracy: 0.8170 - val_loss: 0.7836
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.9562 - loss: 0.1238 - val_accuracy: 0.8197 - val_loss: 0.7686
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.9682 - loss: 0.0844 - val_accuracy: 0.8102 - val_loss: 0.8912
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.9750 - loss: 0.0766 - val_accuracy: 0.8062 - val_loss: 0.6105
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.9747 - loss: 0.0893 - val_accuracy: 0.7954 - val_loss: 0.7672
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.9936 - loss: 0.0373 - val_accuracy: 0.8223 - val_loss: 0.8723
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.9957 - loss: 0.0210 - val_accuracy: 0.7927 - val_loss: 0.9791
# 🏁 Best epoch for Fold 3: 7
# ✅ Fold 3 test accuracy: 0.8644
#
# 🧪 Fold 4 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.5799 - loss: 0.9481 - val_accuracy: 0.5814 - val_loss: 0.6809
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.6183 - loss: 0.6730 - val_accuracy: 0.5814 - val_loss: 0.6815
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.6193 - loss: 0.6732 - val_accuracy: 0.5814 - val_loss: 0.6770
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.6184 - loss: 0.6619 - val_accuracy: 0.5814 - val_loss: 0.6756
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6174 - loss: 0.6602 - val_accuracy: 0.6716 - val_loss: 0.6293
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6730 - loss: 0.6427 - val_accuracy: 0.6703 - val_loss: 0.6659
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.7365 - loss: 0.5627 - val_accuracy: 0.7631 - val_loss: 0.5474
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.8289 - loss: 0.3909 - val_accuracy: 0.8062 - val_loss: 0.4668
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.8746 - loss: 0.2911 - val_accuracy: 0.8183 - val_loss: 0.4531
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.9092 - loss: 0.2265 - val_accuracy: 0.8116 - val_loss: 0.5189
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.9273 - loss: 0.1766 - val_accuracy: 0.8035 - val_loss: 0.5676
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.9389 - loss: 0.1571 - val_accuracy: 0.8183 - val_loss: 0.5391
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9512 - loss: 0.1326 - val_accuracy: 0.8183 - val_loss: 0.6033
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.9660 - loss: 0.0963 - val_accuracy: 0.8035 - val_loss: 0.7885
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 0.9659 - loss: 0.0917 - val_accuracy: 0.8291 - val_loss: 0.5594
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.9678 - loss: 0.0943 - val_accuracy: 0.8223 - val_loss: 0.7257
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.9817 - loss: 0.0543 - val_accuracy: 0.8183 - val_loss: 0.8895
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.9849 - loss: 0.0448 - val_accuracy: 0.8129 - val_loss: 1.0414
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.9957 - loss: 0.0146 - val_accuracy: 0.7712 - val_loss: 1.0029
# 🏁 Best epoch for Fold 4: 9
# ✅ Fold 4 test accuracy: 0.8136
#
# 🧪 Fold 5 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 332ms/step - accuracy: 0.5647 - loss: 0.7682 - val_accuracy: 0.5922 - val_loss: 0.6775
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6089 - loss: 0.6708 - val_accuracy: 0.5922 - val_loss: 0.6625
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6175 - loss: 0.6655 - val_accuracy: 0.6353 - val_loss: 0.6409
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6676 - loss: 0.6204 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.5777 - loss: 0.6793 - val_accuracy: 0.5922 - val_loss: 0.6698
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6131 - loss: 0.6572 - val_accuracy: 0.5949 - val_loss: 0.6646
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6490 - loss: 0.6244 - val_accuracy: 0.6151 - val_loss: 0.6503
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6612 - loss: 0.6133 - val_accuracy: 0.6178 - val_loss: 0.6533
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.7107 - loss: 0.5506 - val_accuracy: 0.6258 - val_loss: 0.6419
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.7351 - loss: 0.5334 - val_accuracy: 0.6205 - val_loss: 0.6563
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 326ms/step - accuracy: 0.7331 - loss: 0.4854 - val_accuracy: 0.6272 - val_loss: 0.7514
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.7677 - loss: 0.4132 - val_accuracy: 0.6312 - val_loss: 0.7957
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.8117 - loss: 0.3318 - val_accuracy: 0.6151 - val_loss: 0.9562
# 🏁 Best epoch for Fold 5: 3
# ✅ Fold 5 test accuracy: 0.6538
#
# 🧪 Fold 6 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 333ms/step - accuracy: 0.5952 - loss: 1.0380 - val_accuracy: 0.5774 - val_loss: 0.6911
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6124 - loss: 0.6887 - val_accuracy: 0.5774 - val_loss: 0.6876
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6124 - loss: 0.6838 - val_accuracy: 0.5774 - val_loss: 0.6852
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.6124 - loss: 0.6799 - val_accuracy: 0.5774 - val_loss: 0.6836
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6124 - loss: 0.6770 - val_accuracy: 0.5774 - val_loss: 0.6824
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6124 - loss: 0.6748 - val_accuracy: 0.5774 - val_loss: 0.6817
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6124 - loss: 0.6730 - val_accuracy: 0.5774 - val_loss: 0.6814
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6124 - loss: 0.6718 - val_accuracy: 0.5774 - val_loss: 0.6812
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6124 - loss: 0.6708 - val_accuracy: 0.5774 - val_loss: 0.6811
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6124 - loss: 0.6700 - val_accuracy: 0.5774 - val_loss: 0.6812
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.6124 - loss: 0.6695 - val_accuracy: 0.5774 - val_loss: 0.6813
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6124 - loss: 0.6691 - val_accuracy: 0.5774 - val_loss: 0.6814
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6124 - loss: 0.6688 - val_accuracy: 0.5774 - val_loss: 0.6816
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6124 - loss: 0.6685 - val_accuracy: 0.5774 - val_loss: 0.6818
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6124 - loss: 0.6683 - val_accuracy: 0.5774 - val_loss: 0.6819
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 333ms/step - accuracy: 0.6124 - loss: 0.6682 - val_accuracy: 0.5774 - val_loss: 0.6821
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6124 - loss: 0.6681 - val_accuracy: 0.5774 - val_loss: 0.6822
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6124 - loss: 0.6680 - val_accuracy: 0.5774 - val_loss: 0.6823
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6124 - loss: 0.6680 - val_accuracy: 0.5774 - val_loss: 0.6824
# 🏁 Best epoch for Fold 6: 9
# ✅ Fold 6 test accuracy: 0.6019
#
# 🧪 Fold 7 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.5664 - loss: 0.8201 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6143 - loss: 0.6697 - val_accuracy: 0.5882 - val_loss: 0.6799
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6170 - loss: 0.6699 - val_accuracy: 0.5882 - val_loss: 0.6790
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.6151 - loss: 0.6691 - val_accuracy: 0.5882 - val_loss: 0.6895
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6191 - loss: 0.6869 - val_accuracy: 0.5882 - val_loss: 0.6859
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6191 - loss: 0.6820 - val_accuracy: 0.5882 - val_loss: 0.6833
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6191 - loss: 0.6783 - val_accuracy: 0.5882 - val_loss: 0.6814
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6191 - loss: 0.6754 - val_accuracy: 0.5882 - val_loss: 0.6801
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6191 - loss: 0.6731 - val_accuracy: 0.5882 - val_loss: 0.6792
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.6191 - loss: 0.6714 - val_accuracy: 0.5882 - val_loss: 0.6785
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.6191 - loss: 0.6701 - val_accuracy: 0.5882 - val_loss: 0.6781
# 🏁 Best epoch for Fold 7: 1
# ✅ Fold 7 test accuracy: 0.6019
#
# 🧪 Fold 8 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.5461 - loss: 0.8551 - val_accuracy: 0.5908 - val_loss: 0.6896
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6148 - loss: 0.6875 - val_accuracy: 0.5908 - val_loss: 0.6861
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6148 - loss: 0.6831 - val_accuracy: 0.5908 - val_loss: 0.6835
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6148 - loss: 0.6797 - val_accuracy: 0.5908 - val_loss: 0.6815
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.6148 - loss: 0.6769 - val_accuracy: 0.5908 - val_loss: 0.6800
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6148 - loss: 0.6748 - val_accuracy: 0.5908 - val_loss: 0.6789
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6148 - loss: 0.6731 - val_accuracy: 0.5908 - val_loss: 0.6781
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6148 - loss: 0.6718 - val_accuracy: 0.5908 - val_loss: 0.6775
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6148 - loss: 0.6707 - val_accuracy: 0.5908 - val_loss: 0.6771
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.6148 - loss: 0.6699 - val_accuracy: 0.5908 - val_loss: 0.6769
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.6148 - loss: 0.6693 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6148 - loss: 0.6688 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6148 - loss: 0.6684 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6148 - loss: 0.6681 - val_accuracy: 0.5908 - val_loss: 0.6765
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 333ms/step - accuracy: 0.6148 - loss: 0.6678 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6148 - loss: 0.6676 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6148 - loss: 0.6675 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.6148 - loss: 0.6673 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6148 - loss: 0.6673 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 334ms/step - accuracy: 0.6148 - loss: 0.6672 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6148 - loss: 0.6671 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.6148 - loss: 0.6671 - val_accuracy: 0.5908 - val_loss: 0.6767
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6148 - loss: 0.6670 - val_accuracy: 0.5908 - val_loss: 0.6768
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 327ms/step - accuracy: 0.6148 - loss: 0.6670 - val_accuracy: 0.5908 - val_loss: 0.6768
# 🏁 Best epoch for Fold 8: 14
# ✅ Fold 8 test accuracy: 0.6019
#
# 🧪 Fold 9 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6145 - loss: 0.8324 - val_accuracy: 0.5922 - val_loss: 0.6802
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6134 - loss: 0.6686 - val_accuracy: 0.5922 - val_loss: 0.6741
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6470 - loss: 0.6476 - val_accuracy: 0.7793 - val_loss: 0.5396
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.8006 - loss: 0.4503 - val_accuracy: 0.8277 - val_loss: 0.4249
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.8704 - loss: 0.3306 - val_accuracy: 0.8102 - val_loss: 0.4407
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.8816 - loss: 0.2948 - val_accuracy: 0.8197 - val_loss: 0.4534
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.8938 - loss: 0.2750 - val_accuracy: 0.8331 - val_loss: 0.4163
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9077 - loss: 0.2439 - val_accuracy: 0.8654 - val_loss: 0.4091
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9164 - loss: 0.2095 - val_accuracy: 0.8479 - val_loss: 0.4458
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.9351 - loss: 0.1620 - val_accuracy: 0.8385 - val_loss: 0.6353
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.9486 - loss: 0.1465 - val_accuracy: 0.8412 - val_loss: 0.7936
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9637 - loss: 0.1017 - val_accuracy: 0.7847 - val_loss: 1.1412
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.9740 - loss: 0.0840 - val_accuracy: 0.8250 - val_loss: 0.5423
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9604 - loss: 0.1098 - val_accuracy: 0.7779 - val_loss: 0.5352
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 333ms/step - accuracy: 0.9637 - loss: 0.1003 - val_accuracy: 0.8075 - val_loss: 0.9479
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9917 - loss: 0.0299 - val_accuracy: 0.8062 - val_loss: 1.3470
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 333ms/step - accuracy: 0.9948 - loss: 0.0276 - val_accuracy: 0.8358 - val_loss: 0.9035
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9961 - loss: 0.0151 - val_accuracy: 0.8506 - val_loss: 1.1738
# 🏁 Best epoch for Fold 9: 8
# ✅ Fold 9 test accuracy: 0.8714
#
# 🧪 Fold 10 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6076 - loss: 0.8105 - val_accuracy: 0.5922 - val_loss: 0.6776
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 331ms/step - accuracy: 0.6145 - loss: 0.6773 - val_accuracy: 0.5922 - val_loss: 0.6645
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6132 - loss: 0.6576 - val_accuracy: 0.5922 - val_loss: 0.6678
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.6167 - loss: 0.6721 - val_accuracy: 0.6433 - val_loss: 0.6380
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.6459 - loss: 0.6505 - val_accuracy: 0.6501 - val_loss: 0.6469
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.6470 - loss: 0.6357 - val_accuracy: 0.6514 - val_loss: 0.6396
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 335ms/step - accuracy: 0.6818 - loss: 0.5939 - val_accuracy: 0.6541 - val_loss: 0.6850
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.7139 - loss: 0.5370 - val_accuracy: 0.6406 - val_loss: 0.7487
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 332ms/step - accuracy: 0.7687 - loss: 0.4582 - val_accuracy: 0.6487 - val_loss: 0.8916
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.8469 - loss: 0.3341 - val_accuracy: 0.6339 - val_loss: 1.1477
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 330ms/step - accuracy: 0.9042 - loss: 0.2381 - val_accuracy: 0.6366 - val_loss: 1.1708
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9241 - loss: 0.1713 - val_accuracy: 0.6406 - val_loss: 1.4070
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9547 - loss: 0.1140 - val_accuracy: 0.6326 - val_loss: 2.6561
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 329ms/step - accuracy: 0.9753 - loss: 0.0686 - val_accuracy: 0.6501 - val_loss: 2.0012
# 🏁 Best epoch for Fold 10: 4
# ✅ Fold 10 test accuracy: 0.6214
#
# 📌 Mean optimal epoch across folds: 7

# %%
# Cell Block 5: Final Model Training on data again, but for ep_mean Epochs (no validation needed)

# Build your TF datasets
train_final_ds = preprocess(X_rest, y_rest)        # ALL data used in K-Fold
test_final_ds  = preprocess(X_holdout, y_holdout)  # NEVER seen during CV

# Instantiate & train your final model
final_model = create_model()
final_model.fit(
    train_final_ds,
    epochs=ep_mean,
    verbose=1
)

# Evaluate once—only on the true hold-out set
final_results = final_model.evaluate(
    test_final_ds,
    verbose=1
)
print("Hold-out test loss & accuracy:", final_results)
# Out:
# Epoch 1/7
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 46s 391ms/step - accuracy: 0.5810 - loss: 0.8463
# Epoch 2/7
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 355ms/step - accuracy: 0.6524 - loss: 0.6323
# Epoch 3/7
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 326ms/step - accuracy: 0.7170 - loss: 0.5651
# Epoch 4/7
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 37s 323ms/step - accuracy: 0.8226 - loss: 0.4294
# Epoch 5/7
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 326ms/step - accuracy: 0.8765 - loss: 0.3189
# Epoch 6/7
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 37s 319ms/step - accuracy: 0.8970 - loss: 0.2591
# Epoch 7/7
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 325ms/step - accuracy: 0.9175 - loss: 0.2075
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.7905 - loss: 0.5306
# Hold-out test loss & accuracy: [0.5172375440597534, 0.8062953948974609]

# %%
# Cell Block 5: Final Evaluation

# Evaluate final model on the 20% test set
final_test_loss, final_test_acc = final_model.evaluate(test_final_ds, verbose=0)

# Report both results
print(f"\n📊 {k}-Fold Test Accuracy: {np.mean(all_test_accuracies):.4f} ± {np.std(all_test_accuracies):.4f}")
print(f"🏁 Final model test accuracy (trained on hold-out): {final_test_acc:.4f}")
# Out:
# 📊 10-Fold Test Accuracy: 0.7069 ± 0.1138
# 🏁 Final model test accuracy (trained on hold-out): 0.8063

# %%
import numpy as np
from sklearn.metrics import precision_score, roc_curve, auc, f1_score, recall_score
import matplotlib.pyplot as plt

# 1. Extract true labels and model scores from your hold-out dataset
y_true = np.concatenate([y.numpy() for x, y in test_final_ds], axis=0)
y_pred_prob = final_model.predict(test_final_ds)

# 2. If your model outputs two probabilities (one per class), take the “positive” class
if y_pred_prob.ndim > 1 and y_pred_prob.shape[1] > 1:
    y_scores = y_pred_prob[:, 1]
else:
    y_scores = y_pred_prob.ravel()

# 3. Compute ROC curve metrics
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# 4. Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr)               # ROC curve
plt.plot([0, 1], [0, 1], linestyle='--')  # chance line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (AUC = {roc_auc:.2f})')
plt.show()



# 1. Turn your predicted probabilities into binary preds (threshold = 0.5)
y_pred = (y_scores >= 0.5).astype(int)

# 2. Compute precision, recall, F1
precision = precision_score(y_true, y_pred)
recall    = recall_score(y_true, y_pred)
f1        = f1_score(y_true, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step
# Precision: 0.78
# Recall:    0.72
# F1 Score:  0.75
