# %% [markdown]
# Varroa Mite Detection Final

# %%
# Cell Block 1: Importing Libraries
import os
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold, train_test_split
import numpy as np
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Cell Block 2: Load Data and Preprocess

df = pd.read_csv('labels_augmented.csv')

df['filename'] = df['filename'].apply(lambda fn: os.path.join('rotations_flips', fn.strip()))

filepaths = df['filename'].values
labels = df['has_mite'].values

# %%
# Cell Block 3: Splitting Data

X_rest, X_holdout, y_rest, y_holdout = train_test_split(
    filepaths, labels,
    test_size=0.10,
    stratify=labels,
    random_state=42
)

# %%
# Cell Block 3: K-Fold Cross-Validation

# Early stopping callback
earlystop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    # min_delta=1e-4,
    restore_best_weights=True
)

k = 10  # Number of folds
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

fold = 1
all_test_accuracies = []
best_epochs = []

# Model creation function
def create_model():
    model = models.Sequential([
        layers.Input(shape=(224, 224, 3)),
        layers.Conv2D(32, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Guassian kernel function
def gaussian_kernel(size: int, sigma: float):
    x = tf.range(-size // 2 + 1, size // 2 + 1, dtype=tf.float32)
    xx, yy = tf.meshgrid(x, x)
    kernel = tf.exp(-(xx**2 + yy**2) / (2.0 * sigma**2))
    kernel = kernel / tf.reduce_sum(kernel)
    return kernel

def apply_gaussian_blur(image, kernel_size=5, sigma=1.0):
    kernel = gaussian_kernel(kernel_size, sigma)                 # [5, 5]
    kernel = kernel[:, :, tf.newaxis, tf.newaxis]                # [5, 5, 1, 1]
    kernel = tf.repeat(kernel, repeats=3, axis=2)                # [5, 5, 3, 1] ✅ CORRECT shape
    image = tf.expand_dims(image, 0)                             # [1, H, W, 3]
    blurred = tf.nn.depthwise_conv2d(image, kernel, strides=[1,1,1,1], padding='SAME')
    
    return tf.squeeze(blurred, axis=0)

# Preprocessing function
def preprocess(paths, labels):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    def load_img(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, [224, 224])
        img = img / 255.0

        ## Image Preprocessing Steps
        #######################################################################
        # 1) Apply Gaussian blur
        img = apply_gaussian_blur(img, kernel_size=5, sigma=1.0)

        # 2) Boost blue channel
        img = tf.clip_by_value(img + [0.0, 0.0, 0.2], 0.0, 1.0) 

        # 3) Increase contrast
        img = tf.image.adjust_contrast(img, 2.0) 

        # 4) Boost red channel
        img = tf.clip_by_value(img + [0.2, 0.0, 0.0], 0.0, 1.0)

        # 5) Boost blue and red channel together
        img = tf.clip_by_value(img + [0.2, 0.0, 0.2], 0.0, 1.0)

        # 6) Boost the Brightness
        img = tf.image.adjust_brightness(img, delta=0.1)
        #######################################################################
        
        return img, label

    return ds.map(load_img).batch(32).prefetch(tf.data.AUTOTUNE)

for trainval_index, test_index in skf.split(filepaths, labels):
    print(f"\n🧪 Fold {fold} -----------------------------")

    # Split into trainval and test
    X_trainval, X_test = filepaths[trainval_index], filepaths[test_index]
    y_trainval, y_test = labels[trainval_index], labels[test_index]

    # Further split trainval into train and val (e.g. 80/20)
    val_split = int(0.8 * len(X_trainval))
    X_train, X_val = X_trainval[:val_split], X_trainval[val_split:]
    y_train, y_val = y_trainval[:val_split], y_trainval[val_split:]


    # Preprocess each split
    train_ds = preprocess(X_train, y_train)
    val_ds = preprocess(X_val, y_val)
    test_ds = preprocess(X_test, y_test)



    # Train model with early stopping
    model = create_model()
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[earlystop],
        verbose=1
    )

    # Record best epoch (smallest val_loss)
    best_epoch = np.argmin(history.history['val_loss']) + 1
    best_epochs.append(best_epoch)
    print(f"🏁 Best epoch for Fold {fold}: {best_epoch}")

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    all_test_accuracies.append(test_acc)
    print(f"✅ Fold {fold} test accuracy: {test_acc:.4f}")

    fold += 1

# Calculate mean best epoch
ep_mean = int(np.round(np.mean(best_epochs)))
print(f"\n📌 Mean optimal epoch across folds: {ep_mean}")
# Out:
# 🧪 Fold 1 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 404ms/step - accuracy: 0.5636 - loss: 0.7571 - val_accuracy: 0.5922 - val_loss: 0.6789
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 387ms/step - accuracy: 0.6091 - loss: 0.6760 - val_accuracy: 0.5922 - val_loss: 0.6786
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 364ms/step - accuracy: 0.6091 - loss: 0.6759 - val_accuracy: 0.5922 - val_loss: 0.6775
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 391ms/step - accuracy: 0.6091 - loss: 0.6793 - val_accuracy: 0.5922 - val_loss: 0.6882
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6091 - loss: 0.6862 - val_accuracy: 0.5922 - val_loss: 0.6849
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 381ms/step - accuracy: 0.6091 - loss: 0.6825 - val_accuracy: 0.5922 - val_loss: 0.6825
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 394ms/step - accuracy: 0.6091 - loss: 0.6796 - val_accuracy: 0.5922 - val_loss: 0.6807
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6091 - loss: 0.6773 - val_accuracy: 0.5922 - val_loss: 0.6794
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6091 - loss: 0.6756 - val_accuracy: 0.5922 - val_loss: 0.6784
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 385ms/step - accuracy: 0.6091 - loss: 0.6742 - val_accuracy: 0.5922 - val_loss: 0.6777
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 349ms/step - accuracy: 0.6091 - loss: 0.6731 - val_accuracy: 0.5922 - val_loss: 0.6771
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6091 - loss: 0.6723 - val_accuracy: 0.5922 - val_loss: 0.6768
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6091 - loss: 0.6717 - val_accuracy: 0.5922 - val_loss: 0.6765
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.6091 - loss: 0.6711 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6091 - loss: 0.6707 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6091 - loss: 0.6704 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 384ms/step - accuracy: 0.6091 - loss: 0.6702 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.6091 - loss: 0.6700 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 385ms/step - accuracy: 0.6091 - loss: 0.6698 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6091 - loss: 0.6697 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6091 - loss: 0.6696 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6091 - loss: 0.6696 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6091 - loss: 0.6695 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 370ms/step - accuracy: 0.6091 - loss: 0.6694 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6091 - loss: 0.6694 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 369ms/step - accuracy: 0.6091 - loss: 0.6694 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6091 - loss: 0.6694 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 28/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6091 - loss: 0.6693 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 29/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6091 - loss: 0.6693 - val_accuracy: 0.5922 - val_loss: 0.6762
# 🏁 Best epoch for Fold 1: 19
# ✅ Fold 1 test accuracy: 0.6029
#
# 🧪 Fold 2 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.5846 - loss: 0.7179 - val_accuracy: 0.5868 - val_loss: 0.6855
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6182 - loss: 0.6716 - val_accuracy: 0.5868 - val_loss: 0.6781
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 371ms/step - accuracy: 0.5950 - loss: 0.6687 - val_accuracy: 0.5868 - val_loss: 0.6898
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 371ms/step - accuracy: 0.6182 - loss: 0.6803 - val_accuracy: 0.5868 - val_loss: 0.6783
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.6121 - loss: 0.6674 - val_accuracy: 0.5868 - val_loss: 0.6865
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 31s 338ms/step - accuracy: 0.6182 - loss: 0.6744 - val_accuracy: 0.5868 - val_loss: 0.6811
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6125 - loss: 0.6686 - val_accuracy: 0.5868 - val_loss: 0.6774
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6182 - loss: 0.6667 - val_accuracy: 0.5868 - val_loss: 0.6762
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 371ms/step - accuracy: 0.6182 - loss: 0.6548 - val_accuracy: 0.5868 - val_loss: 0.6829
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6182 - loss: 0.6715 - val_accuracy: 0.5868 - val_loss: 0.6783
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 368ms/step - accuracy: 0.6182 - loss: 0.6617 - val_accuracy: 0.5868 - val_loss: 0.6830
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 364ms/step - accuracy: 0.6182 - loss: 0.6777 - val_accuracy: 0.5868 - val_loss: 0.6814
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6182 - loss: 0.6751 - val_accuracy: 0.5868 - val_loss: 0.6802
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6182 - loss: 0.6730 - val_accuracy: 0.5868 - val_loss: 0.6794
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.6182 - loss: 0.6714 - val_accuracy: 0.5868 - val_loss: 0.6788
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 392ms/step - accuracy: 0.6182 - loss: 0.6702 - val_accuracy: 0.5868 - val_loss: 0.6785
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 396ms/step - accuracy: 0.6182 - loss: 0.6692 - val_accuracy: 0.5868 - val_loss: 0.6782
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6182 - loss: 0.6685 - val_accuracy: 0.5868 - val_loss: 0.6781
# 🏁 Best epoch for Fold 2: 8
# ✅ Fold 2 test accuracy: 0.6029
#
# 🧪 Fold 3 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 357ms/step - accuracy: 0.5886 - loss: 0.8279 - val_accuracy: 0.5828 - val_loss: 0.6814
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.6153 - loss: 0.6647 - val_accuracy: 0.5828 - val_loss: 0.6693
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6617 - loss: 0.6165 - val_accuracy: 0.7308 - val_loss: 0.5929
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 355ms/step - accuracy: 0.7408 - loss: 0.5443 - val_accuracy: 0.7133 - val_loss: 0.5884
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.7916 - loss: 0.4712 - val_accuracy: 0.7833 - val_loss: 0.4748
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 355ms/step - accuracy: 0.8252 - loss: 0.4165 - val_accuracy: 0.7981 - val_loss: 0.4658
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 355ms/step - accuracy: 0.8339 - loss: 0.3886 - val_accuracy: 0.7268 - val_loss: 0.5647
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.8118 - loss: 0.4398 - val_accuracy: 0.8022 - val_loss: 0.4410
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 360ms/step - accuracy: 0.8442 - loss: 0.3654 - val_accuracy: 0.8143 - val_loss: 0.4544
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.8528 - loss: 0.3490 - val_accuracy: 0.8116 - val_loss: 0.4331
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.8596 - loss: 0.3293 - val_accuracy: 0.8075 - val_loss: 0.4748
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.8621 - loss: 0.3270 - val_accuracy: 0.8089 - val_loss: 0.4370
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.8804 - loss: 0.2988 - val_accuracy: 0.7968 - val_loss: 0.5332
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.8742 - loss: 0.2926 - val_accuracy: 0.7995 - val_loss: 0.5704
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.8863 - loss: 0.2751 - val_accuracy: 0.7954 - val_loss: 0.5575
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 356ms/step - accuracy: 0.8936 - loss: 0.2486 - val_accuracy: 0.8223 - val_loss: 0.4867
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.9049 - loss: 0.2362 - val_accuracy: 0.8129 - val_loss: 0.5694
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.9129 - loss: 0.2095 - val_accuracy: 0.8048 - val_loss: 0.6325
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.9273 - loss: 0.1840 - val_accuracy: 0.8129 - val_loss: 0.6614
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.9309 - loss: 0.1699 - val_accuracy: 0.8062 - val_loss: 0.8015
# 🏁 Best epoch for Fold 3: 10
# ✅ Fold 3 test accuracy: 0.8378
#
# 🧪 Fold 4 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 356ms/step - accuracy: 0.5702 - loss: 0.8018 - val_accuracy: 0.5814 - val_loss: 0.6880
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 362ms/step - accuracy: 0.5834 - loss: 0.6747 - val_accuracy: 0.5814 - val_loss: 0.6807
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.6035 - loss: 0.6761 - val_accuracy: 0.5814 - val_loss: 0.6804
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6185 - loss: 0.6696 - val_accuracy: 0.5814 - val_loss: 0.6665
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.6302 - loss: 0.6572 - val_accuracy: 0.5814 - val_loss: 0.6804
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6183 - loss: 0.6804 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 368ms/step - accuracy: 0.6183 - loss: 0.6706 - val_accuracy: 0.5814 - val_loss: 0.6807
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 402ms/step - accuracy: 0.6183 - loss: 0.6715 - val_accuracy: 0.5814 - val_loss: 0.6798
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 373ms/step - accuracy: 0.6183 - loss: 0.6685 - val_accuracy: 0.5814 - val_loss: 0.6798
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6183 - loss: 0.6682 - val_accuracy: 0.5814 - val_loss: 0.6801
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 365ms/step - accuracy: 0.6183 - loss: 0.6673 - val_accuracy: 0.5814 - val_loss: 0.6799
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 408ms/step - accuracy: 0.6183 - loss: 0.6656 - val_accuracy: 0.5814 - val_loss: 0.6798
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.6183 - loss: 0.6678 - val_accuracy: 0.5814 - val_loss: 0.6802
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6183 - loss: 0.6669 - val_accuracy: 0.5814 - val_loss: 0.6803
# 🏁 Best epoch for Fold 4: 4
# ✅ Fold 4 test accuracy: 0.6029
#
# 🧪 Fold 5 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 405ms/step - accuracy: 0.5837 - loss: 0.7793 - val_accuracy: 0.5922 - val_loss: 0.6765
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 403ms/step - accuracy: 0.6099 - loss: 0.6724 - val_accuracy: 0.5922 - val_loss: 0.6774
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6099 - loss: 0.6727 - val_accuracy: 0.5922 - val_loss: 0.6894
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.6099 - loss: 0.6874 - val_accuracy: 0.5922 - val_loss: 0.6854
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6099 - loss: 0.6829 - val_accuracy: 0.5922 - val_loss: 0.6826
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 356ms/step - accuracy: 0.6099 - loss: 0.6795 - val_accuracy: 0.5922 - val_loss: 0.6806
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.6099 - loss: 0.6770 - val_accuracy: 0.5922 - val_loss: 0.6792
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6099 - loss: 0.6751 - val_accuracy: 0.5922 - val_loss: 0.6781
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.6099 - loss: 0.6736 - val_accuracy: 0.5922 - val_loss: 0.6774
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6099 - loss: 0.6725 - val_accuracy: 0.5922 - val_loss: 0.6769
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 403ms/step - accuracy: 0.6099 - loss: 0.6717 - val_accuracy: 0.5922 - val_loss: 0.6765
# 🏁 Best epoch for Fold 5: 1
# ✅ Fold 5 test accuracy: 0.6029
#
# 🧪 Fold 6 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 405ms/step - accuracy: 0.5809 - loss: 0.8753 - val_accuracy: 0.5774 - val_loss: 0.6845
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 406ms/step - accuracy: 0.6124 - loss: 0.6760 - val_accuracy: 0.5774 - val_loss: 0.6902
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 406ms/step - accuracy: 0.6064 - loss: 0.6762 - val_accuracy: 0.5774 - val_loss: 0.6893
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.6124 - loss: 0.6862 - val_accuracy: 0.5774 - val_loss: 0.6862
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 401ms/step - accuracy: 0.6124 - loss: 0.6816 - val_accuracy: 0.5774 - val_loss: 0.6842
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 396ms/step - accuracy: 0.6124 - loss: 0.6781 - val_accuracy: 0.5774 - val_loss: 0.6828
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 391ms/step - accuracy: 0.6124 - loss: 0.6756 - val_accuracy: 0.5774 - val_loss: 0.6820
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6124 - loss: 0.6736 - val_accuracy: 0.5774 - val_loss: 0.6815
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6124 - loss: 0.6722 - val_accuracy: 0.5774 - val_loss: 0.6812
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.6124 - loss: 0.6711 - val_accuracy: 0.5774 - val_loss: 0.6811
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6124 - loss: 0.6703 - val_accuracy: 0.5774 - val_loss: 0.6811
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 356ms/step - accuracy: 0.6124 - loss: 0.6696 - val_accuracy: 0.5774 - val_loss: 0.6812
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 356ms/step - accuracy: 0.6124 - loss: 0.6692 - val_accuracy: 0.5774 - val_loss: 0.6814
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 356ms/step - accuracy: 0.6124 - loss: 0.6688 - val_accuracy: 0.5774 - val_loss: 0.6815
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6124 - loss: 0.6686 - val_accuracy: 0.5774 - val_loss: 0.6817
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.6124 - loss: 0.6684 - val_accuracy: 0.5774 - val_loss: 0.6819
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6124 - loss: 0.6683 - val_accuracy: 0.5774 - val_loss: 0.6820
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 377ms/step - accuracy: 0.6124 - loss: 0.6681 - val_accuracy: 0.5774 - val_loss: 0.6822
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6124 - loss: 0.6681 - val_accuracy: 0.5774 - val_loss: 0.6823
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6124 - loss: 0.6680 - val_accuracy: 0.5774 - val_loss: 0.6824
# 🏁 Best epoch for Fold 6: 10
# ✅ Fold 6 test accuracy: 0.6019
#
# 🧪 Fold 7 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 384ms/step - accuracy: 0.6101 - loss: 0.7386 - val_accuracy: 0.5882 - val_loss: 0.6786
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6162 - loss: 0.6670 - val_accuracy: 0.5882 - val_loss: 0.6903
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 360ms/step - accuracy: 0.6191 - loss: 0.6879 - val_accuracy: 0.5882 - val_loss: 0.6864
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6191 - loss: 0.6828 - val_accuracy: 0.5882 - val_loss: 0.6837
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 351ms/step - accuracy: 0.6191 - loss: 0.6789 - val_accuracy: 0.5882 - val_loss: 0.6817
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6191 - loss: 0.6758 - val_accuracy: 0.5882 - val_loss: 0.6803
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 355ms/step - accuracy: 0.6191 - loss: 0.6735 - val_accuracy: 0.5882 - val_loss: 0.6793
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.6191 - loss: 0.6717 - val_accuracy: 0.5882 - val_loss: 0.6786
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 354ms/step - accuracy: 0.6191 - loss: 0.6703 - val_accuracy: 0.5882 - val_loss: 0.6782
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 353ms/step - accuracy: 0.6191 - loss: 0.6692 - val_accuracy: 0.5882 - val_loss: 0.6779
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 367ms/step - accuracy: 0.6191 - loss: 0.6683 - val_accuracy: 0.5882 - val_loss: 0.6777
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6191 - loss: 0.6676 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6191 - loss: 0.6671 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6191 - loss: 0.6667 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6191 - loss: 0.6664 - val_accuracy: 0.5882 - val_loss: 0.6775
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6191 - loss: 0.6661 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 380ms/step - accuracy: 0.6191 - loss: 0.6659 - val_accuracy: 0.5882 - val_loss: 0.6776
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.6191 - loss: 0.6657 - val_accuracy: 0.5882 - val_loss: 0.6777
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6191 - loss: 0.6656 - val_accuracy: 0.5882 - val_loss: 0.6777
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6191 - loss: 0.6655 - val_accuracy: 0.5882 - val_loss: 0.6778
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 0.6191 - loss: 0.6654 - val_accuracy: 0.5882 - val_loss: 0.6778
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 362ms/step - accuracy: 0.6191 - loss: 0.6653 - val_accuracy: 0.5882 - val_loss: 0.6779
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6191 - loss: 0.6652 - val_accuracy: 0.5882 - val_loss: 0.6779
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6191 - loss: 0.6652 - val_accuracy: 0.5882 - val_loss: 0.6779
# 🏁 Best epoch for Fold 7: 14
# ✅ Fold 7 test accuracy: 0.6019
#
# 🧪 Fold 8 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 376ms/step - accuracy: 0.6038 - loss: 0.8599 - val_accuracy: 0.5908 - val_loss: 0.6787
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.5982 - loss: 0.6731 - val_accuracy: 0.5908 - val_loss: 0.6774
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 384ms/step - accuracy: 0.6135 - loss: 0.6717 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 384ms/step - accuracy: 0.6148 - loss: 0.6740 - val_accuracy: 0.5908 - val_loss: 0.6768
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 384ms/step - accuracy: 0.6148 - loss: 0.6702 - val_accuracy: 0.5908 - val_loss: 0.6765
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6148 - loss: 0.6692 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 379ms/step - accuracy: 0.6148 - loss: 0.6690 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6148 - loss: 0.6688 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6148 - loss: 0.6687 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 414ms/step - accuracy: 0.6148 - loss: 0.6693 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 40s 432ms/step - accuracy: 0.6148 - loss: 0.6688 - val_accuracy: 0.5908 - val_loss: 0.6765
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 39s 419ms/step - accuracy: 0.6148 - loss: 0.6686 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 381ms/step - accuracy: 0.6148 - loss: 0.6686 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 367ms/step - accuracy: 0.6148 - loss: 0.6685 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 367ms/step - accuracy: 0.6148 - loss: 0.6688 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6148 - loss: 0.6686 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.6148 - loss: 0.6685 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 352ms/step - accuracy: 0.6148 - loss: 0.6684 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6148 - loss: 0.6684 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 383ms/step - accuracy: 0.6148 - loss: 0.6684 - val_accuracy: 0.5908 - val_loss: 0.6766
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 375ms/step - accuracy: 0.6148 - loss: 0.6683 - val_accuracy: 0.5908 - val_loss: 0.6766
# 🏁 Best epoch for Fold 8: 11
# ✅ Fold 8 test accuracy: 0.6019
#
# 🧪 Fold 9 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 370ms/step - accuracy: 0.6017 - loss: 0.8685 - val_accuracy: 0.5922 - val_loss: 0.6915
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 388ms/step - accuracy: 0.6206 - loss: 0.6897 - val_accuracy: 0.5922 - val_loss: 0.6874
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6206 - loss: 0.6843 - val_accuracy: 0.5922 - val_loss: 0.6843
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 367ms/step - accuracy: 0.6206 - loss: 0.6802 - val_accuracy: 0.5922 - val_loss: 0.6819
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.6206 - loss: 0.6770 - val_accuracy: 0.5922 - val_loss: 0.6802
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 372ms/step - accuracy: 0.6206 - loss: 0.6744 - val_accuracy: 0.5922 - val_loss: 0.6789
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 376ms/step - accuracy: 0.6206 - loss: 0.6724 - val_accuracy: 0.5922 - val_loss: 0.6780
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.6206 - loss: 0.6708 - val_accuracy: 0.5922 - val_loss: 0.6774
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 388ms/step - accuracy: 0.6206 - loss: 0.6695 - val_accuracy: 0.5922 - val_loss: 0.6769
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 393ms/step - accuracy: 0.6206 - loss: 0.6685 - val_accuracy: 0.5922 - val_loss: 0.6766
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 370ms/step - accuracy: 0.6206 - loss: 0.6677 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 38s 409ms/step - accuracy: 0.6206 - loss: 0.6671 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 384ms/step - accuracy: 0.6206 - loss: 0.6666 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.6206 - loss: 0.6662 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 378ms/step - accuracy: 0.6206 - loss: 0.6658 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.6206 - loss: 0.6656 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 384ms/step - accuracy: 0.6206 - loss: 0.6654 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 382ms/step - accuracy: 0.6206 - loss: 0.6652 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 370ms/step - accuracy: 0.6206 - loss: 0.6651 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.6206 - loss: 0.6649 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 367ms/step - accuracy: 0.6206 - loss: 0.6648 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.6206 - loss: 0.6648 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.6206 - loss: 0.6647 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 368ms/step - accuracy: 0.6206 - loss: 0.6646 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 367ms/step - accuracy: 0.6206 - loss: 0.6646 - val_accuracy: 0.5922 - val_loss: 0.6762
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 368ms/step - accuracy: 0.6206 - loss: 0.6646 - val_accuracy: 0.5922 - val_loss: 0.6763
# 🏁 Best epoch for Fold 9: 16
# ✅ Fold 9 test accuracy: 0.6019
#
# 🧪 Fold 10 -----------------------------
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 366ms/step - accuracy: 0.5563 - loss: 0.7058 - val_accuracy: 0.5922 - val_loss: 0.6759
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 369ms/step - accuracy: 0.6145 - loss: 0.6761 - val_accuracy: 0.5922 - val_loss: 0.6773
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 365ms/step - accuracy: 0.6145 - loss: 0.6737 - val_accuracy: 0.5922 - val_loss: 0.6770
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 367ms/step - accuracy: 0.6123 - loss: 0.6731 - val_accuracy: 0.5922 - val_loss: 0.6763
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 35s 374ms/step - accuracy: 0.6145 - loss: 0.6735 - val_accuracy: 0.5922 - val_loss: 0.6753
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 364ms/step - accuracy: 0.6145 - loss: 0.6742 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6145 - loss: 0.6700 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6145 - loss: 0.6707 - val_accuracy: 0.5922 - val_loss: 0.6787
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 361ms/step - accuracy: 0.6145 - loss: 0.6735 - val_accuracy: 0.5922 - val_loss: 0.6767
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 360ms/step - accuracy: 0.6145 - loss: 0.6737 - val_accuracy: 0.5922 - val_loss: 0.6765
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.6145 - loss: 0.6700 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 357ms/step - accuracy: 0.6145 - loss: 0.6688 - val_accuracy: 0.5922 - val_loss: 0.6760
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 359ms/step - accuracy: 0.6165 - loss: 0.6672 - val_accuracy: 0.5922 - val_loss: 0.6765
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 33s 358ms/step - accuracy: 0.6145 - loss: 0.6683 - val_accuracy: 0.5922 - val_loss: 0.6761
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 34s 366ms/step - accuracy: 0.6145 - loss: 0.6685 - val_accuracy: 0.5922 - val_loss: 0.6761
# 🏁 Best epoch for Fold 10: 5
# ✅ Fold 10 test accuracy: 0.6019
#
# 📌 Mean optimal epoch across folds: 10

# %%
# Cell Block 5: Final Model Training on data again, but for ep_mean Epochs (no validation needed)

# Build your TF datasets
train_final_ds = preprocess(X_rest, y_rest)        # ALL data used in K-Fold
test_final_ds  = preprocess(X_holdout, y_holdout)  # NEVER seen during CV

# Instantiate & train your final model
final_model = create_model()
final_model.fit(
    train_final_ds,
    epochs=ep_mean,
    verbose=1
)

# Evaluate once—only on the true hold-out set
final_results = final_model.evaluate(
    test_final_ds,
    verbose=1
)
print("Hold-out test loss & accuracy:", final_results)
# Out:
# Epoch 1/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 39s 330ms/step - accuracy: 0.5805 - loss: 0.8937
# Epoch 2/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 330ms/step - accuracy: 0.5996 - loss: 0.6728
# Epoch 3/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 329ms/step - accuracy: 0.6010 - loss: 0.6680
# Epoch 4/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 39s 338ms/step - accuracy: 0.6566 - loss: 0.6271
# Epoch 5/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 330ms/step - accuracy: 0.7225 - loss: 0.5629
# Epoch 6/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 38s 330ms/step - accuracy: 0.7492 - loss: 0.5263
# Epoch 7/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 39s 337ms/step - accuracy: 0.7756 - loss: 0.4865
# Epoch 8/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 39s 334ms/step - accuracy: 0.8066 - loss: 0.4380
# Epoch 9/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 39s 332ms/step - accuracy: 0.8463 - loss: 0.3618
# Epoch 10/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 39s 332ms/step - accuracy: 0.8616 - loss: 0.3504
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.6331 - loss: 0.6634
# Hold-out test loss & accuracy: [0.6447073221206665, 0.658595621585846]

# %%
# Cell Block 5: Final Evaluation

# Evaluate final model on the 20% test set
final_test_loss, final_test_acc = final_model.evaluate(test_final_ds, verbose=0)

# Report both results
print(f"\n📊 {k}-Fold Test Accuracy: {np.mean(all_test_accuracies):.4f} ± {np.std(all_test_accuracies):.4f}")
print(f"🏁 Final model test accuracy (trained on hold-out): {final_test_acc:.4f}")
# Out:
# 📊 10-Fold Test Accuracy: 0.6259 ± 0.0706
# 🏁 Final model test accuracy (trained on hold-out): 0.6586

# %%
import numpy as np
from sklearn.metrics import precision_score, roc_curve, auc, f1_score, recall_score
import matplotlib.pyplot as plt

# 1. Extract true labels and model scores from your hold-out dataset
y_true = np.concatenate([y.numpy() for x, y in test_final_ds], axis=0)
y_pred_prob = final_model.predict(test_final_ds)

# 2. If your model outputs two probabilities (one per class), take the “positive” class
if y_pred_prob.ndim > 1 and y_pred_prob.shape[1] > 1:
    y_scores = y_pred_prob[:, 1]
else:
    y_scores = y_pred_prob.ravel()

# 3. Compute ROC curve metrics
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# 4. Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr)               # ROC curve
plt.plot([0, 1], [0, 1], linestyle='--')  # chance line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic (AUC = {roc_auc:.2f})')
plt.show()



# 1. Turn your predicted probabilities into binary preds (threshold = 0.5)
y_pred = (y_scores >= 0.5).astype(int)

# 2. Compute precision, recall, F1
precision = precision_score(y_true, y_pred)
recall    = recall_score(y_true, y_pred)
f1        = f1_score(y_true, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step
# Precision: 0.55
# Recall:    0.82
# F1 Score:  0.66
